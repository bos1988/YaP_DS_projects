# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Цели-проекта" data-toc-modified-id="Цели-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Цели проекта</a></span></li><li><span><a href="#Исходные-данные" data-toc-modified-id="Исходные-данные-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исходные данные</a></span><ul class="toc-item"><li><span><a href="#Подключаемые-модули,-общие-функции:-" data-toc-modified-id="Подключаемые-модули,-общие-функции:--2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Подключаемые модули, общие функции: <a id="functions" rel="nofollow"></a></a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Общая-информация" data-toc-modified-id="Общая-информация-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Общая информация</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Исправление-заголовков" data-toc-modified-id="Исправление-заголовков-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Исправление заголовков</a></span></li><li><span><a href="#Проверка-на-явные-дубликаты" data-toc-modified-id="Проверка-на-явные-дубликаты-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Проверка на явные дубликаты</a></span></li><li><span><a href="#Проверка-пропусков" data-toc-modified-id="Проверка-пропусков-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Проверка пропусков</a></span><ul class="toc-item"><li><span><a href="#Названия-игр,-жанры" data-toc-modified-id="Названия-игр,-жанры-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Названия игр, жанры</a></span></li><li><span><a href="#Год-выпуска" data-toc-modified-id="Год-выпуска-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Год выпуска</a></span></li><li><span><a href="#Рейтинг" data-toc-modified-id="Рейтинг-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>Рейтинг</a></span></li><li><span><a href="#Итоги-обработки-пропусков" data-toc-modified-id="Итоги-обработки-пропусков-3.3.4"><span class="toc-item-num">3.3.4&nbsp;&nbsp;</span>Итоги обработки пропусков</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-3.3.5"><span class="toc-item-num">3.3.5&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Замена-типов-данных" data-toc-modified-id="Замена-типов-данных-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Замена типов данных</a></span><ul class="toc-item"><li><span><a href="#Год-выпуска" data-toc-modified-id="Год-выпуска-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Год выпуска</a></span></li><li><span><a href="#Оценки-пользователей" data-toc-modified-id="Оценки-пользователей-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>Оценки пользователей</a></span></li><li><span><a href="#Шкала-оценок" data-toc-modified-id="Шкала-оценок-3.4.3"><span class="toc-item-num">3.4.3&nbsp;&nbsp;</span>Шкала оценок</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-3.4.4"><span class="toc-item-num">3.4.4&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Проверка-смысловых-зависимостей" data-toc-modified-id="Проверка-смысловых-зависимостей-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Проверка смысловых зависимостей</a></span></li><li><span><a href="#Проверка-значений:-ошибки,-выбросы,-дубликаты" data-toc-modified-id="Проверка-значений:-ошибки,-выбросы,-дубликаты-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Проверка значений: ошибки, выбросы, дубликаты</a></span><ul class="toc-item"><li><span><a href="#Название-игры" data-toc-modified-id="Название-игры-3.6.1"><span class="toc-item-num">3.6.1&nbsp;&nbsp;</span>Название игры</a></span></li><li><span><a href="#Платформа" data-toc-modified-id="Платформа-3.6.2"><span class="toc-item-num">3.6.2&nbsp;&nbsp;</span>Платформа</a></span></li><li><span><a href="#Жанры" data-toc-modified-id="Жанры-3.6.3"><span class="toc-item-num">3.6.3&nbsp;&nbsp;</span>Жанры</a></span></li><li><span><a href="#Рейтинг-ESRB" data-toc-modified-id="Рейтинг-ESRB-3.6.4"><span class="toc-item-num">3.6.4&nbsp;&nbsp;</span>Рейтинг ESRB</a></span></li><li><span><a href="#Год-выпуска" data-toc-modified-id="Год-выпуска-3.6.5"><span class="toc-item-num">3.6.5&nbsp;&nbsp;</span>Год выпуска</a></span></li><li><span><a href="#Продажи-в-Северной-Америке" data-toc-modified-id="Продажи-в-Северной-Америке-3.6.6"><span class="toc-item-num">3.6.6&nbsp;&nbsp;</span>Продажи в Северной Америке</a></span></li><li><span><a href="#Продажи-в-Европе" data-toc-modified-id="Продажи-в-Европе-3.6.7"><span class="toc-item-num">3.6.7&nbsp;&nbsp;</span>Продажи в Европе</a></span></li><li><span><a href="#Продажи-в-Японии" data-toc-modified-id="Продажи-в-Японии-3.6.8"><span class="toc-item-num">3.6.8&nbsp;&nbsp;</span>Продажи в Японии</a></span></li><li><span><a href="#Продажи-в-других-странах" data-toc-modified-id="Продажи-в-других-странах-3.6.9"><span class="toc-item-num">3.6.9&nbsp;&nbsp;</span>Продажи в других странах</a></span></li><li><span><a href="#Оценка-критиков" data-toc-modified-id="Оценка-критиков-3.6.10"><span class="toc-item-num">3.6.10&nbsp;&nbsp;</span>Оценка критиков</a></span></li><li><span><a href="#Оценка-пользователей" data-toc-modified-id="Оценка-пользователей-3.6.11"><span class="toc-item-num">3.6.11&nbsp;&nbsp;</span>Оценка пользователей</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Дополнение-данных" data-toc-modified-id="Дополнение-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Дополнение данных</a></span><ul class="toc-item"><li><span><a href="#Общий-объем-продаж" data-toc-modified-id="Общий-объем-продаж-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Общий объем продаж</a></span></li><li><span><a href="#Категория-оценки" data-toc-modified-id="Категория-оценки-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Категория оценки</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Платформы,-актуальный-период" data-toc-modified-id="Платформы,-актуальный-период-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Платформы, актуальный период</a></span><ul class="toc-item"><li><span><a href="#Временная-шкала" data-toc-modified-id="Временная-шкала-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Временная шкала</a></span></li><li><span><a href="#Игры-по-платформам" data-toc-modified-id="Игры-по-платформам-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Игры по платформам</a></span></li></ul></li><li><span><a href="#Оценки-игры" data-toc-modified-id="Оценки-игры-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Оценки игры</a></span></li><li><span><a href="#Жанры" data-toc-modified-id="Жанры-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Жанры</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Портрет-пользователя-по-регионам" data-toc-modified-id="Портрет-пользователя-по-регионам-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Портрет пользователя по регионам</a></span><ul class="toc-item"><li><span><a href="#Популярные-платформы" data-toc-modified-id="Популярные-платформы-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Популярные платформы</a></span></li><li><span><a href="#Популярные-жанры" data-toc-modified-id="Популярные-жанры-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Популярные жанры</a></span></li><li><span><a href="#Влияние-ретинга-ESBR" data-toc-modified-id="Влияние-ретинга-ESBR-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Влияние ретинга ESBR</a></span></li></ul></li><li><span><a href="#Проверка-гипотез" data-toc-modified-id="Проверка-гипотез-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Проверка гипотез</a></span><ul class="toc-item"><li><span><a href="#Гипотеза-1" data-toc-modified-id="Гипотеза-1-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Гипотеза 1</a></span></li><li><span><a href="#Гипотеза-2" data-toc-modified-id="Гипотеза-2-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Гипотеза 2</a></span></li></ul></li><li><span><a href="#Общие-выводы" data-toc-modified-id="Общие-выводы-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Общие выводы</a></span></li></ul></div>

# %% [markdown]
# # Исследование рынка компьютерных игр

# %% [markdown]
# ## Цели проекта

# %% [markdown]
# Определить закономерности, определяющие успешность выпускаемой игры.
#
# На основе выявленных закономерностей спланоровать рекламные кампании на будущий год.
#
# Отработать общий принцип работы с данными для прогнозирования кампании на следующий год.

# %% [markdown]
# ## Исходные данные

# %% [markdown]
# ### Подключаемые модули, общие функции: <a id='functions'></a>

# %%
# Подключаемый модули:
import random as rnd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import seaborn as sns
from scipy import stats as st

from pymystem3 import Mystem
from collections import Counter

import warnings
warnings.simplefilter('ignore')

# %%
# ПАРАМЕТРЫ,, общие переменные
table_size = 100
sales_list = ['na_sales', 'eu_sales', 'jp_sales', 'other_sales']

# ФУНКЦИИ:

#=====================================================================================================================
# Информирование:

# вывод таблицы описания данных
def print_descripltion(df):
    len_index = max([len(i) for i in df])
    for index in df:
        end = '' if len(description[index]) < table_size else '...'
        print(f'{index.ljust(len_index)} - {description[index][:table_size]}{end}')

# остаток данных
def show_remains(df):
    print(f'Остаток данных после обработки: {df.shape[0] / original_shape[0]:.2%}')

# проверка пропусков
def na_info(df, light=False):
    indent_1 = max([len(i) for i in df]) + 2
    indent_2 = 12
    
    # Список колонок с пропусками:
    list_nan = [index for index, val in df.isna().sum().items() if val > 0]
    # Список колонок без пропусков и числовые (для проверки на корреляцию)
    list_not_nan_num = [index for index, val in df.isna().sum().items() if (val == 0 and df[index].dtype in (int ,float))]

    # Список колонок на удаление пропусков:
    list_drop_nan = []

    # Список коррелируемых колонок:
    list_corr_nan = {}

    # Заголовок выводимой таблицы
    print('Колонка'.ljust(indent_1), '| Пропуски'.ljust(indent_2), '| Доля'.ljust(indent_2), end='')
    if light == False:
        [print(f'| {val}'.ljust(indent_1), end='') for val in list_not_nan_num]
    print()
    print('-'*indent_1, '| ' + '-'*(indent_2-2), '| ' + '-'*(indent_2-2), end='')
    if light == False:
        [print('| ' + '-'*(indent_1-2), end='') for val in list_not_nan_num]
    print()

    # Таблица данных по пропускам
    for name in list_nan:
        temp_percent = df[name].isna().mean()
        print(name.ljust(indent_1), f'| {df[name].isna().sum()}'.ljust(indent_2), f'| {temp_percent:<10.1%}'.ljust(indent_2), end='')
        if light == False:
            if df[name].dtype in (int ,float):
                for nn_name in list_not_nan_num:
                    temp_corr = df[name].corr(df[nn_name])
                    print(f'| {temp_corr:.2f}'.ljust(indent_1), end='')

                    # Добавим в список корреляции колонки с высокой корреляцией > 0.8:
                    if temp_corr >= 0.8:
                        list_corr_nan.setdefault(name, []).append(nn_name)
            else:
                for nn_name in list_not_nan_num:
                    print(f'|'.ljust(indent_1), end='')
        print()

        # Добавим в список на удаление имя колонки, в которой доля пропусков менее 1%:
        if temp_percent < 0.01:
            list_drop_nan.append(name)
            
    if light == False:
        print()
        print('Список колонок на удаление пропусков:')
        print(list_drop_nan)
        print()
        print('Список коррелируемых колонок:')
        print(list_corr_nan)
    
        return list_drop_nan


#=====================================================================================================================
# Презентации:

def print_plot(df, col=None, data=None,
               title='График', subtitle='', xlabel=None, ylabel=None,
               s_grid=True, figsize=(10, 6), **kwargs):
    if type(data) == type(None):
        data = df[col]

    fig, ax = plt.subplots()
    data.plot(ax=ax, **kwargs)
    
    fig.set_figwidth(figsize[0])
    fig.set_figheight(figsize[1])
    
    ax.minorticks_on()
    if s_grid:
        ax.grid(which='major',
                color = 'grey', 
                linewidth = 1.2)
        ax.grid(which='minor', 
                color = 'grey', 
                linestyle = ':')
    ax.tick_params(labelsize = 12)
    ax.set_title(title + subtitle, pad=15, fontsize = 16)
    
    ax.set_xlabel(xlabel, fontsize = 14)
    ax.set_ylabel(ylabel, fontsize = 14)

def print_scatter(data, x, y, title=None, subtitle='', xlabel=None, ylabel=None, **kwargs):
    if xlabel == None:
        xlabel = description[x]
    if ylabel == None:
        ylabel = description[y]
    if title == None:
        title = f'Взаимосвязь показателей "{xlabel}" и \n"{ylabel}"'
    print_plot(data, data=data, kind='scatter', x=x, y=y,
               title=title, subtitle=subtitle, xlabel=xlabel, ylabel=ylabel,
               s_grid=False, **kwargs)
    
    plt.text(data.dropna()[x].min() * 1.1, data.dropna()[y].max() * 0.95, f'Корреляция = \n{df[x].corr(df[y]):.4f}',
        rotation = 0,
        fontsize = 14)

def print_hist(df, col, data=None, title=None, subtitle='', xlabel=None, ylabel=None, bins=None, **kwargs):
    if type(data) == type(None):
        data = df[col]
    if bins == None:
        bins = data.nunique()
    if xlabel == None:
        try:
            xlabel = description[col]
        except:
            pass
    ylabel = 'Количество значений' if ylabel == None else ylabel
    param = "" if xlabel == None else xlabel
    if title == None:
        title = f'Распределение показателя "{param}"'
    print_plot(df=df, col=col, data=data, kind='hist', bins=bins,
               title=title, subtitle=subtitle, xlabel=xlabel, ylabel=ylabel, **kwargs)


def hist_box_describe(df, col, subtitle='', xlabel=None, ylabel=None, data=None, bins=None, figsize=(10, 12), **kwargs):
    if type(data) == type(None):
        data = df[col]
    if xlabel == None:
        try:
            xlabel = description[col]
        except:
            pass
    if bins == None:
        bins = data.nunique()
    
    fig = plt.figure()
    
    # Разделение fig на зоны разных размеров:
    gs1 = GridSpec(5, 1, left=0.05, right=0.95, hspace=0.03)
    # (y, x) - размеры сетки (высота, ширина)
    # left - расположние левой границы всей сетки (топа margin)
    # right - расположние правой границы всей сетки (топа margin)
    # wspace, hspace - зазоры между графиками (вертикальный, горизонтальный)
    ax1 = fig.add_subplot(gs1[:1, :]) # (срез по Y, срез по X)
    ax2 = fig.add_subplot(gs1[1:, :])
    
    # Построение графиков:
    data.plot(ax=ax1, kind='box', vert=False, widths=0.6, **kwargs)
    data.plot(ax=ax2, kind='hist', grid=True, bins=bins, **kwargs)
    
    # Различные настройки графиков:
    fig.set_figwidth(figsize[0])
    fig.set_figheight(figsize[1])
    #fig.suptitle(f'Распределение показателя "{xlabel}"', fontsize = 16)
    
    ax1.xaxis.tick_top()
    ax2.minorticks_on()
    ax2.grid(which='major',
            color = 'grey', 
            linewidth = 1.2)
    ax2.grid(which='minor', 
            color = 'grey', 
            linestyle = ':')
    
    ax1.set_yticklabels([''])
    ax2.set_xlabel(xlabel, fontsize = 14)
    ax2.set_ylabel('Количество значений', fontsize = 14)
    ax1.tick_params(labelsize = 12)
    ax2.tick_params(labelsize = 12)
    ax1.set_title(f'Распределение показателя "{xlabel}"{subtitle}', pad=15, fontsize = 16)
    #ax2.set_title('Гистограмма', fontsize = 16)

# MOD 1.1 ****************************************************************************
    x = ax2.get_xbound()
    y = ax2.get_ybound()
    x_coord = x[0] + (x[1]-x[0])/figsize[0]*figsize[1]*0.03 if data.mean() < data.quantile(0.5) else x[1] - (x[1]-x[0])/figsize[0]*figsize[1]*0.29
    y_coord = y[1] - (y[1]-y[0])*0.29
    ax2.text(x_coord, y_coord, str(data.describe()),
        rotation = 0,
        fontsize = figsize[1],
        bbox = {'facecolor':'white', 'boxstyle': 'round', 'pad': 1}
            )
    #display(data.describe())
# MOD 1.1 ****************************************************************************
    
#=====================================================================================================================
# Анализ (графический):

# 1 Распределение значений общих продаж по категориям
def total_sales_boxplot(df, name, w=15, h=10, period='весь'):
    plt.figure(figsize=(w, h))
    plt.grid(visible=True, axis='both')
    sns.boxplot(data=df, x='total_sales', y=name, orient='h')
    plt.title(f'Распределние значений объема продаж по отдельным играм за {period} период:', pad=15, fontsize = 16)
    plt.xlabel('Продажи (млн. копий)', fontsize = 14)
    plt.ylabel(description[name], fontsize = 14)
    plt.show()

# 2 Сумма общих продаж за весь период по категориям
def total_sales_barplot(df, name, w=15, h=10, period='весь'):
    plt.figure(figsize=(w, h))
    plt.grid(visible=True, axis='both')
    sns.barplot(data=df, x='total_sales', y=name, estimator=np.sum)
    plt.title(f'Сумма продаж (миллионы копий) за {period} период:', pad=15, fontsize = 16)
    plt.xlabel('Продажи (млн. копий)', fontsize = 14)
    plt.ylabel(description[name], fontsize = 14)
    plt.show()

# 3 Сумма общих продаж (либо кол-во выпущенных игр) по годам по категориям
def years_heatmap(df, name, w=15, h=10, absolute=True, aggfunc='count'):
    
    title_start = ''
    title_end= ''
    fmt='.1f'
    if aggfunc == 'sum':
        title_start = 'Сумма продаж (миллионы копий)'
    else:
        title_start = 'Выпуск новых игр (шт)'
        
    if absolute == False:
        title_end = ' (% от всех игр по году)'
        fmt='.1%'
    title = title_start + ' по годам' + title_end
    
    shares_by_year = df.pivot_table(index=name, columns='year_of_release', values='total_sales', aggfunc=aggfunc).fillna(0)   
    if absolute == False:
        for col in shares_by_year:
            shares_by_year[col] = shares_by_year[col] / shares_by_year[col].sum()
    
    plt.figure(figsize=(w, h))
    sns.heatmap(shares_by_year, cmap='Purples', annot=True, fmt=fmt)
    plt.title(title, pad=15, fontsize = 16)
    plt.xlabel('Год', fontsize = 14)
    plt.ylabel(description[name], fontsize = 14)
    plt.yticks(rotation=0)
    plt.show()


def get_region_name(col):
    return description[col][8:description[col].index('(')-1].replace(' ', '\n')

# 41 Топ 5 (или сколько нужно) позиций (заданного классификатора) по регионам
def top_sales(df, classifier, n=5, w=13, h=None):
    #sales_list
    if h == None:
        h = n + 1
    shares = df.pivot_table(index=classifier, aggfunc='sum').fillna(0)
    color_list = []
    for j in range(3):
        for k in range(3):
            for l in range(3):
                if not (k == j == l):
                    color_list.append([l/4+0.25, k/4+0.25 ,j/4+0.25])
    shares['color'] = rnd.sample(color_list, shares.shape[0])
    
    xlimit = round(shares[sales_list].max().max(), -2)
    
    fig, axs = plt.subplots(1, 4, constrained_layout=True)
    fig.set_figwidth(w)
    fig.set_figheight(h)
    fig.suptitle(f'Самые популярные платформы (топ-{n}) по регионам (по числу продаж млн. копий)', fontsize = 16)

    for i in range(len(sales_list)):
        (shares[sales_list[i]]
         .sort_values()
         .tail(n)
         .plot(ax=axs[i], kind='barh', width=0.8, xlim=(0, xlimit), grid=True,
               color = list(shares.sort_values(sales_list[i]).tail(n)['color']))
        )
        axs[i].tick_params(labelsize = 12)
        axs[i].set_xlabel('Продажи (млн. копий)', fontsize = 12)
        axs[i].set_ylabel('', fontsize = 12)
        axs[i].set_title(get_region_name(sales_list[i]), pad=15, fontsize = 12)

# 42 Сумма общих продаж (либо кол-во выпущенных игр) по годам по категориям
def region_heatmap(df, name, w=8, h=8, absolute=True, aggfunc='sum'):

    title_start = ''
    title_end= ''
    
    fmt='.1f'
    if aggfunc == 'sum':
        title_start = 'Сумма продаж (миллионы копий)'
    else:
        title_start = 'Выпуск новых игр (шт)'
        
    if absolute == False:
        title_end = ' (% от всех игр по региону)'
        fmt='.1%'
    
    title = title_start + ' по регионам' + title_end
    
    shares = df.pivot_table(index=name, aggfunc='sum')[sales_list].fillna(0)
    if absolute == False:
        for col in shares:
            shares[col] = shares[col] / shares[col].sum()
    
    plt.figure(figsize=(w, h))
    sns.heatmap(shares, cmap='Purples', annot=True, fmt=fmt, xticklabels=[get_region_name(col) for col in sales_list])

    plt.title(title, pad=15, fontsize = 16)
    plt.xlabel('Регион', fontsize = 14)
    plt.ylabel(description[name], fontsize = 14)
    plt.tick_params(labelsize = 12)
    plt.yticks(rotation=0)
    plt.show()

# %% [markdown]
# Чтение данных из файла

# %%
df = pd.read_csv('games.csv')

# %% [markdown]
# ### Описание данных

# %% [markdown]
# Создадим словарь описания данных

# %%
# Создадим словарь описания данных
description = {
    'Name': 'название игры',
    'Platform': 'платформа',
    'Year_of_Release': 'год выпуска',
    'Genre': 'жанр игры',
    'NA_sales': 'продажи в Северной Америке (миллионы проданных копий)',
    'EU_sales': 'продажи в Европе (миллионы проданных копий)',
    'JP_sales': 'продажи в Японии (миллионы проданных копий)',
    'Other_sales': 'продажи в других странах (миллионы проданных копий)',
    'Critic_Score': 'оценка критиков',
    'User_Score': 'оценка пользователей',
    'Rating': 'рейтинг от организации ESRB',
}

# %% [markdown]
# Выведем словарь описнаия данных

# %%
print_descripltion(df)
# Out:
# Name            - название игры
# Platform        - платформа
# Year_of_Release - год выпуска
# Genre           - жанр игры
# NA_sales        - продажи в Северной Америке (миллионы проданных копий)
# EU_sales        - продажи в Европе (миллионы проданных копий)
# JP_sales        - продажи в Японии (миллионы проданных копий)
# Other_sales     - продажи в других странах (миллионы проданных копий)
# Critic_Score    - оценка критиков
# User_Score      - оценка пользователей
# Rating          - рейтинг от организации ESRB

# %% [markdown]
# ### Общая информация

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
df.nunique()
# Out:
# Name               11559
# Platform              31
# Year_of_Release       37
# Genre                 12
# NA_sales             402
# EU_sales             307
# JP_sales             244
# Other_sales          155
# Critic_Score          82
# User_Score            96
# Rating                 8
# dtype: int64

# %% [markdown]
# ### Выводы

# %% [markdown]
# В таблице 11 колонок:
# - 5 колонок предвтавляют собой **характеристики** непосредственно игры, это:
#     - название
#     - жанр
#     - год выпуска
#     - платформа
#     - рейтинг ESRB
# - 4 колонки содержат **данные о продажах** в различных регионах:
#     - Северная Америка
#     - Европа
#     - Япония
#     - другие страны
# - 2 колонки содержат **оценки** игры (пользователями и критиками)
#
# СТРУКУТРА ДАННЫХ:
#
# * Необходимо перевести названия колонок к нижнемй регистру
# * Проверить данные на явные дубликаты
# * В исходной таблице имеются **попуски** данных в  колонках:
#     - название игры
#     - жанр
#     - год выпуска
#     - оценки (обе)
#     - рейтинг ESRB
#
#
# * По типам данных колонки можно разделить:
#     - **Текстовые (Наименования):** (Название игры)
#     - **Категории:** (платформа, жанр, рейтинг ESRB)
#     - **Численные:** (год выпуска, объемы продаж, оценки)
#
#
# * По **типам данных** нужно исправить
#     - год выпуска - целочисленный
#     - оценка пользователей - вещественный
#     - привести оценки к одной шкале
#
#
# * Возможное разделение на категории:
#     - **Уровень оценки (низкий, средний, высокий)**
#
#
# * Смысловых взаимосвязей между колонкми нет.
#
# Уникальных значений названий игр меньше, чем общее число записей в таблице. Значит название игры не является уникальным идентификатором игры. Отличительными характеристиками каждой игры являются: название, год выпуска, платформа. Если эти характеристики совпадают, значит это одна и та же игра, несмотря на различия в других данных.

# %%
# Исходный размер таблицы:
original_shape = df.shape
original_shape
# Out:
# (16715, 11)

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Исправление заголовков

# %% [markdown]
# Приведем названия заголовков к нижнему регистру

# %%
df.columns = [val.lower() for val in df.columns]

# %% [markdown]
# Проверим

# %%
print(*df.columns, sep='\n')
# Out:
# name
# platform
# year_of_release
# genre
# na_sales
# eu_sales
# jp_sales
# other_sales
# critic_score
# user_score
# rating

# %% [markdown]
# Перепишем ключи в словаре описания данных

# %%
description = dict(zip(df.columns, description.values()))

# %%
print_descripltion(df)
# Out:
# name            - название игры
# platform        - платформа
# year_of_release - год выпуска
# genre           - жанр игры
# na_sales        - продажи в Северной Америке (миллионы проданных копий)
# eu_sales        - продажи в Европе (миллионы проданных копий)
# jp_sales        - продажи в Японии (миллионы проданных копий)
# other_sales     - продажи в других странах (миллионы проданных копий)
# critic_score    - оценка критиков
# user_score      - оценка пользователей
# rating          - рейтинг от организации ESRB

# %% [markdown]
# ### Проверка на явные дубликаты

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Явных дубликатов нет

# %% [markdown]
# ### Проверка пропусков

# %%
na_info(df)
# Out:
# Колонка           | Пропуски   | Доля      | na_sales       | eu_sales       | jp_sales       | other_sales
# ----------------- | ---------- | ----------| ---------------| ---------------| ---------------| ---------------
# name              | 2          | 0.0%      |                |                |                |
# year_of_release   | 269        | 1.6%      | -0.09          | 0.00           | -0.17          | 0.04
# genre             | 2          | 0.0%      |                |                |                |
# critic_score      | 8578       | 51.3%     | 0.24           | 0.22           | 0.15           | 0.20
# user_score        | 6701       | 40.1%     |                |                |                |
# rating            | 6766       | 40.5%     |                |                |                |
#
# Список колонок на удаление пропусков:
# ['name', 'genre']
#
# Список коррелируемых колонок:
# {}
# ['name', 'genre']

# %% [markdown]
# **Выводы, решения:**
#
# 1. Хотя доля назвнаний игр и жанров мала, оставим их и заменим на значение `unknown`.
# 1. Доля пропусков по годам не более 2%. В дальнейшем будем проводить анализ с обязательным использованием года выпуска. Можно поискать информацию по каждой игре, но количественно их немало и это займет много времени и ручного труда. Удалим эти данные по следующим причинам:
#     - занимают малую долю
#     - пропущенные значения неприменимы в анализе
#     - есть необходимость заменить данные в этой колонке на тип int не принимающий пропуски
# 1. Оценки игр - несистиматическая независимая от какого-либо параметра характеристика. Может наблюдаться прямая зависимость объемов продаж от оценки игры. Тогда по обратной зависимости можно было бы определить оценку. Но в текущем исследовании важно влияние каких-либо параметров на объемы продаж, и если изменить набор данных прямо влияющий на объем продаж, можно получить искаженную информацию.
# > Оставим пропуски по данным оценок игр.
# 1. рейтинг ESRB может зависеть только от жанра. Проверим это.

# %% [markdown]
# #### Названия игр, жанры

# %% [markdown]
# Заменим пропущенные значения названий ирг и жанров на значение `unknown`

# %%
for col in ['name', 'genre']:
    df[col] = df[col].fillna('unknown')

# %% [markdown]
# #### Год выпуска

# %% [markdown]
# Удалим данные с неизвестным годом выпуска игры

# %%
df = df.dropna(subset=['year_of_release'])

# %% [markdown]
# #### Рейтинг

# %% [markdown]
# Проверим зависит ли рейтинг от жанра:

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(pd.crosstab(df['genre'], df['rating']), cmap='Purples', annot=True, fmt=".0f")
plt.show()

# %% [markdown]
# Явной зависимости, достаточной для заполнения пропусков, не прослеживается.
#
# Поскольку доля пропусков по данным рейтинга высокая, то заменим эти пропуски на маркерное значение no-rating ("нет рейтинга")

# %%
df['rating'] = df['rating'].fillna('no-rating')

# %% [markdown]
# #### Итоги обработки пропусков

# %%
na_info(df, light=True)
# Out:
# Колонка           | Пропуски   | Доля
# ----------------- | ---------- | ----------
# critic_score      | 8463       | 51.5%
# user_score        | 6607       | 40.2%

# %%
show_remains(df)
# Out:
# Остаток данных после обработки: 98.39%

# %% [markdown]
# #### Выводы

# %% [markdown]
# 1. Заменены пропуски в названиях игр и жанрах на значение `unknown`
# 1. Удалены пропуски по данным года выпуска.
# > Остаток от оригинала - 98,39%. Потеря данных не более 2%.
# 1. Оставлены пропуски по оценкам игр (критики и пользователи) и по рейтингу ESBR.

# %% [markdown]
# ### Замена типов данных

# %% [markdown]
# #### Год выпуска

# %%
print('Количество значений года выпуска с дробной частью:', sum(df['year_of_release'].value_counts() % 1 > 0.000001))
# Out:
# Количество значений года выпуска с дробной частью: 0

# %% [markdown]
# Заменим тип данных года выпуска на `int`

# %%
df['year_of_release'] = df['year_of_release'].astype('int')

# %% [markdown]
# #### Оценки пользователей

# %% [markdown]
# Найдем нечисловые значения в данных по оценке пользователей

# %%
not_numeric = []
for j in df['user_score'].unique():
    try:
        float(j)
    except ValueError:
        not_numeric.append(j)

not_numeric
# Out:
# ['tbd']

# %% [markdown]
# Значение tbd значит ["еще не определено"](https://technical_abbreviations.academic.ru/22545/TBD).
#
# Заменим это значение пропуском и поменяем тип данных на вещественный.

# %%
df['user_score'] = pd.to_numeric(df['user_score'].replace('tbd', np.NaN))

# %% [markdown]
# #### Шкала оценок

# %% [markdown]
# Приведем оценки к единой шкале (для удобства работы с данными, на смысл и логику это не повлияет)

# %%
for name in ['user_score', 'critic_score']:
    print(f'Минимальное значение для  "{name}":', df[name].min())
    print(f'Максимальное значение для  "{name}":', df[name].max())
# Out:
# Минимальное значение для  "user_score": 0.0
# Максимальное значение для  "user_score": 9.7
# Минимальное значение для  "critic_score": 13.0
# Максимальное значение для  "critic_score": 98.0

# %% [markdown]
# Максимальное значение оценки критоков в 10 раз больше максимального значения оценки пользователей.
#
# Примем 10-бальную шкалу, для этого разделим в се значения оценки критиков на 10:

# %%
df['critic_score'] = df['critic_score'] / 10

# %% [markdown]
# #### Выводы

# %%
df.dtypes
# Out:
# name                object
# platform            object
# year_of_release      int32
# genre               object
# na_sales           float64
# eu_sales           float64
# jp_sales           float64
# other_sales        float64
# critic_score       float64
# user_score         float64
# rating              object
# dtype: object

# %% [markdown]
# Все параметры приведены к соответствующему типу данны:
# - **4** текстовых и категориальных (*название игры, платформа, жанр, рейтинг ESRB*) имеют тип **`object`**
# - **6** численных с дробной частью (*объемы продаж, оценки*) имеют тип **`float`**
# - **1** целочисленный (*год выпуска*) имеет тип **`int`**

# %% [markdown]
# ### Проверка смысловых зависимостей

# %% [markdown]
# Смысловые зависимости в данных отсутствуют

# %% [markdown]
# ### Проверка значений: ошибки, выбросы, дубликаты

# %% [markdown]
# #### Название игры

# %% [markdown]
# Отличительными характеристиками каждой игры являются:
# - название
# - год выпуска
# - платформа
#
# Если эти характеристики совпадают, значит это одна и та же игра, несмотря на различия в других данных.
#
# Найдем такие совпадения:

# %%
# Отличительные характеристики:
u_features = ['name', 'platform', 'year_of_release']

# %%
df[df[u_features].duplicated(keep=False)]
# Out:
#                 name platform  year_of_release    genre  na_sales  eu_sales  \
# 604    Madden NFL 13      PS3             2012   Sports      2.11      0.22
# 659          unknown      GEN             1993  unknown      1.78      0.53
# 14244        unknown      GEN             1993  unknown      0.00      0.00
# 16230  Madden NFL 13      PS3             2012   Sports      0.00      0.01
#
#        jp_sales  other_sales  critic_score  user_score     rating
# 604        0.00         0.23           8.3         5.5          E
# 659        0.00         0.08           NaN         NaN  no-rating
# 14244      0.03         0.00           NaN         NaN  no-rating
# 16230      0.00         0.00           8.3         5.5          E

# %% [markdown]
# Как видно эти записи отличаются только объемом продаж. Возможно при составлении базы данных информация частично разделилась в разные записи. Сложим объемы продаж в одну запись. Другие параметры возьмем из первой дублирующей записи.

# %%
#sales_list = ['na_sales', 'eu_sales', 'jp_sales', 'other_sales']    >>> см п.2.1
first_indexes = df[df[u_features].duplicated(keep='last')].index
last_indexes = df[df[u_features].duplicated(keep='first')].index

# %%
for index in first_indexes:
    for f in u_features:
        exec(f'{f} = df.loc[index]["{f}"]')

    for sale in sales_list:
        df.loc[index, sale] = df.query(f'name == @name and platform == @platform and year_of_release == @year_of_release')[sale].sum()

df = df.drop(last_indexes)

# %% [markdown]
# Проверим

# %%
df[df[u_features].duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [name, platform, year_of_release, genre, na_sales, eu_sales, jp_sales, other_sales, critic_score, user_score, rating]
# Index: []

# %%
df.loc[first_indexes]
# Out:
#               name platform  year_of_release    genre  na_sales  eu_sales  \
# 604  Madden NFL 13      PS3             2012   Sports      2.11      0.23
# 659        unknown      GEN             1993  unknown      1.78      0.53
#
#      jp_sales  other_sales  critic_score  user_score     rating
# 604      0.00         0.23           8.3         5.5          E
# 659      0.03         0.08           NaN         NaN  no-rating

# %% [markdown]
# Проверять конкретно названия ирг на дуликаты не имеет смысла, поскольку названия могут быть какими угодно и могут дублироваться для разных годов выпуска и разных платформ.

# %% [markdown]
# #### Платформа

# %% [markdown]
# Проверим перечень наименований платформ.
#
# Для этого выведем для каждой платформы название игры первого и последнего вхождения и число игр на этой платформе в таблице данных. Наиболее редкие или сомнительные платформы проверим по данным в интернете.

# %%
df.pivot_table(index='platform', values='name', aggfunc=['first', 'last', 'count'])
# Out:
#                                            first  \
#                                             name
# platform
# 2600                                     Pac-Man
# 3DO                                  Policenauts
# 3DS                          Pokemon X/Pokemon Y
# DC                               Sonic Adventure
# DS                         New Super Mario Bros.
# GB                      Pokemon Red/Pokemon Blue
# GBA                Pokemon Ruby/Pokemon Sapphire
# GC                       Super Smash Bros. Melee
# GEN                         Sonic the Hedgehog 2
# GG                  Sonic the Hedgehog 2 (8-bit)
# N64                               Super Mario 64
# NES                            Super Mario Bros.
# NG                            Samurai Shodown II
# PC                                    The Sims 3
# PCFX          Blue Breaker: Ken Yorimo Hohoemi o
# PS                                  Gran Turismo
# PS2                Grand Theft Auto: San Andreas
# ...

# %% [markdown]
# Все платформы существуют. Дубликатов нет.
#
# Наиболее редки или сомнительные расшифруем:
#
# 2600 - Atari 2600
#
# 3DO - 3DO Interactive Multiplayer
#
# DC - Sega Dreamcast
#
# GB - Game Boy
#
# GEN - Sega Genesis
#
# GG - Sega Game Gear
#
# NES - Nintendo Entertainment System (NES)
#
# NG - Neo Geo (игровой автомат)
#
# PCFX - сомнительная платформа, но единственная на ней игра существует
#
# SAT - Sega Saturn
#
# SCD - Sega CD
#
# TG16 - The TurboGrafx-16, known as the PC Engine (NEC PC-9801)
#
# WS - WonderSwan

# %% [markdown]
# #### Жанры

# %% [markdown]
# Просмотрим перечень жанров:

# %%
df['genre'].value_counts().sort_index()
# Out:
# Action          3307
# Adventure       1293
# Fighting         837
# Misc            1721
# Platform         878
# Puzzle           569
# Racing          1226
# Role-Playing    1481
# Shooter         1296
# Simulation       857
# Sports          2305
# Strategy         673
# unknown            1
# Name: genre, dtype: int64

# %% [markdown]
# Дубликатов нет, наименования допустимые.

# %% [markdown]
# #### Рейтинг ESRB

# %% [markdown]
# Просмотрим перечень наименований рейтингов (переведем их предварително к верхнему регистру):

# %%
df['rating'] = df['rating'].str.upper()

# %%
df['rating'].value_counts()
# Out:
# NO-RATING    6677
# E            3920
# T            2905
# M            1536
# E10+         1393
# EC              8
# K-A             3
# AO              1
# RP              1
# Name: rating, dtype: int64

# %% [markdown]
# Все рейтинги имели место быть в то или иное время. Оставим все данные.
#
# ***[Действующие рейтинги](https://www.esrb.org/ratings-guide/)***

# %% [markdown]
# #### Год выпуска

# %% [markdown]
# Посмотрим диапазон и распределение значений по году выпуска

# %%
hist_box_describe(df, 'year_of_release')

# %% [markdown]
# **Выводы:**
#
# - Диапазон значений приемлимый.
# - Наблюдается общий рост числа выпущенных игр с годами. Имеется пик в районе 2008-2009 гг. и дальнейший спад к 2016-му г.
# - Выбросов нет, есть тенденция резкого роста выхода игр после 1990 г.

# %% [markdown]
# #### Продажи в Северной Америке

# %% [markdown]
# Посмотрим диапазон и распределение значений для ненулевых объемов продаж

# %%
hist_box_describe(df.query('na_sales > 0'), 'na_sales', bins=100)

# %% [markdown]
# Имеются большие выбросы. Посмотрим на характер распределения без выбросов. Примем для рассмотрения границу занчений в 3 IQR

# %%
def hist_box_describe_clean(df, col):
    # Примем границу в 3 IQR:
    border = df[col].quantile(0.75) + st.iqr(df[col]) * 3
    hist_box_describe(df.query(f'{col} < @border'), col)

# %%
hist_box_describe_clean(df.query('na_sales > 0'), 'na_sales')

# %% [markdown]
# **Выводы:**
#
# - Диапазон значений приемлимый.
# - Распределение нормальное (распределние Пуассона, поэтому выбросы на диаграмме размаха - это не аномальные значения).
# - Выбросы значительные, но это не ошибки, а уникальные значения. Оставим их.

# %% [markdown]
# #### Продажи в Европе

# %% [markdown]
# Посмотрим диапазон и распределение значений для ненулевых объемов продаж

# %%
hist_box_describe(df.query('eu_sales > 0'), 'eu_sales', bins=100)

# %% [markdown]
# Имеются большие выбросы. Посмотрим на характер распределения без выбросов. Примем для рассмотрения границу занчений в 3 IQR

# %%
hist_box_describe_clean(df.query('eu_sales > 0'), 'eu_sales')

# %% [markdown]
# **Выводы:**
#
# - Диапазон значений приемлимый.
# - Распределение нормальное (распределние Пуассона, поэтому выбросы на диаграмме размаха - это не аномальные значения).
# - Выбросы значительные, но это не ошибки, а уникальные значения. Оставим их.

# %% [markdown]
# #### Продажи в Японии

# %% [markdown]
# Посмотрим диапазон и распределение значений для ненулевых объемов продаж

# %%
hist_box_describe(df.query('jp_sales > 0'), 'jp_sales', bins=100)

# %% [markdown]
# Имеются большие выбросы. Посмотрим на характер распределения без выбросов. Примем для рассмотрения границу занчений в 3 IQR

# %%
hist_box_describe_clean(df.query('jp_sales > 0'), 'jp_sales')

# %% [markdown]
# **Выводы:**
#
# - Диапазон значений приемлимый.
# - Распределение нормальное (распределние Пуассона, поэтому выбросы на диаграмме размаха - это не аномальные значения).
# - Выбросы значительные, но это не ошибки, а уникальные значения. Оставим их.

# %% [markdown]
# #### Продажи в других странах

# %% [markdown]
# Посмотрим диапазон и распределение значений для ненулевых объемов продаж

# %%
hist_box_describe(df.query('other_sales > 0'), 'other_sales', bins=100)

# %% [markdown]
# Имеются большие выбросы. Посмотрим на характер распределения без выбросов. Примем для рассмотрения границу занчений в 3 IQR

# %%
hist_box_describe_clean(df.query('other_sales > 0'), 'other_sales')

# %% [markdown]
# **Выводы:**
#
# - Диапазон значений приемлимый.
# - Распределение нормальное (распределние Пуассона, поэтому выбросы на диаграмме размаха - это не аномальные значения).
# - Выбросы значительные, но это не ошибки, а уникальные значения. Оставим их.

# %% [markdown]
# #### Оценка критиков

# %% [markdown]
# Посмотрим диапазон и распределение значений

# %%
hist_box_describe(df, 'critic_score')

# %% [markdown]
# **Выводы:**
#
# - Диапазон занчений приемлимый (в границах оценочной шкалы 0...10).
# - Распределение нормальное со смещением влево.
# - Выбросов нет.
# - Наблюдается 2 значения выделяющихся наиболее частых оценок.

# %% [markdown]
# #### Оценка пользователей

# %% [markdown]
# Посмотрим диапазон и распределение значений

# %%
hist_box_describe(df, 'user_score')

# %% [markdown]
# **Выводы:**
#
# - Диапазон занчений приемлимый (в границах оценочной шкалы 0...10).
# - Распределение нормальное со смещением влево.
# - Выбросов нет.

# %% [markdown]
# ### Выводы

# %%
show_remains(df)
# Out:
# Остаток данных после обработки: 98.38%

# %% [markdown]
# Удалены только дубликаты игр по связке параметров (название, год выпуска, платформа)
#
# Остальные данные имеют допустимые значения и оставлены в полном объеме.
#
# Имеются выбросы по объемам продаж во всех регионах, но это - допустимые уникальные значения.
#
# > Остаток от оригинала - 98,38%. Общая потеря данных менее 2%.

# %% [markdown]
# ## Дополнение данных

# %% [markdown]
# ### Общий объем продаж

# %% [markdown]
# Дополним данные значениями общего объема продаж по всем регионам

# %%
df['total_sales'] = df['na_sales'] + df['eu_sales'] + df['jp_sales'] + df['other_sales']
description['total_sales'] = 'суммарные продажи (миллионы проданных копий)'

# %%
df.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score     rating  \
# 0     28.96      3.77         8.45           7.6         8.0          E
# 1      3.58      6.81         0.77           NaN         NaN  NO-RATING
# 2     12.76      3.79         3.29           8.2         8.3          E
# 3     10.93      3.28         2.95           8.0         8.0          E
# 4      8.89     10.22         1.00           NaN         NaN  NO-RATING
#
#    total_sales
# 0        82.54
# 1        40.24
# ...

# %% [markdown]
# ### Категория оценки

# %% [markdown]
# Проверим взаимосвязь между оценками критиков и пользователей

# %%
print_scatter(df, x='critic_score', y='user_score', alpha=0.2, figsize=(8, 8))

# %% [markdown]
# Поскольку есть линейная зависимость средней силы, то примем определяющим параметром среднюю оценку между критиками и пользователями для установления уровня оценки.
#
# Для определния границ уровенй оценки проверим 30% и 70% процентили:

# %%
print(f"Потенциальная верхняя граница низкой оценки критиков: {df['critic_score'].quantile(0.3):.2f}")
print(f"Потенциальная нижняя граница высокой оценки критиков: {df['critic_score'].quantile(0.7):.2f}")
print(f"Потенциальная верхняя граница низкой оценки пользователей: {df['user_score'].quantile(0.3):.2f}")
print(f"Потенциальная нижняя граница высокой оценки пользователей: {df['user_score'].quantile(0.7):.2f}")
# Out:
# Потенциальная верхняя граница низкой оценки критиков: 6.30
# Потенциальная нижняя граница высокой оценки критиков: 7.80
# Потенциальная верхняя граница низкой оценки пользователей: 6.70
# Потенциальная нижняя граница высокой оценки пользователей: 8.10

# %% [markdown]
# Примем границы категории оценок 6 и 8

# %%
def set_score_level(row):
    median_score = (row['critic_score']**2 + row['user_score']**2)
    if median_score < 6**2 * 2:
        return 'низкая оценка'
    elif median_score > 8**2 * 2:
        return 'высокая оценка'
    else:
        return 'средняя оценка'

# %%
df['score_level'] = df.apply(set_score_level, axis=1)
description['score_level'] = 'уровень оценки'
df.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score     rating  \
# 0     28.96      3.77         8.45           7.6         8.0          E
# 1      3.58      6.81         0.77           NaN         NaN  NO-RATING
# 2     12.76      3.79         3.29           8.2         8.3          E
# 3     10.93      3.28         2.95           8.0         8.0          E
# 4      8.89     10.22         1.00           NaN         NaN  NO-RATING
#
#    total_sales     score_level
# 0        82.54  средняя оценка
# ...

# %%
plt.figure(figsize=(8, 8))
plt.grid(visible=True, axis='both')
sns.scatterplot(data=df, x='critic_score', y='user_score', hue='score_level', alpha=0.3)
plt.title(f'Взаимосвязь оценок', pad=15, fontsize = 16)
plt.xlabel(description['critic_score'], fontsize = 14)
plt.ylabel(description['user_score'], fontsize = 14)
plt.show()

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Платформы, актуальный период

# %% [markdown]
# #### Временная шкала

# %% [markdown]
# Посмотрим сколько игр выпускалось в разные годы и как менялись суммарные продажи игр выпущенных в разные годы

# %%
fig, axs = plt.subplots(2, 1, sharex=True)

df['year_of_release'].value_counts().sort_index().plot(ax=axs[1], kind='bar', width=1)
df.pivot_table(index='year_of_release', values='total_sales', aggfunc='sum').plot(ax=axs[0], kind='bar', width=1)

fig.set_figwidth(10)
fig.set_figheight(12)

axs[1].minorticks_on()
#axs[0].xaxis.tick_top()

for i in range(2):
    axs[i].grid(visible=True, axis='both')
    axs[i].tick_params(labelsize = 12)

axs[0].set_title('Суммарные продажи по году выхода игры', pad=15, fontsize = 16)
axs[1].set_title('Суммарный выход игр по годам', pad=15, fontsize = 16)

axs[1].set_xlabel('Год', fontsize = 14)
axs[0].set_ylabel('Продажи игр,\n выпущенных в определенный год\n(млн. копий)', fontsize = 12)
axs[1].set_ylabel('Число выпущенных игр', fontsize = 14)

plt.show()

# %% [markdown]
# Популярность игр и количество выпускаемых игр значительно выросло в период с 1990 по 2000 гг.
#
# Объемы производства и потребления игр до 1990 уже не соответствуют текущей ситуации на рынке. Поскольку при пргнозировнии нужно учесть актуальные тенденции, то отбросим период до 1990 года.

# %%
df_actual = df.query('year_of_release > 1990')

# %% [markdown]
# #### Игры по платформам

# %% [markdown]
# **Посмотрм как менялись продажи по платформам.**
#
# Проверим суммарные продажи по всем платформам:

# %%
total_sales_barplot(df_actual, 'platform', period='актуальный')

# %% [markdown]
# Выделяются платформы с весьма низкими продажами.
#
# Рассмотрим объемы продаж по таким платформам:

# %%
(df_actual.pivot_table(index='platform', values='total_sales', aggfunc='sum')
 .query('total_sales < 100')
 .sort_values('total_sales')
)
# Out:
#           total_sales
# platform
# PCFX             0.03
# GG               0.04
# 3DO              0.10
# TG16             0.16
# WS               1.42
# NG               1.44
# SCD              1.86
# NES             11.81
# DC              15.95
# GEN             28.17
# SAT             33.59
# PSV             53.81
# WiiU            82.19

# %% [markdown]
# Отбросим самые малодоходные платформы. Примем за порог 50 млн. копий.

# %%
actual_platform = list(df_actual.pivot_table(index='platform', values='total_sales', aggfunc='sum')
 .query('total_sales > 50')
 .sort_values('total_sales')
 .index
)
print('Наиболее продаваемые платформы:', *sorted(actual_platform), sep='\n')
# Out:
# Наиболее продаваемые платформы:
# 3DS
# DS
# GB
# GBA
# GC
# N64
# PC
# PS
# PS2
# PS3
# PS4
# PSP
# PSV
# SNES
# Wii
# WiiU
# X360
# XB
# XOne

# %%
df_actual = df_actual.query('platform in @actual_platform')
total_sales_barplot(df_actual, 'platform', period='актуальный')

# %% [markdown]
# Построим распределение выхода игр на различных платформах по годам.

# %%
years_heatmap(df_actual, 'platform', w=18)

# %% [markdown]
# В среднем за 6 - 10 лет появляются новые и исчезают старые платформы. Исключение составляет персональный компьютер, который пользуется спросом практически все время.
#
# В 2011-2013 гг появиляются новые поколения консолей и, сменяя старые поколения, набирают все большую популярность. В текущем исследовании важно прогнозирование *будущих продаж*, поэтому нужно исключить влияние данных по уходящим с рынка платформам. Как видно из тепловой карты на 2009-2011 гг приходятся пики продаж по отходящим платформам. Чтобы не попасть под это влияние, отбросим данные до 2012 года для формирования актуального периода и правильной оценки современного пользовательского портрета.
#
# Отбросим также из данных последний год, поскольку данные в последний год неполные.

# %%
df_actual = df_actual.query('year_of_release > 2011 and year_of_release < year_of_release.max()')

# %% [markdown]
# Рассмотрим изменения в объемах продаж по актуальным платформам

# %%
years_heatmap(df_actual, 'platform', aggfunc='sum', w=7, h=7)

# %% [markdown]
# По всем платформам можно наблюдать нарастание спроса и последующий спад спроса.
#
# Потенциально прибыльные платформы, по которым идет нарастание спроса, это:
# - **PlayStation 4**
# - **Xbox One**
#
# Удерживают спадающий спрос:
# - Nintendo 3DS
# - PlayStation 3
# - Wii U
# - Xbox 360
# - PC
# - PlayStation Vita

# %% [markdown]
# Рассмотрим распределение значений объемов продаж по платформам

# %%
total_sales_boxplot(df_actual, 'platform', period='актуальный')

# %% [markdown]
# Очень большие выбросы.
#
# Рассмотрим ту же картинку, отбросив бОльшую часть выбрососв (более 2 млн. копий)

# %%
df_actual_normal = df_actual.query('total_sales < 2')
total_sales_boxplot(df_actual_normal, 'platform', period='актуальный нормализированный')

# %% [markdown]
# > - Точки на диаграмме - это "Выбросы" значений, т.е. редкие (исключительные) значения, отбивающие от основной массы занчений. эти значения влияют на среднее значени и суммарное число продаж. Это скорее самые популярные топовые игры (но в основной массе их не так много).
# > - Прямоугольником выделен "нормальный" диапазон распределения объема продаж, а черта внутри прямоугольника - медиана (иными словами "середитнное" значение). На этот прямоугольник и будем ориентироваться в нашем анализе.
#
# С наиболее широким нормальным диапазоном и более высоким средним выделяются **XBOX** (360 и One) и **PlayStation** (3 и 4). Чуть ниже, то так же с высоким диапазоном платформа **Wii** (Wii и WiiU)
#
# Медианные значения по остальным платформам выделяются несильно и колюблются вокруг одних значений.
#
# Рекордные продажи ("выбросы" на первой диаграмме) наблюдаются по платформам **PlayStation, Xbos и Nintendo**.

# %% [markdown]
# ### Оценки игры

# %% [markdown]
# Посмотрим, как влияют на продажи отзывы пользователей и критиков.

# %%
for col in ['critic_score', 'user_score']:
    print_scatter(df_actual_normal, x=col, y='total_sales', alpha=0.4, figsize=(8,6))

# %% [markdown]
# Посмотрим, как влияют на продажи внутри самых популярных платформ отзывы пользователей и критиков.
#
# Напомним суммарное число продаж по платформам за актульный период:

# %%
total_sales_barplot(df_actual, 'platform', period='актуальный')

# %% [markdown]
# При сокращении актуального периода популярность игр изменилась. Возьмем для анализа платформы, набирающие популярность:
# - **PlayStation 4**
# - **Xbox One**

# %%
for name in ['PS4', 'XOne']:
    for col in ['critic_score', 'user_score']:
        print_scatter(df_actual.query('platform == @name'), x=col, y='total_sales', subtitle=f' для платформы {name}', alpha=0.6, figsize=(8,7))
        plt.show()

# %%
#total_sales_boxplot(df, name, w=15, h=10, period='весь'):
total_sales_boxplot(df_actual_normal, 'score_level', period='актуальный нормализированный', w=12, h=6)

# %% [markdown]
# **Выводы:**
#
# По общей картине продаж видно, что есть низкие продажи и при высокой оценке (но их значительно меньше). Нет высоких продаж при низкой оценке.
#
# В разрезе популярных платформ линейная зависимость еще слабее. При низких и средних оценках нет высоких продаж, а при высоких оценках критиков низкие продажи - редкость.
#
# Оценки пользователей меньше влияют на продажи, чем оценки критиков. При низких и средних оценках критоков - продажи не ведики, но при высокой оценке критиков - продажи высокие. При средних оценках пользователей продажи таже могут быть высокими. При любых низких оценках продажи низкие.

# %% [markdown]
# ### Жанры

# %%
# 1 Распределение значений общих продаж по категориям
# def total_sales_boxplot(df, name, w=15, h=10, period='весь'):
total_sales_boxplot(df_actual, 'genre', period='актуальный')

# %%
# 1 Распределение значений общих продаж по категориям
# def total_sales_boxplot(df, name, w=15, h=10, period='весь'):
total_sales_boxplot(df_actual_normal, 'genre', h=8, period='актуальный нормализированный')

# %%
# 2 Сумма общих продаж за весь период по категориям
# def total_sales_barplot(df, name, w=15, h=10, period='весь'):
total_sales_barplot(df_actual, 'genre', h=7, period='актуальный')

# %%
# 3 Сумма общих продаж (либо кол-во выпущенных игр) по годам по категориям
# def years_heatmap(df, name, w=15, h=10, absolute=True, aggfunc='count'):
years_heatmap(df_actual, 'genre', absolute=False, aggfunc='sum', w=7, h=8)

# %% [markdown]
# **Выводы:**
#
# Больше всего продаж в сумме по жанрам **Action (Shooter)**. Меньше, но так же значительны **Sports** и **Role-Playing**. (На эти значения повлияли "выбросы" топовых игр)
#
# С наиболее широким нормальным диапазоном и более высоким средним выделяются жанры **Shooter**, **Platform** и **Sports**. Platform имеет меньше "выбросов" и поэтому в суммарных продажах отстает (Role-Playing же напротив).
#
# Медианные значения по остальным платформам выделяются несильно и колюблются вокруг примерно одних значений.
#
# Рекордные продажи ("выбросы" на первой диаграмме) наблюдаются по жанрам **Action, Shooter и Role-Playing**.
#
# За время актуального периода предпочтения игроков изменились не сильно. енсколько снизились предпочтения по Platform и Action и увеличились продажи Sports.
#
# По большей части игроки предпочитают динамичные жанры игр.

# %% [markdown]
# ### Выводы

# %% [markdown]
# - Наибольшим спросом пользуются платформы XBOX и PlayStation (новые модели платформ набирают обороты продаж и потенциально прибыльны)
# - Оценки критиков имеют влияние на объем продаж
# - Наибольшие предпочения по жанрам среди игроков: Action, Shooter, Sports.

# %% [markdown]
# ## Портрет пользователя по регионам

# %% [markdown]
# ### Популярные платформы

# %%
top_sales(df_actual, 'platform')

# %%
region_heatmap(df_actual, 'platform', absolute=False, w=7, h=7)

# %% [markdown]
# В Америке, Европе и других странах предпочтения по платформам одинаковые. Разве что в Америке предпочтения по Xbox и PlayStation разделились поровну, а в Европе и других странах больше предпочитают PlayStation нежели Xbox.
#
# В Японии несколько иная картина по платформам:
# - японцы предпочитают портативные консоли
# - из стационарных консолей в топ Японии попала только PlaySation3 (консоли нового поколения еще не популярны)
# - Xbox совсем не популярен
#
# Наиболее равномерная значимая популярность по всему миру наблюдается у **PlayStation 3**.

# %% [markdown]
# ### Популярные жанры

# %%
top_sales(df_actual, 'genre')

# %%
region_heatmap(df_actual, 'genre', absolute=False)

# %% [markdown]
# Предпочтения по жанрам одинаковы по всем регионам (Action, Shooter, Sports, Role-Playing), за исключением Японии.
#
# В Японии на первом месте установился жанр Role-Playing. Японцы не любят Shooter в отличие от остальных регионов, но также играют в Action.
#
# Наиболее равномерная значимая популярность по всему миру наблюдается по жанру **Action**

# %% [markdown]
# ### Влияние ретинга ESBR

# %% [markdown]
# Проверим влияет ли рейтинг ESRB на продажи в отдельном регионе.

# %%
region_heatmap(df_actual, 'rating', h=5, absolute=False)

# %% [markdown]
# Вляиние рейтинга выражено наибольшим образом в Японии.
#
# В Япони предпочитают больше рейтинги `E` и `T` и меньше рейтинг `M` (Это проекты, которые могут содержать достаточно жестокое насилие, большое количество крови с расчленением, непристойные сексуальные сцены или грубую ненормативную лексику, нежелательную для младшей аудитории.). В остальном мире предпочтение ретинга `M` высоко (около 40%)
#
# В Японии более 50% продаж ирг *без рейтинга*, в то время как в остальном мире менее 20%. Возможно это связано с тем, что ESBR - это американская негосударственная организация, и на игры, выпускаемые в Японии, действует другая система рейтинга.

# %% [markdown]
# ## Проверка гипотез

# %% [markdown]
# ### Гипотеза 1

# %% [markdown]
# Нулевая гитотеза: Средние пользовательские рейтинги платформ Xbox One и PC одинаковые
#
# Альтернативная гипотеза: Средние пользовательские рейтинги платформы Xbox One не равны средним пользовательским рейтингам платформы PC
#
# Воспользуемся методом проверки двусторонней гипотезы.
#
# Критический уровень значисмости примем 1%

# %%
alpha = 0.01

results = st.ttest_ind(df_actual.query('platform == "PC"')['user_score'].dropna(),
                       df_actual.query('platform == "XOne"')['user_score'].dropna())

print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.9463196313131612
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# **Вывод:**
#
# **Гипотеза о том, что средние пользовательские рейтинги платформ Xbox One и PC одинаковые, потвердилась**

# %% [markdown]
# ### Гипотеза 2

# %% [markdown]
# Нулевая гитотеза: Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») равны.
#
# Альтернативная гипотеза: Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
#
# Воспользуемся методом проверки двусторонней гипотезы.
#
# Критический уровень значисмости примем 1%

# %%
alpha = 0.01

results = st.ttest_ind(df_actual.query('genre == "Action"')['user_score'].dropna(),
                       df_actual.query('genre == "Sports"')['user_score'].dropna())

print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 1.828696730145466e-23
# Отвергаем нулевую гипотезу

# %% [markdown]
# **Вывод:**
#
# **Гипотеза о том, что cредние пользовательские рейтинги жанров "Action" и "Sports" равны, не потвердилась**

# %% [markdown]
# ## Общие выводы

# %% [markdown]
# 1. За последние 5 лет продажи и выпуск игр несколько снизились в сравнении с периодом 5-10 летней давности.
# 2. Старые платформы теряют популярность (период расцвета и заката примерно 6-10 лет). Потенциалтно прибыльные платформы - это новые **PlayStation4** и **XboxOne**
# 3. Оценки критиков могут повлиять на продажи: чем выше оценка критиков тем больший объем продаж обеспечен игре.
# 4. Большее предпочтение игроки отдают "динамичным" жанрам игр (**Action**, **Shooter**, **Sports**) и **Role-Playing**.
#
# Частные картины по регонам:
#
# ***Северная Америка:***
#
# - Играют одинаково на ***Xbox*** и ***Playstation*** в жанры ***Action***, ***Shooter***, ***Sports*** с рейтингом ESBR `M`, `E`(`E10+`)
#
# ***Япония:***
#
# - Играют одинаково на портативных консолях (***Nintendo, PSVita, WiiU***) в жанры ***Role-Playing*** и ***Action*** без рейтинга ESBR
#
# ***Европа и другие страны:***
#
# - Играют преимущественно на ***Playstation*** в жанры ***Action***, ***Shooter***, ***Sports*** с рейтингом ESBR `M`, `E`(`E10+`)
