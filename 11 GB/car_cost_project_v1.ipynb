# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Цель-исследования" data-toc-modified-id="Цель-исследования-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Цель исследования</a></span></li><li><span><a href="#Исходные-данные" data-toc-modified-id="Исходные-данные-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исходные данные</a></span><ul class="toc-item"><li><span><a href="#Подключаемые-модули" data-toc-modified-id="Подключаемые-модули-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Подключаемые модули</a></span></li><li><span><a href="#Настройка-окружения" data-toc-modified-id="Настройка-окружения-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Настройка окружения</a></span></li><li><span><a href="#Общие-параметры" data-toc-modified-id="Общие-параметры-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Общие параметры</a></span></li><li><span><a href="#Функции" data-toc-modified-id="Функции-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Функции</a></span></li></ul></li><li><span><a href="#Получение-данных" data-toc-modified-id="Получение-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Получение данных</a></span><ul class="toc-item"><li><span><a href="#Чтение-данных-из-файла" data-toc-modified-id="Чтение-данных-из-файла-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Чтение данных из файла</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Общая-информация" data-toc-modified-id="Общая-информация-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Общая информация</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Исправление-заголовков" data-toc-modified-id="Исправление-заголовков-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Исправление заголовков</a></span></li><li><span><a href="#Проверка-на-явные-дубликаты" data-toc-modified-id="Проверка-на-явные-дубликаты-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Проверка на явные дубликаты</a></span></li><li><span><a href="#Проверка-пропусков" data-toc-modified-id="Проверка-пропусков-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Проверка пропусков</a></span></li><li><span><a href="#Замена-типов-данных" data-toc-modified-id="Замена-типов-данных-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Замена типов данных</a></span><ul class="toc-item"><li><span><a href="#Была-машина-в-ремонте-или-нет-(NotRepaired)" data-toc-modified-id="Была-машина-в-ремонте-или-нет-(NotRepaired)-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Была машина в ремонте или нет (NotRepaired)</a></span></li><li><span><a href="#Признаки-даты-в-фомате-даты-(DateCrawled,-DateCreated,-LastSeen)" data-toc-modified-id="Признаки-даты-в-фомате-даты-(DateCrawled,-DateCreated,-LastSeen)-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>Признаки даты в фомате даты (DateCrawled, DateCreated, LastSeen)</a></span></li><li><span><a href="#Почтовый-индекс-владельца-анкеты-(PostalCode)" data-toc-modified-id="Почтовый-индекс-владельца-анкеты-(PostalCode)-4.4.3"><span class="toc-item-num">4.4.3&nbsp;&nbsp;</span>Почтовый индекс владельца анкеты (PostalCode)</a></span></li><li><span><a href="#Перепроверим-типы-данных" data-toc-modified-id="Перепроверим-типы-данных-4.4.4"><span class="toc-item-num">4.4.4&nbsp;&nbsp;</span>Перепроверим типы данных</a></span></li></ul></li><li><span><a href="#Вывод-по-предобработке" data-toc-modified-id="Вывод-по-предобработке-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Вывод по предобработке</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Проверка-смысловых-зависимостей" data-toc-modified-id="Проверка-смысловых-зависимостей-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Проверка смысловых зависимостей</a></span><ul class="toc-item"><li><span><a href="#Условие-1:" data-toc-modified-id="Условие-1:-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Условие 1:</a></span></li><li><span><a href="#Условие-2:" data-toc-modified-id="Условие-2:-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Условие 2:</a></span></li><li><span><a href="#Условие-3:" data-toc-modified-id="Условие-3:-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>Условие 3:</a></span></li></ul></li><li><span><a href="#Проверка-значений:-ошибки,-выбросы,-дубликаты" data-toc-modified-id="Проверка-значений:-ошибки,-выбросы,-дубликаты-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Проверка значений: ошибки, выбросы, дубликаты</a></span><ul class="toc-item"><li><span><a href="#Дата-время" data-toc-modified-id="Дата-время-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Дата-время</a></span><ul class="toc-item"><li><span><a href="#Дата-скачивания-анкеты-из-базы-[DateCrawled]" data-toc-modified-id="Дата-скачивания-анкеты-из-базы-[DateCrawled]-5.2.1.1"><span class="toc-item-num">5.2.1.1&nbsp;&nbsp;</span>Дата скачивания анкеты из базы [DateCrawled]</a></span></li><li><span><a href="#Дата-создания-анкеты-[DateCreated]" data-toc-modified-id="Дата-создания-анкеты-[DateCreated]-5.2.1.2"><span class="toc-item-num">5.2.1.2&nbsp;&nbsp;</span>Дата создания анкеты [DateCreated]</a></span></li><li><span><a href="#Дата-последней-активности-пользователя-[LastSeen]" data-toc-modified-id="Дата-последней-активности-пользователя-[LastSeen]-5.2.1.3"><span class="toc-item-num">5.2.1.3&nbsp;&nbsp;</span>Дата последней активности пользователя [LastSeen]</a></span></li></ul></li><li><span><a href="#Категории" data-toc-modified-id="Категории-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Категории</a></span><ul class="toc-item"><li><span><a href="#Модель-автомобиля-[Model]" data-toc-modified-id="Модель-автомобиля-[Model]-5.2.2.1"><span class="toc-item-num">5.2.2.1&nbsp;&nbsp;</span>Модель автомобиля [Model]</a></span></li><li><span><a href="#Марка-автомобиля-[Brand]" data-toc-modified-id="Марка-автомобиля-[Brand]-5.2.2.2"><span class="toc-item-num">5.2.2.2&nbsp;&nbsp;</span>Марка автомобиля [Brand]</a></span></li><li><span><a href="#Тип-автомобильного-кузова-[VehicleType]" data-toc-modified-id="Тип-автомобильного-кузова-[VehicleType]-5.2.2.3"><span class="toc-item-num">5.2.2.3&nbsp;&nbsp;</span>Тип автомобильного кузова [VehicleType]</a></span></li><li><span><a href="#Тип-коробки-передач-[Gearbox]" data-toc-modified-id="Тип-коробки-передач-[Gearbox]-5.2.2.4"><span class="toc-item-num">5.2.2.4&nbsp;&nbsp;</span>Тип коробки передач [Gearbox]</a></span></li><li><span><a href="#Тип-топлива-[FuelType]" data-toc-modified-id="Тип-топлива-[FuelType]-5.2.2.5"><span class="toc-item-num">5.2.2.5&nbsp;&nbsp;</span>Тип топлива [FuelType]</a></span></li><li><span><a href="#Была-машина-в-ремонте-или-нет-[NotRepaired]" data-toc-modified-id="Была-машина-в-ремонте-или-нет-[NotRepaired]-5.2.2.6"><span class="toc-item-num">5.2.2.6&nbsp;&nbsp;</span>Была машина в ремонте или нет [NotRepaired]</a></span></li><li><span><a href="#Почтовый-индекс-владельца-анкеты-(пользователя)-[PostalCode]" data-toc-modified-id="Почтовый-индекс-владельца-анкеты-(пользователя)-[PostalCode]-5.2.2.7"><span class="toc-item-num">5.2.2.7&nbsp;&nbsp;</span>Почтовый индекс владельца анкеты (пользователя) [PostalCode]</a></span></li></ul></li><li><span><a href="#Числовые" data-toc-modified-id="Числовые-5.2.3"><span class="toc-item-num">5.2.3&nbsp;&nbsp;</span>Числовые</a></span><ul class="toc-item"><li><span><a href="#Цена-(евро)-[Price]" data-toc-modified-id="Цена-(евро)-[Price]-5.2.3.1"><span class="toc-item-num">5.2.3.1&nbsp;&nbsp;</span>Цена (евро) [Price]</a></span></li><li><span><a href="#Мощность-(л.-с.)-[Power]" data-toc-modified-id="Мощность-(л.-с.)-[Power]-5.2.3.2"><span class="toc-item-num">5.2.3.2&nbsp;&nbsp;</span>Мощность (л. с.) [Power]</a></span></li><li><span><a href="#Пробег-(км)-[Kilometer]" data-toc-modified-id="Пробег-(км)-[Kilometer]-5.2.3.3"><span class="toc-item-num">5.2.3.3&nbsp;&nbsp;</span>Пробег (км) [Kilometer]</a></span></li><li><span><a href="#Год-регистрации-автомобиля-[RegistrationYear]" data-toc-modified-id="Год-регистрации-автомобиля-[RegistrationYear]-5.2.3.4"><span class="toc-item-num">5.2.3.4&nbsp;&nbsp;</span>Год регистрации автомобиля [RegistrationYear]</a></span></li><li><span><a href="#Месяц-регистрации-автомобиля-[RegistrationMonth]" data-toc-modified-id="Месяц-регистрации-автомобиля-[RegistrationMonth]-5.2.3.5"><span class="toc-item-num">5.2.3.5&nbsp;&nbsp;</span>Месяц регистрации автомобиля [RegistrationMonth]</a></span></li></ul></li></ul></li><li><span><a href="#Корреляция-признаков" data-toc-modified-id="Корреляция-признаков-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Корреляция признаков</a></span></li><li><span><a href="#Отбор-признаков" data-toc-modified-id="Отбор-признаков-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Отбор признаков</a></span></li><li><span><a href="#Вывод-по-анализу-данных" data-toc-modified-id="Вывод-по-анализу-данных-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Вывод по анализу данных</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Функция-подготовки-данных" data-toc-modified-id="Функция-подготовки-данных-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Функция подготовки данных</a></span></li><li><span><a href="#Отделим-тестовую-часть" data-toc-modified-id="Отделим-тестовую-часть-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Отделим тестовую часть</a></span><ul class="toc-item"><li><span><a href="#Прямое-кодирование" data-toc-modified-id="Прямое-кодирование-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>Прямое кодирование</a></span></li><li><span><a href="#Порядковое-кодирование" data-toc-modified-id="Порядковое-кодирование-6.2.2"><span class="toc-item-num">6.2.2&nbsp;&nbsp;</span>Порядковое кодирование</a></span></li></ul></li></ul></li><li><span><a href="#Исследование-задачи" data-toc-modified-id="Исследование-задачи-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Исследование задачи</a></span><ul class="toc-item"><li><span><a href="#Подбор-базовой-модели" data-toc-modified-id="Подбор-базовой-модели-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Подбор базовой модели</a></span></li><li><span><a href="#Оценка-признаков-на-базовой-модели" data-toc-modified-id="Оценка-признаков-на-базовой-модели-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Оценка признаков на базовой модели</a></span><ul class="toc-item"><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-7.2.1"><span class="toc-item-num">7.2.1&nbsp;&nbsp;</span>Случайный лес</a></span></li><li><span><a href="#Градиентный-бустинг" data-toc-modified-id="Градиентный-бустинг-7.2.2"><span class="toc-item-num">7.2.2&nbsp;&nbsp;</span>Градиентный бустинг</a></span></li></ul></li><li><span><a href="#Переподготовка-данных-(переоценка-признаков)" data-toc-modified-id="Переподготовка-данных-(переоценка-признаков)-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Переподготовка данных (переоценка признаков)</a></span></li><li><span><a href="#Подбор-гиперпараметров" data-toc-modified-id="Подбор-гиперпараметров-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Подбор гиперпараметров</a></span><ul class="toc-item"><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-7.4.1"><span class="toc-item-num">7.4.1&nbsp;&nbsp;</span>Случайный лес</a></span></li><li><span><a href="#Градиентный-бустинг" data-toc-modified-id="Градиентный-бустинг-7.4.2"><span class="toc-item-num">7.4.2&nbsp;&nbsp;</span>Градиентный бустинг</a></span></li></ul></li><li><span><a href="#Выбор-лучшей-модели" data-toc-modified-id="Выбор-лучшей-модели-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>Выбор лучшей модели</a></span></li></ul></li><li><span><a href="#Тестирование-модели" data-toc-modified-id="Тестирование-модели-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Тестирование модели</a></span><ul class="toc-item"><li><span><a href="#Тестовые-признаки" data-toc-modified-id="Тестовые-признаки-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Тестовые признаки</a></span></li><li><span><a href="#Обучение-модели" data-toc-modified-id="Обучение-модели-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Обучение модели</a></span></li><li><span><a href="#Проверка-модели" data-toc-modified-id="Проверка-модели-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Проверка модели</a></span></li><li><span><a href="#Проверка-модели-на-адекватность" data-toc-modified-id="Проверка-модели-на-адекватность-8.4"><span class="toc-item-num">8.4&nbsp;&nbsp;</span>Проверка модели на адекватность</a></span></li></ul></li><li><span><a href="#Рабочий-код" data-toc-modified-id="Рабочий-код-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Рабочий код</a></span></li><li><span><a href="#Общие-выводы" data-toc-modified-id="Общие-выводы-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Общие выводы</a></span></li></ul></div>

# %%
import time
START_PROJECT = time.time()

# %% [markdown]
# # Определение стоимости автомобилей

# %% [markdown]
# Сервис по продаже автомобилей с пробегом «Не бит, не крашен» разрабатывает приложение для привлечения новых клиентов. В нём можно быстро узнать рыночную стоимость своего автомобиля. В вашем распоряжении исторические данные: технические характеристики, комплектации и цены автомобилей. Вам нужно построить модель для определения стоимости.
#
# Заказчику важны:
#
# - качество предсказания;
# - скорость предсказания;
# - время обучения.

# %% [markdown]
# ## Цель исследования

# %% [markdown]
# - Создать модель для предсказания стоимости автомобиля.
# - Оптимизировать время и качество предсказаний модели.
# - Повысить скорость обучения модели.

# %% [markdown]
# ## Исходные данные

# %% [markdown]
# ### Подключаемые модули

# %%
# Основное
import time
import pandas as pd
import numpy as np
import lightgbm as lgb

from itertools import product

# %%
# Гарфика
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import seaborn as sns

# %%
# sklearn
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from lightgbm import LGBMRegressor

from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import OrdinalEncoder
from sklearn.dummy import DummyRegressor

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_selector

from sklearn.inspection import permutation_importance

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

from sklearn.model_selection import cross_val_score

# %%
# другое
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# ### Настройка окружения

# %%
pd.set_option('display.max_rows', 500)

# %% [markdown]
# ### Общие параметры

# %%
TABLE_SIZE = 100
YANDEX_STORAGE = None
TARGET_COL = 'price'

# %% [markdown]
# ### Функции

# %% [markdown]
# Общее

# %%
# формат текста для output
class text:
    END = '\x1b[0m'
    BOLD = '\x1b[1m'
    
    UNDERLINE = '\x1b[4m'
    
    NEGATIVE = '\x1b[7m'

    GREY = '\x1b[30m'
    RED = '\x1b[31m'
    GREEN = '\x1b[32m'
    YELLOW = '\x1b[33m'
    BLUE = '\x1b[34m'
    PURPLE = '\x1b[35m'
    CYAN = '\x1b[36m'
    SILVER = '\x1b[37m'
    BLACK = '\x1b[39m'
    
    BG_GREY = '\x1b[40m'
    BG_RED = '\x1b[41m'
    BG_GREEN = '\x1b[42m'
    BG_YELLOW = '\x1b[43m'
    BG_BLUE = '\x1b[44m'
    BG_PURPLE = '\x1b[45m'
    BG_CYAN = '\x1b[46m'
    BG_SILVER = '\x1b[47m'
    
    DARKGREY = '\x1b[90m'
    DARKRED = '\x1b[91m'
    DARKGREEN = '\x1b[92m'
    DARKYELLOW = '\x1b[93m'
    DARKBLUE = '\x1b[94m'
    DARKPURPLE = '\x1b[95m'
    DARKCYAN = '\x1b[96m'
    DARKSILVER = '\x1b[97m'
    
    BG_DARKGREY = '\x1b[100m'
    BG_DARKRED = '\x1b[101m'
    BG_DARKGREEN = '\x1b[102m'
    BG_DARKYELLOW = '\x1b[103m'
    BG_DARKBLUE = '\x1b[104m'
    BG_DARKPURPLE = '\x1b[105m'
    BG_DARKCYAN = '\x1b[106m'
    BG_DARKSILVER = '\x1b[107m'
    
    END_B = '\x1b[21m'
    END_U = '\x1b[24m'
    END_NEGATIVE = '\x1b[27m'
    END_C = '\x1b[39m'
    END_BG = '\x1b[49m'

# %% [markdown]
# Обработка

# %%
# перевод из верблюжъего в змеиный регистр
def camel_to_snake(string, sep='_'):
    return ''.join([sep+c.lower() if c.isupper() else c for c in string]).lstrip(sep)

# %% [markdown]
# Информирование

# %%
# вывод таблицы описания данных
def print_description(df):
    len_index = max([len(i) for i in df])
    for ind, name in enumerate(df):
        end = '' if len(description[name]) < TABLE_SIZE else '...'
        print(f'{str(ind).ljust(3)} {name.ljust(len_index)} - {description[name][:TABLE_SIZE]}{end}')

# %%
# общая информация об исходной таблице
def start_information(df):
    result = []
    for col in df:
        result.append([
            col, df[col].count(), df[col].isna().sum(),
            df[col].dtype, df[col].nunique(), df[col].sample(10).values,
        ])
        if str(df[col].dtype)[:3] in ('intflo'):
            result[-1].extend([df[col].min(), df[col].max()])
        else:
            result[-1].extend(['-', '-'])
        result[-1].append(description[col])
    
    res = pd.DataFrame(result, columns=['Name', 'Count', 'NA', 'Type', 'Unique', 'Sample', 'min', 'max', 'description'])
    res.index = res['Name']
    res = res.drop('Name', axis=1)
    display(res)
    print(f'Размер таблицы: {text.BOLD} {df.shape} {text.END}')
    print(f'Целевой признак: {text.BOLD} {TARGET_COL} {text.END}')

# %%
# остаток данных
def show_remains(data):
    display((pd.DataFrame(data.shape, columns=['остаток']).T / original_shape).rename(columns={0:'Строк', 1:'Столбцов'}).style.format({'Строк': '{:.1%}', 'Столбцов': '{:.1%}'}))

# %%
# проверка пропусков
def na_info(df, level=0.01):
    sum_table = df.isna().sum()
    na_table = df.count()
    res_table = pd.DataFrame([na_table, sum_table, sum_table / na_table]).T.rename(columns = {0: 'count', 1: 'na', 2: 'fraction'})
    res_table[['count', 'na']] = res_table[['count', 'na']].astype('int')
    
    # Нет пропусков
    print(text.BOLD, text.BG_SILVER, 'Нет пропусков:'.ljust(TABLE_SIZE, ' '), text.END)
    if res_table.query('na == 0').shape[0] > 0:
        display(res_table.query('na == 0').style.format({'fraction': '{:.2%}'}))
    else:
        print(f'\n {text.RED}{text.BOLD} Во всех объектах имеются пропуски {text.END}')
    print()

    # Малая доля (на удаление)
    print(text.BOLD, text.BG_SILVER, 'Малая доля пропусков:'.ljust(TABLE_SIZE, ' '), text.END)
    small = res_table.query('fraction < @level and na > 0')
    if small.shape[0] > 0:
        display(small.style.format({'fraction': '{:.2%}'}))
        remains = df[res_table.query('fraction < @level and na > 0').index].dropna().shape[0] / df.shape[0]
        print(f'Оценка остатка (при удалении пропусков с малой долей): {text.BOLD}{text.BG_YELLOW} {remains:.3%} {text.END}')
    else:
        print(f'\n {text.GREEN}{text.BOLD} Нет пропусков с малой долей {text.END}')
    print()
    
    # Большая доля (на обработку)
    print(text.BOLD, text.BG_SILVER, 'Большая доля пропусков:'.ljust(TABLE_SIZE, ' '), text.END)
    big = res_table.query('fraction > @level')
    if big.shape[0] > 0:
        display(big.style.format({'fraction': '{:.2%}'}))
    else:
        print(f'\n {text.GREEN}{text.BOLD} Нет пропусков с большой долей {text.END}')
    
    return {'delete': list(small.index), 'process': list(big.index)}

# %% [markdown]
# Презентации

# %%
def hist_box_describe(df, col, subtitle='', xlabel=None, ylabel=None, data=None, bins=None, figsize=(8, 8), **kwargs):
    if type(data) == type(None):
        data = df[col]
    if xlabel == None:
        try:
            xlabel = description[col]
        except:
            pass
    if bins == None:
        bins = data.nunique()
    
    fig = plt.figure()
    
    # Разделение fig на зоны разных размеров:
    gs1 = GridSpec(5, 1, left=0.05, right=0.95, hspace=0.03)
    # (y, x) - размеры сетки (высота, ширина)
    # left - расположние левой границы всей сетки (топа margin)
    # right - расположние правой границы всей сетки (топа margin)
    # wspace, hspace - зазоры между графиками (вертикальный, горизонтальный)
    ax1 = fig.add_subplot(gs1[:1, :]) # (срез по Y, срез по X)
    ax2 = fig.add_subplot(gs1[1:, :])
    
    # Построение графиков:
    data.plot(ax=ax1, kind='box', vert=False, widths=0.6, **kwargs)
    data.plot(ax=ax2, kind='hist', grid=True, bins=bins, **kwargs)
    
    # Различные настройки графиков:
    fig.set_figwidth(figsize[0])
    fig.set_figheight(figsize[1])
    #fig.suptitle(f'Распределение показателя "{xlabel}"', fontsize = 16)
    
    ax1.xaxis.tick_top()
    ax2.minorticks_on()
    ax2.grid(which='major',
            color = 'grey', 
            linewidth = 1.2)
    ax2.grid(which='minor', 
            color = 'grey', 
            linestyle = ':')
    
    ax1.set_yticklabels([''])
    ax2.set_xlabel(xlabel, fontsize = 14)
    ax2.set_ylabel('Количество значений', fontsize = 14)
    ax1.tick_params(labelsize = 12)
    ax2.tick_params(labelsize = 12)
    ax1.set_title(f'Распределение показателя "{xlabel}"{subtitle}', pad=15, fontsize = 16)

    x = ax2.get_xbound()
    y = ax2.get_ybound()
    x_coord = x[0] + (x[1]-x[0])/figsize[0]*figsize[1]*0.03 if data.mean() < data.quantile(0.5) else x[1] - (x[1]-x[0])/figsize[0]*figsize[1]*0.29
    y_coord = y[1] - (y[1]-y[0])*0.35
    ax2.text(x_coord, y_coord, str(data.describe()),
        rotation = 0,
        fontsize = figsize[1]*1.2,
        bbox = {'facecolor':'white', 'boxstyle': 'round', 'pad': 1}
            )

# %%
def date_hist_describe(df, col, subtitle='', xlabel=None, ylabel=None, data=None, bins=100, figsize=(12, 6), **kwargs):
    if type(data) == type(None):
        data = df[col]
    if xlabel == None:
        try:
            xlabel = description[col]
        except:
            pass
    
    plt.figure(figsize=figsize)
    data.hist(bins=bins)

    plt.title(f'Распределение количества анкет по временной шкале\n({xlabel})', pad=15, fontsize = 16)
    plt.xlabel(xlabel, fontsize = 14)
    plt.ylabel('Кол-во анкет', fontsize = 14)

    plt.show()
    print(f'{text.BOLD}{text.BG_SILVER} Общая информация по шкале дат: ', text.END)
    display(data.describe(datetime_is_numeric=True))

# %% [markdown]
# Машинное обучение:

# %%
# выделение целевого признака:
def xy_split(data, target_column):
    return data.drop(columns=[target_column], axis=1), data[target_column]

# %%
# разбивка на валидационную и тестовую выборки
def research_test_split(df, test_size=0.2, random_state=12345):
    df_research, df_test = train_test_split(df, test_size=test_size, random_state=random_state)
    print()
    display(pd.DataFrame({
        'Выборка:': ['Исследовательская', 'Тестовая'],
        'Количество значений:': [df_research.shape[0], df_test.shape[0]],
        'Доля выборки:': [df_research.shape[0] / df.shape[0], df_test.shape[0] / df.shape[0]]
            }).style.format({'Количество значений': '{:.0f}', 'Доля выборки:': '{:.2%}'})
         )
    return df_research, df_test

# %%
# Рабочая версия с обработкой Pipeline
# Проходит не по всей сетке, а пока растет значение метрики (Бейесовская оптимизация).
# Если метрика не растет на протажении хвоста (max_tail) цикл заканчивается
# На вход подается Класс модели, исследуемые гиперапараметры в виде словаря
# Работает быстрее, чем GridSearchCV
def ascending_grid(df_features, df_target, func, parameters, scoring=None, plot=False, subtitle='', max_tail=None, cv=5, n_jobs=-1, **kwargs):
    #cv = 5 #при значении 5 результаты отличаются от результатов при значении > 10 ! но по умолчанию в cross_val_score стоит 5, поэтому оставим по умоланию 5
    steps = 100
    iterator = 0
    best_score = -1_000_000
    best_param = parameters
    tail = 0
    if max_tail == None:
        max_tail = 1 if 5 - len(parameters) < 1 else 5 - len(parameters)
    
    param = list(parameters.keys())[0]
    start = parameters[param][0]
    sep = parameters[param][1]
    
    if len(parameters) == 1:
        for p in np.arange(start, start+steps*sep, sep):
            set_param = {param: p}
            if type(func) == Pipeline:
                model = func
                model_name = model.get_params().get("steps")[-1][0]
                # Гиперпараметры (стандартные random_state=123, n_jobs=n_jobs задаются извне):
                # Текущая настройка
                model.set_params(**{model_name+'__'+param: p})
                # **kwargs
                params_temp = {}
                for key, val in kwargs.items():
                    params_temp[model_name+'__'+key] = val
                model.set_params(**params_temp)
            else:
                model = func(random_state=123, n_jobs=n_jobs, **set_param, **kwargs)
            scores = cross_val_score(model, df_features, df_target, scoring=scoring, cv=cv)
            score = scores.mean()
            iterator += len(scores)
            if plot:
                print(f'{p} >>> {set_param} {kwargs} - {score:.4f}')

            if score > best_score:
                best_score = score
                set_param.update(kwargs)
                best_param = set_param
                tail = 0
            else:
                tail += 1
            if tail >= max_tail:
                break
    else:
        # рекурсия
        parameters_minus = parameters.copy()
        del parameters_minus[param]
        for p in np.arange(start, start+steps*sep, sep):
            set_param = {param: p}
            result = ascending_grid(df_features, df_target, func, parameters_minus,
                                    scoring=scoring, plot=plot, subtitle=subtitle, max_tail=max_tail, cv=cv,
                                    **set_param, **kwargs)
            iterator += result['iterations']
            score = result['score']
            
            # Сокращение нижней границы поиска (предыдущее лучшее минус 2 промежутка)
            for key in result['parameters'].keys():
                try:
                    new_start = result['parameters'][key] - parameters_minus[key][1]*2
                    if parameters_minus[key][0] < new_start:
                        parameters_minus[key][0] = result['parameters'][key] - parameters_minus[key][1] * (max_tail + 1)
                except:
                    pass
            
            if score > best_score:
                best_score = score
                best_param = result['parameters']
                tail = 0
            else:
                tail += 1
            if tail >= max_tail:
                break
        
        if plot:
            print('best_score =', best_score)
            print('best_param =', best_param)
    if plot:
        print('-'*TABLE_SIZE)
    return ({'iterations': iterator, 'score':best_score, 'parameters':best_param})

# %%
# Кросс-валидация с результатом для одной модели
def cross_val_base(model_name, model, X, y, scoring, print_res=True):
    time_start = time.time()
    scores = cross_val_score(model, X, y, scoring=scoring, cv=5)
    if print_res:
        print(f'Среднее значение метрики {scoring} для базовой модели {text.BOLD}{model_name}:\n{text.BG_SILVER} {scoring} = {scores.mean():.2f} {text.END}')
        print('-'*TABLE_SIZE)
        return
    return (model_name, scores.mean(), time.time() - time_start)

# %%
# вывод таблицы сравнения
def get_selection_model_results(results, score_name = 'Score'):
    res = pd.DataFrame(results, columns = ['Model', score_name, 'Time']).sort_values(by=score_name, ascending=False)
    
    res['rating_score'] = res.apply(
        lambda row: round((row[score_name] - res[score_name].min()) / (res[score_name].max() - res[score_name].min()), 3)
        , axis=1)
    res['rating_time'] = res.apply(
        lambda row: round(-(row['Time'] - res['Time'].min()) / (res['Time'].max() - res['Time'].min()), 3)
        , axis=1)
    res['rating_total'] = res['rating_score'] + res['rating_time']
    
    return res

# %% [markdown]
# ## Получение данных

# %% [markdown]
# ### Чтение данных из файла

# %%
file = 'autos.csv'

# %%
df = pd.read_csv(f'{YANDEX_STORAGE}{file} ')

# %% [markdown]
# ### Описание данных

# %% [markdown]
# Создадим словарь описания данных на основании предоставленного описания

# %%
# Создадим словарь описания данных
description = {
    'DateCrawled' : 'дата скачивания анкеты из базы',
    'Price' : 'цена (евро)',
    'VehicleType' : 'тип автомобильного кузова',
    'RegistrationYear' : 'год регистрации автомобиля',
    'Gearbox' : 'тип коробки передач',
    'Power' : 'мощность (л. с.)',
    'Model' : 'модель автомобиля',
    'Kilometer' : 'пробег (км)',
    'RegistrationMonth' : 'месяц регистрации автомобиля',
    'FuelType' : 'тип топлива',
    'Brand' : 'марка автомобиля',
    'NotRepaired' : 'была машина в ремонте или нет',
    'DateCreated' : 'дата создания анкеты',
    'NumberOfPictures' : 'количество фотографий автомобиля',
    'PostalCode' : 'почтовый индекс владельца анкеты (пользователя)',
    'LastSeen' : 'дата последней активности пользователя',
}

# %% [markdown]
# Выведем словарь описания данных

# %%
print_description(df)
# Out:
# 0   DateCrawled       - дата скачивания анкеты из базы
# 1   Price             - цена (евро)
# 2   VehicleType       - тип автомобильного кузова
# 3   RegistrationYear  - год регистрации автомобиля
# 4   Gearbox           - тип коробки передач
# 5   Power             - мощность (л. с.)
# 6   Model             - модель автомобиля
# 7   Kilometer         - пробег (км)
# 8   RegistrationMonth - месяц регистрации автомобиля
# 9   FuelType          - тип топлива
# 10  Brand             - марка автомобиля
# 11  NotRepaired       - была машина в ремонте или нет
# 12  DateCreated       - дата создания анкеты
# 13  NumberOfPictures  - количество фотографий автомобиля
# 14  PostalCode        - почтовый индекс владельца анкеты (пользователя)
# 15  LastSeen          - дата последней активности пользователя

# %% [markdown]
# ### Общая информация

# %%
start_information(df)
# Out:
#                     Count     NA    Type  Unique  \
# Name
# DateCrawled        354369      0  object  271174
# Price              354369      0   int64    3731
# VehicleType        316879  37490  object       8
# RegistrationYear   354369      0   int64     151
# Gearbox            334536  19833  object       2
# Power              354369      0   int64     712
# Model              334664  19705  object     250
# Kilometer          354369      0   int64      13
# RegistrationMonth  354369      0   int64      13
# FuelType           321474  32895  object       7
# Brand              354369      0  object      40
# NotRepaired        283215  71154  object       2
# DateCreated        354369      0  object     109
# NumberOfPictures   354369      0   int64       1
# PostalCode         354369      0   int64    8143
# LastSeen           354369      0  object  179150
#
#                                                               Sample   min  \
# Name
# ...

# %%
# Исходный размер таблицы:
original_shape = df.shape

# %% [markdown]
# ### Выводы

# %% [markdown]
# В таблице данных
# **`354369` строк и `16` колонок**
#
# ---
# ---
#
# **Группы данных по смыслу:**
#
# ---
# 1. данные о транспортном средстве:
#     - цена (евро) [Price]
#     - тип автомобильного кузова [VehicleType]
#     - год регистрации автомобиля [RegistrationYear]
#     - тип коробки передач [Gearbox]
#     - мощность (л. с.) [Power]
#     - модель автомобиля [Model]
#     - пробег (км) [Kilometer]
#     - месяц регистрации автомобиля [RegistrationMonth]
#     - тип топлива [FuelType]
#     - марка автомобиля [Brand]
#     - была машина в ремонте или нет [NotRepaired]
#
# ---
# 2. данные об анкете
#     - дата скачивания анкеты из базы [DateCrawled]
#     - дата создания анкеты [DateCreated]
#     - количество фотографий автомобиля [NumberOfPictures]
# ---
# 3. данные о владельце транспортного средства:
#     - почтовый индекс владельца анкеты (пользователя) [PostalCode]
#     - дата последней активности пользователя [LastSeen]
#
# ---
# ---
#
# **СТРУКТУРА ДАННЫХ:**
#
# 1. Необходимо перевести названия колонок к змеиному регистру
# 1. Проверить данные на явные дубликаты
#
#
# 3. В исходной таблице имеются **попуски** данных в  колонках:
#     - VehicleType (тип автомобильного кузова)
#     - Gearbox (тип коробки передач)
#     - Model (модель автомобиля)
#     - FuelType (тип топлива)
#     - NotRepaired (была машина в ремонте или нет)
#
#
# 4. По **`типам данных`** колонки можно ***разделить***:
#     - **Дата:**
#         - дата скачивания анкеты из базы [DateCrawled]
#         - год регистрации автомобиля [RegistrationYear]
#         - дата создания анкеты [DateCreated]
#         - месяц регистрации автомобиля [RegistrationMonth]
#         - дата последней активности пользователя [LastSeen]
#     - **Наименования (текстовые):**
#         - модель автомобиля [Model]
#         - марка автомобиля [Brand]
#     - **Наименования (численные):**
#         - почтовый индекс владельца анкеты (пользователя) [PostalCode]
#     - **Категории (текстовые):**
#         - тип автомобильного кузова [VehicleType]
#         - тип коробки передач [Gearbox]
#         - тип топлива [FuelType]
#     - **Численные:**
#         - цена (евро) [Price]
#         - мощность (л. с.) [Power]
#         - пробег (км) [Kilometer]
#         - количество фотографий автомобиля [NumberOfPictures]
#     - **Булевые:**
#         - была машина в ремонте или нет [NotRepaired]
#
#
# 5. По **`типам данных`** нужно ***исправить***:
#     - привести к ***датам***:
#         - дата скачивания анкеты из базы [DateCrawled]
#         - дата создания анкеты [DateCreated]
#         - дата последней активности пользователя [LastSeen]
#     - привести к ***числовому типу (int)***:
#         - была машина в ремонте или нет [NotRepaired]
#
#
# 6. Возможное разделение на категории:
#     - Год регистрации автомобиля (по десятилетиям)
#
#
# 7. Смыслове (логические) взаимосвязи:
#     - дата создания анкеты < дата скачивания анкеты из базы
#     - дата создания анкеты < дата последней активности пользователя
#     - дата регистрации автомобиля < дата создания анкеты
#
#
# 8. Признак **`количество фотографий автомобиля [NumberOfPictures]`** имеет только одно значение и поэтому не может влиять на предказания целевого признака. Можно его отбросить.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Создадим предобработанный набор данных:

# %%
df_prep = df.copy()

# %% [markdown]
# **На следующищ этапах формируется набор `df_prep`**

# %% [markdown]
# Сохраним оригинальный набор исходных данных (не будем проводить какие-либо изменения в нем).

# %% [markdown]
# ### Исправление заголовков

# %% [markdown]
# Приведем названия заголовков к земиному регистру

# %%
df_prep.columns = [camel_to_snake(val) for val in df_prep.columns]

# %% [markdown]
# Проверим

# %%
print(*df_prep.columns, sep='\n')
# Out:
# date_crawled
# price
# vehicle_type
# registration_year
# gearbox
# power
# model
# kilometer
# registration_month
# fuel_type
# brand
# not_repaired
# date_created
# number_of_pictures
# postal_code
# last_seen

# %% [markdown]
# Перепишем ключи в словаре описания данных

# %%
description = dict(zip(df_prep.columns, description.values()))

# %%
print_description(df_prep)
# Out:
# 0   date_crawled       - дата скачивания анкеты из базы
# 1   price              - цена (евро)
# 2   vehicle_type       - тип автомобильного кузова
# 3   registration_year  - год регистрации автомобиля
# 4   gearbox            - тип коробки передач
# 5   power              - мощность (л. с.)
# 6   model              - модель автомобиля
# 7   kilometer          - пробег (км)
# 8   registration_month - месяц регистрации автомобиля
# 9   fuel_type          - тип топлива
# 10  brand              - марка автомобиля
# 11  not_repaired       - была машина в ремонте или нет
# 12  date_created       - дата создания анкеты
# 13  number_of_pictures - количество фотографий автомобиля
# 14  postal_code        - почтовый индекс владельца анкеты (пользователя)
# 15  last_seen          - дата последней активности пользователя

# %% [markdown]
# ### Проверка на явные дубликаты

# %%
df_prep.duplicated().sum()
# Out:
# 4

# %% [markdown]
# Удалим явные дубликаты:

# %%
df_prep = df_prep.drop_duplicates()

# %% [markdown]
# **Вывод:**
#
# Явные дубликаты удалены

# %% [markdown]
# ### Проверка пропусков

# %%
na_columns = na_info(df_prep,  level=0.02)
# Out:
#   Нет пропусков:
# <style type="text/css">
# </style>
# <table id="T_c28ed_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >na</th>
#       <th class="col_heading level0 col2" >fraction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c28ed_level0_row0" class="row_heading level0 row0" >date_crawled</th>
#       <td id="T_c28ed_row0_col0" class="data row0 col0" >354365</td>
#       <td id="T_c28ed_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_c28ed_row0_col2" class="data row0 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_c28ed_level0_row1" class="row_heading level0 row1" >price</th>
#       <td id="T_c28ed_row1_col0" class="data row1 col0" >354365</td>
#       <td id="T_c28ed_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_c28ed_row1_col2" class="data row1 col2" >0.00%</td>
#     </tr>
#     <tr>
# ...

# %%
na_columns
# Out:
# {'delete': [],
#  'process': ['vehicle_type', 'gearbox', 'model', 'fuel_type', 'not_repaired']}

# %% [markdown]
# **Выводы, решения:**
#
# 1. `vehicle_type`, `gearbox`, `model`, `fuel_type` относятся текстовым категориальным данным. Заменим пропуски по ним на значение `unknown`.
# 1. По булевому признаку `not_repaired` также можно произвести замену пропусков на `unknown`. Тогда это будет категориальный признак.
#
# *Таким образом будут сохранены данные и размечены данные с пропусками, поскольку непосредственно пропуски тоже могут нести какую-либо информацию*

# %% [markdown]
# Проверим не занято ли значение `unknown` по признакам с пропусками:

# %%
pd.DataFrame((df_prep[na_columns['process']] == "unknown").sum(), columns=['Кол-во значений "unknown"'])
# Out:
#               Кол-во значений "unknown"
# vehicle_type                          0
# gearbox                               0
# model                                 0
# fuel_type                             0
# not_repaired                          0

# %% [markdown]
# Заменим пропуски:

# %%
df_prep = df_prep.fillna('unknown')

# %% [markdown]
# **Вывод:**
#
# 1. Пропуски сохранены.
# 1. Все пропуски заменены на значение **`unknown`**
# 1. Объем данных без изменений.
# 1. Признак `not_repaired` становится категориальным типом

# %%
del na_columns

# %% [markdown]
# ### Замена типов данных

# %% [markdown]
# #### Была машина в ремонте или нет (NotRepaired)

# %% [markdown]
# Ввиду имеющихся пропусков и замены их на значение `unknown` оставим этот признак категориальным с типом **`object`**.

# %% [markdown]
# #### Признаки даты в фомате даты (DateCrawled, DateCreated, LastSeen)

# %%
df_prep[['date_crawled', 'date_created', 'last_seen']].head()
# Out:
#           date_crawled         date_created            last_seen
# 0  2016-03-24 11:52:17  2016-03-24 00:00:00  2016-04-07 03:16:57
# 1  2016-03-24 10:58:45  2016-03-24 00:00:00  2016-04-07 01:46:50
# 2  2016-03-14 12:52:21  2016-03-14 00:00:00  2016-04-05 12:47:46
# 3  2016-03-17 16:54:04  2016-03-17 00:00:00  2016-03-17 17:40:17
# 4  2016-03-31 17:25:20  2016-03-31 00:00:00  2016-04-06 10:17:21

# %% [markdown]
# Преобразуем признаки в формате дата-время к соовтетствующему типу:

# %%
for col in ['date_crawled', 'date_created', 'last_seen']:
    df_prep[col] = pd.to_datetime(df_prep[col], format='%Y-%m-%d %H:%M:%S')

# %% [markdown]
# #### Почтовый индекс владельца анкеты (PostalCode)

# %% [markdown]
# Почтовый индекс имеет тип `int`, но на самом деле является категориальным и не может участвовать в вычислениях. Тме не менее оставим его типом `int` в силу того, что он содержит более 1000 уникальных значений и при перекодировании обратно из категориального в числовой (методом ohe) очень сильно размножится и в значительной мере повлияет на скрость работы модели.

# %% [markdown]
# #### Перепроверим типы данных

# %%
df_prep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 354365 entries, 0 to 354368
# Data columns (total 16 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   date_crawled        354365 non-null  datetime64[ns]
#  1   price               354365 non-null  int64
#  2   vehicle_type        354365 non-null  object
#  3   registration_year   354365 non-null  int64
#  4   gearbox             354365 non-null  object
#  5   power               354365 non-null  int64
#  6   model               354365 non-null  object
#  7   kilometer           354365 non-null  int64
#  8   registration_month  354365 non-null  int64
#  9   fuel_type           354365 non-null  object
#  10  brand               354365 non-null  object
#  11  not_repaired        354365 non-null  object
#  12  date_created        354365 non-null  datetime64[ns]
#  13  number_of_pictures  354365 non-null  int64
#  14  postal_code         354365 non-null  int64
# ...

# %% [markdown]
# **Вывод:**
#
# 1. Признаки `DateCrawled, DateCreated, LastSeen` приведены к типу даты
# 1. Все параметры соответствуют своему типу данных:
# - **3** дата-время (*дата скачивания анкеты из базы, дата создания анкеты, дата последней активности пользователя*) имеют тип **`datetime`**
# - **6** текстовых и категориальных (*тип автомобильного кузова, тип коробки передач, модель автомобиля, тип топлива, марка автомобиля, была машина в ремонте или нет*) имеют тип **`object`**
# - **7** целочисленных (*цена, год регистрации автомобиля, мощность, пробег, месяц регистрации автомобиля, количество фотографий автомобиля, почтовый индекс владельца анкеты (пользователя)*) имеют тип **`int`**

# %%
df_prep.dtypes.value_counts()
# Out:
# int64             7
# object            6
# datetime64[ns]    3
# dtype: int64

# %% [markdown]
# ### Вывод по предобработке

# %% [markdown]
# 1. Заголовки таблицы переведены к змеиному регистру.
# 1. Выявлены явные дубликаты обхектов.
#     - Дубликаты удалены.
# 1. Выявлены пропуски в категориальных признаках (`'vehicle_type', 'gearbox', 'model', 'fuel_type', 'not_repaired'`).
#     - Все пропуски сохранены.
#     - Все пропуски заменены на значение `unknown`.
# 1. Заменены типы данных на `datetime` для признаков даты (`'date_crawled', 'date_created', 'last_seen'`).

# %%
show_remains(df_prep)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1fb48_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Строк</th>
#       <th class="col_heading level0 col1" >Столбцов</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1fb48_level0_row0" class="row_heading level0 row0" >остаток</th>
#       <td id="T_1fb48_row0_col0" class="data row0 col0" >100.0%</td>
#       <td id="T_1fb48_row0_col1" class="data row0 col1" >100.0%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Закончено формировнаие набора `df_prep`
#
# **На следующищ этапах формируется набор `df_clean`**

# %% [markdown]
# ## Анализ данных

# %%
df_clean = df_prep.copy()

# %%
# только для Jupyter на Яндексе (чтобы не зависал):
del df_prep

# %% [markdown]
# ### Проверка смысловых зависимостей

# %% [markdown]
# Проверим соовтествет ли последовательость дат:
# 1. дата создания анкеты < дата скачивания анкеты из базы
# 1. дата создания анкеты < дата последней активности пользователя
# 1. дата регистрации автомобиля < дата создания анкеты

# %% [markdown]
# *Взаимосвязь `даты последней активности` и `даты скачивания анкеты из базы` установить интуитивно сложно (заказчик не смог дать пояснений по данному вопросу)*

# %% [markdown]
# #### Условие 1:

# %%
print(f'Количество смысловых ошибок по дате скачивания анкеты из базы:', text.BOLD, text.BG_SILVER, 
      df_clean.shape[0] - (df_clean['date_created'] < df_clean['date_crawled']).sum(), text.END)
# Out:
# Количество смысловых ошибок по дате скачивания анкеты из базы:   0

# %% [markdown]
# #### Условие 2:

# %%
print(f'Количество смысловых ошибок по дате последней активности пользователя:', text.BOLD, text.BG_SILVER, 
      df_clean.shape[0] - (df_clean['date_created'] < df_clean['last_seen']).sum(), text.END)
# Out:
# Количество смысловых ошибок по дате последней активности пользователя:   0

# %% [markdown]
# #### Условие 3:

# %%
def check_registration_date(df):
    # Переведем даты создания анкеты в общее число месяцев, прошедших с 0 года:
    months_in_date_created = df['date_created'].dt.year * 12 + df['date_created'].dt.month
    
    # Переведем даты регистарции автомобиля в общее число месяцев, прошедших с 0 года:
    months_in_registration_date = df['registration_year'] * 12 + df['registration_month']
    
    # Дата регистрации автомобиля не должна быть после даты создания анкеты (т.е. число месяцев в дате создания анкеты должно быть больше числа месяцев в дате регистрации автомобиля):
    print(f'Количество смысловых ошибок по дате регистрации автомобиля:', text.BOLD, text.BG_SILVER, 
      (months_in_date_created < months_in_registration_date).sum(), text.END)

# %% [markdown]
# Дата регистрации автомобиля не должна быть после даты создания анкеты (т.е. число месяцев в дате создания анкеты должно быть больше числа месяцев в дате регистрации автомобиля):

# %%
check_registration_date(df_clean)
# Out:
# Количество смысловых ошибок по дате регистрации автомобиля:   19760

# %% [markdown]
# По условию 3 имеются притиворечия в данных.

# %% [markdown]
# Оставим только корректные данные:

# %%
correct_index = (df_clean['date_created'].dt.year * 12 + df_clean['date_created'].dt.month) > (df_clean['registration_year'] * 12 + df_clean['registration_month'])
df_clean = df_clean[correct_index]
del correct_index

# %% [markdown]
# Перепроверим:

# %%
check_registration_date(df_clean)
# Out:
# Количество смысловых ошибок по дате регистрации автомобиля:   0

# %% [markdown]
# **Вывод:**
#
# - Обнаружены противоречия в данных
# - Удалены смысловые ошибки по дате регистрации автомобиля

# %% [markdown]
# ### Проверка значений: ошибки, выбросы, дубликаты

# %% [markdown]
# Еще раз просмортим количество уникальных значений по столбцам:

# %%
pd.DataFrame({'type':df_clean.dtypes, 'n_unique': df_clean.nunique()})
# Out:
#                               type  n_unique
# date_crawled        datetime64[ns]    259675
# price                        int64      3684
# vehicle_type                object         9
# registration_year            int64       110
# gearbox                     object         3
# power                        int64       692
# model                       object       251
# kilometer                    int64        13
# registration_month           int64        13
# fuel_type                   object         8
# brand                       object        40
# not_repaired                object         3
# date_created        datetime64[ns]       108
# number_of_pictures           int64         1
# postal_code                  int64      8135
# last_seen           datetime64[ns]    170460

# %% [markdown]
# Признак **`количество фотографий автомобиля [NumberOfPictures]`** имеет только одно значение и поэтому не может влиять на предказания целевого признака. Можно его отбросить.

# %% [markdown]
# #### Дата-время

# %% [markdown]
# ##### Дата скачивания анкеты из базы [DateCrawled]

# %%
date_hist_describe(df_clean, 'date_crawled', bins=200, figsize=(15, 5))
# Out:
#  Общая информация по шкале дат:
# count                           333926
# mean     2016-03-21 12:47:22.517800448
# min                2016-03-05 14:06:22
# 25%      2016-03-13 11:38:14.249999872
# 50%         2016-03-21 17:49:04.500000
# 75%      2016-03-29 14:39:05.249999872
# max                2016-04-07 14:36:58
# Name: date_crawled, dtype: object

# %% [markdown]
# Рассмотрим отдельный гребень подробнее:

# %%
date_hist_describe(df_clean.query('date_crawled > "2016-03-21" and date_crawled < "2016-03-23"'), 'date_crawled', bins=300, figsize=(15, 5))
# Out:
#  Общая информация по шкале дат:
# count                            22801
# mean     2016-03-22 03:05:52.887724032
# min                2016-03-21 00:14:25
# 25%                2016-03-21 15:52:57
# 50%                2016-03-21 22:57:20
# 75%                2016-03-22 15:52:17
# max                2016-03-22 23:59:59
# Name: date_crawled, dtype: object

# %% [markdown]
# **Вывод:**
# - Диапазон значений приемлимый.
# - Наблюдаются "дневные" всплески активности скачивания (ночью меньше скачиваний)
# - Также прослеживается волнообразный характер активности скачивания от по часам (по какой-то причине останавливается скачивание в конце-начале часа)

# %% [markdown]
# ##### Дата создания анкеты [DateCreated]

# %%
date_hist_describe(df_clean, 'date_created', bins=200, figsize=(15, 5))
# Out:
#  Общая информация по шкале дат:
# count                           333926
# mean     2016-03-20 18:58:03.804195840
# min                2014-03-10 00:00:00
# 25%                2016-03-13 00:00:00
# 50%                2016-03-21 00:00:00
# 75%                2016-03-29 00:00:00
# max                2016-04-07 00:00:00
# Name: date_created, dtype: object

# %% [markdown]
# Проверим в диапазоне других признакв даты (т.е. с 2016-03-05)

# %%
date_hist_describe(df_clean.query('date_created >= "2016-03-05"'), 'date_created', bins=100, figsize=(15, 5))
# Out:
#  Общая информация по шкале дат:
# count                           332417
# mean     2016-03-20 21:41:10.779773440
# min                2016-03-05 00:00:00
# 25%                2016-03-13 00:00:00
# 50%                2016-03-21 00:00:00
# 75%                2016-03-29 00:00:00
# max                2016-04-07 00:00:00
# Name: date_created, dtype: object

# %% [markdown]
# Количество созданных анкет вне этого диапазона:

# %%
df_clean.query('date_created < "2016-03-05"')['date_created'].count()
# Out:
# 1509

# %% [markdown]
# **Вывод:**
# - Диапазон значений приемлимый.
# - 99,5% анкет было создано после 2016-03-05

# %% [markdown]
# ##### Дата последней активности пользователя [LastSeen]

# %%
date_hist_describe(df_clean, 'last_seen', bins=200, figsize=(15, 5))
# Out:
#  Общая информация по шкале дат:
# count                           333926
# mean     2016-03-30 01:38:35.541344256
# min                2016-03-05 14:15:08
# 25%      2016-03-23 08:15:19.249999872
# 50%         2016-04-03 19:15:34.500000
# 75%                2016-04-06 10:17:23
# max                2016-04-07 14:58:51
# Name: last_seen, dtype: object

# %% [markdown]
# **Вывод:**
# - Диапазон значений приемлимый.
# - Основная активность пользователей сосредоточена в последних двух днях выборки

# %% [markdown]
# #### Категории

# %%
def category_overview(df, col):
    print(f'Количество уникальных значений {text.BOLD}{text.BG_SILVER} {df[col].nunique()} {text.END} :')
    display(df[col].value_counts(dropna=False).sort_index())

# %% [markdown]
# ##### Модель автомобиля [Model]

# %%
category_overview(df_clean, 'model')
# Out:
# Количество уникальных значений  251  :
# 100                     409
# 145                      44
# 147                     520
# 156                     608
# 159                     206
# 1_reihe                1233
# 1er                    3387
# 200                      18
# 2_reihe                4634
# 300c                    140
# 3_reihe                3292
# 3er                   19029
# 4_reihe                 623
# 500                     901
# 5_reihe                 432
# 5er                    7677
# 601                     411
# 6_reihe                1226
# 6er                     154
# 7er                     971
# 80                     1537
# 850                     206
# 90                       96
# 900                     114
# 9000                     26
# 911                      82
# a1                      578
# a2                      349
# a3                     5612
# a4                     9622
# a5                      537
# ...

# %% [markdown]
# **Вывод:**
# - значений более 100
# - значения могет быть какими угодно
# - правльность названий оценить весьма затруднительно
#
# Примем все как есть.

# %% [markdown]
# ##### Марка автомобиля [Brand]

# %%
category_overview(df_clean, 'brand')
# Out:
# Количество уникальных значений  40  :
# alfa_romeo         2195
# audi              28095
# bmw               35423
# chevrolet          1684
# chrysler           1374
# citroen            4834
# dacia               866
# daewoo              499
# daihatsu            761
# fiat               8986
# ford              23702
# honda              2636
# hyundai            3405
# jaguar              500
# jeep                647
# kia                2325
# lada                213
# lancia              437
# land_rover          536
# mazda              5285
# mercedes_benz     30594
# mini               3070
# mitsubishi         2857
# nissan             4667
# opel              37122
# peugeot           10444
# porsche             744
# renault           16539
# rover               446
# saab                511
# seat               6384
# skoda              5295
# smart              4954
# sonstige_autos     3180
# subaru              727
# suzuki             2192
# ...

# %% [markdown]
# **Вывод:** значения приемлимы.

# %% [markdown]
# ##### Тип автомобильного кузова [VehicleType]

# %%
category_overview(df_clean, 'vehicle_type')
# Out:
# Количество уникальных значений  9  :
# bus            28769
# convertible    20200
# coupe          16150
# other           3285
# sedan          91434
# small          79775
# suv            11990
# unknown        17168
# wagon          65155
# Name: vehicle_type, dtype: int64

# %% [markdown]
# **Вывод:**
# - значения приемлимы
# - имеется значение `other`, которое присутствовало в исходных данных, и `unknown`, которое появилось вследствие замены пропусков. Оставим оба значения в знак особой отметки именно пропуска.

# %% [markdown]
# ##### Тип коробки передач [Gearbox]

# %%
category_overview(df_clean, 'gearbox')
# Out:
# Количество уникальных значений  3  :
# auto        63619
# manual     252864
# unknown     17443
# Name: gearbox, dtype: int64

# %% [markdown]
# **Вывод:** значения приемлимы.

# %% [markdown]
# ##### Тип топлива [FuelType]

# %%
category_overview(df_clean, 'fuel_type')
# Out:
# Количество уникальных значений  8  :
# cng            532
# electric        88
# gasoline     95489
# hybrid         220
# lpg           5101
# other          193
# petrol      207324
# unknown      24979
# Name: fuel_type, dtype: int64

# %% [markdown]
# **Вывод:**
# - значения приемлимы
# - имеется значение `other`, которое присутствовало в исходных данных, и `unknown`, которое появилось вследствие замены пропусков. Оставим оба значения в знак особой отметки именно пропуска.

# %% [markdown]
# ##### Была машина в ремонте или нет [NotRepaired]

# %%
category_overview(df_clean, 'not_repaired')
# Out:
# Количество уникальных значений  3  :
# no         237341
# unknown     62434
# yes         34151
# Name: not_repaired, dtype: int64

# %% [markdown]
# **Вывод:** значения приемлимы.

# %% [markdown]
# ##### Почтовый индекс владельца анкеты (пользователя) [PostalCode]

# %%
category_overview(df_clean, 'postal_code')
# Out:
# Количество уникальных значений  8135  :
# 1067     89
# 1068      1
# 1069     53
# 1097     27
# 1099     60
#          ..
# 99988     9
# 99991     2
# 99994     6
# 99996     3
# 99998    16
# Name: postal_code, Length: 8135, dtype: int64

# %% [markdown]
# **Вывод:** значения приемлимы.

# %% [markdown]
# #### Числовые

# %% [markdown]
# ##### Цена (евро) [Price]

# %%
hist_box_describe(df_clean, 'price', bins=200)

# %% [markdown]
# Поскольку настоящее исследование относится к постронению модели определения цены в сервисе по ***продаже*** автомобилей (а не бесплатной раздаче), то нужно будет предсказывать какую-либо цену **отличную от нуля**.
#
# Составители анкет могли указать по какой-либо причине цену `0`, но в поставленной задаче значения цены `0` недопустимы как в обучающей, так и в тестовой выборках.

# %% [markdown]
# Удалим нули по целевому признаку:

# %%
df_clean = df_clean.query('price > 0')

# %% [markdown]
# Перепроверим:

# %%
df_clean['price'].describe()
# Out:
# count    324196.000000
# mean       4642.237199
# std        4557.320542
# min           1.000000
# 25%        1200.000000
# 50%        2950.000000
# 75%        6700.000000
# max       20000.000000
# Name: price, dtype: float64

# %% [markdown]
# В данных присутствуют очень малые значения ненулевой цены. Оценим долю цен менее 200 евро:

# %%
print(f"Доля цен менее 200 евро: {len(df_clean.query('price < 200')) / df_clean.shape[0]:.2%}")
# Out:
# Доля цен менее 200 евро: 1.94%

# %% [markdown]
# Поскольку доля низких цен мала (и должная не сильно влиять на работу модели), то оставим эти значения для сохранения других данных и полного рапределения цен.

# %% [markdown]
# *Можно определить у заказчика нижнюю границу цены, приемлимую для его сервиса, и подстроить модель под более качественные ("адекватные") предсказания*

# %% [markdown]
# **Вывод:**
#
# - Значения цены `0` удалены
# - Низкие и высокие значения цен оставлены в силу их малого количества
# - Средняя цена (медиана) составляет **2950** евро.
# - Распределение Пуассона.

# %% [markdown]
# ##### Мощность (л. с.) [Power]

# %%
hist_box_describe(df_clean, 'power')

# %% [markdown]
# Имеются выбросы больших значений и значение `0`.
#
# Отбросим 0,1% выбросов сверху и знчание `0`:

# %%
df_clean = df_clean.query('power > 0 and power < power.quantile(0.999)')

# %% [markdown]
# Перепроверим

# %%
hist_box_describe(df_clean, 'power', bins=50)

# %% [markdown]
# Удаление 0,1% выбросов полностью ликвидирует аномальные значения

# %% [markdown]
# **Вывод:**
#
# - Значения мощности `0` удалены
# - Выбросы высоких значений удалены
# - Средняя мощность (медиана) составляет **110** л.с.
# - Распределение нормальное со смщением вправо.

# %% [markdown]
# ##### Пробег (км) [Kilometer]

# %%
hist_box_describe(df_clean, 'kilometer')

# %% [markdown]
# **Выводы:**
#
# - Диапазон значений приемлимый.
# - Диапазон значений определеяется не распределением, а набором заданных категорий округленных значений.

# %% [markdown]
# ##### Год регистрации автомобиля [RegistrationYear]

# %%
hist_box_describe(df_clean, 'registration_year')

# %% [markdown]
# Имеются выбросы малых значений.
#
# Отбросим 0,1% выбросов снизу:

# %%
df_clean = df_clean.query('registration_year > registration_year.quantile(0.001)')

# %% [markdown]
# Перепроверим

# %%
hist_box_describe(df_clean, 'registration_year')

# %% [markdown]
# Удаление 0,1% выбросов полностью ликвидирует аномальные значения

# %% [markdown]
# **Вывод:**
#
# - Выбросы низких значений удалены
# - Распределение нормальное со смщением слево.

# %% [markdown]
# ##### Месяц регистрации автомобиля [RegistrationMonth]

# %%
hist_box_describe(df_clean, 'registration_month')

# %% [markdown]
# **Выводы:**
#
# - Диапазон значений приемлимый.
# - Распределение равномерное (что допустимо).

# %% [markdown]
# ### Корреляция признаков

# %% [markdown]
# Проверим корреляцию признаков.
#
# Построим график heatmap.

# %%
# Корреляция признаков
def print_corr(df):
    sns.heatmap(df.corr())
    plt.title('Корреляция признаков', pad=15, fontsize= 14)
    plt.show()
    print(f'Максимальная выявленная корреляция: {text.BOLD}{text.BG_SILVER} {df.corr().replace(1, 0).abs().max().max():.3f} {text.END}')

# %%
print_corr(df_clean)
# Out:
# Максимальная выявленная корреляция:  0.535

# %% [markdown]
# **Выводы:**
#
# - Между собой признаки коррелируют слабо (num_of_pictures не рассматриваем, поскольку он не меняется)
# - Хорошая зависимость цены прослеживается от года регистрации автомобиля и мощности двигателя.

# %% [markdown]
# ### Отбор признаков

# %%
print_description(df_clean)
# Out:
# 0   date_crawled       - дата скачивания анкеты из базы
# 1   price              - цена (евро)
# 2   vehicle_type       - тип автомобильного кузова
# 3   registration_year  - год регистрации автомобиля
# 4   gearbox            - тип коробки передач
# 5   power              - мощность (л. с.)
# 6   model              - модель автомобиля
# 7   kilometer          - пробег (км)
# 8   registration_month - месяц регистрации автомобиля
# 9   fuel_type          - тип топлива
# 10  brand              - марка автомобиля
# 11  not_repaired       - была машина в ремонте или нет
# 12  date_created       - дата создания анкеты
# 13  number_of_pictures - количество фотографий автомобиля
# 14  postal_code        - почтовый индекс владельца анкеты (пользователя)
# 15  last_seen          - дата последней активности пользователя

# %% [markdown]
# - Уберем `number_of_pictures`, поскольку этот признак имеет одно значение и не влияет ни на что
# - Уберем признаки `date_crawled` и `last_seen`, поскольку они не влияют на формирование анкеты и соответственно на цену. А признак `date_created` оставим, поскольку момент создания анкеты может влиять на цену.
# - Остальные признаки оценим на модели

# %%
features = ['price', 'vehicle_type', 'registration_year', 'gearbox',
       'power', 'model', 'kilometer', 'registration_month', 'fuel_type',
       'brand', 'not_repaired', 'date_created', 'postal_code']

# %% [markdown]
# Выделим категориальные признаки для обработки данных:

# %%
categorical_features = ['vehicle_type', 'gearbox', 'model', 'fuel_type', 'brand', 'not_repaired']

# %%
def set_category_type(df, cat_features):
    df_cat = df.copy()
    df_cat[cat_features] = df_cat[cat_features].astype('category')
    return df_cat

# %%
df_clean_cat = set_category_type(df_clean, categorical_features)

# %%
df_clean_cat.dtypes
# Out:
# date_crawled          datetime64[ns]
# price                          int64
# vehicle_type                category
# registration_year              int64
# gearbox                     category
# power                          int64
# model                       category
# kilometer                      int64
# registration_month             int64
# fuel_type                   category
# brand                       category
# not_repaired                category
# date_created          datetime64[ns]
# number_of_pictures             int64
# postal_code                    int64
# last_seen             datetime64[ns]
# dtype: object

# %% [markdown]
# ### Вывод по анализу данных

# %% [markdown]
# 1. Выявлены противоречия дат регистрации автомобиля и даты создания анкеты
# 	- Все объекты со смысловыми ошибками удалены
# 2. Удалены обекты с целевым признаком цены 0 и менее
# 3. Все низкие цены больше 0 оставлены (Доля цен менее 200 евро: 1.94%)
# 4. Значения мощности двигателя 0 и менее удалены
# 5. Выбросы высоких значений мощности двигателя удалены (0,1%)
# 6. Выбросы низких значений года регистрации автомобиля удалены (0,1%)
# 7. Определен рабочий набор признаков:
#     - все признаки без `number_of_pictures`, `date_crawled` и `last_seen`

# %%
show_remains(df_clean)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c35ae_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Строк</th>
#       <th class="col_heading level0 col1" >Столбцов</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c35ae_level0_row0" class="row_heading level0 row0" >остаток</th>
#       <td id="T_c35ae_row0_col0" class="data row0 col0" >82.4%</td>
#       <td id="T_c35ae_row0_col1" class="data row0 col1" >100.0%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Функция подготовки данных

# %% [markdown]
# Создадим функцию подготовки основного набора признаков:
# - оставим только рабочие признаки
# - преобразуем дату создания анкеты в числовой тип - количество дней с 01.01.1970

# %%
def make_df_major(df, features):
    df_major = df[features]
    if 'date_created' in features:
        df_major['date_created'] = (df_major['date_created'] - pd.Timestamp('01-01-1970')).dt.days
    return df_major

# %% [markdown]
# ### Отделим тестовую часть

# %% [markdown]
# Предварительно определим тестовую выборку. Оставим ее для окончательной проверки.

# %% [markdown]
# #### Прямое кодирование

# %% [markdown]
# Применим технику прямого кодирования (One-Hot Encoding, OHE) для преобразования всех категориальных признаков в численные.

# %%
def get_research_test_m_ohe(df, features):
    df_major = make_df_major(df, features)
    df_major_ohe = pd.get_dummies(df_major, drop_first=True)
    
    # возвращаем df_research, df_test
    return research_test_split(df_major_ohe)

# %%
df_research_cl_ohe, df_test_cl_ohe = get_research_test_m_ohe(df_clean_cat, features)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c51f3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Выборка:</th>
#       <th class="col_heading level0 col1" >Количество значений:</th>
#       <th class="col_heading level0 col2" >Доля выборки:</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c51f3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c51f3_row0_col0" class="data row0 col0" >Исследовательская</td>
#       <td id="T_c51f3_row0_col1" class="data row0 col1" >233600</td>
#       <td id="T_c51f3_row0_col2" class="data row0 col2" >80.00%</td>
#     </tr>
#     <tr>
#       <th id="T_c51f3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c51f3_row1_col0" class="data row1 col0" >Тестовая</td>
#       <td id="T_c51f3_row1_col1" class="data row1 col1" >58400</td>
#       <td id="T_c51f3_row1_col2" class="data row1 col2" >20.00%</td>
#     </tr>
# ...

# %%
df_research_cl_ohe.head()
# Out:
#         price  registration_year  power  kilometer  registration_month  \
# 41940    1750               2002     95     100000                   4
# 170999   1300               2002     82     150000                  11
# 139345   1499               1997    170     150000                   9
# 43473    2300               2000     82     125000                   7
# 204026   1500               1966     70     150000                   3
#
#         date_created  postal_code  vehicle_type_convertible  \
# 41940          16885        76131                         0
# 170999         16876        28197                         0
# 139345         16895        79761                         0
# 43473          16880        21682                         0
# 204026         16874        58239                         0
#
#         vehicle_type_coupe  vehicle_type_other  ...  brand_smart  \
# 41940                    0                   0  ...            0
# ...

# %% [markdown]
# #### Порядковое кодирование

# %% [markdown]
# Применим технику порядкового кодирования (Ordinal Encoding, OE) для преобразования всех категориальных признаков в численные.

# %%
# на вход подается pandas.DataFrame с признаками которые нужно кодировать типа 'category'
def get_research_test_m_oe(df, features):
    df_major = make_df_major(df, features)
    cat_feat = df_major[make_column_selector(dtype_include='category')].columns
    
    # через ColumnTransformer получается array без подписей с перемешанными колонками, поэтому так удобнее:
    encoder = OrdinalEncoder()
    df_major_oe = df_major.copy().reset_index(drop=True)
    df_major_oe[cat_feat] = encoder.fit_transform(df_major[cat_feat])
    df_major_oe[cat_feat] = df_major_oe[cat_feat].astype('category')
    
    # возвращаем df_research, df_test
    return research_test_split(df_major_oe)

# %%
df_research_cl_oe, df_test_cl_oe = get_research_test_m_oe(df_clean_cat, features)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9a9fb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Выборка:</th>
#       <th class="col_heading level0 col1" >Количество значений:</th>
#       <th class="col_heading level0 col2" >Доля выборки:</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a9fb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9a9fb_row0_col0" class="data row0 col0" >Исследовательская</td>
#       <td id="T_9a9fb_row0_col1" class="data row0 col1" >233600</td>
#       <td id="T_9a9fb_row0_col2" class="data row0 col2" >80.00%</td>
#     </tr>
#     <tr>
#       <th id="T_9a9fb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9a9fb_row1_col0" class="data row1 col0" >Тестовая</td>
#       <td id="T_9a9fb_row1_col1" class="data row1 col1" >58400</td>
#       <td id="T_9a9fb_row1_col2" class="data row1 col2" >20.00%</td>
#     </tr>
# ...

# %%
df_research_cl_oe.head()
# Out:
#         price vehicle_type  registration_year gearbox  power  model  \
# 34411    1750          4.0               2002     1.0     95  149.0
# 140884   1300          5.0               2002     1.0     82  113.0
# 114866   1499          4.0               1997     0.0    170   15.0
# 35682    2300          5.0               2000     0.0     82   33.0
# 168080   1500          8.0               1966     1.0     70  166.0
#
#         kilometer  registration_month fuel_type brand not_repaired  \
# 34411      100000                   4       6.0  27.0          0.0
# 140884     150000                  11       6.0  12.0          0.0
# 114866     150000                   9       6.0   2.0          0.0
# 35682      125000                   7       6.0  20.0          0.0
# 168080     150000                   3       6.0  10.0          1.0
#
#         date_created  postal_code
# 34411          16885        76131
# 140884         16876        28197
# 114866         16895        79761
# ...

# %% [markdown]
# ## Исследование задачи

# %% [markdown]
# Выделим целевой признак и набор обучающих признаков из *исследовательского* набора данных

# %%
TARGET_COL
# Out:
# 'price'

# %%
X_c_m_ohe, y_c_ohe = xy_split(df_research_cl_ohe, TARGET_COL)

# %%
X_c_m_oe, y_c_oe = xy_split(df_research_cl_oe, TARGET_COL)

# %%
X_c_m_ohe.head()
# Out:
#         registration_year  power  kilometer  registration_month  date_created  \
# 41940                2002     95     100000                   4         16885
# 170999               2002     82     150000                  11         16876
# 139345               1997    170     150000                   9         16895
# 43473                2000     82     125000                   7         16880
# 204026               1966     70     150000                   3         16874
#
#         postal_code  vehicle_type_convertible  vehicle_type_coupe  \
# 41940         76131                         0                   0
# 170999        28197                         0                   0
# 139345        79761                         0                   0
# 43473         21682                         0                   0
# 204026        58239                         0                   0
#
#         vehicle_type_other  vehicle_type_sedan  ...  brand_smart  \
# ...

# %%
X_c_m_oe.head()
# Out:
#        vehicle_type  registration_year gearbox  power  model  kilometer  \
# 34411           4.0               2002     1.0     95  149.0     100000
# 140884          5.0               2002     1.0     82  113.0     150000
# 114866          4.0               1997     0.0    170   15.0     150000
# 35682           5.0               2000     0.0     82   33.0     125000
# 168080          8.0               1966     1.0     70  166.0     150000
#
#         registration_month fuel_type brand not_repaired  date_created  \
# 34411                    4       6.0  27.0          0.0         16885
# 140884                  11       6.0  12.0          0.0         16876
# 114866                   9       6.0   2.0          0.0         16895
# 35682                    7       6.0  20.0          0.0         16880
# 168080                   3       6.0  10.0          1.0         16874
#
#         postal_code
# 34411         76131
# 140884        28197
# 114866        79761
# 35682         21682
# ...

# %%
y_c_ohe.head()
# Out:
# 41940     1750
# 170999    1300
# 139345    1499
# 43473     2300
# 204026    1500
# Name: price, dtype: int64

# %%
y_c_oe.head()
# Out:
# 34411     1750
# 140884    1300
# 114866    1499
# 35682     2300
# 168080    1500
# Name: price, dtype: int64

# %%
X_c_m_oe.dtypes
# Out:
# vehicle_type          category
# registration_year        int64
# gearbox               category
# power                    int64
# model                 category
# kilometer                int64
# registration_month       int64
# fuel_type             category
# brand                 category
# not_repaired          category
# date_created             int64
# postal_code              int64
# dtype: object

# %% [markdown]
# Установим искомую метрику

# %%
scoring = 'neg_root_mean_squared_error'
metric = 'rmse'

# %%
# только для Jupyter на Яндексе (чтобы не зависал):
del df_research_cl_ohe
del df_research_cl_oe

# %% [markdown]
# ### Подбор базовой модели

# %% [markdown]
# Подготовим для оценки Линейную регрессию с маштабированием и регуляризацией:

# %%
ct_scaling_only = ColumnTransformer([
        ('scale', RobustScaler(), make_column_selector(dtype_include=np.number))
    ],
    remainder="passthrough"
)

# %%
linear_pipe_base = Pipeline([
                ("ct", ct_scaling_only),
                ("model", Lasso(random_state=123))
            ])

# %% [markdown]
# Оценим работу базовых моделей:

# %%
results = []

# %%
# %%time
results.append(
    cross_val_base('DecisionTreeRegressor',
                   DecisionTreeRegressor(random_state=123),
                   X_c_m_oe, y_c_oe,
                   scoring,
                   print_res=False)
)
# Out:
# Wall time: 5.2 s

# %%
# %%time
results.append(
    cross_val_base('RandomForestRegressor',
                   RandomForestRegressor(n_estimators=10, random_state=123, n_jobs=-1),
                   X_c_m_oe, y_c_oe,
                   scoring,
                   print_res=False)
)
# Out:
# Wall time: 7.23 s

# %%
# %%time
results.append(
    cross_val_base('LinearRegression',
                   LinearRegression(n_jobs=-1),
                   X_c_m_ohe, y_c_ohe,
                   scoring,
                   print_res=False)
)
# results.append(['LinearRegression (платф.Яндекса)', -2532.193886, 109.826712])
# Out:
# Wall time: 16.1 s

# %%
# %%time
results.append(
    cross_val_base('Lasso_scaling',
                   linear_pipe_base,
                   X_c_m_ohe, y_c_ohe,
                   scoring,
                   print_res=False)
)
# results.append(['Lasso_scaling (платф.Яндекса)', -2564.274019, 295.204186])
# Out:
# Wall time: 38.4 s

# %%
# %%time
results.append(
    cross_val_base('LGBMRegressor',
                   LGBMRegressor(random_state=123, n_jobs=-1),
                   X_c_m_oe, y_c_oe,
                   scoring,
                   print_res=False)
)
# Out:
# Wall time: 2.48 s

# %% [markdown]
# Сводная таблица работы базовых моделей:

# %%
get_selection_model_results(results, score_name='RMSE_score')
# Out:
#                    Model   RMSE_score       Time  rating_score  rating_time  \
# 4          LGBMRegressor -1587.038699   2.477733         1.000       -0.000
# 1  RandomForestRegressor -1641.606328   7.225885         0.944       -0.132
# 0  DecisionTreeRegressor -2160.696950   5.198832         0.413       -0.076
# 2       LinearRegression -2532.193886  16.125292         0.033       -0.379
# 3          Lasso_scaling -2564.274019  38.445225         0.000       -1.000
#
#    rating_total
# 4         1.000
# 1         0.812
# 0         0.337
# 2        -0.346
# 3        -1.000

# %%
del results

# %% [markdown]
# Выберем для дальнейшего анализа 2 лучших (по метрике) модели:
# - Случайный лес (RandomForestRegressor)
# - Градиентный бустинг (LGBMRegressor)

# %% [markdown]
# **Отметим**, что лучший рейтинг получила модель **`Градиентного бустинга`** в силу быстрой работы и высокой метрики качества.

# %%
# только для Jupyter на Яндексе (чтобы не зависал):
del X_c_m_ohe
del y_c_ohe
del df_test_cl_ohe

# %% [markdown]
# ### Оценка признаков на базовой модели

# %%
# Оценка важности признаков
def get_important_columns(model, X, y, scoring, n_repeats=30, random_state=12345):
    model.fit(X, y)
    r = permutation_importance(model, X, y,
                               scoring = scoring,
                               n_repeats=n_repeats,
                               random_state=random_state)
    for i in r.importances_mean.argsort()[::-1]:
        if r.importances_mean[i] - 2 * r.importances_std[i] > 0:
            print(f"{X.columns[i]:<40}"
                  f"{r.importances_mean[i]:.6f}"
                  f" +/- {r.importances_std[i]:.6f}")
    return X.columns[r.importances_mean.argsort()[::-1]]

# %% [markdown]
# #### Случайный лес

# %% [markdown]
# Определим важность признаков на модели Случайного леса:

# %%
# %%time
pe_forest_columns = get_important_columns(
    RandomForestRegressor(n_estimators=10, random_state=123, n_jobs=-1),
    X_c_m_oe, y_c_oe, scoring,
    n_repeats=10
)
# Out:
# registration_year                       3732.913114 +/- 5.655671
# power                                   2869.609906 +/- 7.030788
# kilometer                               1124.013034 +/- 2.622187
# brand                                   1095.394064 +/- 4.092467
# vehicle_type                            903.380243 +/- 4.348711
# model                                   725.284884 +/- 3.266529
# not_repaired                            547.660532 +/- 2.231898
# postal_code                             496.510195 +/- 1.678985
# registration_month                      351.855975 +/- 1.672784
# date_created                            341.911321 +/- 1.162403
# fuel_type                               328.726450 +/- 1.956863
# gearbox                                 186.195992 +/- 1.077886
# Wall time: 20.6 s

# %% [markdown]
# Возьмем 10 признаков с лучшими коэффициентами важности и проверим работу модели на "урезанном" наборе признаков:

# %%
print(*pe_forest_columns[:10], sep='\n')
# Out:
# registration_year
# power
# kilometer
# brand
# vehicle_type
# model
# not_repaired
# postal_code
# registration_month
# date_created

# %%
# %%time
cross_val_base(
    model_name = 'RandomForestRegressor',
    model = RandomForestRegressor(n_estimators=10, random_state=123, n_jobs=-1),
    X = X_c_m_oe[pe_forest_columns[:10]],
    y = y_c_oe,
    scoring = scoring
)
# Out:
# Среднее значение метрики neg_root_mean_squared_error для базовой модели RandomForestRegressor:
#  neg_root_mean_squared_error = -1652.24
# ----------------------------------------------------------------------------------------------------
# Wall time: 6.08 s

# %% [markdown]
# **Вывод:**
#
# 1. Наименьшую значимость для Случайного леса можно имеют признаки:
# - gearbox
# - fuel_type
#
# 2. На уменьшенном наборе признаков метрика качества RMSE на Случайном лесе ниже, чем на полном наборе признаков.
# 3. На уменьшенном наборе признаков модель работает быстрее

# %% [markdown]
# #### Градиентный бустинг

# %% [markdown]
# Определим важность признаков на модели Градиентного бустинга:

# %%
# %%time
pe_booster_columns = get_important_columns(
    LGBMRegressor(random_state=123, n_jobs=-1),
    X_c_m_oe, y_c_oe, scoring,
    n_repeats=10
)
# Out:
# registration_year                       2768.798997 +/- 4.062354
# power                                   1404.191811 +/- 3.903277
# model                                   503.348222 +/- 2.235000
# kilometer                               464.026073 +/- 1.162220
# vehicle_type                            215.462609 +/- 1.452651
# brand                                   171.069778 +/- 1.893274
# not_repaired                            169.706358 +/- 1.749327
# fuel_type                               35.701628 +/- 0.634557
# postal_code                             25.984110 +/- 0.378611
# gearbox                                 22.024767 +/- 0.381410
# registration_month                      11.988253 +/- 0.363642
# date_created                            8.284177 +/- 0.208044
# Wall time: 25.1 s

# %% [markdown]
# Возьмем 10 признаков с лучшими коэффициентами важности и проверим работу модели на "урезанном" наборе признаков:

# %%
print(*pe_booster_columns[:10], sep='\n')
# Out:
# registration_year
# power
# model
# kilometer
# vehicle_type
# brand
# not_repaired
# fuel_type
# postal_code
# gearbox

# %%
# %%time
cross_val_base('LGBMRegressor',
               LGBMRegressor(random_state=123, n_jobs=-1),
               X_c_m_oe[pe_booster_columns[:10]], y_c_oe,
               scoring,
               print_res=True)
# Out:
# Среднее значение метрики neg_root_mean_squared_error для базовой модели LGBMRegressor:
#  neg_root_mean_squared_error = -1584.30
# ----------------------------------------------------------------------------------------------------
# Wall time: 2.27 s

# %% [markdown]
# **Вывод:**
#
# 1. Наименьшую значимость для Градиентного бустинга можно имеют признаки:
# - date_created
# - registration_month
#
# 2. На уменьшенном наборе признаков метрика качества RMSE на Градиентного бустинга чуть лучше в сравнении с полным набором признаков.
# 3. На уменьшенном наборе признаков модель работает медленее (?). *Ососбенность платформы Яндекса? На локальной машине модель на уменьшенном наборе признаков отрабатывает быстрее.*

# %% [markdown]
# ### Переподготовка данных (переоценка признаков)

# %% [markdown]
# Изменим набор значимых признаков в соответсвии с определением важности признаков (для Градиентного бустинга).
#
# Удалим наименее значимые признаки: `registration_month` и `date_created`.

# %%
features_important_lgbm = features.copy()
features_important_lgbm.remove('registration_month')
features_important_lgbm.remove('date_created')

# %%
features_important_lgbm
# Out:
# ['price',
#  'vehicle_type',
#  'registration_year',
#  'gearbox',
#  'power',
#  'model',
#  'kilometer',
#  'fuel_type',
#  'brand',
#  'not_repaired',
#  'postal_code']

# %% [markdown]
# Заново произведем подготовку данных и выделим целевой признак и набор обучающих признаков из *исследовательского* набора данных

# %%
df_research_cl_oe_lite, df_test_cl_oe_lite = get_research_test_m_oe(df_clean_cat, features_important_lgbm)
# Out:
# <style type="text/css">
# </style>
# <table id="T_43d90_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Выборка:</th>
#       <th class="col_heading level0 col1" >Количество значений:</th>
#       <th class="col_heading level0 col2" >Доля выборки:</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_43d90_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_43d90_row0_col0" class="data row0 col0" >Исследовательская</td>
#       <td id="T_43d90_row0_col1" class="data row0 col1" >233600</td>
#       <td id="T_43d90_row0_col2" class="data row0 col2" >80.00%</td>
#     </tr>
#     <tr>
#       <th id="T_43d90_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_43d90_row1_col0" class="data row1 col0" >Тестовая</td>
#       <td id="T_43d90_row1_col1" class="data row1 col1" >58400</td>
#       <td id="T_43d90_row1_col2" class="data row1 col2" >20.00%</td>
#     </tr>
# ...

# %%
X_c_m_oe_lite, y_c_oe_lite = xy_split(df_research_cl_oe_lite, TARGET_COL)

# %%
X_c_m_oe_lite.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 233600 entries, 34411 to 217570
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   vehicle_type       233600 non-null  category
#  1   registration_year  233600 non-null  int64
#  2   gearbox            233600 non-null  category
#  3   power              233600 non-null  int64
#  4   model              233600 non-null  category
#  5   kilometer          233600 non-null  int64
#  6   fuel_type          233600 non-null  category
#  7   brand              233600 non-null  category
#  8   not_repaired       233600 non-null  category
#  9   postal_code        233600 non-null  int64
# dtypes: category(6), int64(4)
# memory usage: 10.5 MB

# %%
# только для Jupyter на Яндексе (чтобы не зависал):
del df_research_cl_oe_lite
del df_clean

# %% [markdown]
# ### Подбор гиперпараметров

# %% [markdown]
# #### Случайный лес

# %% [markdown]
# Для случайного леса можно подобрать следующие гиперапараметры:
# - max_depth
# - n_estimators
# - min_samples_leaf
# - min_samples_split
#
# Для данного набора данных увеличение гиперпараметра `n_estimators` дает непрерывное увеличение метрики качества и нет локального максимума. При этом все более увеличивается время вычислений.
#
# Определим характер зависимости качество/вермя при изменении гиперапараметра `n_estimators` для оценки оптимального значения.

# %% [markdown]
# *Здесь по-хорошему при первичном анализе берется более широкий диапазон, но в силу ограниченности вычислительной мощности сократим его до минимально необходимого для презентации сути процесса (на локальной машине проанализирован более широкий диапазон)*

# %%
models_n_estimators = {}
for n in range(10, 61, 10):
    models_n_estimators['n_estimators='+str(n)] = RandomForestRegressor(n_estimators=n, random_state=123, n_jobs=-1)

# %%
results = []

# %%
# %%time
for model_name, model in models_n_estimators.items():
    results.append(
        cross_val_base(model_name,
                       model,
                       X_c_m_oe, y_c_oe,
                       scoring,
                       print_res=False)
    )
# Out:
# Wall time: 1min 46s

# %%
valuation_n_estimators = get_selection_model_results(results, score_name='RMSE_score')

# %%
del results

# %%
valuation_n_estimators.sort_values('rating_total', ascending=False)
# Out:
#              Model   RMSE_score       Time  rating_score  rating_time  \
# 2  n_estimators=30 -1580.729223  15.739712         0.821       -0.433
# 1  n_estimators=20 -1597.791826  10.999574         0.591       -0.211
# 3  n_estimators=40 -1573.983809  20.410748         0.912       -0.651
# 4  n_estimators=50 -1569.932792  24.702257         0.967       -0.851
# 5  n_estimators=60 -1567.450695  27.890016         1.000       -1.000
# 0  n_estimators=10 -1641.606328   6.469759         0.000       -0.000
#
#    rating_total
# 2         0.388
# 1         0.380
# 3         0.261
# 4         0.116
# 5         0.000
# 0         0.000

# %%
valuation_n_estimators.plot(x='RMSE_score', y='Time', linewidth=3, color = 'darkcyan', figsize=(8, 8))
plt.grid(visible=True, axis='both')
plt.title('Зависимость время/качество модели Случайного леса\n(при линейном изменении гиперпараметра n_estimators)', pad=20, fontsize = 15)
plt.xlabel('Метрика качества (RMSE)', fontsize = 14)
plt.ylabel('Время валидации (сек)', fontsize = 14)
plt.plot()
# Out:
# []

# %% [markdown]
# По характеру напоминает степенную зависимость. Идеальная точка определяется приравниванием производной к единице.
#
# На взляд при значении мерики более -1580 скорость роста времени больше скорости роста качества. Примем метрику -1580 за максимальную из оптимальных и подберем соответствующие гиперапараметры:
# - `n_estimators` = **30**

# %%
# только для Jupyter на Яндексе (чтобы не зависал):
del models_n_estimators
del valuation_n_estimators

# %%
# %%time
# parameters = {
#     'min_samples_split': [2, 1],
#     'min_samples_leaf': [1, 1],
#     'max_depth': [5, 5],
#     }

# ascending_grid(X_c_m_oe_lite, y_c_oe_lite,
#                RandomForestRegressor,
#                parameters, scoring=scoring, plot=True, cv=5, n_estimators=30)

# Результат работы ячейки:
print('''
Wall time: 10min 49s

{'iterations': 360,
 'score': -1574.853893651321,
 'parameters': {'max_depth': 25,
  'min_samples_leaf': 2,
  'min_samples_split': 2,
  'n_estimators': 30}}
''')
# Out:
# Wall time: 10min 49s
#
# {'iterations': 360,
#  'score': -1574.853893651321,
#  'parameters': {'max_depth': 25,
#   'min_samples_leaf': 2,
#   'min_samples_split': 2,
#   'n_estimators': 30}}

# %% [markdown]
# Оптимальные гиперапараметры для модели Случайного леса:

# %%
best_forest = {'max_depth': 25, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 30}

# %% [markdown]
# #### Градиентный бустинг

# %% [markdown]
# Для градиентго бустинга можно подобрать следующие гиперапараметры:
# - max_depth
# - num_leaves
# - n_estimators
# - learning_rate
#
# Для данного набора данных увеличение гиперпараметров `max_depth`, или `n_estimators`, или `n_estimators` дает непрерывное увеличение метрики качества и нет локального максимума. При этом все более увеличивается время вычислений.
#
# Определим характер зависимости качество/вермя при комплексном изменении гиперапараметров `max_depth`, `n_estimators`, `n_estimators` для оценки оптимального значения.

# %% [markdown]
# *Здесь по-хорошему при первичном анализе берется более широкий диапазон, но в силу ограниченности вычислительной мощности сократим его до минимально необходимого для презентации сути процесса (на локальной машине проанализирован более широкий диапазон)*

# %%
models_booster = {}
for max_depth, num_leaves, n_estimators in product(range(15, 51, 10), range(30, 201, 50), range(100, 201, 50)):
    name = f'{max_depth} {num_leaves} {n_estimators}'
    params = {
        'n_estimators': n_estimators,
        'max_depth': max_depth,
        'num_leaves': num_leaves,
        'random_state': 123,
        'n_jobs': -1
    }
    models_booster[name] = params

# %%
results = []

# %%
# %%time
# for model_name, params in models_booster.items():
#     results.append(
#         cross_val_lgbm_rmse(model_name,
#                             params,
#                             X_c_m_oe_lite, y_c_oe_lite,
#                             categorical_features,
#                             print_res=False)
#     )

# # Результат работы ячейки:
# print('''
# CPU times: user 1h 8min 4s, sys: 28.2 s, total: 1h 8min 32s
# Wall time: 1h 9min 48s
# ''')

# results = [['15 30 100', -1584.567069, 41.391106],
#        ['15 30 150', -1564.471695, 68.291628],
#        ['15 30 200', -1554.22137, 66.79926],
#        ['15 80 100', -1540.397454, 60.309656],
#        ['15 80 150', -1526.083405, 71.300473],
#        ['15 80 200', -1517.853235, 95.997176],
#        ['15 130 100', -1521.949002, 74.101142],
#        ['15 130 150', -1510.377872, 91.098704],
#        ['15 130 200', -1505.290338, 122.501198],
#        ['15 180 100', -1512.628911, 98.694083],
#        ['15 180 150', -1502.655292, 114.808298],
#        ['15 180 200', -1497.126953, 144.500226],
#        ['25 30 100', -1584.515756, 42.38237],
#        ['25 30 150', -1564.767583, 49.009083],
#        ['25 30 200', -1553.796712, 67.706102],
#        ['25 80 100', -1539.267098, 52.694777],
#        ['25 80 150', -1524.718221, 78.49967],
#        ['25 80 200', -1517.171598, 96.402318],
#        ['25 130 100', -1521.304402, 67.102745],
#        ['25 130 150', -1509.328786, 98.402446],
#        ['25 130 200', -1503.174736, 126.193598],
#        ['25 180 100', -1510.705841, 86.1021],
#        ['25 180 150', -1499.963597, 118.29598],
#        ['25 180 200', -1493.765869, 157.702839],
#        ['35 30 100', -1584.515756, 38.299947],
#        ['35 30 150', -1564.767583, 55.497254],
#        ['35 30 200', -1553.796712, 62.495528],
#        ['35 80 100', -1539.267098, 59.102269],
#        ['35 80 150', -1524.718221, 79.083314],
#        ['35 80 200', -1517.171598, 90.618083],
#        ['35 130 100', -1521.478651, 72.997596],
#        ['35 130 150', -1509.338133, 98.69086],
#        ['35 130 200', -1503.043129, 116.003188],
#        ['35 180 100', -1510.316147, 98.206728],
#        ['35 180 150', -1500.745851, 120.091048],
#        ['35 180 200', -1495.435271, 160.013396],
#        ['45 30 100', -1584.515756, 36.896384],
#        ['45 30 150', -1564.767583, 55.196626],
#        ['45 30 200', -1553.796712, 63.80138],
#        ['45 80 100', -1539.267098, 58.403256],
#        ['45 80 150', -1524.718221, 75.398381],
#        ['45 80 200', -1517.171598, 104.405474],
#        ['45 130 100', -1521.478651, 73.983632],
#        ['45 130 150', -1509.338133, 102.61486],
#        ['45 130 200', -1503.043129, 121.697468],
#        ['45 180 100', -1510.316147, 84.900098],
#        ['45 180 150', -1500.745851, 117.996984],
#        ['45 180 200', -1495.377784, 151.690868]]

# %%
# %%time
for model_name, params in models_booster.items():
    results.append(
        cross_val_base(model_name,
                       LGBMRegressor(**params),
                       X_c_m_oe_lite, y_c_oe_lite,
                       scoring,
                       print_res=False)
    )
# Out:
# Wall time: 4min 40s

# %%
valuation_booster = get_selection_model_results(results, score_name='RMSE_score')

# %%
del results

# %%
valuation_booster
# Out:
#          Model   RMSE_score       Time  rating_score  rating_time  \
# 23  25 180 200 -1497.107762  11.070678         1.000       -0.996
# 35  35 180 200 -1498.967690  11.072681         0.979       -0.996
# 47  45 180 200 -1499.035479  11.069676         0.979       -0.996
# 11  15 180 200 -1499.419389  11.109098         0.974       -1.000
# 22  25 180 150 -1502.764559   8.724143         0.937       -0.734
# 46  45 180 150 -1504.042494   8.732155         0.923       -0.735
# 34  35 180 150 -1504.042494   8.779226         0.923       -0.740
# 10  15 180 150 -1504.957797   8.698103         0.913       -0.731
# 20  25 130 200 -1505.666147   8.809271         0.905       -0.743
# 8   15 130 200 -1506.085111   8.798255         0.900       -0.742
# 32  35 130 200 -1506.292851   8.666055         0.898       -0.727
# 44  45 130 200 -1506.292851   8.751184         0.898       -0.737
# 19  25 130 150 -1511.700913   7.013565         0.838       -0.543
# ...

# %%
valuation_booster.sort_values('rating_total', ascending=False)
# Out:
#          Model   RMSE_score       Time  rating_score  rating_time  \
# 18  25 130 100 -1523.351933   4.937438         0.709       -0.311
# 6   15 130 100 -1523.728407   4.938439         0.705       -0.311
# 4    15 80 150 -1524.289843   4.924418         0.699       -0.310
# 30  35 130 100 -1523.508944   5.033583         0.707       -0.322
# 16   25 80 150 -1525.083847   4.922415         0.690       -0.310
# 3    15 80 100 -1538.280514   3.631471         0.544       -0.166
# 28   35 80 150 -1525.083847   4.950458         0.690       -0.313
# 40   45 80 150 -1525.083847   4.964479         0.690       -0.314
# 42  45 130 100 -1523.508944   5.123719         0.707       -0.332
# 15   25 80 100 -1539.251856   3.626463         0.533       -0.165
# 39   45 80 100 -1539.251856   3.666523         0.533       -0.170
# 27   35 80 100 -1539.251856   3.676538         0.533       -0.171
# 45  45 180 100 -1513.875852   6.257427         0.814       -0.459
# ...

# %%
valuation_booster.plot(x='RMSE_score', y='Time', linewidth=3, color = 'darkcyan', figsize=(8, 8))
plt.grid(visible=True, axis='both')
plt.title('Зависимость время/качество модели Градиентного бустинга\n(при комплексном изменении нескольких гиперпараметров)', pad=20, fontsize = 15)
plt.xlabel('Метрика качетсва (RMSE)', fontsize = 14)
plt.ylabel('Время валидации (сек)', fontsize = 14)
plt.plot()
# Out:
# []

# %% [markdown]
# *(На локальной машине скорость рассчетов выше (время меньше) и график более сглаженный)*

# %% [markdown]
# По характеру напоминает степенную зависимость. Идеальная точка определяется приравниванием производной к единице.
#
# На взляд при значении мерики более -1510 скорость роста времени больше скорости роста качества. Примем метрику -1510 за максимальную из оптимальных и подберем соответствующие гиперапараметры:
# - `max_depth` = **45**
# - `num_leaves` = **180**
# - `n_estimators` = **100**
#
# *Оставил старые метрики, отобранные по lgbm.cv*

# %%
# только для Jupyter на Яндексе (чтобы не зависал):
del models_booster
del valuation_booster

# %% [markdown]
# Подберем `learning_rate`:

# %%
results = []

# %%
# %%time
parameters = {
    'learning_rate': [0.1, 0.1],
    }

best_booster = ascending_grid(X_c_m_oe_lite, y_c_oe_lite,
                              LGBMRegressor,
                              parameters, scoring=scoring, plot=True, cv=5,
                              **{'n_jobs': -1, 'max_depth': 45, 'num_leaves': 180, 'n_estimators': 100})['parameters']
# Out:
# 0.1 >>> {'learning_rate': 0.1} {'max_depth': 45, 'num_leaves': 180, 'n_estimators': 100} - -1513.8759
# 0.2 >>> {'learning_rate': 0.2} {'max_depth': 45, 'num_leaves': 180, 'n_estimators': 100} - -1513.7266
# 0.30000000000000004 >>> {'learning_rate': 0.30000000000000004} {'max_depth': 45, 'num_leaves': 180, 'n_estimators': 100} - -1529.7469
# 0.4 >>> {'learning_rate': 0.4} {'max_depth': 45, 'num_leaves': 180, 'n_estimators': 100} - -1553.3437
# 0.5 >>> {'learning_rate': 0.5} {'max_depth': 45, 'num_leaves': 180, 'n_estimators': 100} - -1580.1885
# 0.6 >>> {'learning_rate': 0.6} {'max_depth': 45, 'num_leaves': 180, 'n_estimators': 100} - -1607.8121
# ----------------------------------------------------------------------------------------------------
# Wall time: 33.6 s

# %% [markdown]
# Оптимальные гиперапараметры для модели Градиентного бустинга:

# %%
best_booster
# Out:
# {'learning_rate': 0.2, 'max_depth': 45, 'num_leaves': 180, 'n_estimators': 100}

# %% [markdown]
# ### Выбор лучшей модели

# %% [markdown]
# Сравним работу двух лучхих ранее отобранных моделей с подобранными оптимальными гиперпараметрами:

# %%
results = []

# %%
# %%time
results.append(
    cross_val_base('RandomForestRegressor',
                   RandomForestRegressor(**best_forest, random_state=123, n_jobs=-1),
                   X_c_m_oe, y_c_oe,
                   scoring,
                   print_res=False)
)
# Out:
# Wall time: 13.7 s

# %%
# %%time
results.append(
    cross_val_base('LGBMRegressor (full_df)',
                   LGBMRegressor(**best_booster, random_state=123, n_jobs=-1),
                   X_c_m_oe, y_c_oe,
                   scoring,
                   print_res=False)
)
# Out:
# Wall time: 5.93 s

# %%
# %%time
results.append(
    cross_val_base('LGBMRegressor (pe)',
                   LGBMRegressor(**best_booster, random_state=123, n_jobs=-1),
                   X_c_m_oe_lite, y_c_oe_lite,
                   scoring,
                   print_res=False)
)
# Out:
# Wall time: 5.72 s

# %%
get_selection_model_results(results, score_name='RMSE_score')
# Out:
#                      Model   RMSE_score       Time  rating_score  rating_time  \
# 2       LGBMRegressor (pe) -1513.726551   5.716611         1.000       -0.000
# 1  LGBMRegressor (full_df) -1515.104137   5.929933         0.979       -0.027
# 0    RandomForestRegressor -1579.924498  13.691626         0.000       -1.000
#
#    rating_total
# 2         1.000
# 1         0.952
# 0        -1.000

# %% [markdown]
# Модель Градиентного бустинга на отобранном наборе признаков дает лучшую метрику и работает в разы быстрее. Используем ее.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий от ревьюера v1</b>
#
# <b>Успех:</b> Увидеть выбор лучшей модели я не смог, но спасибо, что сделал возможность частично востановить ход исследования.
# </div>

# %%
# только для Jupyter на Яндексе (чтобы не зависал):
del X_c_m_oe
del y_c_oe
del df_test_cl_oe

# %% [markdown]
# ## Тестирование модели

# %% [markdown]
# ### Тестовые признаки

# %% [markdown]
# Выделим целевой признак и набор обучающих признаков из *тестового* набора данных

# %%
X_test, y_test = xy_split(df_test_cl_oe_lite, TARGET_COL)

# %%
# только для Jupyter на Яндексе (чтобы не зависал):
del df_test_cl_oe_lite

# %% [markdown]
# ### Обучение модели

# %% [markdown]
# Обучим лучшую подобранную модель:
#
# **Градиентный бустинг с гиперпараметрами:**
#
# - `max_depth` = **45**
# - `num_leaves` = **180**
# - `n_estimators` = **100**
# - `learning_rate` = **0.2**

# %%
model = LGBMRegressor(**best_booster, random_state=123, n_jobs=-1)
model.fit(X_c_m_oe_lite, y_c_oe_lite)
# Out:
# LGBMRegressor(learning_rate=0.2, max_depth=45, num_leaves=180, random_state=123)

# %%
X_c_m_oe_lite.dtypes
# Out:
# vehicle_type         category
# registration_year       int64
# gearbox              category
# power                   int64
# model                category
# kilometer               int64
# fuel_type            category
# brand                category
# not_repaired         category
# postal_code             int64
# dtype: object

# %% [markdown]
# ### Проверка модели

# %% [markdown]
# Получим предсказания для обучающй и валидной выборки:

# %%
predictions_train = model.predict(X_c_m_oe_lite)
predictions_test = model.predict(X_test)

# %%
def print_predictions_type1(pred, y):
    plt.figure(figsize=(8, 8))
    plt.grid(visible=True, axis='both')
    plt.plot(y, pred, 'x', alpha=0.2)
    plt.plot([0, y.max()], [0, pred.max()], linewidth=3, color = 'firebrick')
    plt.title('Соотношение значений предсказаний и истинных значений\nна тестовой выборке', pad=15, fontsize = 15)
    plt.xlabel("Истинные значения", fontsize = 14)
    plt.ylabel("Значения предсказаний", fontsize = 14)
    plt.plot()

# %%
print_predictions_type1(predictions_test, y_test)

# %%
def print_predictions_type2(pred, y):
    plt.figure(figsize=(8, 8))
    plt.grid(visible=True, axis='both')
    plt.plot(y, pred-y, 'x', alpha=0.2)
    plt.plot(np.zeros(y.max()), linewidth=3, color = 'firebrick')
    plt.title('Отклонения значений предсказаний от истинных значений\nна тестовой выборке', pad=15, fontsize = 15)
    plt.xlabel("Истинные значения", fontsize = 14)
    plt.ylabel("Отклонения предсказаний", fontsize = 14)
    plt.plot()

# %%
print_predictions_type2(predictions_test, y_test)

# %% [markdown]
# Получим значения метрики `rmse` для обучающй и валидной выборки.
#
# Также рассмотрим значение метрики `mae`.

# %%
# r2_train = r2_score(y_c_lite, predictions_train)
# r2_test = r2_score(y_test, predictions_test)
rmse_train = mean_squared_error(y_c_oe_lite, predictions_train, squared=False)
rmse_test = mean_squared_error(y_test, predictions_test, squared=False)

#mae_test = mean_absolute_error(y_test, predictions_test)

# %%
print('-'*TABLE_SIZE, '\n')
# print(f'Метрика R2 на обучающей выборке: {r2_train:.4f}\n')
# print(f'Метрика R2 на тестовой выборке: {text.BOLD}{text.BG_CYAN} {r2_test:.4f} {text.END}\n')
print(f'Метрика RMSE на обучающей выборке: {text.BOLD}{text.BG_CYAN} {rmse_train:.1f} {text.END}\n')
print(f'Метрика RMSE на тестовой выборке: {text.BOLD}{text.BG_CYAN} {rmse_test:.1f} {text.END}\n')
#print(f'Метрика MAE на тестовой выборке: {text.BOLD}{text.BG_CYAN} {mae_test:.1f} {text.END}\n')
print('-'*TABLE_SIZE, '\n')
# Out:
# ----------------------------------------------------------------------------------------------------
#
# Метрика RMSE на обучающей выборке:  1267.5
#
# Метрика RMSE на тестовой выборке:  1512.0
#
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Проверка модели на адекватность

# %% [markdown]
# Воспользуемся классом DummyClassifier для определения значения метрики RMSE модели на констатных средних значениях целевых признаков:

# %%
dummy_clf = DummyRegressor(strategy="mean")
dummy_clf.fit(X_c_m_oe_lite, y_c_oe_lite)
dummy_predictions = dummy_clf.predict(X_test)
dummy_score_r = mean_squared_error(y_test, dummy_predictions) ** 0.5
# dummy_score_a = mean_absolute_error(y_test, dummy_predictions)
print(f'Метрика RMSE для случайной модели: {dummy_score_r:.1f}')
# print(f'Метрика MAE для случайной модели: {dummy_score_a:.1f}')
# Out:
# Метрика RMSE для случайной модели: 4630.3

# %% [markdown]
# Метрика RMSE на константной модели также хуже, чем по предсказаниям модели, значит модель проходит проверку на адекватность.

# %%
# только для Jupyter на Яндексе (чтобы не зависал):
del dummy_clf
del X_c_m_oe_lite
del y_c_oe_lite
del X_test
del y_test

# %% [markdown]
# ## Рабочий код

# %% [markdown]
# Функции обработки:

# %%
def train_preparation(df_inp):
    df = df_inp.copy()
    # 0. признаки
    features = ['price', 'vehicle_type', 'registration_year', 'gearbox', 'power', 'model', 'kilometer', 'fuel_type', 'brand', 'not_repaired', 'postal_code']
    
    # 1. замена названий признаков
    df.columns = [camel_to_snake(val) for val in df.columns]
    # 2. удаление дубликатов
    df = df.drop_duplicates()
    
    # ОБРАБОТКА АНОМАЛИЙ:
    # 3. замена типов данных
    df['date_created'] = pd.to_datetime(df['date_created'], format='%Y-%m-%d %H:%M:%S')
    # 4. удаление противоречий в данных
    correct_index = (df['date_created'].dt.year * 12 + df['date_created'].dt.month) > (df['registration_year'] * 12 + df['registration_month'])
    df = df[correct_index]
    # 5. Удаление выбросов, ошибок
    df = df.query('price > 0')
    df = df.query('power > 0 and power < power.quantile(0.999)')
    df = df.query('registration_year > registration_year.quantile(0.001)')
    
    # 6. отбор рабочих признаков
    df = df[features]
    
    return xy_split(df, 'price')

# %%
def get_model(df_train):
    # 0. признаки
    cat_features = ['vehicle_type', 'gearbox', 'model', 'fuel_type', 'brand', 'not_repaired']
#     tr_columns = categorical_features + ['registration_year', 'power', 'kilometer', 'postal_code']
    
    # pipeline
    tr = ColumnTransformer([
                            ("oe", OrdinalEncoder(), [0, 2, 4, 6, 7, 8]),
                           ],
                            remainder="passthrough")
    pipe = Pipeline([("imputer", SimpleImputer(fill_value='unknown', strategy="constant")),
                     ("oe", tr),
                     ("model", LGBMRegressor(random_state=123, n_jobs=-1, learning_rate=0.2, max_depth=45, num_leaves=180, n_estimators=100)) 
                    ])
    
    # обработка данных:
    X_train, y_train = train_preparation(df_train)
#     pipe.fit(X_train, y_train, model__feature_name = tr_columns, model__categorical_feature=categorical_features)
    # Обучение pipeline
    pipe.fit(X_train, y_train, model__categorical_feature=range(len(cat_features)))
    
    return pipe

# %%
def get_predictions(df_inp, work_model):
    X_test = df_inp.copy()
    # 0. признаки
    features = ['vehicle_type', 'registration_year', 'gearbox', 'power', 'model', 'kilometer', 'fuel_type', 'brand', 'not_repaired', 'postal_code']

    # 1. замена названий признаков
    X_test.columns = [camel_to_snake(val) for val in X_test.columns]
    # 2. отбор рабочих признаков
    X_test = X_test[features]
    
    return work_model.predict(X_test)

# %% [markdown]
# Создадим наборы данных максимально приближенные к реальному использованию модели предсказаний. Т.е. предварительно необработанные.

# %% [markdown]
# **1. Разделим исходный (загруженный из файла) набор данных на обучающую и тестовую выборки**

# %%
df_train_life, df_test_life = research_test_split(df)
# Out:
# <style type="text/css">
# </style>
# <table id="T_be0c4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Выборка:</th>
#       <th class="col_heading level0 col1" >Количество значений:</th>
#       <th class="col_heading level0 col2" >Доля выборки:</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be0c4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_be0c4_row0_col0" class="data row0 col0" >Исследовательская</td>
#       <td id="T_be0c4_row0_col1" class="data row0 col1" >283495</td>
#       <td id="T_be0c4_row0_col2" class="data row0 col2" >80.00%</td>
#     </tr>
#     <tr>
#       <th id="T_be0c4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_be0c4_row1_col0" class="data row1 col0" >Тестовая</td>
#       <td id="T_be0c4_row1_col1" class="data row1 col1" >70874</td>
#       <td id="T_be0c4_row1_col2" class="data row1 col2" >20.00%</td>
#     </tr>
# ...

# %% [markdown]
# **2. Отделим целевой признак от тестовой выборки**

# %%
X_life, y_life = xy_split(df_test_life, 'Price')

# %% [markdown]
# **3. Создадим и обучим модель используя исходный набор данных и функции обработки**

# %%
time_start_learning = time.time()

# %%
work_model = get_model(df_train_life)

# %%
work_model
# Out:
# Pipeline(steps=[('imputer',
#                  SimpleImputer(fill_value='unknown', strategy='constant')),
#                 ('oe',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('oe', OrdinalEncoder(),
#                                                   [0, 2, 4, 6, 7, 8])])),
#                 ('model',
#                  LGBMRegressor(learning_rate=0.2, max_depth=45, num_leaves=180,
#                                random_state=123))])

# %%
print(f'Вермя обучения модели: {round(time.time() - time_start_learning, 3)} сек')
# Out:
# Вермя обучения модели: 2.407 сек

# %% [markdown]
# **4. Получим предсказания на входном наборе данных**

# %%
time_start_predictions = time.time()

# %%
predictions_life = get_predictions(X_life, work_model)

# %%
print(f'Вермя предсказания модели: {round(time.time() - time_start_predictions, 3)} сек')
# Out:
# Вермя предсказания модели: 0.196 сек

# %% [markdown]
# **Проверим метрики**

# %%
print('-'*TABLE_SIZE, '\n')
# print(f'Метрика R2: {text.BOLD}{text.BG_SILVER} {r2_score(y_life, predictions_life):.4f} {text.END}\n')
print(f'Метрика RMSE: {text.BOLD}{text.BG_SILVER} {mean_squared_error(y_life, predictions_life, squared=False):.1f} {text.END}\n')
# print(f'Метрика MAE: {text.BOLD}{text.BG_SILVER} {mean_absolute_error(y_life, predictions_life):.1f} {text.END}\n')
print('-'*TABLE_SIZE, '\n')
# Out:
# ----------------------------------------------------------------------------------------------------
#
# Метрика RMSE:  1790.0
#
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# Поскольку настоящее исследование относится к постронению модели определения цены в сервисе по ***продаже*** автомобилей (а не бесплатной раздаче), то нужно предсказывать какую-либо цену **отличную от нуля**.
#
# Составители анкет могли указать по какой-либо причине цену `0`, но в поставленной задаче значения цены `0` недопустимы как в обучающей, так и в тестовой выборках.

# %% [markdown]
# ***Исключим целевые признаки со значеним 0 для более адекватной оценки работы модели:***

# %%
y_life_correct = y_life[y_life > 0]
predictions_life_correct = predictions_life[y_life.reset_index(drop=True) > 0]

# %%
print('-'*TABLE_SIZE, '\n')
# print(f'Метрика R2: {text.BOLD}{text.BG_CYAN} {r2_score(y_life_correct, predictions_life_correct):.4f} {text.END}\n')
print(f'Метрика RMSE: {text.BOLD}{text.BG_CYAN} {mean_squared_error(y_life_correct, predictions_life_correct, squared=False):.1f} {text.END}\n')
# print(f'Метрика MAE: {text.BOLD}{text.BG_CYAN} {mean_absolute_error(y_life_correct, predictions_life_correct):.1f} {text.END}\n')
print('-'*TABLE_SIZE, '\n')
# Out:
# ----------------------------------------------------------------------------------------------------
#
# Метрика RMSE:  1695.5
#
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# Тестовые метрики в рабочем коде немного хуже, чем метрики в исследовательской части, поскольку в реальных данных не удалаются выбросы и ошибки, а делаются предсказания **по всем** объектам пришедшим на вход модели (что более приближенно к реальности). И нам важно сделать **наиболее адекватное** предсказание цены, а не угадать все значения (в том числе и некорректные). Поэтому в данном случае в качестве именно метрик работы модели нужно рассматривать метрики, полученные на этапе тестирвания в исследовательской части проекта.

# %% [markdown]
# **Вывод:**
#
# - Время обучения и время предказания низкие
# - Точность предсказания хорошая

# %% [markdown]
# Рассмортим вероятность получить отколение как в полученной метрике:

# %%
rmse = round(mean_squared_error(y_life_correct, predictions_life_correct, squared=False), -1)
data_dev = (predictions_life_correct - y_life_correct).abs()
probability = (data_dev < rmse).sum() / data_dev.count()
plt.figure(figsize=(15, 8))
plt.grid(visible=True, axis='both')
data_dev.hist(bins=1000)
plt.plot(np.concatenate((np.zeros(int(rmse)), [plt.ylim()[1]])), linewidth=3, color = 'firebrick', linestyle='--')
plt.title('Отклонения значений предсказаний от истинных значений\nна Градиентном бустинге на тестовой выборке', pad=15, fontsize = 15)
plt.xlabel("Значение отклонения", fontsize = 14)
plt.ylabel("Количество значений с соответствующим отклонением", fontsize = 14)
plt.text(plt.xlim()[1]*0.4, plt.ylim()[1]*0.8, f'Вероятность получить на единичном предсказании\nотклонение менее {rmse} - {probability:.2%}',
        rotation = 0,
        fontsize = 13,
        bbox = {'facecolor':'powderblue', 'pad': 13}
        )
plt.text(plt.xlim()[1]*0.4, plt.ylim()[1]*0.6, f'Вероятность получить на единичном предсказании\nотклонение более {rmse} - {1-probability:.2%}',
        rotation = 0,
        fontsize = 13,
        bbox = {'facecolor':'lightcoral', 'pad': 13}
        )
plt.plot()
# Out:
# []

# %% [markdown]
# Еще наблюдения:

# %%
data_reg = (predictions_life_correct - y_life_correct).abs() / y_life_correct

# %%
results = []
for reg in np.arange(0.1, 1.1, 0.1):
    results.append([f'{reg:.0%}', (data_reg > reg).sum() / data_reg.count()])
res = pd.DataFrame(results, columns=['error', 'probability'])

# %%
plt.figure(figsize=(8, 6))
plt.grid(visible=True, axis='both')
plt.plot(res['error'], res['probability'], linewidth=3, color = 'firebrick')
plt.title('Вероятности относительной ошибки предсказаний', pad=15, fontsize = 15)
plt.xlabel("Относительная ошибка", fontsize = 14)
plt.ylabel("Вероятность большей ошибки", fontsize = 14)
plt.plot()
print()
reg = 0.5
print(f'Вероятность получить на единичном предсказании отклонение более {reg:.1%} от истинного значения:{text.BOLD} {(data_reg > reg).sum() / data_reg.count():.2%} {text.END}')
# Out:
# Вероятность получить на единичном предсказании отклонение более 50.0% от истинного значения: 22.70%

# %% [markdown]
# ## Общие выводы

# %% [markdown]
# **1. Проанализированы и обработаны исторические данные по продаже автомобилей:**
# - В данных имеются пропуски категриальных значений, которые заменяются значением `unknown` в обучающей выборке
# - В данных выявлены противоречия по части объектов:
# 	- дата регистрации автомобиля старше даты создания анкеты (порядка 6% даных)
# - В данных имеются значения низких цен (далеких от реальности) и значения цен = 0
#     - нулевые значнеия цен удаляются из обучающей выборки
#     - *возможная более тонкая настройка диапазона цен*
# - В данных имеются низкие и высокие значения мощности двигателя (далекие от реальности)
#     - выбросы значнеий мощности двигателя удаляются из обучающей выборки
# - В данных имеются невероятные года регистрации автомобиля (начиная с 1000 года)
#     - выбросы значнеий года регистрации автомобиля удаляются из обучающей выборки
# - В наибольшей степени цена на автомобиль зависит от мощности двигателя и года регистрации автомобиля
# - Для обучения модели отобрано 10 наиболее важных признаков (не учитывая целевой):
# 	- 'vehicle_type', 'registration_year', 'gearbox', 'power', 'model', 'kilometer', 'fuel_type', 'brand', 'not_repaired', 'postal_code'
#
# **2. Пободрана модель предсказания цены автомобиля:**
#
# ***LGBMRegressor(learning_rate=0.1, max_depth=45, num_leaves=180, random_state=123)***
# - Модель градиентного бустинга имеет лучшие оптимальное соотношение скорости вычислений и точности предсказаний
# - Для модели градиентного бустинга подобраны гиперапараметры, создан рабочий код, проверена работоспособность на тестовой выборке
# - Качество предсказаний, выраженное в метрике MRSE, составило порядка 1500 евро
#
# **3. На реальных данных метрики численно могут оказаться хуже, чем в исследовательской части данного проекта (но на уровне метрики из "рабочего кода").**<br/>
#
# Это нормально, поскольку модель настраивается на предсказание более *адекватной* цены и может чаще ошибаться в предсказаниях некорректных и аномальных анкет.<br/>
# Можно дополнительно подстроить выборку *адекватного* дипазона цен для обучения модели и таким образом скорректировать *адекватный* диапазон предсказаний.

# %%
END_PROJECT = time.time()

# %%
full_time = END_PROJECT - START_PROJECT
hour = int(full_time / 3600)
print(f'Время вычисления проекта:\n{text.BOLD}{text.BG_CYAN} {hour} ч {time.localtime(full_time)[4]} мин {time.localtime(full_time)[5]} сек {text.END}')
# Out:
# Время вычисления проекта:
#  0 ч 9 мин 52 сек

# %% [markdown]
# ---
