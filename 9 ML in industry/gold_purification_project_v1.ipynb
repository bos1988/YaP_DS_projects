# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Цель-исследования" data-toc-modified-id="Цель-исследования-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Цель исследования</a></span></li><li><span><a href="#Условия-задачи" data-toc-modified-id="Условия-задачи-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Условия задачи</a></span></li><li><span><a href="#Исходные-данные" data-toc-modified-id="Исходные-данные-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исходные данные</a></span><ul class="toc-item"><li><span><a href="#Подключаемые-модули" data-toc-modified-id="Подключаемые-модули-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Подключаемые модули</a></span></li><li><span><a href="#Настройка-окружения" data-toc-modified-id="Настройка-окружения-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Настройка окружения</a></span></li><li><span><a href="#Общие-параметры" data-toc-modified-id="Общие-параметры-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Общие параметры</a></span></li><li><span><a href="#Общие-функции" data-toc-modified-id="Общие-функции-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Общие функции</a></span></li><li><span><a href="#Функции-машинного-обучения" data-toc-modified-id="Функции-машинного-обучения-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Функции машинного обучения</a></span></li></ul></li><li><span><a href="#Получение-данных" data-toc-modified-id="Получение-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Получение данных</a></span><ul class="toc-item"><li><span><a href="#Чтение-данных-из-файла" data-toc-modified-id="Чтение-данных-из-файла-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Чтение данных из файла</a></span></li><li><span><a href="#Общая-информация" data-toc-modified-id="Общая-информация-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Общая информация</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Исправление-заголовков" data-toc-modified-id="Исправление-заголовков-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Исправление заголовков</a></span></li><li><span><a href="#Проверка-на-явные-дубликаты" data-toc-modified-id="Проверка-на-явные-дубликаты-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Проверка на явные дубликаты</a></span></li><li><span><a href="#Проверка-пропусков" data-toc-modified-id="Проверка-пропусков-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Проверка пропусков</a></span><ul class="toc-item"><li><span><a href="#Удалим-пропуски-из-тестовой-выборки:" data-toc-modified-id="Удалим-пропуски-из-тестовой-выборки:-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>Удалим пропуски из тестовой выборки:</a></span></li><li><span><a href="#Обработаем-пропуски-из-обучающей-выборки:" data-toc-modified-id="Обработаем-пропуски-из-обучающей-выборки:-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>Обработаем пропуски из обучающей выборки:</a></span></li></ul></li><li><span><a href="#Замена-типов-данных" data-toc-modified-id="Замена-типов-данных-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Замена типов данных</a></span></li><li><span><a href="#Проверка-смысловых-зависимостей" data-toc-modified-id="Проверка-смысловых-зависимостей-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Проверка смысловых зависимостей</a></span></li><li><span><a href="#Проверка-значений:-ошибки,-выбросы,-дубликаты" data-toc-modified-id="Проверка-значений:-ошибки,-выбросы,-дубликаты-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Проверка значений: ошибки, выбросы, дубликаты</a></span><ul class="toc-item"><li><span><a href="#Объемы-воздуха-и-Уровень-жидкости:" data-toc-modified-id="Объемы-воздуха-и-Уровень-жидкости:-5.6.1"><span class="toc-item-num">5.6.1&nbsp;&nbsp;</span>Объемы воздуха и Уровень жидкости:</a></span></li><li><span><a href="#Размер-гранул-сырья:" data-toc-modified-id="Размер-гранул-сырья:-5.6.2"><span class="toc-item-num">5.6.2&nbsp;&nbsp;</span>Размер гранул сырья:</a></span></li><li><span><a href="#Скорость-подачи:" data-toc-modified-id="Скорость-подачи:-5.6.3"><span class="toc-item-num">5.6.3&nbsp;&nbsp;</span>Скорость подачи:</a></span></li><li><span><a href="#Исходное-сырье:" data-toc-modified-id="Исходное-сырье:-5.6.4"><span class="toc-item-num">5.6.4&nbsp;&nbsp;</span>Исходное сырье:</a></span></li><li><span><a href="#Депрессант-(силикат-натрия).:" data-toc-modified-id="Депрессант-(силикат-натрия).:-5.6.5"><span class="toc-item-num">5.6.5&nbsp;&nbsp;</span>Депрессант (силикат натрия).:</a></span></li><li><span><a href="#Ксантогенат-(промотер,-или-активатор-флотации):" data-toc-modified-id="Ксантогенат-(промотер,-или-активатор-флотации):-5.6.6"><span class="toc-item-num">5.6.6&nbsp;&nbsp;</span>Ксантогенат (промотер, или активатор флотации):</a></span></li><li><span><a href="#Сульфат-(сульфид-натрия):" data-toc-modified-id="Сульфат-(сульфид-натрия):-5.6.7"><span class="toc-item-num">5.6.7&nbsp;&nbsp;</span>Сульфат (сульфид натрия):</a></span></li><li><span><a href="#Целевые-признаки-(эффективность-обогащения):" data-toc-modified-id="Целевые-признаки-(эффективность-обогащения):-5.6.8"><span class="toc-item-num">5.6.8&nbsp;&nbsp;</span>Целевые признаки (эффективность обогащения):</a></span></li><li><span><a href="#Выводы:" data-toc-modified-id="Выводы:-5.6.9"><span class="toc-item-num">5.6.9&nbsp;&nbsp;</span>Выводы:</a></span></li><li><span><a href="#Проверка-исправление:" data-toc-modified-id="Проверка-исправление:-5.6.10"><span class="toc-item-num">5.6.10&nbsp;&nbsp;</span>Проверка-исправление:</a></span></li></ul></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки." data-toc-modified-id="Концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки.-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Концентрация металлов (Au, Ag, Pb) на различных этапах очистки.</a></span><ul class="toc-item"><li><span><a href="#Золото" data-toc-modified-id="Золото-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>Золото</a></span></li><li><span><a href="#Серебро" data-toc-modified-id="Серебро-6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span>Серебро</a></span></li><li><span><a href="#Свинец" data-toc-modified-id="Свинец-6.1.3"><span class="toc-item-num">6.1.3&nbsp;&nbsp;</span>Свинец</a></span></li></ul></li><li><span><a href="#Сравнение-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках." data-toc-modified-id="Сравнение-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках.-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Сравнение распределения размеров гранул сырья на обучающей и тестовой выборках.</a></span></li><li><span><a href="#Суммарная-концентрацию-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах." data-toc-modified-id="Суммарная-концентрацию-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах.-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Суммарная концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Новые-индексы" data-toc-modified-id="Новые-индексы-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Новые индексы</a></span></li><li><span><a href="#Упрощенная-выборка" data-toc-modified-id="Упрощенная-выборка-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Упрощенная выборка</a></span></li><li><span><a href="#Признаки" data-toc-modified-id="Признаки-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Признаки</a></span><ul class="toc-item"><li><span><a href="#Исходные-признаки" data-toc-modified-id="Исходные-признаки-7.3.1"><span class="toc-item-num">7.3.1&nbsp;&nbsp;</span>Исходные признаки</a></span></li><li><span><a href="#Предобработанные-признаки" data-toc-modified-id="Предобработанные-признаки-7.3.2"><span class="toc-item-num">7.3.2&nbsp;&nbsp;</span>Предобработанные признаки</a></span></li><li><span><a href="#Предобработанные-упрощенные-признаки" data-toc-modified-id="Предобработанные-упрощенные-признаки-7.3.3"><span class="toc-item-num">7.3.3&nbsp;&nbsp;</span>Предобработанные упрощенные признаки</a></span></li></ul></li><li><span><a href="#Целевой-признак" data-toc-modified-id="Целевой-признак-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Целевой признак</a></span><ul class="toc-item"><li><span><a href="#Исходный-целевой-признак" data-toc-modified-id="Исходный-целевой-признак-7.4.1"><span class="toc-item-num">7.4.1&nbsp;&nbsp;</span>Исходный целевой признак</a></span></li><li><span><a href="#Предобработанный-целевой-признак" data-toc-modified-id="Предобработанный-целевой-признак-7.4.2"><span class="toc-item-num">7.4.2&nbsp;&nbsp;</span>Предобработанный целевой признак</a></span></li></ul></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Функции-вычисления-метрик" data-toc-modified-id="Функции-вычисления-метрик-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Функции вычисления метрик</a></span></li><li><span><a href="#Подбор-базовой-модели" data-toc-modified-id="Подбор-базовой-модели-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Подбор базовой модели</a></span><ul class="toc-item"><li><span><a href="#ЛИНЕЙНАЯ-РЕГРЕССИЯ" data-toc-modified-id="ЛИНЕЙНАЯ-РЕГРЕССИЯ-8.2.1"><span class="toc-item-num">8.2.1&nbsp;&nbsp;</span>ЛИНЕЙНАЯ РЕГРЕССИЯ</a></span><ul class="toc-item"><li><span><a href="#Оригинальный-датасет" data-toc-modified-id="Оригинальный-датасет-8.2.1.1"><span class="toc-item-num">8.2.1.1&nbsp;&nbsp;</span>Оригинальный датасет</a></span></li><li><span><a href="#Предобработанный-датасет" data-toc-modified-id="Предобработанный-датасет-8.2.1.2"><span class="toc-item-num">8.2.1.2&nbsp;&nbsp;</span>Предобработанный датасет</a></span></li><li><span><a href="#Предобработанный-упрощенный-датасет" data-toc-modified-id="Предобработанный-упрощенный-датасет-8.2.1.3"><span class="toc-item-num">8.2.1.3&nbsp;&nbsp;</span>Предобработанный упрощенный датасет</a></span></li></ul></li><li><span><a href="#ДЕРЕВО-РЕШЕНИЙ" data-toc-modified-id="ДЕРЕВО-РЕШЕНИЙ-8.2.2"><span class="toc-item-num">8.2.2&nbsp;&nbsp;</span>ДЕРЕВО РЕШЕНИЙ</a></span><ul class="toc-item"><li><span><a href="#Оригинальный-датасет" data-toc-modified-id="Оригинальный-датасет-8.2.2.1"><span class="toc-item-num">8.2.2.1&nbsp;&nbsp;</span>Оригинальный датасет</a></span></li><li><span><a href="#Предобработанный-датасет" data-toc-modified-id="Предобработанный-датасет-8.2.2.2"><span class="toc-item-num">8.2.2.2&nbsp;&nbsp;</span>Предобработанный датасет</a></span></li><li><span><a href="#Предобработанный-упрощенный-датасет" data-toc-modified-id="Предобработанный-упрощенный-датасет-8.2.2.3"><span class="toc-item-num">8.2.2.3&nbsp;&nbsp;</span>Предобработанный упрощенный датасет</a></span></li></ul></li><li><span><a href="#СЛУЧАНЫЙ-ЛЕС" data-toc-modified-id="СЛУЧАНЫЙ-ЛЕС-8.2.3"><span class="toc-item-num">8.2.3&nbsp;&nbsp;</span>СЛУЧАНЫЙ ЛЕС</a></span><ul class="toc-item"><li><span><a href="#Оригинальный-датасет" data-toc-modified-id="Оригинальный-датасет-8.2.3.1"><span class="toc-item-num">8.2.3.1&nbsp;&nbsp;</span>Оригинальный датасет</a></span></li><li><span><a href="#Предобработанный-датасет" data-toc-modified-id="Предобработанный-датасет-8.2.3.2"><span class="toc-item-num">8.2.3.2&nbsp;&nbsp;</span>Предобработанный датасет</a></span></li><li><span><a href="#Предобработанный-упрощенный-датасет" data-toc-modified-id="Предобработанный-упрощенный-датасет-8.2.3.3"><span class="toc-item-num">8.2.3.3&nbsp;&nbsp;</span>Предобработанный упрощенный датасет</a></span></li></ul></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-8.2.4"><span class="toc-item-num">8.2.4&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Подбор-гиперпараметров" data-toc-modified-id="Подбор-гиперпараметров-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Подбор гиперпараметров</a></span><ul class="toc-item"><li><span><a href="#СЛУЧАНЫЙ-ЛЕС" data-toc-modified-id="СЛУЧАНЫЙ-ЛЕС-8.3.1"><span class="toc-item-num">8.3.1&nbsp;&nbsp;</span>СЛУЧАНЫЙ ЛЕС</a></span><ul class="toc-item"><li><span><a href="#Предобработанный-датасет" data-toc-modified-id="Предобработанный-датасет-8.3.1.1"><span class="toc-item-num">8.3.1.1&nbsp;&nbsp;</span>Предобработанный датасет</a></span></li><li><span><a href="#Предобработанный-упрощенный-датасет" data-toc-modified-id="Предобработанный-упрощенный-датасет-8.3.1.2"><span class="toc-item-num">8.3.1.2&nbsp;&nbsp;</span>Предобработанный упрощенный датасет</a></span></li></ul></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-8.3.2"><span class="toc-item-num">8.3.2&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Тестирование-модели" data-toc-modified-id="Тестирование-модели-8.4"><span class="toc-item-num">8.4&nbsp;&nbsp;</span>Тестирование модели</a></span></li><li><span><a href="#Проверка-модели-на-адекватность" data-toc-modified-id="Проверка-модели-на-адекватность-8.5"><span class="toc-item-num">8.5&nbsp;&nbsp;</span>Проверка модели на адекватность</a></span></li><li><span><a href="#Итоговое-sMAPE" data-toc-modified-id="Итоговое-sMAPE-8.6"><span class="toc-item-num">8.6&nbsp;&nbsp;</span>Итоговое sMAPE</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Выводы</a></span></li></ul></div>

# %% [markdown]
# # Исследование технологического процесса очистки золота

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.

# %% [markdown]
# ## Цель исследования

# %% [markdown]
# 1. Проанализировать этапы технологического процесса.
# 1. Разработать модель предсказания коэффициента восстановления золота из золотосодержащей руды.

# %% [markdown]
# ## Условия задачи

# %% [markdown]
# Для оценки правильности предсказаний использовать метрику качетсва sMAPE (англ. Symmetric Mean Absolute Percentage Error, «симметричное среднее абсолютное процентное отклонение»).

# %% [markdown]
# ## Исходные данные

# %% [markdown]
# ### Подключаемые модули

# %%
# Подключаемые модули:

# Основное
import pandas as pd
import numpy as np
from scipy import stats as st

# Гарфика
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import seaborn as sns

# sklearn
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import make_scorer

from sklearn.preprocessing import StandardScaler
from sklearn.dummy import DummyRegressor

# %% [markdown]
# ### Настройка окружения

# %%
pd.set_option('display.max_rows', 100)

# %% [markdown]
# ### Общие параметры

# %%
# ПАРАМЕТРЫ,, общие переменные
YANDEX_STORAGE = None
TABLE_SIZE = 100
R_STATE = np.random.RandomState(123)

# %% [markdown]
# ### Общие функции

# %% [markdown]
# Инструменты

# %%
# перевод из верблюжъего в змеиный регистр
def camel_to_snake(string, sep='_'):
    return ''.join([sep+c.lower() if c.isupper() else c for c in string]).lstrip(sep)

# формат текста для output
class text:
    END = '\x1b[0m'
    BOLD = '\x1b[1m'
    
    UNDERLINE = '\x1b[4m'
    
    NEGATIVE = '\x1b[7m'

    GREY = '\x1b[30m'
    RED = '\x1b[31m'
    GREEUN = '\x1b[32m'
    YELLOW = '\x1b[33m'
    BLUE = '\x1b[34m'
    PURPLE = '\x1b[35m'
    CYAN = '\x1b[36m'
    SILVER = '\x1b[37m'
    BLACK = '\x1b[39m'
    
    BG_GREY = '\x1b[40m'
    BG_RED = '\x1b[41m'
    BG_GREEUN = '\x1b[42m'
    BG_YELLOW = '\x1b[43m'
    BG_BLUE = '\x1b[44m'
    BG_PURPLE = '\x1b[45m'
    BG_CYAN = '\x1b[46m'
    BG_SILVER = '\x1b[47m'
    
    DARKGREY = '\x1b[90m'
    DARKRED = '\x1b[91m'
    DARKGREEUN = '\x1b[92m'
    DARKYELLOW = '\x1b[93m'
    DARKBLUE = '\x1b[94m'
    DARKPURPLE = '\x1b[95m'
    DARKCYAN = '\x1b[96m'
    DARKSILVER = '\x1b[97m'
    
    BG_DARKGREY = '\x1b[100m'
    BG_DARKRED = '\x1b[101m'
    BG_DARKGREEUN = '\x1b[102m'
    BG_DARKYELLOW = '\x1b[103m'
    BG_DARKBLUE = '\x1b[104m'
    BG_DARKPURPLE = '\x1b[105m'
    BG_DARKCYAN = '\x1b[106m'
    BG_DARKSILVER = '\x1b[107m'
    
    END_B = '\x1b[21m'
    END_U = '\x1b[24m'
    END_NEGATIVE = '\x1b[27m'
    END_C = '\x1b[39m'
    END_BG = '\x1b[49m'

# %% [markdown]
# Информирование:

# %%
# Вывод информации о всех таблицах:
def display_all(df, names, functions, divider=False):
    size = TABLE_SIZE
    for name in names:
        if divider:
            print('_'*size)
        table_name = ' ТАБЛИЦА ' + name + ' '
        print(text.BOLD, text.BG_SILVER, table_name + table_name.rjust(size-len(table_name)-2, '='), text.END)
        if type(functions) == str:
            display(eval(f"df['{name}'].{functions}"))
        else:
            for func in functions:
                print("\x1b[1m", end='')
                print('.'*size)
                print(func.rjust(size))
                print("\x1b[22m", end='')
                display(eval(f"df['{name}'].{func}"))
        print()

# %%
# проверка пропусков
def na_info(df, level=0.01):
    sum_table = df.isna().sum()
    na_table = df.count()
    res_table = pd.DataFrame([na_table, sum_table, sum_table / na_table]).T.rename(columns = {0: 'count', 1: 'na', 2: 'fraction'})
    
    # Нет пропусков
    print(text.BOLD, text.BG_SILVER, 'Нет пропусков:'.ljust(TABLE_SIZE, ' '), text.END)
    display(res_table.query('na == 0').style.format({'fraction': '{:.2%}'}))

    # Малая доля (на удаление)
    print(text.BOLD, text.BG_SILVER, 'Малая доля пропусков:'.ljust(TABLE_SIZE, ' '), text.END)
    small = res_table.query('fraction < @level and na > 0')
    display(small.style.format({'fraction': '{:.2%}'}))
    remains = df[res_table.query('fraction < @level and na > 0').index].dropna().shape[0] / df.shape[0]
    print(f'Оценка остатка (при удалении пропусков с малой долей): {text.BOLD}{text.BG_YELLOW} {remains:.3%} {text.END}')
    print()
    
    # Большая доля (на обработку)
    print(text.BOLD, text.BG_SILVER, 'Большая доля пропусков:'.ljust(TABLE_SIZE, ' '), text.END)
    big = res_table.query('fraction > @level')
    display(big.style.format({'fraction': '{:.2%}'}))
    
    return {'delete': list(small.index), 'process': list(big.index)}

# %%
# остаок таблицы:
def show_remain(data):
    display((get_shape(data) / origin_shape).style.format({'Число строк': '{:.1%}', 'Число столбцов': '{:.1%}'}))

# размер таблиц:
def get_shape(data):
    shape = {}
    for name in data.keys():
        shape[name] = data[name].shape
    shape = pd.DataFrame(shape).T.rename(columns={0:'Число строк', 1:'Число столбцов'})
    return shape

# %% [markdown]
# Презентации:

# %%
def double_hist_box_describe(data1, data2, xlabel, *,
                             label1='label1', label2='label2', subtitle='', ylabel=None,
                             bins=50, figsize=(10, 10), **kwargs):
    fig = plt.figure()
    
    # Разделение fig на зоны разных размеров:
    gs1 = GridSpec(8, 1, left=0.05, right=0.95, hspace=0.03)
    # (y, x) - размеры сетки (высота, ширина)
    # left - расположние левой границы всей сетки (топа margin)
    # right - расположние правой границы всей сетки (топа margin)
    # wspace, hspace - зазоры между графиками (вертикальный, горизонтальный)
    ax3 = fig.add_subplot(gs1[2:, :])
    ax1 = fig.add_subplot(gs1[:1, :], sharex=ax3) # (срез по Y, срез по X)
    ax2 = fig.add_subplot(gs1[1:2, :], sharex=ax3)
    
    
    # Построение графиков:
    color_1 = 'darkcyan'
    color_2 = 'darkorchid'
    data1.plot(ax=ax1, kind='box', vert=False, widths=0.8, color='black', **kwargs)
    data2.plot(ax=ax2, kind='box', vert=False, widths=0.8, color='black', **kwargs)
    #data1.plot(ax=ax2, kind='hist', grid=True, bins=bins, **kwargs)
    data1.plot(ax=ax3, kind='hist', bins=bins, histtype='step', linewidth=2, color=color_1, label=label1, **kwargs)
    data1.plot(ax=ax3, kind='hist', bins=bins, alpha=0.3, color=color_1, label='', **kwargs)
    data2.plot(ax=ax3, kind='hist', bins=bins, histtype='step', linewidth=2, color=color_2, label=label2, **kwargs)
    data2.plot(ax=ax3, kind='hist', bins=bins, alpha=0.3, color=color_2, label='', **kwargs)
    
    ax1.set_facecolor((0/255, 139/255, 139/255, 0.2))
    ax2.set_facecolor((153/255, 50/255, 204/255, 0.2))
    
    # Различные настройки графиков:
    fig.set_figwidth(figsize[0])
    fig.set_figheight(figsize[1])
    #fig.suptitle(f'Распределение показателя "{xlabel}"', fontsize = 16)
    
    ax1.xaxis.tick_top()
    ax3.minorticks_on()
    ax3.grid(which='major',
            color = 'darkgrey', 
            linewidth = 1.2)
    ax3.grid(which='minor', 
            color = 'darkgrey', 
            linestyle = ':')
    
    ax1.set_yticklabels([''])
    ax2.set_yticklabels([''])
    ax3.set_xlabel(xlabel, fontsize = 14)
    ax3.set_ylabel('Количество значений', fontsize = 14)
    ax1.tick_params(labelsize = 12)
    ax3.tick_params(labelsize = 12)
    ax1.set_title(f'Распределение показателя "{xlabel}"{subtitle}', pad=15, fontsize = 16)
    ax1.legend([label1], fontsize = 12, loc='upper right')
    ax2.legend([label2], fontsize = 12, loc='upper right')
    ax3.legend(fontsize = 14, loc='upper right')
    
    describe_data = pd.DataFrame(data1.describe()).join(pd.Series(data2.describe(), name='new'))
    describe_data = describe_data.rename(columns=dict(zip(describe_data.columns, [label1, label2]))).drop(['25%', '75%'])
    #display(describe_data)
    bit = 5 - len(str(round(data1.mean()//1)))
    x = ax3.get_xbound()
    y = ax3.get_ybound()
    ax3.set_ylim(y[0], y[1]*1.3)
    x_coord = x[0] + (x[1]-x[0])/figsize[0]*figsize[1]*0.03
    y_coord = y[1] - (y[1] - y[0])*0
    ax3.text(x_coord, y_coord, str(describe_data.round(bit)),
        rotation = 0,
        fontsize = figsize[1]*1.0,
        bbox = {'facecolor': (0.95, 0.95, 0.95, 0.9), 'boxstyle': 'round', 'pad': 0.6}
            )

# %%
def u_hist_box_describe(data, xlabel, *,
                         labeles=None, subtitle='', ylabel=None, describe=True,
                         bins=50, figsize=(10, 10), **kwargs):
    fig = plt.figure()
    
    count = len(data.columns)
    
    # Разделение fig на зоны разных размеров:
    gs1 = GridSpec(7+count, 1, left=0.05, right=0.95, hspace=0.03)
    # (y, x) - размеры сетки (высота, ширина)
    # left - расположние левой границы всей сетки (топа margin)
    # right - расположние правой границы всей сетки (топа margin)
    # wspace, hspace - зазоры между графиками (вертикальный, горизонтальный)
    ax=['']*(count+1)
    ax[count] = fig.add_subplot(gs1[count:, :])
    for i in range(count):
        ax[i] = fig.add_subplot(gs1[i:i+1, :], sharex=ax[-1])
    
    # Построение графиков:
    color = ['darkcyan', 'darkorchid', 'gold', 'firebrick', 'royalblue']
    color_back = [(0/255, 139/255, 139/255, 0.2),
                  (153/255, 50/255, 204/255, 0.2),
                  (255/255, 215/255, 0/255, 0.2),
                  (178/255, 34/255, 34/255, 0.2),
                  (65/255, 105/255, 225/255, 0.2)] # а больше пяти нецелесообразно, будет сливаться все
    i = 0
    for col in data.columns:
        data[col].plot(ax=ax[i], kind='box', vert=False, widths=0.8, color='black', **kwargs)
        data[col].plot(ax=ax[-1], kind='hist', bins=bins, histtype='step', linewidth=2, alpha=0.6+0.4/(count), color=color[i], **kwargs)
        data[col].plot(ax=ax[-1], kind='hist', bins=bins, alpha=1/2/count, color=color[i], label='', **kwargs)
        ax[i].set_facecolor(color_back[i])
        i += 1
    
    # Различные настройки графиков:
    fig.set_figwidth(figsize[0])
    fig.set_figheight(figsize[1])
    #fig.suptitle(f'Распределение показателя "{xlabel}"', fontsize = 16)
    
    ax[0].xaxis.tick_top()
    ax[-1].minorticks_on()
    ax[-1].grid(which='major',
            color = 'darkgrey', 
            linewidth = 1.2)
    ax[-1].grid(which='minor', 
            color = 'darkgrey', 
            linestyle = ':')
    
    for i in range(count):
        ax[i].xaxis.tick_top()
        ax[i].tick_params(labelsize = 6)
        ax[i].set_yticklabels([''])
        #ax[i].legend([label1], fontsize = 12, loc='upper right')
    ax[-1].set_xlabel(xlabel, fontsize = 14)
    ax[-1].set_ylabel('Количество значений', fontsize = 14)
    ax[0].tick_params(labelsize = 12)
    ax[-1].tick_params(labelsize = 12)
    ax[0].set_title(f'Распределение показателя "{xlabel}"{subtitle}', pad=15, fontsize = 16)
    ax[-1].legend(fontsize = 14, loc='upper right')
    
    if describe:
        describe_data = data.describe().drop(['25%', '75%'])
        #display(describe_data)
        bit = 5 - len(str(round(data.mean()[0]//1)))
        x = ax[-1].get_xbound()
        y = ax[-1].get_ybound()
        ax[-1].set_ylim(y[0], y[1]*1.3)
        x_coord = x[0] + (x[1]-x[0])/figsize[0]*figsize[1]*0.03
        y_coord = y[1] - (y[1] - y[0])*0
        ax[-1].text(x_coord, y_coord, str(describe_data.round(bit)),
            rotation = 0,
            fontsize = figsize[1]*1.0,
            bbox = {'facecolor': (0.95, 0.95, 0.95, 0.9), 'boxstyle': 'round', 'pad': 0.6}
                )

# %% [markdown]
# Работа с данными:

# %%
# выборка колонок по stage, param_type, param_name
# на входе: df и списки (в список можно отрывок названия)
def qdf(df, *args):
    args = list(args[:3])
    names = list(df.columns[1:])
    for i in range(len(args)):
        if type(args[i]) == str:
            args[i] = [args[i]]
        if args[i]:
            names = list(filter(
                    lambda x: any([s in x.split('.')[i] for s in args[i]]), names
                ))
    if not args or 'date' in args[0] or len(args[0]) == 0:
        names.append('date')
    
#     print(len(names))
#     print(*names, sep='\n')
    return df[names] if len(names) > 0 else None

# %%
# пример работы функции qdf()
# qdf(df['full'], ['sec', 'prim', 'date'], 'out', 'tail', 'sfdsfdf').sample().T

# %% [markdown]
# ### Функции машинного обучения

# %% [markdown]
# Поиск гиперпараметров (кросс-валидация)

# %%
# Рабочая версия
# Проходит не по всей сетке, а пока растет значение метрики (Бейесовская оптимизация).
# Если метрика не растет на протажении хвоста (max_tail) цикл заканчивается
# На вход подается Класс модели, исследуемые гиперапараметры в виде словаря
# Работает быстрее, чем GridSearchCV
def ascending_grid(df_features, df_target, func, parameters, scoring=None, plot=False, subtitle='', max_tail=None, cv=5, n_jobs=-1, **kwargs):
    #cv = 5 #при значении 5 результаты отличаются от результатов при значении > 10 ! но по умолчанию в cross_val_score стоит 5, поэтому оставим по умоланию 5
    steps = 100
    iterator = 0
    best_score = -1_000_000
    best_param = parameters
    tail = 0
    if max_tail == None:
        max_tail = 1 if 5 - len(parameters) < 1 else 5 - len(parameters)
    
    param = list(parameters.keys())[0]
    start = parameters[param][0]
    sep = parameters[param][1]
    
    if len(parameters) == 1:
        for p in range(start, start+steps*sep, sep):
            set_param = {param: p}
            model = func(random_state=123, n_jobs=n_jobs, **set_param, **kwargs)
            scores = cross_val_score(model, df_features, df_target, scoring=scoring, cv=cv)
            score = scores.mean()
            iterator += len(scores)
            if plot:
                print(f'{p} >>> {set_param} {kwargs} - {score:.4f}')

            if score > best_score:
                best_score = score
                set_param.update(kwargs)
                best_param = set_param
                tail = 0
            else:
                tail += 1
            if tail >= max_tail:
                break
    else:
        # рекурсия
        parameters_minus = parameters.copy()
        del parameters_minus[param]
        for p in range(start, start+steps*sep, sep):
            set_param = {param: p}
            result = ascending_grid(df_features, df_target, func, parameters_minus,
                                    scoring=scoring, plot=plot, subtitle=subtitle, max_tail=max_tail, cv=cv,
                                    **set_param, **kwargs)
            iterator += result['iterations']
            score = result['score']
            
            # Сокращение нижней границы поиска (предыдущее лучшее минус 2 промежутка)
            for key in result['parameters'].keys():
                try:
                    new_start = result['parameters'][key] - parameters_minus[key][1]*2
                    if parameters_minus[key][0] < new_start:
                        parameters_minus[key][0] = result['parameters'][key] - parameters_minus[key][1] * (max_tail + 1)
                except:
                    pass
            
            if score > best_score:
                best_score = score
                best_param = result['parameters']
                tail = 0
            else:
                tail += 1
            if tail >= max_tail:
                break
        
        if plot:
            print('best_score =', best_score)
            print('best_param =', best_param)
    if plot:
        print('-'*TABLE_SIZE)
    return ({'iterations': iterator, 'score':best_score, 'parameters':best_param})

# %% [markdown]
# ## Получение данных

# %% [markdown]
# ### Чтение данных из файла

# %% [markdown]
# Имена баз данных:

# %%
data_names = ['full', 'train', 'test']

# %% [markdown]
# Исходные файлы данных:

# %%
file = {}
for name in data_names:
    file[name] = f'gold_recovery_{name}_new.csv'

# %% [markdown]
# Загрузка данных для работы в pandas:

# %%
df = {}
for name in data_names:
    df[name] = pd.read_csv(f"{YANDEX_STORAGE}{file[name]}")

# %% [markdown]
# ### Общая информация

# %% [markdown]
# Общий обзор:

# %%
display_all(df, data_names, ['head()', 'info()'])
# Out:
#    ТАБЛИЦА full ====================================================================== ТАБЛИЦА full
# ....................................................................................................
#                                                                                               head()
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# 2                    42.657501              68.116445             10.507046
# 3                    42.689819              68.347543             10.422762
# 4                    42.774141              66.927016             10.360302
#
#    final.output.tail_pb  final.output.tail_sol  final.output.tail_au  ...  \
# 0              0.895447              16.904297              2.143149  ...
# 1              0.927452              16.634514              2.224930  ...
# 2              0.953716              16.208849              2.257889  ...
# 3              0.883763              16.532835              2.146849  ...
# 4              0.792826              16.525686              2.055292  ...
#
#    secondary_cleaner.state.floatbank4_a_air  \
# 0                                 14.016835
# 1                                 13.992281
# 2                                 14.015015
# 3                                 14.036510
# 4                                 14.027298
#
#    secondary_cleaner.state.floatbank4_a_level  \
# 0                                 -502.488007
# 1                                 -505.503262
# 2                                 -502.520901
# 3                                 -500.857308
# 4                                 -499.838632
#
#    secondary_cleaner.state.floatbank4_b_air  \
# 0                                 12.099931
# 1                                 11.950531
# 2                                 11.912783
# 3                                 11.999550
# 4                                 11.953070
#
#    secondary_cleaner.state.floatbank4_b_level  \
# 0                                 -504.715942
# 1                                 -501.331529
# 2                                 -501.133383
# 3                                 -501.193686
# 4                                 -501.053894
#
#    secondary_cleaner.state.floatbank5_a_air  \
# 0                                  9.925633
# 1                                 10.039245
# 2                                 10.070913
# 3                                  9.970366
# 4                                  9.925709
#
#    secondary_cleaner.state.floatbank5_a_level  \
# 0                                 -498.310211
# 1                                 -500.169983
# 2                                 -500.129135
# 3                                 -499.201640
# 4                                 -501.686727
#
#    secondary_cleaner.state.floatbank5_b_air  \
# 0                                  8.079666
# 1                                  7.984757
# 2                                  8.013877
# 3                                  7.977324
# 4                                  7.894242
#
#    secondary_cleaner.state.floatbank5_b_level  \
# 0                                 -500.470978
# 1                                 -500.582168
# 2                                 -500.517572
# 3                                 -500.255908
# 4                                 -500.356035
#
#    secondary_cleaner.state.floatbank6_a_air  \
# 0                                 14.151341
# 1                                 13.998353
# 2                                 14.028663
# 3                                 14.005551
# 4                                 13.996647
#
#    secondary_cleaner.state.floatbank6_a_level
# 0                                 -605.841980
# 1                                 -599.787184
# 2                                 -601.427363
# 3                                 -599.996129
# 4                                 -601.496691
#
# [5 rows x 87 columns]
# ....................................................................................................
#                                                                                               info()
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
# date                                                  19439 non-null object
# final.output.concentrate_ag                           19438 non-null float64
# final.output.concentrate_pb                           19438 non-null float64
# final.output.concentrate_sol                          19228 non-null float64
# final.output.concentrate_au                           19439 non-null float64
# final.output.recovery                                 19439 non-null float64
# final.output.tail_ag                                  19438 non-null float64
# final.output.tail_pb                                  19338 non-null float64
# final.output.tail_sol                                 19433 non-null float64
# final.output.tail_au                                  19439 non-null float64
# primary_cleaner.input.sulfate                         19415 non-null float64
# primary_cleaner.input.depressant                      19402 non-null float64
# primary_cleaner.input.feed_size                       19439 non-null float64
# primary_cleaner.input.xanthate                        19335 non-null float64
# primary_cleaner.output.concentrate_ag                 19439 non-null float64
# primary_cleaner.output.concentrate_pb                 19323 non-null float64
# primary_cleaner.output.concentrate_sol                19069 non-null float64
# primary_cleaner.output.concentrate_au                 19439 non-null float64
# primary_cleaner.output.tail_ag                        19435 non-null float64
# primary_cleaner.output.tail_pb                        19418 non-null float64
# primary_cleaner.output.tail_sol                       19377 non-null float64
# primary_cleaner.output.tail_au                        19439 non-null float64
# primary_cleaner.state.floatbank8_a_air                19435 non-null float64
# primary_cleaner.state.floatbank8_a_level              19438 non-null float64
# primary_cleaner.state.floatbank8_b_air                19435 non-null float64
# primary_cleaner.state.floatbank8_b_level              19438 non-null float64
# primary_cleaner.state.floatbank8_c_air                19437 non-null float64
# primary_cleaner.state.floatbank8_c_level              19438 non-null float64
# primary_cleaner.state.floatbank8_d_air                19436 non-null float64
# primary_cleaner.state.floatbank8_d_level              19438 non-null float64
# rougher.calculation.sulfate_to_au_concentrate         19437 non-null float64
# rougher.calculation.floatbank10_sulfate_to_au_feed    19437 non-null float64
# rougher.calculation.floatbank11_sulfate_to_au_feed    19437 non-null float64
# rougher.calculation.au_pb_ratio                       19439 non-null float64
# rougher.input.feed_ag                                 19439 non-null float64
# rougher.input.feed_pb                                 19339 non-null float64
# rougher.input.feed_rate                               19428 non-null float64
# rougher.input.feed_size                               19294 non-null float64
# rougher.input.feed_sol                                19340 non-null float64
# rougher.input.feed_au                                 19439 non-null float64
# rougher.input.floatbank10_sulfate                     19405 non-null float64
# rougher.input.floatbank10_xanthate                    19431 non-null float64
# rougher.input.floatbank11_sulfate                     19395 non-null float64
# rougher.input.floatbank11_xanthate                    18986 non-null float64
# rougher.output.concentrate_ag                         19439 non-null float64
# rougher.output.concentrate_pb                         19439 non-null float64
# rougher.output.concentrate_sol                        19416 non-null float64
# rougher.output.concentrate_au                         19439 non-null float64
# rougher.output.recovery                               19439 non-null float64
# rougher.output.tail_ag                                19438 non-null float64
# rougher.output.tail_pb                                19439 non-null float64
# rougher.output.tail_sol                               19439 non-null float64
# rougher.output.tail_au                                19439 non-null float64
# rougher.state.floatbank10_a_air                       19438 non-null float64
# rougher.state.floatbank10_a_level                     19438 non-null float64
# rougher.state.floatbank10_b_air                       19438 non-null float64
# rougher.state.floatbank10_b_level                     19438 non-null float64
# rougher.state.floatbank10_c_air                       19438 non-null float64
# rougher.state.floatbank10_c_level                     19438 non-null float64
# rougher.state.floatbank10_d_air                       19439 non-null float64
# rougher.state.floatbank10_d_level                     19439 non-null float64
# rougher.state.floatbank10_e_air                       19003 non-null float64
# rougher.state.floatbank10_e_level                     19439 non-null float64
# rougher.state.floatbank10_f_air                       19439 non-null float64
# rougher.state.floatbank10_f_level                     19439 non-null float64
# secondary_cleaner.output.tail_ag                      19437 non-null float64
# secondary_cleaner.output.tail_pb                      19427 non-null float64
# secondary_cleaner.output.tail_sol                     17691 non-null float64
# secondary_cleaner.output.tail_au                      19439 non-null float64
# secondary_cleaner.state.floatbank2_a_air              19219 non-null float64
# secondary_cleaner.state.floatbank2_a_level            19438 non-null float64
# secondary_cleaner.state.floatbank2_b_air              19416 non-null float64
# secondary_cleaner.state.floatbank2_b_level            19438 non-null float64
# secondary_cleaner.state.floatbank3_a_air              19426 non-null float64
# secondary_cleaner.state.floatbank3_a_level            19438 non-null float64
# secondary_cleaner.state.floatbank3_b_air              19438 non-null float64
# secondary_cleaner.state.floatbank3_b_level            19438 non-null float64
# secondary_cleaner.state.floatbank4_a_air              19433 non-null float64
# secondary_cleaner.state.floatbank4_a_level            19438 non-null float64
# secondary_cleaner.state.floatbank4_b_air              19438 non-null float64
# secondary_cleaner.state.floatbank4_b_level            19438 non-null float64
# secondary_cleaner.state.floatbank5_a_air              19438 non-null float64
# secondary_cleaner.state.floatbank5_a_level            19438 non-null float64
# secondary_cleaner.state.floatbank5_b_air              19438 non-null float64
# secondary_cleaner.state.floatbank5_b_level            19438 non-null float64
# secondary_cleaner.state.floatbank6_a_air              19437 non-null float64
# secondary_cleaner.state.floatbank6_a_level            19438 non-null float64
# dtypes: float64(86), object(1)
# memory usage: 12.9+ MB
# None
#    ТАБЛИЦА train ==================================================================== ТАБЛИЦА train
# ....................................................................................................
#                                                                                               head()
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# 2                    42.657501              68.116445             10.507046
# 3                    42.689819              68.347543             10.422762
# 4                    42.774141              66.927016             10.360302
#
#    final.output.tail_pb  final.output.tail_sol  final.output.tail_au  ...  \
# 0              0.895447              16.904297              2.143149  ...
# 1              0.927452              16.634514              2.224930  ...
# 2              0.953716              16.208849              2.257889  ...
# 3              0.883763              16.532835              2.146849  ...
# 4              0.792826              16.525686              2.055292  ...
#
#    secondary_cleaner.state.floatbank4_a_air  \
# 0                                 14.016835
# 1                                 13.992281
# 2                                 14.015015
# 3                                 14.036510
# 4                                 14.027298
#
#    secondary_cleaner.state.floatbank4_a_level  \
# 0                                 -502.488007
# 1                                 -505.503262
# 2                                 -502.520901
# 3                                 -500.857308
# 4                                 -499.838632
#
#    secondary_cleaner.state.floatbank4_b_air  \
# 0                                 12.099931
# 1                                 11.950531
# 2                                 11.912783
# 3                                 11.999550
# 4                                 11.953070
#
#    secondary_cleaner.state.floatbank4_b_level  \
# 0                                 -504.715942
# 1                                 -501.331529
# 2                                 -501.133383
# 3                                 -501.193686
# 4                                 -501.053894
#
#    secondary_cleaner.state.floatbank5_a_air  \
# 0                                  9.925633
# 1                                 10.039245
# 2                                 10.070913
# 3                                  9.970366
# 4                                  9.925709
#
#    secondary_cleaner.state.floatbank5_a_level  \
# 0                                 -498.310211
# 1                                 -500.169983
# 2                                 -500.129135
# 3                                 -499.201640
# 4                                 -501.686727
#
#    secondary_cleaner.state.floatbank5_b_air  \
# 0                                  8.079666
# 1                                  7.984757
# 2                                  8.013877
# 3                                  7.977324
# 4                                  7.894242
#
#    secondary_cleaner.state.floatbank5_b_level  \
# 0                                 -500.470978
# 1                                 -500.582168
# 2                                 -500.517572
# 3                                 -500.255908
# 4                                 -500.356035
#
#    secondary_cleaner.state.floatbank6_a_air  \
# 0                                 14.151341
# 1                                 13.998353
# 2                                 14.028663
# 3                                 14.005551
# 4                                 13.996647
#
#    secondary_cleaner.state.floatbank6_a_level
# 0                                 -605.841980
# 1                                 -599.787184
# 2                                 -601.427363
# 3                                 -599.996129
# 4                                 -601.496691
#
# [5 rows x 87 columns]
# ....................................................................................................
#                                                                                               info()
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 87 columns):
# date                                                  14149 non-null object
# final.output.concentrate_ag                           14148 non-null float64
# final.output.concentrate_pb                           14148 non-null float64
# final.output.concentrate_sol                          13938 non-null float64
# final.output.concentrate_au                           14149 non-null float64
# final.output.recovery                                 14149 non-null float64
# final.output.tail_ag                                  14149 non-null float64
# final.output.tail_pb                                  14049 non-null float64
# final.output.tail_sol                                 14144 non-null float64
# final.output.tail_au                                  14149 non-null float64
# primary_cleaner.input.sulfate                         14129 non-null float64
# primary_cleaner.input.depressant                      14117 non-null float64
# primary_cleaner.input.feed_size                       14149 non-null float64
# primary_cleaner.input.xanthate                        14049 non-null float64
# primary_cleaner.output.concentrate_ag                 14149 non-null float64
# primary_cleaner.output.concentrate_pb                 14063 non-null float64
# primary_cleaner.output.concentrate_sol                13863 non-null float64
# primary_cleaner.output.concentrate_au                 14149 non-null float64
# primary_cleaner.output.tail_ag                        14148 non-null float64
# primary_cleaner.output.tail_pb                        14134 non-null float64
# primary_cleaner.output.tail_sol                       14103 non-null float64
# primary_cleaner.output.tail_au                        14149 non-null float64
# primary_cleaner.state.floatbank8_a_air                14145 non-null float64
# primary_cleaner.state.floatbank8_a_level              14148 non-null float64
# primary_cleaner.state.floatbank8_b_air                14145 non-null float64
# primary_cleaner.state.floatbank8_b_level              14148 non-null float64
# primary_cleaner.state.floatbank8_c_air                14147 non-null float64
# primary_cleaner.state.floatbank8_c_level              14148 non-null float64
# primary_cleaner.state.floatbank8_d_air                14146 non-null float64
# primary_cleaner.state.floatbank8_d_level              14148 non-null float64
# rougher.calculation.sulfate_to_au_concentrate         14148 non-null float64
# rougher.calculation.floatbank10_sulfate_to_au_feed    14148 non-null float64
# rougher.calculation.floatbank11_sulfate_to_au_feed    14148 non-null float64
# rougher.calculation.au_pb_ratio                       14149 non-null float64
# rougher.input.feed_ag                                 14149 non-null float64
# rougher.input.feed_pb                                 14049 non-null float64
# rougher.input.feed_rate                               14141 non-null float64
# rougher.input.feed_size                               14005 non-null float64
# rougher.input.feed_sol                                14071 non-null float64
# rougher.input.feed_au                                 14149 non-null float64
# rougher.input.floatbank10_sulfate                     14120 non-null float64
# rougher.input.floatbank10_xanthate                    14141 non-null float64
# rougher.input.floatbank11_sulfate                     14113 non-null float64
# rougher.input.floatbank11_xanthate                    13721 non-null float64
# rougher.output.concentrate_ag                         14149 non-null float64
# rougher.output.concentrate_pb                         14149 non-null float64
# rougher.output.concentrate_sol                        14127 non-null float64
# rougher.output.concentrate_au                         14149 non-null float64
# rougher.output.recovery                               14149 non-null float64
# rougher.output.tail_ag                                14148 non-null float64
# rougher.output.tail_pb                                14149 non-null float64
# rougher.output.tail_sol                               14149 non-null float64
# rougher.output.tail_au                                14149 non-null float64
# rougher.state.floatbank10_a_air                       14148 non-null float64
# rougher.state.floatbank10_a_level                     14148 non-null float64
# rougher.state.floatbank10_b_air                       14148 non-null float64
# rougher.state.floatbank10_b_level                     14148 non-null float64
# rougher.state.floatbank10_c_air                       14148 non-null float64
# rougher.state.floatbank10_c_level                     14148 non-null float64
# rougher.state.floatbank10_d_air                       14149 non-null float64
# rougher.state.floatbank10_d_level                     14149 non-null float64
# rougher.state.floatbank10_e_air                       13713 non-null float64
# rougher.state.floatbank10_e_level                     14149 non-null float64
# rougher.state.floatbank10_f_air                       14149 non-null float64
# rougher.state.floatbank10_f_level                     14149 non-null float64
# secondary_cleaner.output.tail_ag                      14147 non-null float64
# secondary_cleaner.output.tail_pb                      14139 non-null float64
# secondary_cleaner.output.tail_sol                     12544 non-null float64
# secondary_cleaner.output.tail_au                      14149 non-null float64
# secondary_cleaner.state.floatbank2_a_air              13932 non-null float64
# secondary_cleaner.state.floatbank2_a_level            14148 non-null float64
# secondary_cleaner.state.floatbank2_b_air              14128 non-null float64
# secondary_cleaner.state.floatbank2_b_level            14148 non-null float64
# secondary_cleaner.state.floatbank3_a_air              14145 non-null float64
# secondary_cleaner.state.floatbank3_a_level            14148 non-null float64
# secondary_cleaner.state.floatbank3_b_air              14148 non-null float64
# secondary_cleaner.state.floatbank3_b_level            14148 non-null float64
# secondary_cleaner.state.floatbank4_a_air              14143 non-null float64
# secondary_cleaner.state.floatbank4_a_level            14148 non-null float64
# secondary_cleaner.state.floatbank4_b_air              14148 non-null float64
# secondary_cleaner.state.floatbank4_b_level            14148 non-null float64
# secondary_cleaner.state.floatbank5_a_air              14148 non-null float64
# secondary_cleaner.state.floatbank5_a_level            14148 non-null float64
# secondary_cleaner.state.floatbank5_b_air              14148 non-null float64
# secondary_cleaner.state.floatbank5_b_level            14148 non-null float64
# secondary_cleaner.state.floatbank6_a_air              14147 non-null float64
# secondary_cleaner.state.floatbank6_a_level            14148 non-null float64
# dtypes: float64(86), object(1)
# memory usage: 9.4+ MB
# None
#    ТАБЛИЦА test ====================================================================== ТАБЛИЦА test
# ....................................................................................................
#                                                                                               head()
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
# 2  2016-09-01 02:59:59                     215.259946
# 3  2016-09-01 03:59:59                     215.336236
# 4  2016-09-01 04:59:59                     199.099327
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# 4                         10.682530                         7.530000
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# 1                        0.990469                             1398.777912
# 2                        0.996043                             1398.493666
# 3                        0.863514                             1399.618111
# 4                        0.805575                             1401.268123
#
#    primary_cleaner.state.floatbank8_a_level  \
# 0                               -500.225577
# 1                               -500.057435
# 2                               -500.868360
# 3                               -498.863574
# 4                               -500.808305
#
#    primary_cleaner.state.floatbank8_b_air  \
# 0                             1399.144926
# 1                             1398.055362
# 2                             1398.860436
# 3                             1397.440120
# 4                             1398.128818
#
#    primary_cleaner.state.floatbank8_b_level  \
# 0                               -499.919735
# 1                               -499.778182
# 2                               -499.764529
# 3                               -499.211024
# 4                               -499.504543
#
#    primary_cleaner.state.floatbank8_c_air  ...  \
# 0                             1400.102998  ...
# 1                             1396.151033  ...
# 2                             1398.075709  ...
# 3                             1400.129303  ...
# 4                             1402.172226  ...
#
#    secondary_cleaner.state.floatbank4_a_air  \
# 0                                 12.023554
# 1                                 12.058140
# 2                                 11.962366
# 3                                 12.033091
# 4                                 12.025367
#
#    secondary_cleaner.state.floatbank4_a_level  \
# 0                                 -497.795834
# 1                                 -498.695773
# 2                                 -498.767484
# 3                                 -498.350935
# 4                                 -500.786497
#
#    secondary_cleaner.state.floatbank4_b_air  \
# 0                                  8.016656
# 1                                  8.130979
# 2                                  8.096893
# 3                                  8.074946
# 4                                  8.054678
#
#    secondary_cleaner.state.floatbank4_b_level  \
# 0                                 -501.289139
# 1                                 -499.634209
# 2                                 -500.827423
# 3                                 -499.474407
# 4                                 -500.397500
#
#    secondary_cleaner.state.floatbank5_a_air  \
# 0                                  7.946562
# 1                                  7.958270
# 2                                  8.071056
# 3                                  7.897085
# 4                                  8.107890
#
#    secondary_cleaner.state.floatbank5_a_level  \
# 0                                 -432.317850
# 1                                 -525.839648
# 2                                 -500.801673
# 3                                 -500.868509
# 4                                 -509.526725
#
#    secondary_cleaner.state.floatbank5_b_air  \
# 0                                  4.872511
# 1                                  4.878850
# 2                                  4.905125
# 3                                  4.931400
# 4                                  4.957674
#
#    secondary_cleaner.state.floatbank5_b_level  \
# 0                                 -500.037437
# 1                                 -500.162375
# 2                                 -499.828510
# 3                                 -499.963623
# 4                                 -500.360026
#
#    secondary_cleaner.state.floatbank6_a_air  \
# 0                                 26.705889
# 1                                 25.019940
# 2                                 24.994862
# 3                                 24.948919
# 4                                 25.003331
#
#    secondary_cleaner.state.floatbank6_a_level
# 0                                 -499.709414
# 1                                 -499.819438
# 2                                 -500.622559
# 3                                 -498.709987
# 4                                 -500.856333
#
# [5 rows x 53 columns]
# ....................................................................................................
#                                                                                               info()
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5290 entries, 0 to 5289
# Data columns (total 53 columns):
# date                                          5290 non-null object
# primary_cleaner.input.sulfate                 5286 non-null float64
# primary_cleaner.input.depressant              5285 non-null float64
# primary_cleaner.input.feed_size               5290 non-null float64
# primary_cleaner.input.xanthate                5286 non-null float64
# primary_cleaner.state.floatbank8_a_air        5290 non-null float64
# primary_cleaner.state.floatbank8_a_level      5290 non-null float64
# primary_cleaner.state.floatbank8_b_air        5290 non-null float64
# primary_cleaner.state.floatbank8_b_level      5290 non-null float64
# primary_cleaner.state.floatbank8_c_air        5290 non-null float64
# primary_cleaner.state.floatbank8_c_level      5290 non-null float64
# primary_cleaner.state.floatbank8_d_air        5290 non-null float64
# primary_cleaner.state.floatbank8_d_level      5290 non-null float64
# rougher.input.feed_ag                         5290 non-null float64
# rougher.input.feed_pb                         5290 non-null float64
# rougher.input.feed_rate                       5287 non-null float64
# rougher.input.feed_size                       5289 non-null float64
# rougher.input.feed_sol                        5269 non-null float64
# rougher.input.feed_au                         5290 non-null float64
# rougher.input.floatbank10_sulfate             5285 non-null float64
# rougher.input.floatbank10_xanthate            5290 non-null float64
# rougher.input.floatbank11_sulfate             5282 non-null float64
# rougher.input.floatbank11_xanthate            5265 non-null float64
# rougher.state.floatbank10_a_air               5290 non-null float64
# rougher.state.floatbank10_a_level             5290 non-null float64
# rougher.state.floatbank10_b_air               5290 non-null float64
# rougher.state.floatbank10_b_level             5290 non-null float64
# rougher.state.floatbank10_c_air               5290 non-null float64
# rougher.state.floatbank10_c_level             5290 non-null float64
# rougher.state.floatbank10_d_air               5290 non-null float64
# rougher.state.floatbank10_d_level             5290 non-null float64
# rougher.state.floatbank10_e_air               5290 non-null float64
# rougher.state.floatbank10_e_level             5290 non-null float64
# rougher.state.floatbank10_f_air               5290 non-null float64
# rougher.state.floatbank10_f_level             5290 non-null float64
# secondary_cleaner.state.floatbank2_a_air      5287 non-null float64
# secondary_cleaner.state.floatbank2_a_level    5290 non-null float64
# secondary_cleaner.state.floatbank2_b_air      5288 non-null float64
# secondary_cleaner.state.floatbank2_b_level    5290 non-null float64
# secondary_cleaner.state.floatbank3_a_air      5281 non-null float64
# secondary_cleaner.state.floatbank3_a_level    5290 non-null float64
# secondary_cleaner.state.floatbank3_b_air      5290 non-null float64
# secondary_cleaner.state.floatbank3_b_level    5290 non-null float64
# secondary_cleaner.state.floatbank4_a_air      5290 non-null float64
# secondary_cleaner.state.floatbank4_a_level    5290 non-null float64
# secondary_cleaner.state.floatbank4_b_air      5290 non-null float64
# secondary_cleaner.state.floatbank4_b_level    5290 non-null float64
# secondary_cleaner.state.floatbank5_a_air      5290 non-null float64
# secondary_cleaner.state.floatbank5_a_level    5290 non-null float64
# secondary_cleaner.state.floatbank5_b_air      5290 non-null float64
# secondary_cleaner.state.floatbank5_b_level    5290 non-null float64
# secondary_cleaner.state.floatbank6_a_air      5290 non-null float64
# secondary_cleaner.state.floatbank6_a_level    5290 non-null float64
# dtypes: float64(52), object(1)
# memory usage: 2.1+ MB
# None

# %% [markdown]
# Выведем структуру данных и количество объектов по каждой таблице:

# %%
# информация по числу объектов в каждой из таблиц
rows_info = pd.DataFrame(df['full'].count(), columns=['full'])\
    .join(pd.Series(df['train'].count(), name='train'))\
    .join(pd.Series(df['test'].count(), name='test'))
#rows_info

# %%
# разделение имен столбцов:
split_names_rows_info = pd.DataFrame([i.split('.') + rows_info.loc[i, data_names].to_list() for i in df['full'].columns[1:]], columns=['stage', 'param_type', 'param_name']+data_names)
# split_names_rows_info

# %%
# Структура данных через сложный индекс:
data_structure = split_names_rows_info.pivot_table(index=['stage', 'param_type', 'param_name'])
data_structure
# Out:
#                                                                  full    test  \
# stage             param_type  param_name
# final             output      concentrate_ag                  19438.0     NaN
#                               concentrate_au                  19439.0     NaN
#                               concentrate_pb                  19438.0     NaN
#                               concentrate_sol                 19228.0     NaN
#                               recovery                        19439.0     NaN
#                               tail_ag                         19438.0     NaN
#                               tail_au                         19439.0     NaN
#                               tail_pb                         19338.0     NaN
#                               tail_sol                        19433.0     NaN
# primary_cleaner   input       depressant                      19402.0  5285.0
#                               feed_size                       19439.0  5290.0
#                               sulfate                         19415.0  5286.0
#                               xanthate                        19335.0  5286.0
#                   output      concentrate_ag                  19439.0     NaN
#                               concentrate_au                  19439.0     NaN
#                               concentrate_pb                  19323.0     NaN
#                               concentrate_sol                 19069.0     NaN
#                               tail_ag                         19435.0     NaN
#                               tail_au                         19439.0     NaN
#                               tail_pb                         19418.0     NaN
#                               tail_sol                        19377.0     NaN
#                   state       floatbank8_a_air                19435.0  5290.0
#                               floatbank8_a_level              19438.0  5290.0
#                               floatbank8_b_air                19435.0  5290.0
#                               floatbank8_b_level              19438.0  5290.0
#                               floatbank8_c_air                19437.0  5290.0
#                               floatbank8_c_level              19438.0  5290.0
#                               floatbank8_d_air                19436.0  5290.0
#                               floatbank8_d_level              19438.0  5290.0
# rougher           calculation au_pb_ratio                     19439.0     NaN
#                               floatbank10_sulfate_to_au_feed  19437.0     NaN
#                               floatbank11_sulfate_to_au_feed  19437.0     NaN
#                               sulfate_to_au_concentrate       19437.0     NaN
#                   input       feed_ag                         19439.0  5290.0
#                               feed_au                         19439.0  5290.0
#                               feed_pb                         19339.0  5290.0
#                               feed_rate                       19428.0  5287.0
#                               feed_size                       19294.0  5289.0
#                               feed_sol                        19340.0  5269.0
#                               floatbank10_sulfate             19405.0  5285.0
#                               floatbank10_xanthate            19431.0  5290.0
#                               floatbank11_sulfate             19395.0  5282.0
#                               floatbank11_xanthate            18986.0  5265.0
#                   output      concentrate_ag                  19439.0     NaN
#                               concentrate_au                  19439.0     NaN
#                               concentrate_pb                  19439.0     NaN
#                               concentrate_sol                 19416.0     NaN
#                               recovery                        19439.0     NaN
#                               tail_ag                         19438.0     NaN
#                               tail_au                         19439.0     NaN
#                               tail_pb                         19439.0     NaN
#                               tail_sol                        19439.0     NaN
#                   state       floatbank10_a_air               19438.0  5290.0
#                               floatbank10_a_level             19438.0  5290.0
#                               floatbank10_b_air               19438.0  5290.0
#                               floatbank10_b_level             19438.0  5290.0
#                               floatbank10_c_air               19438.0  5290.0
#                               floatbank10_c_level             19438.0  5290.0
#                               floatbank10_d_air               19439.0  5290.0
#                               floatbank10_d_level             19439.0  5290.0
#                               floatbank10_e_air               19003.0  5290.0
#                               floatbank10_e_level             19439.0  5290.0
#                               floatbank10_f_air               19439.0  5290.0
#                               floatbank10_f_level             19439.0  5290.0
# secondary_cleaner output      tail_ag                         19437.0     NaN
#                               tail_au                         19439.0     NaN
#                               tail_pb                         19427.0     NaN
#                               tail_sol                        17691.0     NaN
#                   state       floatbank2_a_air                19219.0  5287.0
#                               floatbank2_a_level              19438.0  5290.0
#                               floatbank2_b_air                19416.0  5288.0
#                               floatbank2_b_level              19438.0  5290.0
#                               floatbank3_a_air                19426.0  5281.0
#                               floatbank3_a_level              19438.0  5290.0
#                               floatbank3_b_air                19438.0  5290.0
#                               floatbank3_b_level              19438.0  5290.0
#                               floatbank4_a_air                19433.0  5290.0
#                               floatbank4_a_level              19438.0  5290.0
#                               floatbank4_b_air                19438.0  5290.0
#                               floatbank4_b_level              19438.0  5290.0
#                               floatbank5_a_air                19438.0  5290.0
#                               floatbank5_a_level              19438.0  5290.0
#                               floatbank5_b_air                19438.0  5290.0
#                               floatbank5_b_level              19438.0  5290.0
#                               floatbank6_a_air                19437.0  5290.0
#                               floatbank6_a_level              19438.0  5290.0
#
#                                                                 train
# stage             param_type  param_name
# final             output      concentrate_ag                  14148.0
#                               concentrate_au                  14149.0
#                               concentrate_pb                  14148.0
#                               concentrate_sol                 13938.0
#                               recovery                        14149.0
#                               tail_ag                         14149.0
#                               tail_au                         14149.0
#                               tail_pb                         14049.0
#                               tail_sol                        14144.0
# primary_cleaner   input       depressant                      14117.0
#                               feed_size                       14149.0
#                               sulfate                         14129.0
#                               xanthate                        14049.0
#                   output      concentrate_ag                  14149.0
#                               concentrate_au                  14149.0
#                               concentrate_pb                  14063.0
#                               concentrate_sol                 13863.0
#                               tail_ag                         14148.0
#                               tail_au                         14149.0
#                               tail_pb                         14134.0
#                               tail_sol                        14103.0
#                   state       floatbank8_a_air                14145.0
#                               floatbank8_a_level              14148.0
#                               floatbank8_b_air                14145.0
#                               floatbank8_b_level              14148.0
#                               floatbank8_c_air                14147.0
#                               floatbank8_c_level              14148.0
#                               floatbank8_d_air                14146.0
#                               floatbank8_d_level              14148.0
# rougher           calculation au_pb_ratio                     14149.0
#                               floatbank10_sulfate_to_au_feed  14148.0
#                               floatbank11_sulfate_to_au_feed  14148.0
#                               sulfate_to_au_concentrate       14148.0
#                   input       feed_ag                         14149.0
#                               feed_au                         14149.0
#                               feed_pb                         14049.0
#                               feed_rate                       14141.0
#                               feed_size                       14005.0
#                               feed_sol                        14071.0
#                               floatbank10_sulfate             14120.0
#                               floatbank10_xanthate            14141.0
#                               floatbank11_sulfate             14113.0
#                               floatbank11_xanthate            13721.0
#                   output      concentrate_ag                  14149.0
#                               concentrate_au                  14149.0
#                               concentrate_pb                  14149.0
#                               concentrate_sol                 14127.0
#                               recovery                        14149.0
#                               tail_ag                         14148.0
#                               tail_au                         14149.0
#                               tail_pb                         14149.0
#                               tail_sol                        14149.0
#                   state       floatbank10_a_air               14148.0
#                               floatbank10_a_level             14148.0
#                               floatbank10_b_air               14148.0
#                               floatbank10_b_level             14148.0
#                               floatbank10_c_air               14148.0
#                               floatbank10_c_level             14148.0
#                               floatbank10_d_air               14149.0
#                               floatbank10_d_level             14149.0
#                               floatbank10_e_air               13713.0
#                               floatbank10_e_level             14149.0
#                               floatbank10_f_air               14149.0
#                               floatbank10_f_level             14149.0
# secondary_cleaner output      tail_ag                         14147.0
#                               tail_au                         14149.0
#                               tail_pb                         14139.0
#                               tail_sol                        12544.0
#                   state       floatbank2_a_air                13932.0
#                               floatbank2_a_level              14148.0
#                               floatbank2_b_air                14128.0
#                               floatbank2_b_level              14148.0
#                               floatbank3_a_air                14145.0
#                               floatbank3_a_level              14148.0
#                               floatbank3_b_air                14148.0
#                               floatbank3_b_level              14148.0
#                               floatbank4_a_air                14143.0
#                               floatbank4_a_level              14148.0
#                               floatbank4_b_air                14148.0
#                               floatbank4_b_level              14148.0
#                               floatbank5_a_air                14148.0
#                               floatbank5_a_level              14148.0
#                               floatbank5_b_air                14148.0
#                               floatbank5_b_level              14148.0
#                               floatbank6_a_air                14147.0
#                               floatbank6_a_level              14148.0

# %% [markdown]
# Проверим являются ли данные в таблицах `train` и `test` данными из таблицы `full`.
#
# Для этого по отделности объединим таблицы `train` и `test` с таблицей `full`, а затем в объединенной таблице проверим количество дубликатов. Если количество дубликатов совпадает с размером исходных таблиц, то исходные таблицы входят в состав полных данных и являются непосредственными выборками из таблицы `full`:

# %%
for table in ['train', 'test']:
    print('-'*TABLE_SIZE)
    print(f'Размер исходной таблицы {table}: {df[table].shape}')
    dupl_count = pd.concat([df['full'][df[table].columns], df[table]]).round(8).duplicated().sum()
    
    print(f'Количество дубликатов в объединенной таблице: {dupl_count}')
    if df[table].shape[0] == dupl_count:
        print(f'Таблица {table} полностью является частью таблицы FULL')
    else:
        print(f'Таблица {table} - это не часть таблицы FULL')
# Out:
# ----------------------------------------------------------------------------------------------------
# Размер исходной таблицы train: (14149, 87)
# Количество дубликатов в объединенной таблице: 14149
# Таблица train полностью является частью таблицы FULL
# ----------------------------------------------------------------------------------------------------
# Размер исходной таблицы test: (5290, 53)
# Количество дубликатов в объединенной таблице: 5290
# Таблица test полностью является частью таблицы FULL

# %% [markdown]
# ### Выводы

# %% [markdown]
# Данные представляют из себя информацию по стадиям получения золота из руды.
#
# Данные разделены на **3 части**:
# 1. Полный набор данных `full`
# 1. Обучающая выборка `train` - это часть данных от полного набора `full` (т.е. эти данные дублируются в полном наборе)
# 1. Тестовая выборка `test` - это часть данных от полного набора `full` (т.е. эти данные дублируются в полном наборе)
#
# - *В таблице `test` отсутствует часть данных, доступных в полном наборе*
# - *Индексы разбивок не совпадают с индексами полного набора*
#
# Данные разделены на **4 основных этапа** подготовки руды:
# 1. флотация (`rougher`)
# 1. первичная очистка (`primary_cleaner`)
# 1. вторичная очистка (`secondary_cleaner`)
# 1. финальные характеристики (`final`)
#
# Каждый этап может разделяться на определенные **параметры**:
# - input — параметры сырья
# - output — параметры продукта
# - state — параметры, характеризующие текущее состояние этапа
# - calculation — расчётные характеристики
#
#
#
# СТРУКТУРА ДАННЫХ:
#
# * Названия колонок в таблицах корректны.
# * Проверить данные на явные дубликаты.
# * Имеются множественные пропуски в данных.
#
#
# * Группы данных по типу: 1 колонка с **Датой**, остальные данные - **Численные**.
#
#
# * По **типам данных** нужно исправить
#     - дата - привести к типу даты
#
#
# * Смысловые (логические) взаимосвязи:
#     - эфективноcть обогащения золота должна совпадать с расчетом по формуле

# %%
# Исходный размер таблицы:
origin_shape = get_shape(df)
origin_shape
# Out:
#        Число строк  Число столбцов
# full         19439              87
# train        14149              87
# test          5290              53

# %% [markdown]
# Определим целевые признаки:

# %%
target_col_1 = 'rougher.output.recovery'
target_col_2 = 'final.output.recovery'

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Сохраним отдельный оригинальный набор исходных данных (не будем проводить какие-либо изменения в нем).

# %%
df_origin = df['full'].copy()

# %% [markdown]
# ### Исправление заголовков

# %%
display_all(df, data_names, 'columns.to_list()')
# Out:
#    ТАБЛИЦА full ====================================================================== ТАБЛИЦА full
# ['date',
#  'final.output.concentrate_ag',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.concentrate_au',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'final.output.tail_au',
#  'primary_cleaner.input.sulfate',
#  'primary_cleaner.input.depressant',
#  'primary_cleaner.input.feed_size',
#  'primary_cleaner.input.xanthate',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.state.floatbank8_a_air',
#  'primary_cleaner.state.floatbank8_a_level',
#  'primary_cleaner.state.floatbank8_b_air',
#  'primary_cleaner.state.floatbank8_b_level',
#  'primary_cleaner.state.floatbank8_c_air',
#  'primary_cleaner.state.floatbank8_c_level',
#  'primary_cleaner.state.floatbank8_d_air',
#  'primary_cleaner.state.floatbank8_d_level',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.input.feed_ag',
#  'rougher.input.feed_pb',
#  'rougher.input.feed_rate',
#  'rougher.input.feed_size',
#  'rougher.input.feed_sol',
#  'rougher.input.feed_au',
#  'rougher.input.floatbank10_sulfate',
#  'rougher.input.floatbank10_xanthate',
#  'rougher.input.floatbank11_sulfate',
#  'rougher.input.floatbank11_xanthate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.concentrate_au',
#  'rougher.output.recovery',
#  'rougher.output.tail_ag',
#  'rougher.output.tail_pb',
#  'rougher.output.tail_sol',
#  'rougher.output.tail_au',
#  'rougher.state.floatbank10_a_air',
#  'rougher.state.floatbank10_a_level',
#  'rougher.state.floatbank10_b_air',
#  'rougher.state.floatbank10_b_level',
#  'rougher.state.floatbank10_c_air',
#  'rougher.state.floatbank10_c_level',
#  'rougher.state.floatbank10_d_air',
#  'rougher.state.floatbank10_d_level',
#  'rougher.state.floatbank10_e_air',
#  'rougher.state.floatbank10_e_level',
#  'rougher.state.floatbank10_f_air',
#  'rougher.state.floatbank10_f_level',
#  'secondary_cleaner.output.tail_ag',
#  'secondary_cleaner.output.tail_pb',
#  'secondary_cleaner.output.tail_sol',
#  'secondary_cleaner.output.tail_au',
#  'secondary_cleaner.state.floatbank2_a_air',
#  'secondary_cleaner.state.floatbank2_a_level',
#  'secondary_cleaner.state.floatbank2_b_air',
#  'secondary_cleaner.state.floatbank2_b_level',
#  'secondary_cleaner.state.floatbank3_a_air',
#  'secondary_cleaner.state.floatbank3_a_level',
#  'secondary_cleaner.state.floatbank3_b_air',
#  'secondary_cleaner.state.floatbank3_b_level',
#  'secondary_cleaner.state.floatbank4_a_air',
#  'secondary_cleaner.state.floatbank4_a_level',
#  'secondary_cleaner.state.floatbank4_b_air',
#  'secondary_cleaner.state.floatbank4_b_level',
#  'secondary_cleaner.state.floatbank5_a_air',
#  'secondary_cleaner.state.floatbank5_a_level',
#  'secondary_cleaner.state.floatbank5_b_air',
#  'secondary_cleaner.state.floatbank5_b_level',
#  'secondary_cleaner.state.floatbank6_a_air',
#  'secondary_cleaner.state.floatbank6_a_level']
#    ТАБЛИЦА train ==================================================================== ТАБЛИЦА train
# ['date',
#  'final.output.concentrate_ag',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.concentrate_au',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'final.output.tail_au',
#  'primary_cleaner.input.sulfate',
#  'primary_cleaner.input.depressant',
#  'primary_cleaner.input.feed_size',
#  'primary_cleaner.input.xanthate',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.state.floatbank8_a_air',
#  'primary_cleaner.state.floatbank8_a_level',
#  'primary_cleaner.state.floatbank8_b_air',
#  'primary_cleaner.state.floatbank8_b_level',
#  'primary_cleaner.state.floatbank8_c_air',
#  'primary_cleaner.state.floatbank8_c_level',
#  'primary_cleaner.state.floatbank8_d_air',
#  'primary_cleaner.state.floatbank8_d_level',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.input.feed_ag',
#  'rougher.input.feed_pb',
#  'rougher.input.feed_rate',
#  'rougher.input.feed_size',
#  'rougher.input.feed_sol',
#  'rougher.input.feed_au',
#  'rougher.input.floatbank10_sulfate',
#  'rougher.input.floatbank10_xanthate',
#  'rougher.input.floatbank11_sulfate',
#  'rougher.input.floatbank11_xanthate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.concentrate_au',
#  'rougher.output.recovery',
#  'rougher.output.tail_ag',
#  'rougher.output.tail_pb',
#  'rougher.output.tail_sol',
#  'rougher.output.tail_au',
#  'rougher.state.floatbank10_a_air',
#  'rougher.state.floatbank10_a_level',
#  'rougher.state.floatbank10_b_air',
#  'rougher.state.floatbank10_b_level',
#  'rougher.state.floatbank10_c_air',
#  'rougher.state.floatbank10_c_level',
#  'rougher.state.floatbank10_d_air',
#  'rougher.state.floatbank10_d_level',
#  'rougher.state.floatbank10_e_air',
#  'rougher.state.floatbank10_e_level',
#  'rougher.state.floatbank10_f_air',
#  'rougher.state.floatbank10_f_level',
#  'secondary_cleaner.output.tail_ag',
#  'secondary_cleaner.output.tail_pb',
#  'secondary_cleaner.output.tail_sol',
#  'secondary_cleaner.output.tail_au',
#  'secondary_cleaner.state.floatbank2_a_air',
#  'secondary_cleaner.state.floatbank2_a_level',
#  'secondary_cleaner.state.floatbank2_b_air',
#  'secondary_cleaner.state.floatbank2_b_level',
#  'secondary_cleaner.state.floatbank3_a_air',
#  'secondary_cleaner.state.floatbank3_a_level',
#  'secondary_cleaner.state.floatbank3_b_air',
#  'secondary_cleaner.state.floatbank3_b_level',
#  'secondary_cleaner.state.floatbank4_a_air',
#  'secondary_cleaner.state.floatbank4_a_level',
#  'secondary_cleaner.state.floatbank4_b_air',
#  'secondary_cleaner.state.floatbank4_b_level',
#  'secondary_cleaner.state.floatbank5_a_air',
#  'secondary_cleaner.state.floatbank5_a_level',
#  'secondary_cleaner.state.floatbank5_b_air',
#  'secondary_cleaner.state.floatbank5_b_level',
#  'secondary_cleaner.state.floatbank6_a_air',
#  'secondary_cleaner.state.floatbank6_a_level']
#    ТАБЛИЦА test ====================================================================== ТАБЛИЦА test
# ['date',
#  'primary_cleaner.input.sulfate',
#  'primary_cleaner.input.depressant',
#  'primary_cleaner.input.feed_size',
#  'primary_cleaner.input.xanthate',
#  'primary_cleaner.state.floatbank8_a_air',
#  'primary_cleaner.state.floatbank8_a_level',
#  'primary_cleaner.state.floatbank8_b_air',
#  'primary_cleaner.state.floatbank8_b_level',
#  'primary_cleaner.state.floatbank8_c_air',
#  'primary_cleaner.state.floatbank8_c_level',
#  'primary_cleaner.state.floatbank8_d_air',
#  'primary_cleaner.state.floatbank8_d_level',
#  'rougher.input.feed_ag',
#  'rougher.input.feed_pb',
#  'rougher.input.feed_rate',
#  'rougher.input.feed_size',
#  'rougher.input.feed_sol',
#  'rougher.input.feed_au',
#  'rougher.input.floatbank10_sulfate',
#  'rougher.input.floatbank10_xanthate',
#  'rougher.input.floatbank11_sulfate',
#  'rougher.input.floatbank11_xanthate',
#  'rougher.state.floatbank10_a_air',
#  'rougher.state.floatbank10_a_level',
#  'rougher.state.floatbank10_b_air',
#  'rougher.state.floatbank10_b_level',
#  'rougher.state.floatbank10_c_air',
#  'rougher.state.floatbank10_c_level',
#  'rougher.state.floatbank10_d_air',
#  'rougher.state.floatbank10_d_level',
#  'rougher.state.floatbank10_e_air',
#  'rougher.state.floatbank10_e_level',
#  'rougher.state.floatbank10_f_air',
#  'rougher.state.floatbank10_f_level',
#  'secondary_cleaner.state.floatbank2_a_air',
#  'secondary_cleaner.state.floatbank2_a_level',
#  'secondary_cleaner.state.floatbank2_b_air',
#  'secondary_cleaner.state.floatbank2_b_level',
#  'secondary_cleaner.state.floatbank3_a_air',
#  'secondary_cleaner.state.floatbank3_a_level',
#  'secondary_cleaner.state.floatbank3_b_air',
#  'secondary_cleaner.state.floatbank3_b_level',
#  'secondary_cleaner.state.floatbank4_a_air',
#  'secondary_cleaner.state.floatbank4_a_level',
#  'secondary_cleaner.state.floatbank4_b_air',
#  'secondary_cleaner.state.floatbank4_b_level',
#  'secondary_cleaner.state.floatbank5_a_air',
#  'secondary_cleaner.state.floatbank5_a_level',
#  'secondary_cleaner.state.floatbank5_b_air',
#  'secondary_cleaner.state.floatbank5_b_level',
#  'secondary_cleaner.state.floatbank6_a_air',
#  'secondary_cleaner.state.floatbank6_a_level']

# %% [markdown]
# **Вывод:**
#
# Заголовки не нуждаются в исправлении

# %% [markdown]
# ### Проверка на явные дубликаты

# %%
display_all(df, data_names, 'duplicated().sum()')
# Out:
#    ТАБЛИЦА full ====================================================================== ТАБЛИЦА full
# 0
#    ТАБЛИЦА train ==================================================================== ТАБЛИЦА train
# 0
#    ТАБЛИЦА test ====================================================================== ТАБЛИЦА test
# 0

# %% [markdown]
# **Вывод:**
#
# Явных дубликатов нет

# %% [markdown]
# ### Проверка пропусков

# %% [markdown]
# Проверим пропуски и запишем ключевые колонки по каждой из таблиц

# %%
na_indexes = {}

# %% [markdown]
# Исходные данные:

# %%
na_indexes['full'] = na_info(df['full'], level=0.01)
# Out:
#   Нет пропусков:
# <style  type="text/css" >
# </style><table id="T_a5b49244_994c_11ec_b41f_02420a39e3a2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >na</th>        <th class="col_heading level0 col2" >fraction</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a5b49244_994c_11ec_b41f_02420a39e3a2level0_row0" class="row_heading level0 row0" >date</th>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row0_col0" class="data row0 col0" >19439</td>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row0_col2" class="data row0 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5b49244_994c_11ec_b41f_02420a39e3a2level0_row1" class="row_heading level0 row1" >final.output.concentrate_au</th>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row1_col0" class="data row1 col0" >19439</td>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row1_col1" class="data row1 col1" >0</td>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row1_col2" class="data row1 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5b49244_994c_11ec_b41f_02420a39e3a2level0_row2" class="row_heading level0 row2" >final.output.recovery</th>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row2_col0" class="data row2 col0" >19439</td>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row2_col1" class="data row2 col1" >0</td>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row2_col2" class="data row2 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5b49244_994c_11ec_b41f_02420a39e3a2level0_row3" class="row_heading level0 row3" >final.output.tail_au</th>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row3_col0" class="data row3 col0" >19439</td>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row3_col1" class="data row3 col1" >0</td>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row3_col2" class="data row3 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5b49244_994c_11ec_b41f_02420a39e3a2level0_row4" class="row_heading level0 row4" >primary_cleaner.input.feed_size</th>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row4_col0" class="data row4 col0" >19439</td>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row4_col1" class="data row4 col1" >0</td>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row4_col2" class="data row4 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5b49244_994c_11ec_b41f_02420a39e3a2level0_row5" class="row_heading level0 row5" >primary_cleaner.output.concentrate_ag</th>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row5_col0" class="data row5 col0" >19439</td>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row5_col1" class="data row5 col1" >0</td>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row5_col2" class="data row5 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5b49244_994c_11ec_b41f_02420a39e3a2level0_row6" class="row_heading level0 row6" >primary_cleaner.output.concentrate_au</th>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row6_col0" class="data row6 col0" >19439</td>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row6_col1" class="data row6 col1" >0</td>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row6_col2" class="data row6 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5b49244_994c_11ec_b41f_02420a39e3a2level0_row7" class="row_heading level0 row7" >primary_cleaner.output.tail_au</th>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row7_col0" class="data row7 col0" >19439</td>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row7_col1" class="data row7 col1" >0</td>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row7_col2" class="data row7 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5b49244_994c_11ec_b41f_02420a39e3a2level0_row8" class="row_heading level0 row8" >rougher.calculation.au_pb_ratio</th>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row8_col0" class="data row8 col0" >19439</td>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row8_col1" class="data row8 col1" >0</td>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row8_col2" class="data row8 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5b49244_994c_11ec_b41f_02420a39e3a2level0_row9" class="row_heading level0 row9" >rougher.input.feed_ag</th>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row9_col0" class="data row9 col0" >19439</td>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row9_col1" class="data row9 col1" >0</td>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row9_col2" class="data row9 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5b49244_994c_11ec_b41f_02420a39e3a2level0_row10" class="row_heading level0 row10" >rougher.input.feed_au</th>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row10_col0" class="data row10 col0" >19439</td>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row10_col1" class="data row10 col1" >0</td>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row10_col2" class="data row10 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5b49244_994c_11ec_b41f_02420a39e3a2level0_row11" class="row_heading level0 row11" >rougher.output.concentrate_ag</th>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row11_col0" class="data row11 col0" >19439</td>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row11_col1" class="data row11 col1" >0</td>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row11_col2" class="data row11 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5b49244_994c_11ec_b41f_02420a39e3a2level0_row12" class="row_heading level0 row12" >rougher.output.concentrate_pb</th>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row12_col0" class="data row12 col0" >19439</td>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row12_col1" class="data row12 col1" >0</td>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row12_col2" class="data row12 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5b49244_994c_11ec_b41f_02420a39e3a2level0_row13" class="row_heading level0 row13" >rougher.output.concentrate_au</th>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row13_col0" class="data row13 col0" >19439</td>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row13_col1" class="data row13 col1" >0</td>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row13_col2" class="data row13 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5b49244_994c_11ec_b41f_02420a39e3a2level0_row14" class="row_heading level0 row14" >rougher.output.recovery</th>
#                         <td id="T_a5b49244_994c_11ec_b41f_02420a39e3a2row14_col0" class="
#   Малая доля пропусков:
# <style  type="text/css" >
# </style><table id="T_a5b65192_994c_11ec_b41f_02420a39e3a2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >na</th>        <th class="col_heading level0 col2" >fraction</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a5b65192_994c_11ec_b41f_02420a39e3a2level0_row0" class="row_heading level0 row0" >final.output.concentrate_ag</th>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row0_col0" class="data row0 col0" >19438</td>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row0_col1" class="data row0 col1" >1</td>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row0_col2" class="data row0 col2" >0.01%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5b65192_994c_11ec_b41f_02420a39e3a2level0_row1" class="row_heading level0 row1" >final.output.concentrate_pb</th>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row1_col0" class="data row1 col0" >19438</td>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row1_col2" class="data row1 col2" >0.01%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5b65192_994c_11ec_b41f_02420a39e3a2level0_row2" class="row_heading level0 row2" >final.output.tail_ag</th>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row2_col0" class="data row2 col0" >19438</td>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row2_col1" class="data row2 col1" >1</td>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row2_col2" class="data row2 col2" >0.01%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5b65192_994c_11ec_b41f_02420a39e3a2level0_row3" class="row_heading level0 row3" >final.output.tail_pb</th>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row3_col0" class="data row3 col0" >19338</td>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row3_col1" class="data row3 col1" >101</td>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row3_col2" class="data row3 col2" >0.52%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5b65192_994c_11ec_b41f_02420a39e3a2level0_row4" class="row_heading level0 row4" >final.output.tail_sol</th>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row4_col0" class="data row4 col0" >19433</td>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row4_col1" class="data row4 col1" >6</td>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row4_col2" class="data row4 col2" >0.03%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5b65192_994c_11ec_b41f_02420a39e3a2level0_row5" class="row_heading level0 row5" >primary_cleaner.input.sulfate</th>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row5_col0" class="data row5 col0" >19415</td>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row5_col1" class="data row5 col1" >24</td>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row5_col2" class="data row5 col2" >0.12%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5b65192_994c_11ec_b41f_02420a39e3a2level0_row6" class="row_heading level0 row6" >primary_cleaner.input.depressant</th>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row6_col0" class="data row6 col0" >19402</td>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row6_col1" class="data row6 col1" >37</td>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row6_col2" class="data row6 col2" >0.19%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5b65192_994c_11ec_b41f_02420a39e3a2level0_row7" class="row_heading level0 row7" >primary_cleaner.input.xanthate</th>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row7_col0" class="data row7 col0" >19335</td>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row7_col1" class="data row7 col1" >104</td>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row7_col2" class="data row7 col2" >0.54%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5b65192_994c_11ec_b41f_02420a39e3a2level0_row8" class="row_heading level0 row8" >primary_cleaner.output.concentrate_pb</th>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row8_col0" class="data row8 col0" >19323</td>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row8_col1" class="data row8 col1" >116</td>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row8_col2" class="data row8 col2" >0.60%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5b65192_994c_11ec_b41f_02420a39e3a2level0_row9" class="row_heading level0 row9" >primary_cleaner.output.tail_ag</th>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row9_col0" class="data row9 col0" >19435</td>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row9_col1" class="data row9 col1" >4</td>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row9_col2" class="data row9 col2" >0.02%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5b65192_994c_11ec_b41f_02420a39e3a2level0_row10" class="row_heading level0 row10" >primary_cleaner.output.tail_pb</th>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row10_col0" class="data row10 col0" >19418</td>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row10_col1" class="data row10 col1" >21</td>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row10_col2" class="data row10 col2" >0.11%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5b65192_994c_11ec_b41f_02420a39e3a2level0_row11" class="row_heading level0 row11" >primary_cleaner.output.tail_sol</th>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row11_col0" class="data row11 col0" >19377</td>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row11_col1" class="data row11 col1" >62</td>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row11_col2" class="data row11 col2" >0.32%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5b65192_994c_11ec_b41f_02420a39e3a2level0_row12" class="row_heading level0 row12" >primary_cleaner.state.floatbank8_a_air</th>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row12_col0" class="data row12 col0" >19435</td>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row12_col1" class="data row12 col1" >4</td>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row12_col2" class="data row12 col2" >0.02%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5b65192_994c_11ec_b41f_02420a39e3a2level0_row13" class="row_heading level0 row13" >primary_cleaner.state.floatbank8_a_level</th>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row13_col0" class="data row13 col0" >19438</td>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row13_col1" class="data row13 col1" >1</td>
#                         <td id="T_a5b65192_994c_11ec_b41f_02420a39e3a2row13_col2" class="data row13 col2" >0.01%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5b65192_994c_11ec_b41f_02420a39e3a2level0_row14" class="row_heading level0 row14" >primary_cleaner.state.floatbank8_b_air</th>
# Оценка остатка (при удалении пропусков с малой долей):  96.240%
#
#   Большая доля пропусков:
# <style  type="text/css" >
# </style><table id="T_a5bac056_994c_11ec_b41f_02420a39e3a2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >na</th>        <th class="col_heading level0 col2" >fraction</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a5bac056_994c_11ec_b41f_02420a39e3a2level0_row0" class="row_heading level0 row0" >final.output.concentrate_sol</th>
#                         <td id="T_a5bac056_994c_11ec_b41f_02420a39e3a2row0_col0" class="data row0 col0" >19228</td>
#                         <td id="T_a5bac056_994c_11ec_b41f_02420a39e3a2row0_col1" class="data row0 col1" >211</td>
#                         <td id="T_a5bac056_994c_11ec_b41f_02420a39e3a2row0_col2" class="data row0 col2" >1.10%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5bac056_994c_11ec_b41f_02420a39e3a2level0_row1" class="row_heading level0 row1" >primary_cleaner.output.concentrate_sol</th>
#                         <td id="T_a5bac056_994c_11ec_b41f_02420a39e3a2row1_col0" class="data row1 col0" >19069</td>
#                         <td id="T_a5bac056_994c_11ec_b41f_02420a39e3a2row1_col1" class="data row1 col1" >370</td>
#                         <td id="T_a5bac056_994c_11ec_b41f_02420a39e3a2row1_col2" class="data row1 col2" >1.94%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5bac056_994c_11ec_b41f_02420a39e3a2level0_row2" class="row_heading level0 row2" >rougher.input.floatbank11_xanthate</th>
#                         <td id="T_a5bac056_994c_11ec_b41f_02420a39e3a2row2_col0" class="data row2 col0" >18986</td>
#                         <td id="T_a5bac056_994c_11ec_b41f_02420a39e3a2row2_col1" class="data row2 col1" >453</td>
#                         <td id="T_a5bac056_994c_11ec_b41f_02420a39e3a2row2_col2" class="data row2 col2" >2.39%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5bac056_994c_11ec_b41f_02420a39e3a2level0_row3" class="row_heading level0 row3" >rougher.state.floatbank10_e_air</th>
#                         <td id="T_a5bac056_994c_11ec_b41f_02420a39e3a2row3_col0" class="data row3 col0" >19003</td>
#                         <td id="T_a5bac056_994c_11ec_b41f_02420a39e3a2row3_col1" class="data row3 col1" >436</td>
#                         <td id="T_a5bac056_994c_11ec_b41f_02420a39e3a2row3_col2" class="data row3 col2" >2.29%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5bac056_994c_11ec_b41f_02420a39e3a2level0_row4" class="row_heading level0 row4" >secondary_cleaner.output.tail_sol</th>
#                         <td id="T_a5bac056_994c_11ec_b41f_02420a39e3a2row4_col0" class="data row4 col0" >17691</td>
#                         <td id="T_a5bac056_994c_11ec_b41f_02420a39e3a2row4_col1" class="data row4 col1" >1748</td>
#                         <td id="T_a5bac056_994c_11ec_b41f_02420a39e3a2row4_col2" class="data row4 col2" >9.88%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5bac056_994c_11ec_b41f_02420a39e3a2level0_row5" class="row_heading level0 row5" >secondary_cleaner.state.floatbank2_a_air</th>
#                         <td id="T_a5bac056_994c_11ec_b41f_02420a39e3a2row5_col0" class="data row5 col0" >19219</td>
#                         <td id="T_a5bac056_994c_11ec_b41f_02420a39e3a2row5_col1" class="data row5 col1" >220</td>
#                         <td id="T_a5bac056_994c_11ec_b41f_02420a39e3a2row5_col2" class="data row5 col2" >1.14%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Обучающая выборка

# %%
na_indexes['train'] = na_info(df['train'], level=0.01)
# Out:
#   Нет пропусков:
# <style  type="text/css" >
# </style><table id="T_a5be944c_994c_11ec_b41f_02420a39e3a2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >na</th>        <th class="col_heading level0 col2" >fraction</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a5be944c_994c_11ec_b41f_02420a39e3a2level0_row0" class="row_heading level0 row0" >date</th>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row0_col0" class="data row0 col0" >14149</td>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row0_col2" class="data row0 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5be944c_994c_11ec_b41f_02420a39e3a2level0_row1" class="row_heading level0 row1" >final.output.concentrate_au</th>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row1_col0" class="data row1 col0" >14149</td>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row1_col1" class="data row1 col1" >0</td>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row1_col2" class="data row1 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5be944c_994c_11ec_b41f_02420a39e3a2level0_row2" class="row_heading level0 row2" >final.output.recovery</th>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row2_col0" class="data row2 col0" >14149</td>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row2_col1" class="data row2 col1" >0</td>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row2_col2" class="data row2 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5be944c_994c_11ec_b41f_02420a39e3a2level0_row3" class="row_heading level0 row3" >final.output.tail_ag</th>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row3_col0" class="data row3 col0" >14149</td>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row3_col1" class="data row3 col1" >0</td>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row3_col2" class="data row3 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5be944c_994c_11ec_b41f_02420a39e3a2level0_row4" class="row_heading level0 row4" >final.output.tail_au</th>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row4_col0" class="data row4 col0" >14149</td>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row4_col1" class="data row4 col1" >0</td>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row4_col2" class="data row4 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5be944c_994c_11ec_b41f_02420a39e3a2level0_row5" class="row_heading level0 row5" >primary_cleaner.input.feed_size</th>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row5_col0" class="data row5 col0" >14149</td>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row5_col1" class="data row5 col1" >0</td>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row5_col2" class="data row5 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5be944c_994c_11ec_b41f_02420a39e3a2level0_row6" class="row_heading level0 row6" >primary_cleaner.output.concentrate_ag</th>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row6_col0" class="data row6 col0" >14149</td>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row6_col1" class="data row6 col1" >0</td>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row6_col2" class="data row6 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5be944c_994c_11ec_b41f_02420a39e3a2level0_row7" class="row_heading level0 row7" >primary_cleaner.output.concentrate_au</th>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row7_col0" class="data row7 col0" >14149</td>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row7_col1" class="data row7 col1" >0</td>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row7_col2" class="data row7 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5be944c_994c_11ec_b41f_02420a39e3a2level0_row8" class="row_heading level0 row8" >primary_cleaner.output.tail_au</th>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row8_col0" class="data row8 col0" >14149</td>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row8_col1" class="data row8 col1" >0</td>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row8_col2" class="data row8 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5be944c_994c_11ec_b41f_02420a39e3a2level0_row9" class="row_heading level0 row9" >rougher.calculation.au_pb_ratio</th>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row9_col0" class="data row9 col0" >14149</td>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row9_col1" class="data row9 col1" >0</td>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row9_col2" class="data row9 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5be944c_994c_11ec_b41f_02420a39e3a2level0_row10" class="row_heading level0 row10" >rougher.input.feed_ag</th>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row10_col0" class="data row10 col0" >14149</td>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row10_col1" class="data row10 col1" >0</td>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row10_col2" class="data row10 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5be944c_994c_11ec_b41f_02420a39e3a2level0_row11" class="row_heading level0 row11" >rougher.input.feed_au</th>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row11_col0" class="data row11 col0" >14149</td>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row11_col1" class="data row11 col1" >0</td>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row11_col2" class="data row11 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5be944c_994c_11ec_b41f_02420a39e3a2level0_row12" class="row_heading level0 row12" >rougher.output.concentrate_ag</th>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row12_col0" class="data row12 col0" >14149</td>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row12_col1" class="data row12 col1" >0</td>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row12_col2" class="data row12 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5be944c_994c_11ec_b41f_02420a39e3a2level0_row13" class="row_heading level0 row13" >rougher.output.concentrate_pb</th>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row13_col0" class="data row13 col0" >14149</td>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row13_col1" class="data row13 col1" >0</td>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row13_col2" class="data row13 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5be944c_994c_11ec_b41f_02420a39e3a2level0_row14" class="row_heading level0 row14" >rougher.output.concentrate_au</th>
#                         <td id="T_a5be944c_994c_11ec_b41f_02420a39e3a2row14_col0" class="dat
#   Малая доля пропусков:
# <style  type="text/css" >
# </style><table id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >na</th>        <th class="col_heading level0 col2" >fraction</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2level0_row0" class="row_heading level0 row0" >final.output.concentrate_ag</th>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row0_col0" class="data row0 col0" >14148</td>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row0_col1" class="data row0 col1" >1</td>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row0_col2" class="data row0 col2" >0.01%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2level0_row1" class="row_heading level0 row1" >final.output.concentrate_pb</th>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row1_col0" class="data row1 col0" >14148</td>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row1_col2" class="data row1 col2" >0.01%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2level0_row2" class="row_heading level0 row2" >final.output.tail_pb</th>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row2_col0" class="data row2 col0" >14049</td>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row2_col1" class="data row2 col1" >100</td>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row2_col2" class="data row2 col2" >0.71%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2level0_row3" class="row_heading level0 row3" >final.output.tail_sol</th>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row3_col0" class="data row3 col0" >14144</td>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row3_col1" class="data row3 col1" >5</td>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row3_col2" class="data row3 col2" >0.04%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2level0_row4" class="row_heading level0 row4" >primary_cleaner.input.sulfate</th>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row4_col0" class="data row4 col0" >14129</td>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row4_col1" class="data row4 col1" >20</td>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row4_col2" class="data row4 col2" >0.14%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2level0_row5" class="row_heading level0 row5" >primary_cleaner.input.depressant</th>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row5_col0" class="data row5 col0" >14117</td>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row5_col1" class="data row5 col1" >32</td>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row5_col2" class="data row5 col2" >0.23%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2level0_row6" class="row_heading level0 row6" >primary_cleaner.input.xanthate</th>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row6_col0" class="data row6 col0" >14049</td>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row6_col1" class="data row6 col1" >100</td>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row6_col2" class="data row6 col2" >0.71%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2level0_row7" class="row_heading level0 row7" >primary_cleaner.output.concentrate_pb</th>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row7_col0" class="data row7 col0" >14063</td>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row7_col1" class="data row7 col1" >86</td>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row7_col2" class="data row7 col2" >0.61%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2level0_row8" class="row_heading level0 row8" >primary_cleaner.output.tail_ag</th>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row8_col0" class="data row8 col0" >14148</td>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row8_col1" class="data row8 col1" >1</td>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row8_col2" class="data row8 col2" >0.01%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2level0_row9" class="row_heading level0 row9" >primary_cleaner.output.tail_pb</th>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row9_col0" class="data row9 col0" >14134</td>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row9_col1" class="data row9 col1" >15</td>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row9_col2" class="data row9 col2" >0.11%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2level0_row10" class="row_heading level0 row10" >primary_cleaner.output.tail_sol</th>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row10_col0" class="data row10 col0" >14103</td>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row10_col1" class="data row10 col1" >46</td>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row10_col2" class="data row10 col2" >0.33%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2level0_row11" class="row_heading level0 row11" >primary_cleaner.state.floatbank8_a_air</th>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row11_col0" class="data row11 col0" >14145</td>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row11_col1" class="data row11 col1" >4</td>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row11_col2" class="data row11 col2" >0.03%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2level0_row12" class="row_heading level0 row12" >primary_cleaner.state.floatbank8_a_level</th>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row12_col0" class="data row12 col0" >14148</td>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row12_col1" class="data row12 col1" >1</td>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row12_col2" class="data row12 col2" >0.01%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2level0_row13" class="row_heading level0 row13" >primary_cleaner.state.floatbank8_b_air</th>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row13_col0" class="data row13 col0" >14145</td>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row13_col1" class="data row13 col1" >4</td>
#                         <td id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2row13_col2" class="data row13 col2" >0.03%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5bfc5ba_994c_11ec_b41f_02420a39e3a2level0_row14" class="row_heading level0 row14" >primary_cleaner.state.floatbank8_b_level</th>
# Оценка остатка (при удалении пропусков с малой долей):  96.374%
#
#   Большая доля пропусков:
# <style  type="text/css" >
# </style><table id="T_a5c32412_994c_11ec_b41f_02420a39e3a2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >na</th>        <th class="col_heading level0 col2" >fraction</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a5c32412_994c_11ec_b41f_02420a39e3a2level0_row0" class="row_heading level0 row0" >final.output.concentrate_sol</th>
#                         <td id="T_a5c32412_994c_11ec_b41f_02420a39e3a2row0_col0" class="data row0 col0" >13938</td>
#                         <td id="T_a5c32412_994c_11ec_b41f_02420a39e3a2row0_col1" class="data row0 col1" >211</td>
#                         <td id="T_a5c32412_994c_11ec_b41f_02420a39e3a2row0_col2" class="data row0 col2" >1.51%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5c32412_994c_11ec_b41f_02420a39e3a2level0_row1" class="row_heading level0 row1" >primary_cleaner.output.concentrate_sol</th>
#                         <td id="T_a5c32412_994c_11ec_b41f_02420a39e3a2row1_col0" class="data row1 col0" >13863</td>
#                         <td id="T_a5c32412_994c_11ec_b41f_02420a39e3a2row1_col1" class="data row1 col1" >286</td>
#                         <td id="T_a5c32412_994c_11ec_b41f_02420a39e3a2row1_col2" class="data row1 col2" >2.06%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5c32412_994c_11ec_b41f_02420a39e3a2level0_row2" class="row_heading level0 row2" >rougher.input.feed_size</th>
#                         <td id="T_a5c32412_994c_11ec_b41f_02420a39e3a2row2_col0" class="data row2 col0" >14005</td>
#                         <td id="T_a5c32412_994c_11ec_b41f_02420a39e3a2row2_col1" class="data row2 col1" >144</td>
#                         <td id="T_a5c32412_994c_11ec_b41f_02420a39e3a2row2_col2" class="data row2 col2" >1.03%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5c32412_994c_11ec_b41f_02420a39e3a2level0_row3" class="row_heading level0 row3" >rougher.input.floatbank11_xanthate</th>
#                         <td id="T_a5c32412_994c_11ec_b41f_02420a39e3a2row3_col0" class="data row3 col0" >13721</td>
#                         <td id="T_a5c32412_994c_11ec_b41f_02420a39e3a2row3_col1" class="data row3 col1" >428</td>
#                         <td id="T_a5c32412_994c_11ec_b41f_02420a39e3a2row3_col2" class="data row3 col2" >3.12%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5c32412_994c_11ec_b41f_02420a39e3a2level0_row4" class="row_heading level0 row4" >rougher.state.floatbank10_e_air</th>
#                         <td id="T_a5c32412_994c_11ec_b41f_02420a39e3a2row4_col0" class="data row4 col0" >13713</td>
#                         <td id="T_a5c32412_994c_11ec_b41f_02420a39e3a2row4_col1" class="data row4 col1" >436</td>
#                         <td id="T_a5c32412_994c_11ec_b41f_02420a39e3a2row4_col2" class="data row4 col2" >3.18%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5c32412_994c_11ec_b41f_02420a39e3a2level0_row5" class="row_heading level0 row5" >secondary_cleaner.output.tail_sol</th>
#                         <td id="T_a5c32412_994c_11ec_b41f_02420a39e3a2row5_col0" class="data row5 col0" >12544</td>
#                         <td id="T_a5c32412_994c_11ec_b41f_02420a39e3a2row5_col1" class="data row5 col1" >1605</td>
#                         <td id="T_a5c32412_994c_11ec_b41f_02420a39e3a2row5_col2" class="data row5 col2" >12.79%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5c32412_994c_11ec_b41f_02420a39e3a2level0_row6" class="row_heading level0 row6" >secondary_cleaner.state.floatbank2_a_air</th>
#                         <td id="T_a5c32412_994c_11ec_b41f_02420a39e3a2row6_col0" class="data row6 col0" >13932</td>
#                         <td id="T_a5c32412_994c_11ec_b41f_02420a39e3a2row6_col1" class="data row6 col1" >217</td>
#                         <td id="T_a5c32412_994c_11ec_b41f_02420a39e3a2row6_col2" class="data row6 col2" >1.56%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Тестовая выборка

# %%
na_indexes['test'] = na_info(df['test'], level=0.01)
# Out:
#   Нет пропусков:
# <style  type="text/css" >
# </style><table id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >na</th>        <th class="col_heading level0 col2" >fraction</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2level0_row0" class="row_heading level0 row0" >date</th>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row0_col0" class="data row0 col0" >5290</td>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row0_col2" class="data row0 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2level0_row1" class="row_heading level0 row1" >primary_cleaner.input.feed_size</th>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row1_col0" class="data row1 col0" >5290</td>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row1_col1" class="data row1 col1" >0</td>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row1_col2" class="data row1 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2level0_row2" class="row_heading level0 row2" >primary_cleaner.state.floatbank8_a_air</th>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row2_col0" class="data row2 col0" >5290</td>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row2_col1" class="data row2 col1" >0</td>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row2_col2" class="data row2 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2level0_row3" class="row_heading level0 row3" >primary_cleaner.state.floatbank8_a_level</th>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row3_col0" class="data row3 col0" >5290</td>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row3_col1" class="data row3 col1" >0</td>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row3_col2" class="data row3 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2level0_row4" class="row_heading level0 row4" >primary_cleaner.state.floatbank8_b_air</th>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row4_col0" class="data row4 col0" >5290</td>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row4_col1" class="data row4 col1" >0</td>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row4_col2" class="data row4 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2level0_row5" class="row_heading level0 row5" >primary_cleaner.state.floatbank8_b_level</th>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row5_col0" class="data row5 col0" >5290</td>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row5_col1" class="data row5 col1" >0</td>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row5_col2" class="data row5 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2level0_row6" class="row_heading level0 row6" >primary_cleaner.state.floatbank8_c_air</th>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row6_col0" class="data row6 col0" >5290</td>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row6_col1" class="data row6 col1" >0</td>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row6_col2" class="data row6 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2level0_row7" class="row_heading level0 row7" >primary_cleaner.state.floatbank8_c_level</th>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row7_col0" class="data row7 col0" >5290</td>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row7_col1" class="data row7 col1" >0</td>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row7_col2" class="data row7 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2level0_row8" class="row_heading level0 row8" >primary_cleaner.state.floatbank8_d_air</th>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row8_col0" class="data row8 col0" >5290</td>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row8_col1" class="data row8 col1" >0</td>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row8_col2" class="data row8 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2level0_row9" class="row_heading level0 row9" >primary_cleaner.state.floatbank8_d_level</th>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row9_col0" class="data row9 col0" >5290</td>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row9_col1" class="data row9 col1" >0</td>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row9_col2" class="data row9 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2level0_row10" class="row_heading level0 row10" >rougher.input.feed_ag</th>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row10_col0" class="data row10 col0" >5290</td>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row10_col1" class="data row10 col1" >0</td>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row10_col2" class="data row10 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2level0_row11" class="row_heading level0 row11" >rougher.input.feed_pb</th>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row11_col0" class="data row11 col0" >5290</td>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row11_col1" class="data row11 col1" >0</td>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row11_col2" class="data row11 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2level0_row12" class="row_heading level0 row12" >rougher.input.feed_au</th>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row12_col0" class="data row12 col0" >5290</td>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row12_col1" class="data row12 col1" >0</td>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row12_col2" class="data row12 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2level0_row13" class="row_heading level0 row13" >rougher.input.floatbank10_xanthate</th>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row13_col0" class="data row13 col0" >5290</td>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row13_col1" class="data row13 col1" >0</td>
#                         <td id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2row13_col2" class="data row13 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5c9b58e_994c_11ec_b41f_02420a39e3a2level0_row14" class="row_heading level0 row14" >rougher.state.floatbank10_a_air</th>
#   Малая доля пропусков:
# <style  type="text/css" >
# </style><table id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >na</th>        <th class="col_heading level0 col2" >fraction</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2level0_row0" class="row_heading level0 row0" >primary_cleaner.input.sulfate</th>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row0_col0" class="data row0 col0" >5286</td>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row0_col1" class="data row0 col1" >4</td>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row0_col2" class="data row0 col2" >0.08%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2level0_row1" class="row_heading level0 row1" >primary_cleaner.input.depressant</th>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row1_col0" class="data row1 col0" >5285</td>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row1_col1" class="data row1 col1" >5</td>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row1_col2" class="data row1 col2" >0.09%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2level0_row2" class="row_heading level0 row2" >primary_cleaner.input.xanthate</th>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row2_col0" class="data row2 col0" >5286</td>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row2_col1" class="data row2 col1" >4</td>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row2_col2" class="data row2 col2" >0.08%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2level0_row3" class="row_heading level0 row3" >rougher.input.feed_rate</th>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row3_col0" class="data row3 col0" >5287</td>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row3_col1" class="data row3 col1" >3</td>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row3_col2" class="data row3 col2" >0.06%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2level0_row4" class="row_heading level0 row4" >rougher.input.feed_size</th>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row4_col0" class="data row4 col0" >5289</td>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row4_col1" class="data row4 col1" >1</td>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row4_col2" class="data row4 col2" >0.02%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2level0_row5" class="row_heading level0 row5" >rougher.input.feed_sol</th>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row5_col0" class="data row5 col0" >5269</td>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row5_col1" class="data row5 col1" >21</td>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row5_col2" class="data row5 col2" >0.40%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2level0_row6" class="row_heading level0 row6" >rougher.input.floatbank10_sulfate</th>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row6_col0" class="data row6 col0" >5285</td>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row6_col1" class="data row6 col1" >5</td>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row6_col2" class="data row6 col2" >0.09%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2level0_row7" class="row_heading level0 row7" >rougher.input.floatbank11_sulfate</th>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row7_col0" class="data row7 col0" >5282</td>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row7_col1" class="data row7 col1" >8</td>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row7_col2" class="data row7 col2" >0.15%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2level0_row8" class="row_heading level0 row8" >rougher.input.floatbank11_xanthate</th>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row8_col0" class="data row8 col0" >5265</td>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row8_col1" class="data row8 col1" >25</td>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row8_col2" class="data row8 col2" >0.47%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2level0_row9" class="row_heading level0 row9" >secondary_cleaner.state.floatbank2_a_air</th>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row9_col0" class="data row9 col0" >5287</td>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row9_col1" class="data row9 col1" >3</td>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row9_col2" class="data row9 col2" >0.06%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2level0_row10" class="row_heading level0 row10" >secondary_cleaner.state.floatbank2_b_air</th>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row10_col0" class="data row10 col0" >5288</td>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row10_col1" class="data row10 col1" >2</td>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row10_col2" class="data row10 col2" >0.04%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2level0_row11" class="row_heading level0 row11" >secondary_cleaner.state.floatbank3_a_air</th>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row11_col0" class="data row11 col0" >5281</td>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row11_col1" class="data row11 col1" >9</td>
#                         <td id="T_a5cb79dc_994c_11ec_b41f_02420a39e3a2row11_col2" class="data row11 col2" >0.17%</td>
#             </tr>
#     </tbody></table>
# Оценка остатка (при удалении пропусков с малой долей):  98.847%
#
#   Большая доля пропусков:
# <style  type="text/css" >
# </style><table id="T_a5cd7890_994c_11ec_b41f_02420a39e3a2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >na</th>        <th class="col_heading level0 col2" >fraction</th>    </tr></thead><tbody>
#         </tbody></table>

# %% [markdown]
# **Выводы, решения:**
#
# 1. Исходную выборку оставим без изменения (она не будет участвовать в построении модели и останется базовым хранилищем данных).
# 1. В тестовой выборке отсутствуют некоторые признаки, доступные в исходномй наборе данных и в обучающей выборке. Это вычисляемые значения и данные на "*выходе*" из очередного этапа обработки руды (т.е. типы параметров: `output` и `calculation`)*. Они отсутствуют, потому что замеряются и/или рассчитываются значительно позже.
# > удалим эти данные также и из обучающей выборки, поскольку на вход модели должны подаваться только "*входные*" данные.
# 1. Удалим все пропуски из тестовой выборки, поскольку их менее 2%, и они не будут непосредственно использоваться в прогнозировании на модели, а данном случае пропуски недопустимы.
# 1. Данные с большим количеством пропусков по обучающей выборке рассмотрим отдельно.

# %% [markdown]
# \* *структура отсутствующих в тестовой выборке данных*:

# %%
data_structure[data_structure['test'].isna()].index
# Out:
# MultiIndex([(            'final',      'output', ...),
#             (            'final',      'output', ...),
#             (            'final',      'output', ...),
#             (            'final',      'output', ...),
#             (            'final',      'output', ...),
#             (            'final',      'output', ...),
#             (            'final',      'output', ...),
#             (            'final',      'output', ...),
#             (            'final',      'output', ...),
#             (  'primary_cleaner',      'output', ...),
#             (  'primary_cleaner',      'output', ...),
#             (  'primary_cleaner',      'output', ...),
#             (  'primary_cleaner',      'output', ...),
#             (  'primary_cleaner',      'output', ...),
#             (  'primary_cleaner',      'output', ...),
#             (  'primary_cleaner',      'output', ...),
#             (  'primary_cleaner',      'output', ...),
#             (          'rougher', 'calculation', ...),
#             (          'rougher', 'calculation', ...),
#             (          'rougher', 'calculation', ...),
#             (          'rougher', 'calculation', ...),
#             (          'rougher',      'output', ...),
#             (          'rougher',      'output', ...),
#             (          'rougher',      'output', ...),
#             (          'rougher',      'output', ...),
#             (          'rougher',      'output', ...),
#             (          'rougher',      'output', ...),
#             (          'rougher',      'output', ...),
#             (          'rougher',      'output', ...),
#             (          'rougher',      'output', ...),
#             ('secondary_cleaner',      'output', ...),
#             ('secondary_cleaner',      'output', ...),
#             ('secondary_cleaner',      'output', ...),
#             ('secondary_cleaner',      'output', ...)],
#            names=['stage', 'param_type', 'param_name'])

# %% [markdown]
# #### Удалим пропуски из тестовой выборки:

# %%
df['test'] = df['test'].dropna()

# %%
na_indexes['test'] = na_info(df['test'], level=0.01)
# Out:
#   Нет пропусков:
# <style  type="text/css" >
# </style><table id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >na</th>        <th class="col_heading level0 col2" >fraction</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2level0_row0" class="row_heading level0 row0" >date</th>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row0_col0" class="data row0 col0" >5229</td>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row0_col2" class="data row0 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2level0_row1" class="row_heading level0 row1" >primary_cleaner.input.sulfate</th>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row1_col0" class="data row1 col0" >5229</td>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row1_col1" class="data row1 col1" >0</td>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row1_col2" class="data row1 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2level0_row2" class="row_heading level0 row2" >primary_cleaner.input.depressant</th>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row2_col0" class="data row2 col0" >5229</td>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row2_col1" class="data row2 col1" >0</td>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row2_col2" class="data row2 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2level0_row3" class="row_heading level0 row3" >primary_cleaner.input.feed_size</th>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row3_col0" class="data row3 col0" >5229</td>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row3_col1" class="data row3 col1" >0</td>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row3_col2" class="data row3 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2level0_row4" class="row_heading level0 row4" >primary_cleaner.input.xanthate</th>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row4_col0" class="data row4 col0" >5229</td>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row4_col1" class="data row4 col1" >0</td>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row4_col2" class="data row4 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2level0_row5" class="row_heading level0 row5" >primary_cleaner.state.floatbank8_a_air</th>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row5_col0" class="data row5 col0" >5229</td>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row5_col1" class="data row5 col1" >0</td>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row5_col2" class="data row5 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2level0_row6" class="row_heading level0 row6" >primary_cleaner.state.floatbank8_a_level</th>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row6_col0" class="data row6 col0" >5229</td>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row6_col1" class="data row6 col1" >0</td>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row6_col2" class="data row6 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2level0_row7" class="row_heading level0 row7" >primary_cleaner.state.floatbank8_b_air</th>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row7_col0" class="data row7 col0" >5229</td>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row7_col1" class="data row7 col1" >0</td>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row7_col2" class="data row7 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2level0_row8" class="row_heading level0 row8" >primary_cleaner.state.floatbank8_b_level</th>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row8_col0" class="data row8 col0" >5229</td>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row8_col1" class="data row8 col1" >0</td>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row8_col2" class="data row8 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2level0_row9" class="row_heading level0 row9" >primary_cleaner.state.floatbank8_c_air</th>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row9_col0" class="data row9 col0" >5229</td>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row9_col1" class="data row9 col1" >0</td>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row9_col2" class="data row9 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2level0_row10" class="row_heading level0 row10" >primary_cleaner.state.floatbank8_c_level</th>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row10_col0" class="data row10 col0" >5229</td>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row10_col1" class="data row10 col1" >0</td>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row10_col2" class="data row10 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2level0_row11" class="row_heading level0 row11" >primary_cleaner.state.floatbank8_d_air</th>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row11_col0" class="data row11 col0" >5229</td>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row11_col1" class="data row11 col1" >0</td>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row11_col2" class="data row11 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2level0_row12" class="row_heading level0 row12" >primary_cleaner.state.floatbank8_d_level</th>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row12_col0" class="data row12 col0" >5229</td>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row12_col1" class="data row12 col1" >0</td>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row12_col2" class="data row12 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2level0_row13" class="row_heading level0 row13" >rougher.input.feed_ag</th>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row13_col0" class="data row13 col0" >5229</td>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row13_col1" class="data row13 col1" >0</td>
#                         <td id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2row13_col2" class="data row13 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5d885fa_994c_11ec_b41f_02420a39e3a2level0_row14" class="row_heading level0 row14" >rougher.input.feed_pb</th>
#   Малая доля пропусков:
# <style  type="text/css" >
# </style><table id="T_a5da7248_994c_11ec_b41f_02420a39e3a2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >na</th>        <th class="col_heading level0 col2" >fraction</th>    </tr></thead><tbody>
#         </tbody></table>
# Оценка остатка (при удалении пропусков с малой долей):  100.000%
#
#   Большая доля пропусков:
# <style  type="text/css" >
# </style><table id="T_a5dbca4e_994c_11ec_b41f_02420a39e3a2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >na</th>        <th class="col_heading level0 col2" >fraction</th>    </tr></thead><tbody>
#         </tbody></table>

# %% [markdown]
# #### Обработаем пропуски из обучающей выборки:

# %% [markdown]
# Удалим "*входные*" данные:

# %%
df['train'] = df['train'].drop(rows_info[rows_info['test'].isna()].index, axis=1)

# %%
na_indexes['train'] = na_info(df['train'], level=0.01)
# Out:
#   Нет пропусков:
# <style  type="text/css" >
# </style><table id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >na</th>        <th class="col_heading level0 col2" >fraction</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2level0_row0" class="row_heading level0 row0" >date</th>
#                         <td id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2row0_col0" class="data row0 col0" >14149</td>
#                         <td id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2row0_col2" class="data row0 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2level0_row1" class="row_heading level0 row1" >primary_cleaner.input.feed_size</th>
#                         <td id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2row1_col0" class="data row1 col0" >14149</td>
#                         <td id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2row1_col1" class="data row1 col1" >0</td>
#                         <td id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2row1_col2" class="data row1 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2level0_row2" class="row_heading level0 row2" >rougher.input.feed_ag</th>
#                         <td id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2row2_col0" class="data row2 col0" >14149</td>
#                         <td id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2row2_col1" class="data row2 col1" >0</td>
#                         <td id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2row2_col2" class="data row2 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2level0_row3" class="row_heading level0 row3" >rougher.input.feed_au</th>
#                         <td id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2row3_col0" class="data row3 col0" >14149</td>
#                         <td id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2row3_col1" class="data row3 col1" >0</td>
#                         <td id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2row3_col2" class="data row3 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2level0_row4" class="row_heading level0 row4" >rougher.state.floatbank10_d_air</th>
#                         <td id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2row4_col0" class="data row4 col0" >14149</td>
#                         <td id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2row4_col1" class="data row4 col1" >0</td>
#                         <td id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2row4_col2" class="data row4 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2level0_row5" class="row_heading level0 row5" >rougher.state.floatbank10_d_level</th>
#                         <td id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2row5_col0" class="data row5 col0" >14149</td>
#                         <td id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2row5_col1" class="data row5 col1" >0</td>
#                         <td id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2row5_col2" class="data row5 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2level0_row6" class="row_heading level0 row6" >rougher.state.floatbank10_e_level</th>
#                         <td id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2row6_col0" class="data row6 col0" >14149</td>
#                         <td id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2row6_col1" class="data row6 col1" >0</td>
#                         <td id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2row6_col2" class="data row6 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2level0_row7" class="row_heading level0 row7" >rougher.state.floatbank10_f_air</th>
#                         <td id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2row7_col0" class="data row7 col0" >14149</td>
#                         <td id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2row7_col1" class="data row7 col1" >0</td>
#                         <td id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2row7_col2" class="data row7 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2level0_row8" class="row_heading level0 row8" >rougher.state.floatbank10_f_level</th>
#                         <td id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2row8_col0" class="data row8 col0" >14149</td>
#                         <td id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2row8_col1" class="data row8 col1" >0</td>
#                         <td id="T_a5e29e32_994c_11ec_b41f_02420a39e3a2row8_col2" class="data row8 col2" >0.00%</td>
#             </tr>
#     </tbody></table>
#   Малая доля пропусков:
# <style  type="text/css" >
# </style><table id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >na</th>        <th class="col_heading level0 col2" >fraction</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2level0_row0" class="row_heading level0 row0" >primary_cleaner.input.sulfate</th>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row0_col0" class="data row0 col0" >14129</td>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row0_col1" class="data row0 col1" >20</td>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row0_col2" class="data row0 col2" >0.14%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2level0_row1" class="row_heading level0 row1" >primary_cleaner.input.depressant</th>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row1_col0" class="data row1 col0" >14117</td>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row1_col1" class="data row1 col1" >32</td>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row1_col2" class="data row1 col2" >0.23%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2level0_row2" class="row_heading level0 row2" >primary_cleaner.input.xanthate</th>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row2_col0" class="data row2 col0" >14049</td>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row2_col1" class="data row2 col1" >100</td>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row2_col2" class="data row2 col2" >0.71%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2level0_row3" class="row_heading level0 row3" >primary_cleaner.state.floatbank8_a_air</th>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row3_col0" class="data row3 col0" >14145</td>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row3_col1" class="data row3 col1" >4</td>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row3_col2" class="data row3 col2" >0.03%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2level0_row4" class="row_heading level0 row4" >primary_cleaner.state.floatbank8_a_level</th>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row4_col0" class="data row4 col0" >14148</td>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row4_col1" class="data row4 col1" >1</td>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row4_col2" class="data row4 col2" >0.01%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2level0_row5" class="row_heading level0 row5" >primary_cleaner.state.floatbank8_b_air</th>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row5_col0" class="data row5 col0" >14145</td>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row5_col1" class="data row5 col1" >4</td>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row5_col2" class="data row5 col2" >0.03%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2level0_row6" class="row_heading level0 row6" >primary_cleaner.state.floatbank8_b_level</th>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row6_col0" class="data row6 col0" >14148</td>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row6_col1" class="data row6 col1" >1</td>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row6_col2" class="data row6 col2" >0.01%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2level0_row7" class="row_heading level0 row7" >primary_cleaner.state.floatbank8_c_air</th>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row7_col0" class="data row7 col0" >14147</td>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row7_col1" class="data row7 col1" >2</td>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row7_col2" class="data row7 col2" >0.01%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2level0_row8" class="row_heading level0 row8" >primary_cleaner.state.floatbank8_c_level</th>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row8_col0" class="data row8 col0" >14148</td>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row8_col1" class="data row8 col1" >1</td>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row8_col2" class="data row8 col2" >0.01%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2level0_row9" class="row_heading level0 row9" >primary_cleaner.state.floatbank8_d_air</th>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row9_col0" class="data row9 col0" >14146</td>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row9_col1" class="data row9 col1" >3</td>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row9_col2" class="data row9 col2" >0.02%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2level0_row10" class="row_heading level0 row10" >primary_cleaner.state.floatbank8_d_level</th>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row10_col0" class="data row10 col0" >14148</td>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row10_col1" class="data row10 col1" >1</td>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row10_col2" class="data row10 col2" >0.01%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2level0_row11" class="row_heading level0 row11" >rougher.input.feed_pb</th>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row11_col0" class="data row11 col0" >14049</td>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row11_col1" class="data row11 col1" >100</td>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row11_col2" class="data row11 col2" >0.71%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2level0_row12" class="row_heading level0 row12" >rougher.input.feed_rate</th>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row12_col0" class="data row12 col0" >14141</td>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row12_col1" class="data row12 col1" >8</td>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row12_col2" class="data row12 col2" >0.06%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2level0_row13" class="row_heading level0 row13" >rougher.input.feed_sol</th>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row13_col0" class="data row13 col0" >14071</td>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row13_col1" class="data row13 col1" >78</td>
#                         <td id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2row13_col2" class="data row13 col2" >0.55%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5e3c1b8_994c_11ec_b41f_02420a39e3a2level0_row14" class="row_heading level0 row14" >rougher.i
# Оценка остатка (при удалении пропусков с малой долей):  97.569%
#
#   Большая доля пропусков:
# <style  type="text/css" >
# </style><table id="T_a5e91d16_994c_11ec_b41f_02420a39e3a2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >na</th>        <th class="col_heading level0 col2" >fraction</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a5e91d16_994c_11ec_b41f_02420a39e3a2level0_row0" class="row_heading level0 row0" >rougher.input.feed_size</th>
#                         <td id="T_a5e91d16_994c_11ec_b41f_02420a39e3a2row0_col0" class="data row0 col0" >14005</td>
#                         <td id="T_a5e91d16_994c_11ec_b41f_02420a39e3a2row0_col1" class="data row0 col1" >144</td>
#                         <td id="T_a5e91d16_994c_11ec_b41f_02420a39e3a2row0_col2" class="data row0 col2" >1.03%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5e91d16_994c_11ec_b41f_02420a39e3a2level0_row1" class="row_heading level0 row1" >rougher.input.floatbank11_xanthate</th>
#                         <td id="T_a5e91d16_994c_11ec_b41f_02420a39e3a2row1_col0" class="data row1 col0" >13721</td>
#                         <td id="T_a5e91d16_994c_11ec_b41f_02420a39e3a2row1_col1" class="data row1 col1" >428</td>
#                         <td id="T_a5e91d16_994c_11ec_b41f_02420a39e3a2row1_col2" class="data row1 col2" >3.12%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5e91d16_994c_11ec_b41f_02420a39e3a2level0_row2" class="row_heading level0 row2" >rougher.state.floatbank10_e_air</th>
#                         <td id="T_a5e91d16_994c_11ec_b41f_02420a39e3a2row2_col0" class="data row2 col0" >13713</td>
#                         <td id="T_a5e91d16_994c_11ec_b41f_02420a39e3a2row2_col1" class="data row2 col1" >436</td>
#                         <td id="T_a5e91d16_994c_11ec_b41f_02420a39e3a2row2_col2" class="data row2 col2" >3.18%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5e91d16_994c_11ec_b41f_02420a39e3a2level0_row3" class="row_heading level0 row3" >secondary_cleaner.state.floatbank2_a_air</th>
#                         <td id="T_a5e91d16_994c_11ec_b41f_02420a39e3a2row3_col0" class="data row3 col0" >13932</td>
#                         <td id="T_a5e91d16_994c_11ec_b41f_02420a39e3a2row3_col1" class="data row3 col1" >217</td>
#                         <td id="T_a5e91d16_994c_11ec_b41f_02420a39e3a2row3_col2" class="data row3 col2" >1.56%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Заменим пропуски с большой долей медианными значениями, а пропуски с малой долей удалим:

# %%
for col in na_indexes['train']['process']:
    df['train'][col] = df['train'][col].fillna(df['train'][col].median())

# %%
df['train'] = df['train'].dropna()

# %%
na_info(df['train'], level=0.01)
# Out:
#   Нет пропусков:
# <style  type="text/css" >
# </style><table id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >na</th>        <th class="col_heading level0 col2" >fraction</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2level0_row0" class="row_heading level0 row0" >date</th>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row0_col0" class="data row0 col0" >13805</td>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row0_col2" class="data row0 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2level0_row1" class="row_heading level0 row1" >primary_cleaner.input.sulfate</th>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row1_col0" class="data row1 col0" >13805</td>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row1_col1" class="data row1 col1" >0</td>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row1_col2" class="data row1 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2level0_row2" class="row_heading level0 row2" >primary_cleaner.input.depressant</th>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row2_col0" class="data row2 col0" >13805</td>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row2_col1" class="data row2 col1" >0</td>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row2_col2" class="data row2 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2level0_row3" class="row_heading level0 row3" >primary_cleaner.input.feed_size</th>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row3_col0" class="data row3 col0" >13805</td>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row3_col1" class="data row3 col1" >0</td>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row3_col2" class="data row3 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2level0_row4" class="row_heading level0 row4" >primary_cleaner.input.xanthate</th>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row4_col0" class="data row4 col0" >13805</td>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row4_col1" class="data row4 col1" >0</td>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row4_col2" class="data row4 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2level0_row5" class="row_heading level0 row5" >primary_cleaner.state.floatbank8_a_air</th>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row5_col0" class="data row5 col0" >13805</td>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row5_col1" class="data row5 col1" >0</td>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row5_col2" class="data row5 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2level0_row6" class="row_heading level0 row6" >primary_cleaner.state.floatbank8_a_level</th>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row6_col0" class="data row6 col0" >13805</td>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row6_col1" class="data row6 col1" >0</td>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row6_col2" class="data row6 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2level0_row7" class="row_heading level0 row7" >primary_cleaner.state.floatbank8_b_air</th>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row7_col0" class="data row7 col0" >13805</td>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row7_col1" class="data row7 col1" >0</td>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row7_col2" class="data row7 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2level0_row8" class="row_heading level0 row8" >primary_cleaner.state.floatbank8_b_level</th>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row8_col0" class="data row8 col0" >13805</td>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row8_col1" class="data row8 col1" >0</td>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row8_col2" class="data row8 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2level0_row9" class="row_heading level0 row9" >primary_cleaner.state.floatbank8_c_air</th>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row9_col0" class="data row9 col0" >13805</td>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row9_col1" class="data row9 col1" >0</td>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row9_col2" class="data row9 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2level0_row10" class="row_heading level0 row10" >primary_cleaner.state.floatbank8_c_level</th>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row10_col0" class="data row10 col0" >13805</td>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row10_col1" class="data row10 col1" >0</td>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row10_col2" class="data row10 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2level0_row11" class="row_heading level0 row11" >primary_cleaner.state.floatbank8_d_air</th>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row11_col0" class="data row11 col0" >13805</td>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row11_col1" class="data row11 col1" >0</td>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row11_col2" class="data row11 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2level0_row12" class="row_heading level0 row12" >primary_cleaner.state.floatbank8_d_level</th>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row12_col0" class="data row12 col0" >13805</td>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row12_col1" class="data row12 col1" >0</td>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row12_col2" class="data row12 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2level0_row13" class="row_heading level0 row13" >rougher.input.feed_ag</th>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row13_col0" class="data row13 col0" >13805</td>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row13_col1" class="data row13 col1" >0</td>
#                         <td id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2row13_col2" class="data row13 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5f1f4ae_994c_11ec_b41f_02420a39e3a2level0_row14" class="row_heading level0 row14" >rougher.input.feed_pb</th>
#   Малая доля пропусков:
# <style  type="text/css" >
# </style><table id="T_a5f93890_994c_11ec_b41f_02420a39e3a2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >na</th>        <th class="col_heading level0 col2" >fraction</th>    </tr></thead><tbody>
#         </tbody></table>
# Оценка остатка (при удалении пропусков с малой долей):  100.000%
#
#   Большая доля пропусков:
# <style  type="text/css" >
# </style><table id="T_a5fb2448_994c_11ec_b41f_02420a39e3a2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >na</th>        <th class="col_heading level0 col2" >fraction</th>    </tr></thead><tbody>
#         </tbody></table>
# {'delete': [], 'process': []}

# %%
show_remain(df)
# Out:
# <style  type="text/css" >
# </style><table id="T_a5fce260_994c_11ec_b41f_02420a39e3a2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Число строк</th>        <th class="col_heading level0 col1" >Число столбцов</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a5fce260_994c_11ec_b41f_02420a39e3a2level0_row0" class="row_heading level0 row0" >full</th>
#                         <td id="T_a5fce260_994c_11ec_b41f_02420a39e3a2row0_col0" class="data row0 col0" >100.0%</td>
#                         <td id="T_a5fce260_994c_11ec_b41f_02420a39e3a2row0_col1" class="data row0 col1" >100.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5fce260_994c_11ec_b41f_02420a39e3a2level0_row1" class="row_heading level0 row1" >train</th>
#                         <td id="T_a5fce260_994c_11ec_b41f_02420a39e3a2row1_col0" class="data row1 col0" >97.6%</td>
#                         <td id="T_a5fce260_994c_11ec_b41f_02420a39e3a2row1_col1" class="data row1 col1" >60.9%</td>
#             </tr>
#             <tr>
#                         <th id="T_a5fce260_994c_11ec_b41f_02420a39e3a2level0_row2" class="row_heading level0 row2" >test</th>
#                         <td id="T_a5fce260_994c_11ec_b41f_02420a39e3a2row2_col0" class="data row2 col0" >98.8%</td>
#                         <td id="T_a5fce260_994c_11ec_b41f_02420a39e3a2row2_col1" class="data row2 col1" >100.0%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# **Выводы:**
#
# 1. Исходные данные (таблица `full`) оставлена без изменений.
# 1. В тестовой выборке (таблица `test`) удалены все пропуски.
# 1. В обучающей выборке (таблица `train`) пропуски с большой долей заменены на медианные значения, а пропуски с малой долей удалены.
# 1. Потеря данных (по объектно) - порядка 2%.

# %% [markdown]
# ### Замена типов данных

# %% [markdown]
# Исправим тип данных для параметра `date`:

# %%
for table in data_names:
    df[table]['date'] = pd.to_datetime(df[table]['date'], format='%Y-%m-%d %H:%M:%S')
df_origin['date'] = pd.to_datetime(df_origin['date'], format='%Y-%m-%d %H:%M:%S')

# %%
display_all(df, data_names, 'dtypes')
# Out:
#    ТАБЛИЦА full ====================================================================== ТАБЛИЦА full
# date                                                  datetime64[ns]
# final.output.concentrate_ag                                  float64
# final.output.concentrate_pb                                  float64
# final.output.concentrate_sol                                 float64
# final.output.concentrate_au                                  float64
# final.output.recovery                                        float64
# final.output.tail_ag                                         float64
# final.output.tail_pb                                         float64
# final.output.tail_sol                                        float64
# final.output.tail_au                                         float64
# primary_cleaner.input.sulfate                                float64
# primary_cleaner.input.depressant                             float64
# primary_cleaner.input.feed_size                              float64
# primary_cleaner.input.xanthate                               float64
# primary_cleaner.output.concentrate_ag                        float64
# primary_cleaner.output.concentrate_pb                        float64
# primary_cleaner.output.concentrate_sol                       float64
# primary_cleaner.output.concentrate_au                        float64
# primary_cleaner.output.tail_ag                               float64
# primary_cleaner.output.tail_pb                               float64
# primary_cleaner.output.tail_sol                              float64
# primary_cleaner.output.tail_au                               float64
# primary_cleaner.state.floatbank8_a_air                       float64
# primary_cleaner.state.floatbank8_a_level                     float64
# primary_cleaner.state.floatbank8_b_air                       float64
# primary_cleaner.state.floatbank8_b_level                     float64
# primary_cleaner.state.floatbank8_c_air                       float64
# primary_cleaner.state.floatbank8_c_level                     float64
# primary_cleaner.state.floatbank8_d_air                       float64
# primary_cleaner.state.floatbank8_d_level                     float64
# rougher.calculation.sulfate_to_au_concentrate                float64
# rougher.calculation.floatbank10_sulfate_to_au_feed           float64
# rougher.calculation.floatbank11_sulfate_to_au_feed           float64
# rougher.calculation.au_pb_ratio                              float64
# rougher.input.feed_ag                                        float64
# rougher.input.feed_pb                                        float64
# rougher.input.feed_rate                                      float64
# rougher.input.feed_size                                      float64
# rougher.input.feed_sol                                       float64
# rougher.input.feed_au                                        float64
# rougher.input.floatbank10_sulfate                            float64
# rougher.input.floatbank10_xanthate                           float64
# rougher.input.floatbank11_sulfate                            float64
# rougher.input.floatbank11_xanthate                           float64
# rougher.output.concentrate_ag                                float64
# rougher.output.concentrate_pb                                float64
# rougher.output.concentrate_sol                               float64
# rougher.output.concentrate_au                                float64
# rougher.output.recovery                                      float64
# rougher.output.tail_ag                                       float64
# rougher.output.tail_pb                                       float64
# rougher.output.tail_sol                                      float64
# rougher.output.tail_au                                       float64
# rougher.state.floatbank10_a_air                              float64
# rougher.state.floatbank10_a_level                            float64
# rougher.state.floatbank10_b_air                              float64
# rougher.state.floatbank10_b_level                            float64
# rougher.state.floatbank10_c_air                              float64
# rougher.state.floatbank10_c_level                            float64
# rougher.state.floatbank10_d_air                              float64
# rougher.state.floatbank10_d_level                            float64
# rougher.state.floatbank10_e_air                              float64
# rougher.state.floatbank10_e_level                            float64
# rougher.state.floatbank10_f_air                              float64
# rougher.state.floatbank10_f_level                            float64
# secondary_cleaner.output.tail_ag                             float64
# secondary_cleaner.output.tail_pb                             float64
# secondary_cleaner.output.tail_sol                            float64
# secondary_cleaner.output.tail_au                             float64
# secondary_cleaner.state.floatbank2_a_air                     float64
# secondary_cleaner.state.floatbank2_a_level                   float64
# secondary_cleaner.state.floatbank2_b_air                     float64
# secondary_cleaner.state.floatbank2_b_level                   float64
# secondary_cleaner.state.floatbank3_a_air                     float64
# secondary_cleaner.state.floatbank3_a_level                   float64
# secondary_cleaner.state.floatbank3_b_air                     float64
# secondary_cleaner.state.floatbank3_b_level                   float64
# secondary_cleaner.state.floatbank4_a_air                     float64
# secondary_cleaner.state.floatbank4_a_level                   float64
# secondary_cleaner.state.floatbank4_b_air                     float64
# secondary_cleaner.state.floatbank4_b_level                   float64
# secondary_cleaner.state.floatbank5_a_air                     float64
# secondary_cleaner.state.floatbank5_a_level                   float64
# secondary_cleaner.state.floatbank5_b_air                     float64
# secondary_cleaner.state.floatbank5_b_level                   float64
# secondary_cleaner.state.floatbank6_a_air                     float64
# secondary_cleaner.state.floatbank6_a_level                   float64
# dtype: object
#    ТАБЛИЦА train ==================================================================== ТАБЛИЦА train
# date                                          datetime64[ns]
# primary_cleaner.input.sulfate                        float64
# primary_cleaner.input.depressant                     float64
# primary_cleaner.input.feed_size                      float64
# primary_cleaner.input.xanthate                       float64
# primary_cleaner.state.floatbank8_a_air               float64
# primary_cleaner.state.floatbank8_a_level             float64
# primary_cleaner.state.floatbank8_b_air               float64
# primary_cleaner.state.floatbank8_b_level             float64
# primary_cleaner.state.floatbank8_c_air               float64
# primary_cleaner.state.floatbank8_c_level             float64
# primary_cleaner.state.floatbank8_d_air               float64
# primary_cleaner.state.floatbank8_d_level             float64
# rougher.input.feed_ag                                float64
# rougher.input.feed_pb                                float64
# rougher.input.feed_rate                              float64
# rougher.input.feed_size                              float64
# rougher.input.feed_sol                               float64
# rougher.input.feed_au                                float64
# rougher.input.floatbank10_sulfate                    float64
# rougher.input.floatbank10_xanthate                   float64
# rougher.input.floatbank11_sulfate                    float64
# rougher.input.floatbank11_xanthate                   float64
# rougher.state.floatbank10_a_air                      float64
# rougher.state.floatbank10_a_level                    float64
# rougher.state.floatbank10_b_air                      float64
# rougher.state.floatbank10_b_level                    float64
# rougher.state.floatbank10_c_air                      float64
# rougher.state.floatbank10_c_level                    float64
# rougher.state.floatbank10_d_air                      float64
# rougher.state.floatbank10_d_level                    float64
# rougher.state.floatbank10_e_air                      float64
# rougher.state.floatbank10_e_level                    float64
# rougher.state.floatbank10_f_air                      float64
# rougher.state.floatbank10_f_level                    float64
# secondary_cleaner.state.floatbank2_a_air             float64
# secondary_cleaner.state.floatbank2_a_level           float64
# secondary_cleaner.state.floatbank2_b_air             float64
# secondary_cleaner.state.floatbank2_b_level           float64
# secondary_cleaner.state.floatbank3_a_air             float64
# secondary_cleaner.state.floatbank3_a_level           float64
# secondary_cleaner.state.floatbank3_b_air             float64
# secondary_cleaner.state.floatbank3_b_level           float64
# secondary_cleaner.state.floatbank4_a_air             float64
# secondary_cleaner.state.floatbank4_a_level           float64
# secondary_cleaner.state.floatbank4_b_air             float64
# secondary_cleaner.state.floatbank4_b_level           float64
# secondary_cleaner.state.floatbank5_a_air             float64
# secondary_cleaner.state.floatbank5_a_level           float64
# secondary_cleaner.state.floatbank5_b_air             float64
# secondary_cleaner.state.floatbank5_b_level           float64
# secondary_cleaner.state.floatbank6_a_air             float64
# secondary_cleaner.state.floatbank6_a_level           float64
# dtype: object
#    ТАБЛИЦА test ====================================================================== ТАБЛИЦА test
# date                                          datetime64[ns]
# primary_cleaner.input.sulfate                        float64
# primary_cleaner.input.depressant                     float64
# primary_cleaner.input.feed_size                      float64
# primary_cleaner.input.xanthate                       float64
# primary_cleaner.state.floatbank8_a_air               float64
# primary_cleaner.state.floatbank8_a_level             float64
# primary_cleaner.state.floatbank8_b_air               float64
# primary_cleaner.state.floatbank8_b_level             float64
# primary_cleaner.state.floatbank8_c_air               float64
# primary_cleaner.state.floatbank8_c_level             float64
# primary_cleaner.state.floatbank8_d_air               float64
# primary_cleaner.state.floatbank8_d_level             float64
# rougher.input.feed_ag                                float64
# rougher.input.feed_pb                                float64
# rougher.input.feed_rate                              float64
# rougher.input.feed_size                              float64
# rougher.input.feed_sol                               float64
# rougher.input.feed_au                                float64
# rougher.input.floatbank10_sulfate                    float64
# rougher.input.floatbank10_xanthate                   float64
# rougher.input.floatbank11_sulfate                    float64
# rougher.input.floatbank11_xanthate                   float64
# rougher.state.floatbank10_a_air                      float64
# rougher.state.floatbank10_a_level                    float64
# rougher.state.floatbank10_b_air                      float64
# rougher.state.floatbank10_b_level                    float64
# rougher.state.floatbank10_c_air                      float64
# rougher.state.floatbank10_c_level                    float64
# rougher.state.floatbank10_d_air                      float64
# rougher.state.floatbank10_d_level                    float64
# rougher.state.floatbank10_e_air                      float64
# rougher.state.floatbank10_e_level                    float64
# rougher.state.floatbank10_f_air                      float64
# rougher.state.floatbank10_f_level                    float64
# secondary_cleaner.state.floatbank2_a_air             float64
# secondary_cleaner.state.floatbank2_a_level           float64
# secondary_cleaner.state.floatbank2_b_air             float64
# secondary_cleaner.state.floatbank2_b_level           float64
# secondary_cleaner.state.floatbank3_a_air             float64
# secondary_cleaner.state.floatbank3_a_level           float64
# secondary_cleaner.state.floatbank3_b_air             float64
# secondary_cleaner.state.floatbank3_b_level           float64
# secondary_cleaner.state.floatbank4_a_air             float64
# secondary_cleaner.state.floatbank4_a_level           float64
# secondary_cleaner.state.floatbank4_b_air             float64
# secondary_cleaner.state.floatbank4_b_level           float64
# secondary_cleaner.state.floatbank5_a_air             float64
# secondary_cleaner.state.floatbank5_a_level           float64
# secondary_cleaner.state.floatbank5_b_air             float64
# secondary_cleaner.state.floatbank5_b_level           float64
# secondary_cleaner.state.floatbank6_a_air             float64
# secondary_cleaner.state.floatbank6_a_level           float64
# dtype: object

# %% [markdown]
# **Вывод:**
#
# 1. Признаки `date` приведен к типу даты
# 1. Все параметры соответствуют своему типу данных (для каждой таблицы):
# - **1** дата имеет тип **`datetime`**
# - **86** численных парраметра имеют тип **`float`**

# %% [markdown]
# ### Проверка смысловых зависимостей

# %% [markdown]
# Проверим, что эффективность обогащения рассчитана правильно.

# %% [markdown]
# Проследим за стадиями золота (возьмем средние значения) для определения значений необходимых для расчета:

# %%
qdf(df['full'], '', '', 'au').mean().T
# Out:
# final.output.concentrate_au                              44.076513
# final.output.tail_au                                      3.042467
# primary_cleaner.output.concentrate_au                    32.119400
# primary_cleaner.output.tail_au                            3.914179
# rougher.calculation.sulfate_to_au_concentrate         42171.189025
# rougher.calculation.floatbank10_sulfate_to_au_feed     3393.052498
# rougher.calculation.floatbank11_sulfate_to_au_feed     3256.854171
# rougher.calculation.au_pb_ratio                           2.420119
# rougher.input.feed_au                                     8.266097
# rougher.output.concentrate_au                            19.772000
# rougher.output.tail_au                                    1.816391
# secondary_cleaner.output.tail_au                          4.339625
# dtype: float64

# %%
def changes_by_stages(df, metal):
    temp = {}
    for col in [f'concentrate_{metal}', f'tail_{metal}']:
        temp[col] = {}
        for row in ['rougher', 'primary', 'secondary', 'final']:
            select = qdf(df, row, '', [col])
            try:
                temp[col][row] = select.mean()[0]
            except:
                temp[col][row] = '-'
    return pd.DataFrame(temp)

# %%
changes_by_stages(df['full'], 'au')
# Out:
#           concentrate_au   tail_au
# rougher           19.772  1.816391
# primary          32.1194  3.914179
# secondary              -  4.339625
# final            44.0765  3.042467

# %% [markdown]
# Доля золота в сырье/концентрате увеличивается по ходу технологического процесса.
#
# Доля золота в отвальных хвостах различная по ходу технологического процесса.

# %% [markdown]
# Вычислим эффективность обогащения на полной выборке для признака rougher.output.recovery.

# %%
# Функция вычисления эффективности обогащения
def get_recovery(df, *, C=None, F=None, T=None):
    numerator = df[C] * (df[F] - df[T])
    denominator = df[F] * (df[C] - df[T])
    return numerator / denominator * 100

# %% [markdown]
# Исходный целевой признак (эффективность обогащения):

# %%
df['full'][target_col_1].head()
# Out:
# 0    87.107763
# 1    86.843261
# 2    86.842308
# 3    87.226430
# 4    86.688794
# Name: rougher.output.recovery, dtype: float64

# %% [markdown]
# Рассчитанная эффективность обогащения:

# %%
# доля золота в концентрате после флотации:
coef_C = 'rougher.output.concentrate_au'
# доля золота в сырье до флотации:
coef_F = 'rougher.input.feed_au'
# доля золота в отвальных хвостах после флотации:
coef_T = 'rougher.output.tail_au'
get_recovery(df['full'], C=coef_C, F=coef_F, T=coef_T).head()
# Out:
# 0    87.107763
# 1    86.843261
# 2    86.842308
# 3    87.226430
# 4    86.688794
# dtype: float64

# %% [markdown]
# Найдем MAE между расчётами и значением признака.

# %%
round(mean_squared_error(df['full'][target_col_1], get_recovery(df['full'], C=coef_C, F=coef_F, T=coef_T)), 10)
# Out:
# 0.0

# %% [markdown]
# **Вывод:**
#
# Средняя абсолютная ошибка равна `0`, значит эффективность обогащения в исходных данных рассчитана правильно.
#
# Противоречий в данных нет.

# %% [markdown]
# ### Проверка значений: ошибки, выбросы, дубликаты

# %% [markdown]
# Проверим распределение значений пр признакам, входящим в обучающий набор данных и целевых признаков:

# %% [markdown]
# #### Объемы воздуха и Уровень жидкости:

# %%
for param, param_name in zip(('air', 'level'), ('Объем воздуха', 'Уровень жидкости')):
    for stage, stage_name in zip(('rough', 'prim', 'sec'), ('Флотация', 'Первичная очистка', 'Вторичная очистка')):
        print()
        h = int(len(qdf(df['full'], stage, '', param).columns) * 0.5)
        plt.figure(figsize=(10, h))
        plt.grid(visible=True, axis='both')
        sns.boxplot(data=qdf(df['full'], stage, '', param), orient='h')
        plt.title(f'Распределение значений параметра "{param_name}" на стадии "{stage_name}"', pad=12, fontsize = 15)
        plt.xlabel(param_name, fontsize = 14)
        plt.ylabel('Установка', fontsize = 14)
        plt.show()

# %% [markdown]
# #### Размер гранул сырья:

# %%
u_hist_box_describe(df['full'][['rougher.input.feed_size']], xlabel='Размер гранул на флотацию', figsize=(8,8))

# %%
u_hist_box_describe(df['full'][['primary_cleaner.input.feed_size']], xlabel='Размер гранул на первичную очистку', figsize=(8,8))

# %% [markdown]
# #### Скорость подачи:

# %%
u_hist_box_describe(qdf(df['full'], '', '', 'feed_rate'), xlabel='Скорость подачи', figsize=(8,8))

# %% [markdown]
# #### Исходное сырье:

# %%
u_hist_box_describe(qdf(df['train'], '', 'input', ['ag', 'pb', 'au', 'sol']), xlabel='Исходное сырье на флотацию', describe=False)

# %% [markdown]
# #### Депрессант (силикат натрия).:

# %%
u_hist_box_describe(qdf(df['full'], '', 'input', 'depr'), xlabel='Депрессант на первичную очистку', figsize=(8,8))

# %% [markdown]
# #### Ксантогенат (промотер, или активатор флотации):

# %%
u_hist_box_describe(qdf(df['full'], '', 'input', 'xant'), xlabel='Ксантогенат на различных стадиях', describe=False)

# %% [markdown]
# #### Сульфат (сульфид натрия):

# %%
u_hist_box_describe(qdf(df['train'], '', 'input', 'sulf'), xlabel='Сульфат на различных стадиях', describe=False)

# %% [markdown]
# #### Целевые признаки (эффективность обогащения):

# %%
u_hist_box_describe(qdf(df['full'], '', '', 'recovery'), xlabel='Эффективность обогащения', figsize=(9,8))

# %% [markdown]
# #### Выводы:
#
# 1. Все распределения по форме графика близки к нормальным.
# 1. Имеются большие выбросы по размерам гранул, но значения допустимые.
# 1. Смещение влево по распределению эффективности обогащения.
# 1. Имеются аномальные нулевые значения эффективности обогащения (требуется проверка).

# %% [markdown]
# #### Проверка-исправление:

# %% [markdown]
# Проверим минимальные значения промежуточных концентраций:

# %%
qdf(df['full'], '', '', 'concentrate').min().T
# Out:
# final.output.concentrate_ag                      0.000000e+00
# final.output.concentrate_pb                      0.000000e+00
# final.output.concentrate_sol                     0.000000e+00
# final.output.concentrate_au                      0.000000e+00
# primary_cleaner.output.concentrate_ag            0.000000e+00
# primary_cleaner.output.concentrate_pb            0.000000e+00
# primary_cleaner.output.concentrate_sol           0.000000e+00
# primary_cleaner.output.concentrate_au            0.000000e+00
# rougher.calculation.sulfate_to_au_concentrate   -4.223520e+07
# rougher.output.concentrate_ag                    0.000000e+00
# rougher.output.concentrate_pb                    0.000000e+00
# rougher.output.concentrate_sol                   0.000000e+00
# rougher.output.concentrate_au                    0.000000e+00
# dtype: float64

# %% [markdown]
# Если на вход во флотационную установку подается ненулевая смесь, то промежуточные концентрации не могут быть нулевыми.

# %%
for el in ['ag', 'pb', 'au', 'sol']:
    print(f'Количество нулевых подач {el} на обогащение:', (df['full'][f'rougher.input.feed_{el}'] == 0).sum())
# Out:
# Количество нулевых подач ag на обогащение: 0
# Количество нулевых подач pb на обогащение: 0
# Количество нулевых подач au на обогащение: 0
# Количество нулевых подач sol на обогащение: 0

# %% [markdown]
# Нулевых подач нет, значит промежуточные концентрации не могут быть нулевыми. Удалим их из предобработанного набора данных:

# %%
for col in qdf(df['full'], '', '', 'concentrate').columns:
    df['full'] = df['full'][~(df['full'][col] == 0)]

# %% [markdown]
# Перепроверим значения эффективности обогащения:

# %%
u_hist_box_describe(qdf(df['full'], '', '', 'recovery'), xlabel='Эффективность обогащения', figsize=(9,8))

# %% [markdown]
# Нулевых значений эффективности обогащения не стало. Значения в норме.

# %%
show_remain(df)
# Out:
# <style  type="text/css" >
# </style><table id="T_b26fbd06_994c_11ec_b41f_02420a39e3a2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Число строк</th>        <th class="col_heading level0 col1" >Число столбцов</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b26fbd06_994c_11ec_b41f_02420a39e3a2level0_row0" class="row_heading level0 row0" >full</th>
#                         <td id="T_b26fbd06_994c_11ec_b41f_02420a39e3a2row0_col0" class="data row0 col0" >97.0%</td>
#                         <td id="T_b26fbd06_994c_11ec_b41f_02420a39e3a2row0_col1" class="data row0 col1" >100.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_b26fbd06_994c_11ec_b41f_02420a39e3a2level0_row1" class="row_heading level0 row1" >train</th>
#                         <td id="T_b26fbd06_994c_11ec_b41f_02420a39e3a2row1_col0" class="data row1 col0" >97.6%</td>
#                         <td id="T_b26fbd06_994c_11ec_b41f_02420a39e3a2row1_col1" class="data row1 col1" >60.9%</td>
#             </tr>
#             <tr>
#                         <th id="T_b26fbd06_994c_11ec_b41f_02420a39e3a2level0_row2" class="row_heading level0 row2" >test</th>
#                         <td id="T_b26fbd06_994c_11ec_b41f_02420a39e3a2row2_col0" class="data row2 col0" >98.8%</td>
#                         <td id="T_b26fbd06_994c_11ec_b41f_02420a39e3a2row2_col1" class="data row2 col1" >100.0%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Анализ данных

# %%
# Функция построения графика изменения концентрации элемента по стадиям
def gradual_change_of_concentrations(element, element_name):
    rougher_to_primary = df['full'][f'primary_cleaner.output.concentrate_{element}'] / df['full'][f'rougher.output.concentrate_{element}']
    primary_to_final = df['full'][f'final.output.concentrate_{element}'] / df['full'][f'primary_cleaner.output.concentrate_{element}']
    double_hist_box_describe(rougher_to_primary, primary_to_final, f'Изменение концентрации {element_name}',
                         label1='Флотация -> первый этап', label2='Первый этап -> финальная', bins=200, figsize=(9, 9))
    plt.show()
    plus1 = '+' if rougher_to_primary.median() > 1 else ''
    plus2 = '+' if primary_to_final.median() > 1 else ''
    print(f'Среднее изменение (медиана) концентрации {element_name} \n\
    от выхода материала из флотационной установки \n\
    до выхода из первого этапа очистки составляет:\n {text.BG_SILVER}{text.BOLD} {plus1}{rougher_to_primary.median()-1:.2%} {text.END}')
    print(f'Среднее изменение (медиана) концентрации {element_name} \n\
    от выхода материала из первого этапа очистки \n\
    до финального выхода составляет:\n {text.BG_SILVER}{text.BOLD} {plus2}{primary_to_final.median()-1:.2%} {text.END}')

# %% [markdown]
# ### Концентрация металлов (Au, Ag, Pb) на различных этапах очистки.

# %% [markdown]
# #### Золото

# %%
element = 'au'
element_name = 'золота'

# %% [markdown]
# Распределения значений концентрации на различных этапах:

# %%
u_hist_box_describe(qdf(df['full'], ['roug', 'prim', 'sec', 'fin'], '', f'concentrate_{element}'), xlabel=f'Концентрация {element_name}', describe=False, figsize=(9,8))

# %% [markdown]
# Средние значения:

# %%
changes_by_stages(df['full'], element)
# Out:
#           concentrate_au   tail_au
# rougher          20.1824  1.809392
# primary          32.2732  3.889678
# secondary              -  4.307199
# final            44.2928  3.032764

# %% [markdown]
# Судя по средним значениям концентраций и распределением значений концентрация золота увеличивается в ходе процесса очистки.
#
# Проверим это в разрезе каждого перехода:

# %%
gradual_change_of_concentrations(element, element_name)
# Out:
# Среднее изменение (медиана) концентрации золота
#     от выхода материала из флотационной установки
#     до выхода из первого этапа очистки составляет:
#   +60.45%
# Среднее изменение (медиана) концентрации золота
#     от выхода материала из первого этапа очистки
#     до финального выхода составляет:
#   +35.57%

# %% [markdown]
# Имеются большие выбросы со значениями увеличения концентрации в несколько тысяч раз.
#
# Отбросим верхний 1% квантиль и перепроверим изменения по стадиям очистки:

# %%
rougher_to_primary = df['full'][f'primary_cleaner.output.concentrate_{element}'] / df['full'][f'rougher.output.concentrate_{element}']

df['full'] = df['full'][rougher_to_primary < rougher_to_primary.quantile(0.99)]

primary_to_final = df['full'][f'final.output.concentrate_{element}'] / df['full'][f'primary_cleaner.output.concentrate_{element}']

df['full'] = df['full'][primary_to_final < primary_to_final.quantile(0.99)]

# %%
gradual_change_of_concentrations(element, element_name)
# Out:
# Среднее изменение (медиана) концентрации золота
#     от выхода материала из флотационной установки
#     до выхода из первого этапа очистки составляет:
#   +60.44%
# Среднее изменение (медиана) концентрации золота
#     от выхода материала из первого этапа очистки
#     до финального выхода составляет:
#   +35.50%

# %% [markdown]
# Проверим гипотезу:
# > Конентрация золота увеличивается в ходе процесса очистки руды.
#
# Нулевая гитотеза: Конентрация золота не изменяется в ходе процесса очистки руды.
#
# Альтернативная гипотеза: Конентрация золота увеличивается в ходе процесса очистки руды.
#
# Воспользуемся методом проверки односторонней гипотезы.
#
# Критический уровень значимости примем 1%

# %%
rougher_to_final = df['full'][f'final.output.concentrate_{element}'] / df['full'][f'rougher.output.concentrate_{element}']
rougher_to_final = rougher_to_final.dropna()

interested_value = 1
alpha = 0.01

results = st.ttest_1samp(rougher_to_final, interested_value)

print('p-значение:', results.pvalue)

if (results.pvalue / 2 < alpha and rougher_to_final.mean() > interested_value):
    print(f"Отвергаем нулевую гипотезу: концентрация {element_name} увеличивается")
else:
    print(f"Не получилось отвергнуть нулевую гипотезу: концентрация {element_name} не увеличивается")
# Out:
# p-значение: 0.0
# Отвергаем нулевую гипотезу: концентрация золота увеличивается

# %% [markdown]
# #### Серебро

# %%
element = 'ag'
element_name = 'серебра'

# %% [markdown]
# Распределения значений концентрации на различных этапах:

# %%
u_hist_box_describe(qdf(df['full'], ['roug', 'prim', 'sec', 'fin'], '', f'concentrate_{element}'), xlabel=f'Концентрация {element_name}', describe=False, figsize=(9,8))

# %% [markdown]
# Средние значения:

# %%
changes_by_stages(df['full'], element)
# Out:
#           concentrate_ag    tail_ag
# rougher          12.2916   5.591258
# primary          8.59422  16.141942
# secondary              -  14.616550
# final            5.20412   9.710226

# %% [markdown]
# Судя по средним значениям концентраций и распределением значений концентрация серебра уменьшается в ходе процесса очистки.
#
# Проверим это в разрезе каждого перехода:

# %%
gradual_change_of_concentrations(element, element_name)
# Out:
# Среднее изменение (медиана) концентрации серебра
#     от выхода материала из флотационной установки
#     до выхода из первого этапа очистки составляет:
#   -29.77%
# Среднее изменение (медиана) концентрации серебра
#     от выхода материала из первого этапа очистки
#     до финального выхода составляет:
#   -40.80%

# %% [markdown]
# Проверим гипотезу:
# > Конентрация серебра уменьшается в ходе процесса очистки руды.
#
# Нулевая гитотеза: Конентрация серебра не изменяется в ходе процесса очистки руды.
#
# Альтернативная гипотеза: Конентрация серебра уменьшается в ходе процесса очистки руды.
#
# Воспользуемся методом проверки односторонней гипотезы.
#
# Критический уровень значимости примем 1%

# %%
rougher_to_final = df['full'][f'final.output.concentrate_{element}'] / df['full'][f'rougher.output.concentrate_{element}']
rougher_to_final = rougher_to_final.dropna()

interested_value = 1
alpha = 0.01

results = st.ttest_1samp(rougher_to_final, interested_value)

print('p-значение:', results.pvalue)

if (results.pvalue / 2 < alpha and rougher_to_final.mean() < interested_value):
    print(f"Отвергаем нулевую гипотезу: концентрация {element_name} уменьшается")
else:
    print(f"Не получилось отвергнуть нулевую гипотезу: концентрация {element_name} не уменьшается")
# Out:
# p-значение: 0.0
# Отвергаем нулевую гипотезу: концентрация серебра уменьшается

# %% [markdown]
# #### Свинец

# %%
element = 'pb'
element_name = 'свинца'

# %% [markdown]
# Распределения значений концентрации на различных этапах:

# %%
u_hist_box_describe(qdf(df['full'], ['roug', 'prim', 'sec', 'fin'], '', f'concentrate_{element}'), xlabel=f'Концентрация {element_name}', describe=False, figsize=(9,8))

# %% [markdown]
# Средние значения:

# %%
changes_by_stages(df['full'], element)
# Out:
#           concentrate_pb   tail_pb
# rougher          7.79868  0.646165
# primary          9.97431  3.427180
# secondary              -  5.766808
# final            10.0467  2.709906

# %% [markdown]
# Судя по средним значениям концентраций и распределением значений концентрация свинца незначительно увеличивается либо остается без изменения в ходе процесса очистки.
#
# Проверим это в разрезе каждого перехода:

# %%
gradual_change_of_concentrations(element, element_name)
# Out:
# Среднее изменение (медиана) концентрации свинца
#     от выхода материала из флотационной установки
#     до выхода из первого этапа очистки составляет:
#   +31.80%
# Среднее изменение (медиана) концентрации свинца
#     от выхода материала из первого этапа очистки
#     до финального выхода составляет:
#   -3.18%

# %% [markdown]
# Проверим гипотезу:
# > Конентрация свинца увеличивается в ходе процесса очистки руды.
#
# Нулевая гитотеза: Конентрация свинца не изменяется в ходе процесса очистки руды.
#
# Альтернативная гипотеза: Конентрация свинца увеличивается в ходе процесса очистки руды.
#
# Воспользуемся методом проверки односторонней гипотезы.
#
# Критический уровень значимости примем 1%

# %%
rougher_to_final = df['full'][f'final.output.concentrate_{element}'] / df['full'][f'rougher.output.concentrate_{element}']
rougher_to_final = rougher_to_final.dropna()

interested_value = 1
alpha = 0.01

results = st.ttest_1samp(rougher_to_final, interested_value)

print('p-значение:', results.pvalue)

if (results.pvalue / 2 < alpha and rougher_to_final.mean() > interested_value):
    print(f"Отвергаем нулевую гипотезу: концентрация {element_name} увеличивается")
else:
    print(f"Не получилось отвергнуть нулевую гипотезу: концентрация {element_name} не увеличивается")
# Out:
# p-значение: 0.0
# Отвергаем нулевую гипотезу: концентрация свинца увеличивается

# %% [markdown]
# **Выводы:**
#
# 1. Концентрация золота увеличивается по ходу процесса очистки руды.
# 1. Концентрация серебра уменьшается по ходу процесса очистки руды.
# 1. Концентрация свинца увеличивается по ходу процесса очистки руды.
# 1. Очищены аномальные выбросы

# %%
show_remain(df)
# Out:
# <style  type="text/css" >
# </style><table id="T_bd5998c2_994c_11ec_b41f_02420a39e3a2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Число строк</th>        <th class="col_heading level0 col1" >Число столбцов</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bd5998c2_994c_11ec_b41f_02420a39e3a2level0_row0" class="row_heading level0 row0" >full</th>
#                         <td id="T_bd5998c2_994c_11ec_b41f_02420a39e3a2row0_col0" class="data row0 col0" >95.0%</td>
#                         <td id="T_bd5998c2_994c_11ec_b41f_02420a39e3a2row0_col1" class="data row0 col1" >100.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_bd5998c2_994c_11ec_b41f_02420a39e3a2level0_row1" class="row_heading level0 row1" >train</th>
#                         <td id="T_bd5998c2_994c_11ec_b41f_02420a39e3a2row1_col0" class="data row1 col0" >97.6%</td>
#                         <td id="T_bd5998c2_994c_11ec_b41f_02420a39e3a2row1_col1" class="data row1 col1" >60.9%</td>
#             </tr>
#             <tr>
#                         <th id="T_bd5998c2_994c_11ec_b41f_02420a39e3a2level0_row2" class="row_heading level0 row2" >test</th>
#                         <td id="T_bd5998c2_994c_11ec_b41f_02420a39e3a2row2_col0" class="data row2 col0" >98.8%</td>
#                         <td id="T_bd5998c2_994c_11ec_b41f_02420a39e3a2row2_col1" class="data row2 col1" >100.0%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Сравнение распределения размеров гранул сырья на обучающей и тестовой выборках.

# %% [markdown]
# Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.

# %%
col = 'rougher.input.feed_size'

# %% [markdown]
# Рассмотрим на графиках распределения размеров гранул сырья на обучающей и тестовой выборках:

# %%
double_hist_box_describe(df['train'][col], df['test'][col], 'Размер гранул',
                         label1='Обучающая выборка', label2='Тестовая выборка', bins=200)

# %% [markdown]
# Возьмем распределения без больших выбросов для рассмотрения формы графиков:

# %%
double_hist_box_describe(df['train'][col][df['train'][col] < 150], df['test'][col][df['test'][col] < 150], 'Размер гранул',
                         label1='Обучающая выборка', label2='Тестовая выборка', bins=200)

# %% [markdown]
# Проверим гипотезу:
# > Размер гранул разный на тестовой и обучающей выборках.
#
# Нулевая гитотеза: Размер гранул одинаковый на тестовой и обучающей выборках.
#
# Альтернативная гипотеза: Размер гранул разный на тестовой и обучающей выборках.
#
# Воспользуемся методом проверки двусторонней гипотезы.
#
# Критический уровень значимости примем 1%

# %%
alpha = 0.01
results = st.ttest_ind(df['train'][col], df['test'][col], equal_var=False)
print(results)
print('p-значение: ', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу: величины разные")
else:
    print("Не получилось отвергнуть нулевую гипотезу: величиный одинаковые")
# Out:
# Ttest_indResult(statistic=12.814127233128525, pvalue=2.5513681723439087e-37)
# p-значение:  2.5513681723439087e-37
# Отвергаем нулевую гипотезу: величины разные

# %% [markdown]
# **Выводы:**
#
# 1. Форма распределений размера гранул для обучающей и тестовой выборок разные.
# 1. Проверка гипотезы показывает, что величины размера гранул на обучающей и тестовой выборках разные.

# %% [markdown]
# ### Суммарная концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.

# %% [markdown]
# Напомим стадии концентрации:

# %%
qdf(df['full'], '', ['input', 'output'], ['feed', 'concent']).mean().T
# Out:
# final.output.concentrate_ag                 5.204123
# final.output.concentrate_pb                10.046721
# final.output.concentrate_sol                9.588271
# final.output.concentrate_au                44.326237
# primary_cleaner.input.feed_size             7.311417
# primary_cleaner.output.concentrate_ag       8.594215
# primary_cleaner.output.concentrate_pb       9.974311
# primary_cleaner.output.concentrate_sol     10.645325
# primary_cleaner.output.concentrate_au      32.572050
# rougher.input.feed_ag                       8.807815
# rougher.input.feed_pb                       3.598933
# rougher.input.feed_rate                   479.628833
# rougher.input.feed_size                    58.898071
# rougher.input.feed_sol                     36.760339
# rougher.input.feed_au                       8.288962
# rougher.output.concentrate_ag              12.291593
# rougher.output.concentrate_pb               7.798681
# rougher.output.concentrate_sol             29.561117
# rougher.output.concentrate_au              20.301061
# dtype: float64

# %%
u_hist_box_describe(pd.DataFrame(qdf(df['full'], 'rougher', 'input', ['au', 'ag', 'pb', 'sol']).sum(axis=1), columns=['all_elements']), xlabel='Суммарная концентрация веществ на входе во флотацию', figsize=(8,8))

# %%
u_hist_box_describe(pd.DataFrame(qdf(df['full'], 'rougher', 'output', 'concent').sum(axis=1), columns=['all_elements']), xlabel='Суммарная концентрация веществ после флотации', figsize=(8,8))

# %%
u_hist_box_describe(pd.DataFrame(qdf(df['full'], 'primary', 'output', 'concent').sum(axis=1), columns=['all_elements']), xlabel='Суммарная концентрация веществ после первичной очистки', figsize=(8,8))

# %%
u_hist_box_describe(pd.DataFrame(qdf(df['full'], 'final', 'output', 'concent').sum(axis=1), columns=['all_elements']), xlabel='Суммарная финальная концентрация веществ после очистки', figsize=(8,8))

# %% [markdown]
# **Выводы:**
#
# 1. Все распределения по форме графика близки к нормальным.
# 1. Имеются выбросы, но значения допустимые.
# 1. Аномальных значений нет.
# 1. По ходу процесса очистки концентрация веществ повышается (очевидно происходит очистка)

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Новые индексы

# %% [markdown]
# Индексы разбивок (`train`, `test`) не совпадают с индексами полного набора (`full`)
#
# Определим в каком столбце достаточно уникальных значений для назначения его новым индексом (возьмем исходный набор данных - `df_origin`):

# %%
df_origin.shape[0]
# Out:
# 19439

# %%
df_origin.nunique().sort_values(ascending=False).head()
# Out:
# date                                 19439
# rougher.state.floatbank10_d_air      19439
# rougher.state.floatbank10_d_level    19439
# rougher.state.floatbank10_e_level    19439
# rougher.state.floatbank10_f_air      19439
# dtype: int64

# %% [markdown]
# Для сопоставления рабочих таблиц выборок с исходной таблицей зададим индексы датами (`date`):
#
# *Также признак `date` не несет информации и не нужен на этапе моделирования (удалим его из наборов данных)*

# %%
# Назначение индексов
df_origin.index = df_origin['date']
# Удаление признака date
df_origin = df_origin.drop('date', axis=1)

for table in data_names:
    # Назначение индексов
    df[table].index = df[table]['date']
    # Удаление признака date
    df[table] = df[table].drop('date', axis=1)

# %% [markdown]
# Проверим:

# %%
df['test'].head(3)
# Out:
#                      primary_cleaner.input.sulfate  \
# date
# 2016-09-01 00:59:59                     210.800909
# 2016-09-01 01:59:59                     215.392455
# 2016-09-01 02:59:59                     215.259946
#
#                      primary_cleaner.input.depressant  \
# date
# 2016-09-01 00:59:59                         14.993118
# 2016-09-01 01:59:59                         14.987471
# 2016-09-01 02:59:59                         12.884934
#
#                      primary_cleaner.input.feed_size  \
# date
# 2016-09-01 00:59:59                         8.080000
# 2016-09-01 01:59:59                         8.080000
# 2016-09-01 02:59:59                         7.786667
#
#                      primary_cleaner.input.xanthate  \
# date
# 2016-09-01 00:59:59                        1.005021
# 2016-09-01 01:59:59                        0.990469
# 2016-09-01 02:59:59                        0.996043
#
#                      primary_cleaner.state.floatbank8_a_air  \
# date
# 2016-09-01 00:59:59                             1398.981301
# 2016-09-01 01:59:59                             1398.777912
# 2016-09-01 02:59:59                             1398.493666
#
#                      primary_cleaner.state.floatbank8_a_level  \
# date
# 2016-09-01 00:59:59                               -500.225577
# 2016-09-01 01:59:59                               -500.057435
# 2016-09-01 02:59:59                               -500.868360
#
#                      primary_cleaner.state.floatbank8_b_air  \
# date
# 2016-09-01 00:59:59                             1399.144926
# 2016-09-01 01:59:59                             1398.055362
# 2016-09-01 02:59:59                             1398.860436
#
#                      primary_cleaner.state.floatbank8_b_level  \
# date
# 2016-09-01 00:59:59                               -499.919735
# 2016-09-01 01:59:59                               -499.778182
# 2016-09-01 02:59:59                               -499.764529
#
#                      primary_cleaner.state.floatbank8_c_air  \
# date
# 2016-09-01 00:59:59                             1400.102998
# 2016-09-01 01:59:59                             1396.151033
# 2016-09-01 02:59:59                             1398.075709
#
#                      primary_cleaner.state.floatbank8_c_level  ...  \
# date                                                           ...
# 2016-09-01 00:59:59                               -500.704369  ...
# 2016-09-01 01:59:59                               -499.240168  ...
# 2016-09-01 02:59:59                               -502.151509  ...
#
#                      secondary_cleaner.state.floatbank4_a_air  \
# date
# 2016-09-01 00:59:59                                 12.023554
# 2016-09-01 01:59:59                                 12.058140
# 2016-09-01 02:59:59                                 11.962366
#
#                      secondary_cleaner.state.floatbank4_a_level  \
# date
# 2016-09-01 00:59:59                                 -497.795834
# 2016-09-01 01:59:59                                 -498.695773
# 2016-09-01 02:59:59                                 -498.767484
#
#                      secondary_cleaner.state.floatbank4_b_air  \
# date
# 2016-09-01 00:59:59                                  8.016656
# 2016-09-01 01:59:59                                  8.130979
# 2016-09-01 02:59:59                                  8.096893
#
#                      secondary_cleaner.state.floatbank4_b_level  \
# date
# 2016-09-01 00:59:59                                 -501.289139
# 2016-09-01 01:59:59                                 -499.634209
# 2016-09-01 02:59:59                                 -500.827423
#
#                      secondary_cleaner.state.floatbank5_a_air  \
# date
# 2016-09-01 00:59:59                                  7.946562
# 2016-09-01 01:59:59                                  7.958270
# 2016-09-01 02:59:59                                  8.071056
#
#                      secondary_cleaner.state.floatbank5_a_level  \
# date
# 2016-09-01 00:59:59                                 -432.317850
# 2016-09-01 01:59:59                                 -525.839648
# 2016-09-01 02:59:59                                 -500.801673
#
#                      secondary_cleaner.state.floatbank5_b_air  \
# date
# 2016-09-01 00:59:59                                  4.872511
# 2016-09-01 01:59:59                                  4.878850
# 2016-09-01 02:59:59                                  4.905125
#
#                      secondary_cleaner.state.floatbank5_b_level  \
# date
# 2016-09-01 00:59:59                                 -500.037437
# 2016-09-01 01:59:59                                 -500.162375
# 2016-09-01 02:59:59                                 -499.828510
#
#                      secondary_cleaner.state.floatbank6_a_air  \
# date
# 2016-09-01 00:59:59                                 26.705889
# 2016-09-01 01:59:59                                 25.019940
# 2016-09-01 02:59:59                                 24.994862
#
#                      secondary_cleaner.state.floatbank6_a_level
# date
# 2016-09-01 00:59:59                                 -499.709414
# 2016-09-01 01:59:59                                 -499.819438
# 2016-09-01 02:59:59                                 -500.622559
#
# [3 rows x 52 columns]

# %%
df_origin.loc[df['test'].index, df['test'].columns].head(3)
# Out:
#                      primary_cleaner.input.sulfate  \
# date
# 2016-09-01 00:59:59                     210.800909
# 2016-09-01 01:59:59                     215.392455
# 2016-09-01 02:59:59                     215.259946
#
#                      primary_cleaner.input.depressant  \
# date
# 2016-09-01 00:59:59                         14.993118
# 2016-09-01 01:59:59                         14.987471
# 2016-09-01 02:59:59                         12.884934
#
#                      primary_cleaner.input.feed_size  \
# date
# 2016-09-01 00:59:59                         8.080000
# 2016-09-01 01:59:59                         8.080000
# 2016-09-01 02:59:59                         7.786667
#
#                      primary_cleaner.input.xanthate  \
# date
# 2016-09-01 00:59:59                        1.005021
# 2016-09-01 01:59:59                        0.990469
# 2016-09-01 02:59:59                        0.996043
#
#                      primary_cleaner.state.floatbank8_a_air  \
# date
# 2016-09-01 00:59:59                             1398.981301
# 2016-09-01 01:59:59                             1398.777912
# 2016-09-01 02:59:59                             1398.493666
#
#                      primary_cleaner.state.floatbank8_a_level  \
# date
# 2016-09-01 00:59:59                               -500.225577
# 2016-09-01 01:59:59                               -500.057435
# 2016-09-01 02:59:59                               -500.868360
#
#                      primary_cleaner.state.floatbank8_b_air  \
# date
# 2016-09-01 00:59:59                             1399.144926
# 2016-09-01 01:59:59                             1398.055362
# 2016-09-01 02:59:59                             1398.860436
#
#                      primary_cleaner.state.floatbank8_b_level  \
# date
# 2016-09-01 00:59:59                               -499.919735
# 2016-09-01 01:59:59                               -499.778182
# 2016-09-01 02:59:59                               -499.764529
#
#                      primary_cleaner.state.floatbank8_c_air  \
# date
# 2016-09-01 00:59:59                             1400.102998
# 2016-09-01 01:59:59                             1396.151033
# 2016-09-01 02:59:59                             1398.075709
#
#                      primary_cleaner.state.floatbank8_c_level  ...  \
# date                                                           ...
# 2016-09-01 00:59:59                               -500.704369  ...
# 2016-09-01 01:59:59                               -499.240168  ...
# 2016-09-01 02:59:59                               -502.151509  ...
#
#                      secondary_cleaner.state.floatbank4_a_air  \
# date
# 2016-09-01 00:59:59                                 12.023554
# 2016-09-01 01:59:59                                 12.058140
# 2016-09-01 02:59:59                                 11.962366
#
#                      secondary_cleaner.state.floatbank4_a_level  \
# date
# 2016-09-01 00:59:59                                 -497.795834
# 2016-09-01 01:59:59                                 -498.695773
# 2016-09-01 02:59:59                                 -498.767484
#
#                      secondary_cleaner.state.floatbank4_b_air  \
# date
# 2016-09-01 00:59:59                                  8.016656
# 2016-09-01 01:59:59                                  8.130979
# 2016-09-01 02:59:59                                  8.096893
#
#                      secondary_cleaner.state.floatbank4_b_level  \
# date
# 2016-09-01 00:59:59                                 -501.289139
# 2016-09-01 01:59:59                                 -499.634209
# 2016-09-01 02:59:59                                 -500.827423
#
#                      secondary_cleaner.state.floatbank5_a_air  \
# date
# 2016-09-01 00:59:59                                  7.946562
# 2016-09-01 01:59:59                                  7.958270
# 2016-09-01 02:59:59                                  8.071056
#
#                      secondary_cleaner.state.floatbank5_a_level  \
# date
# 2016-09-01 00:59:59                                 -432.317850
# 2016-09-01 01:59:59                                 -525.839648
# 2016-09-01 02:59:59                                 -500.801673
#
#                      secondary_cleaner.state.floatbank5_b_air  \
# date
# 2016-09-01 00:59:59                                  4.872511
# 2016-09-01 01:59:59                                  4.878850
# 2016-09-01 02:59:59                                  4.905125
#
#                      secondary_cleaner.state.floatbank5_b_level  \
# date
# 2016-09-01 00:59:59                                 -500.037437
# 2016-09-01 01:59:59                                 -500.162375
# 2016-09-01 02:59:59                                 -499.828510
#
#                      secondary_cleaner.state.floatbank6_a_air  \
# date
# 2016-09-01 00:59:59                                 26.705889
# 2016-09-01 01:59:59                                 25.019940
# 2016-09-01 02:59:59                                 24.994862
#
#                      secondary_cleaner.state.floatbank6_a_level
# date
# 2016-09-01 00:59:59                                 -499.709414
# 2016-09-01 01:59:59                                 -499.819438
# 2016-09-01 02:59:59                                 -500.622559
#
# [3 rows x 52 columns]

# %% [markdown]
# Данные в выборках одни и те же - индексы заменены успешно.

# %% [markdown]
# ### Упрощенная выборка

# %% [markdown]
# На стадии предобработки данных настоящего исследования было замечено, что уровень жидкости в установках изменяется в узких диапазонах, соответственно эти признаки могут оказывать очень малое влияние на предсказание модели.
#
# Проверим для каких признаков коэффициент вариации имеет наименьшее значение.

# %%
describe_temp = df['full'].describe().T
describe_temp['pstd'] = abs(describe_temp['std'] / describe_temp['mean'])
describe_temp.sort_values('pstd')[['mean', 'std', 'pstd']].head(20)
# Out:
#                                                    mean         std      pstd
# primary_cleaner.state.floatbank8_c_level    -491.710143   31.581053  0.064227
# primary_cleaner.state.floatbank8_a_level    -491.007090   31.678836  0.064518
# primary_cleaner.state.floatbank8_b_level    -491.950123   32.873973  0.066824
# secondary_cleaner.state.floatbank5_a_level  -488.370466   34.514121  0.070672
# secondary_cleaner.state.floatbank6_a_level  -505.267011   37.326732  0.073875
# secondary_cleaner.state.floatbank5_b_level  -486.916359   37.930470  0.077899
# primary_cleaner.state.floatbank8_a_air      1589.290346  127.546669  0.080254
# primary_cleaner.state.floatbank8_b_air      1591.437942  130.561780  0.082040
# primary_cleaner.input.feed_size                7.311417    0.613831  0.083955
# primary_cleaner.state.floatbank8_c_air      1586.932627  134.010630  0.084446
# rougher.output.recovery                       85.078321    7.342386  0.086301
# final.output.concentrate_au                   44.326237    3.858337  0.087044
# secondary_cleaner.state.floatbank3_b_level  -493.430866   43.207640  0.087566
# primary_cleaner.state.floatbank8_d_level    -488.115437   42.978269  0.088049
# secondary_cleaner.state.floatbank4_a_level  -485.652587   47.715725  0.098251
# secondary_cleaner.state.floatbank2_a_level  -502.077580   53.053077  0.105667
# rougher.output.concentrate_au                 20.301061    2.234589  0.110073
# secondary_cleaner.state.floatbank2_b_level  -502.862811   56.306792  0.111972
# secondary_cleaner.state.floatbank3_a_level  -485.999699   54.518555  0.112178
# rougher.state.floatbank10_c_level           -467.211308   53.478797  0.114464

# %% [markdown]
# Практически все вверхние позиции списка занимают признаки `level` (уровень жидкости).
#
# Далее попробуем исключить эти признаки из обучающего набора для оценки работы модели.

# %% [markdown]
# ### Признаки

# %% [markdown]
# #### Исходные признаки

# %% [markdown]
# 1. Оригинальный набор признаков из обучающей выборки для прогнозирования эффективности обогащения финального концентрата:

# %%
X_final_origin = df['train']
X_final_origin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 13805 entries, 2016-01-15 00:00:00 to 2018-08-18 10:59:59
# Data columns (total 52 columns):
# primary_cleaner.input.sulfate                 13805 non-null float64
# primary_cleaner.input.depressant              13805 non-null float64
# primary_cleaner.input.feed_size               13805 non-null float64
# primary_cleaner.input.xanthate                13805 non-null float64
# primary_cleaner.state.floatbank8_a_air        13805 non-null float64
# primary_cleaner.state.floatbank8_a_level      13805 non-null float64
# primary_cleaner.state.floatbank8_b_air        13805 non-null float64
# primary_cleaner.state.floatbank8_b_level      13805 non-null float64
# primary_cleaner.state.floatbank8_c_air        13805 non-null float64
# primary_cleaner.state.floatbank8_c_level      13805 non-null float64
# primary_cleaner.state.floatbank8_d_air        13805 non-null float64
# primary_cleaner.state.floatbank8_d_level      13805 non-null float64
# rougher.input.feed_ag                         13805 non-null float64
# rougher.input.feed_pb                         13805 non-null float64
# rougher.input.feed_rate                       13805 non-null float64
# rougher.input.feed_size                       13805 non-null float64
# rougher.input.feed_sol                        13805 non-null float64
# rougher.input.feed_au                         13805 non-null float64
# rougher.input.floatbank10_sulfate             13805 non-null float64
# rougher.input.floatbank10_xanthate            13805 non-null float64
# rougher.input.floatbank11_sulfate             13805 non-null float64
# rougher.input.floatbank11_xanthate            13805 non-null float64
# rougher.state.floatbank10_a_air               13805 non-null float64
# rougher.state.floatbank10_a_level             13805 non-null float64
# rougher.state.floatbank10_b_air               13805 non-null float64
# rougher.state.floatbank10_b_level             13805 non-null float64
# rougher.state.floatbank10_c_air               13805 non-null float64
# rougher.state.floatbank10_c_level             13805 non-null float64
# rougher.state.floatbank10_d_air               13805 non-null float64
# rougher.state.floatbank10_d_level             13805 non-null float64
# rougher.state.floatbank10_e_air               13805 non-null float64
# rougher.state.floatbank10_e_level             13805 non-null float64
# rougher.state.floatbank10_f_air               13805 non-null float64
# rougher.state.floatbank10_f_level             13805 non-null float64
# secondary_cleaner.state.floatbank2_a_air      13805 non-null float64
# secondary_cleaner.state.floatbank2_a_level    13805 non-null float64
# secondary_cleaner.state.floatbank2_b_air      13805 non-null float64
# secondary_cleaner.state.floatbank2_b_level    13805 non-null float64
# secondary_cleaner.state.floatbank3_a_air      13805 non-null float64
# secondary_cleaner.state.floatbank3_a_level    13805 non-null float64
# secondary_cleaner.state.floatbank3_b_air      13805 non-null float64
# secondary_cleaner.state.floatbank3_b_level    13805 non-null float64
# secondary_cleaner.state.floatbank4_a_air      13805 non-null float64
# secondary_cleaner.state.floatbank4_a_level    13805 non-null float64
# secondary_cleaner.state.floatbank4_b_air      13805 non-null float64
# secondary_cleaner.state.floatbank4_b_level    13805 non-null float64
# secondary_cleaner.state.floatbank5_a_air      13805 non-null float64
# secondary_cleaner.state.floatbank5_a_level    13805 non-null float64
# secondary_cleaner.state.floatbank5_b_air      13805 non-null float64
# secondary_cleaner.state.floatbank5_b_level    13805 non-null float64
# secondary_cleaner.state.floatbank6_a_air      13805 non-null float64
# secondary_cleaner.state.floatbank6_a_level    13805 non-null float64
# dtypes: float64(52)
# memory usage: 5.6 MB

# %% [markdown]
# 2. Оригинальный набор признаков из обучающей выборки для прогнозирования эффективности обогащения чернового концентрата:
#
# *Входные даныне и параметры текущего состояния только для этапа флотации*

# %%
X_rougher_origin = qdf(X_final_origin, 'rougher', '', '')
X_rougher_origin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 13805 entries, 2016-01-15 00:00:00 to 2018-08-18 10:59:59
# Data columns (total 22 columns):
# rougher.input.feed_ag                 13805 non-null float64
# rougher.input.feed_pb                 13805 non-null float64
# rougher.input.feed_rate               13805 non-null float64
# rougher.input.feed_size               13805 non-null float64
# rougher.input.feed_sol                13805 non-null float64
# rougher.input.feed_au                 13805 non-null float64
# rougher.input.floatbank10_sulfate     13805 non-null float64
# rougher.input.floatbank10_xanthate    13805 non-null float64
# rougher.input.floatbank11_sulfate     13805 non-null float64
# rougher.input.floatbank11_xanthate    13805 non-null float64
# rougher.state.floatbank10_a_air       13805 non-null float64
# rougher.state.floatbank10_a_level     13805 non-null float64
# rougher.state.floatbank10_b_air       13805 non-null float64
# rougher.state.floatbank10_b_level     13805 non-null float64
# rougher.state.floatbank10_c_air       13805 non-null float64
# rougher.state.floatbank10_c_level     13805 non-null float64
# rougher.state.floatbank10_d_air       13805 non-null float64
# rougher.state.floatbank10_d_level     13805 non-null float64
# rougher.state.floatbank10_e_air       13805 non-null float64
# rougher.state.floatbank10_e_level     13805 non-null float64
# rougher.state.floatbank10_f_air       13805 non-null float64
# rougher.state.floatbank10_f_level     13805 non-null float64
# dtypes: float64(22)
# memory usage: 2.4 MB

# %% [markdown]
# #### Предобработанные признаки

# %% [markdown]
# 1. Предобработанный набор признаков из обучающей выборки для прогнозирования эффективности обогащения финального концентрата.
#
# *Берем на основании перекрестного выбора признаков по обучающей выборке и предобработанной исходной выборки*

# %%
X_final_prep = df['full'][df['train'].columns].merge(df['train'], how='inner', left_index=True, right_index=True, suffixes=('_full', ''))

# %%
indexes_prep = filter(lambda x: x.endswith('_full'), X_final_prep.columns)

# %%
X_final_prep = X_final_prep.drop(indexes_prep, axis=1)

# %%
X_final_prep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 13130 entries, 2016-01-15 00:00:00 to 2018-08-18 10:59:59
# Data columns (total 52 columns):
# primary_cleaner.input.sulfate                 13130 non-null float64
# primary_cleaner.input.depressant              13130 non-null float64
# primary_cleaner.input.feed_size               13130 non-null float64
# primary_cleaner.input.xanthate                13130 non-null float64
# primary_cleaner.state.floatbank8_a_air        13130 non-null float64
# primary_cleaner.state.floatbank8_a_level      13130 non-null float64
# primary_cleaner.state.floatbank8_b_air        13130 non-null float64
# primary_cleaner.state.floatbank8_b_level      13130 non-null float64
# primary_cleaner.state.floatbank8_c_air        13130 non-null float64
# primary_cleaner.state.floatbank8_c_level      13130 non-null float64
# primary_cleaner.state.floatbank8_d_air        13130 non-null float64
# primary_cleaner.state.floatbank8_d_level      13130 non-null float64
# rougher.input.feed_ag                         13130 non-null float64
# rougher.input.feed_pb                         13130 non-null float64
# rougher.input.feed_rate                       13130 non-null float64
# rougher.input.feed_size                       13130 non-null float64
# rougher.input.feed_sol                        13130 non-null float64
# rougher.input.feed_au                         13130 non-null float64
# rougher.input.floatbank10_sulfate             13130 non-null float64
# rougher.input.floatbank10_xanthate            13130 non-null float64
# rougher.input.floatbank11_sulfate             13130 non-null float64
# rougher.input.floatbank11_xanthate            13130 non-null float64
# rougher.state.floatbank10_a_air               13130 non-null float64
# rougher.state.floatbank10_a_level             13130 non-null float64
# rougher.state.floatbank10_b_air               13130 non-null float64
# rougher.state.floatbank10_b_level             13130 non-null float64
# rougher.state.floatbank10_c_air               13130 non-null float64
# rougher.state.floatbank10_c_level             13130 non-null float64
# rougher.state.floatbank10_d_air               13130 non-null float64
# rougher.state.floatbank10_d_level             13130 non-null float64
# rougher.state.floatbank10_e_air               13130 non-null float64
# rougher.state.floatbank10_e_level             13130 non-null float64
# rougher.state.floatbank10_f_air               13130 non-null float64
# rougher.state.floatbank10_f_level             13130 non-null float64
# secondary_cleaner.state.floatbank2_a_air      13130 non-null float64
# secondary_cleaner.state.floatbank2_a_level    13130 non-null float64
# secondary_cleaner.state.floatbank2_b_air      13130 non-null float64
# secondary_cleaner.state.floatbank2_b_level    13130 non-null float64
# secondary_cleaner.state.floatbank3_a_air      13130 non-null float64
# secondary_cleaner.state.floatbank3_a_level    13130 non-null float64
# secondary_cleaner.state.floatbank3_b_air      13130 non-null float64
# secondary_cleaner.state.floatbank3_b_level    13130 non-null float64
# secondary_cleaner.state.floatbank4_a_air      13130 non-null float64
# secondary_cleaner.state.floatbank4_a_level    13130 non-null float64
# secondary_cleaner.state.floatbank4_b_air      13130 non-null float64
# secondary_cleaner.state.floatbank4_b_level    13130 non-null float64
# secondary_cleaner.state.floatbank5_a_air      13130 non-null float64
# secondary_cleaner.state.floatbank5_a_level    13130 non-null float64
# secondary_cleaner.state.floatbank5_b_air      13130 non-null float64
# secondary_cleaner.state.floatbank5_b_level    13130 non-null float64
# secondary_cleaner.state.floatbank6_a_air      13130 non-null float64
# secondary_cleaner.state.floatbank6_a_level    13130 non-null float64
# dtypes: float64(52)
# memory usage: 5.3 MB

# %% [markdown]
# 2. Предобработанный набор признаков из обучающей выборки для прогнозирования эффективности обогащения финального концентрата.
#
# *Берем на основании перекрестного выбора признаков по обучающей выборке и предобработанной исходной выборки*
#
# *Входные даныне и параметры текущего состояния только для этапа флотации*

# %%
X_rougher_prep = qdf(X_final_prep, 'rougher', '', '')
X_rougher_prep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 13130 entries, 2016-01-15 00:00:00 to 2018-08-18 10:59:59
# Data columns (total 22 columns):
# rougher.input.feed_ag                 13130 non-null float64
# rougher.input.feed_pb                 13130 non-null float64
# rougher.input.feed_rate               13130 non-null float64
# rougher.input.feed_size               13130 non-null float64
# rougher.input.feed_sol                13130 non-null float64
# rougher.input.feed_au                 13130 non-null float64
# rougher.input.floatbank10_sulfate     13130 non-null float64
# rougher.input.floatbank10_xanthate    13130 non-null float64
# rougher.input.floatbank11_sulfate     13130 non-null float64
# rougher.input.floatbank11_xanthate    13130 non-null float64
# rougher.state.floatbank10_a_air       13130 non-null float64
# rougher.state.floatbank10_a_level     13130 non-null float64
# rougher.state.floatbank10_b_air       13130 non-null float64
# rougher.state.floatbank10_b_level     13130 non-null float64
# rougher.state.floatbank10_c_air       13130 non-null float64
# rougher.state.floatbank10_c_level     13130 non-null float64
# rougher.state.floatbank10_d_air       13130 non-null float64
# rougher.state.floatbank10_d_level     13130 non-null float64
# rougher.state.floatbank10_e_air       13130 non-null float64
# rougher.state.floatbank10_e_level     13130 non-null float64
# rougher.state.floatbank10_f_air       13130 non-null float64
# rougher.state.floatbank10_f_level     13130 non-null float64
# dtypes: float64(22)
# memory usage: 2.3 MB

# %% [markdown]
# #### Предобработанные упрощенные признаки

# %% [markdown]
# 1. Уберем признаки уровня жидкости из предобработанного набора признаков для прогнозирования эффективности обогащения чернового концентрата:

# %%
X_rougher_prep_lite = X_rougher_prep.drop(qdf(X_rougher_prep, '', '', 'level').columns, axis=1)
X_rougher_prep_lite.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 13130 entries, 2016-01-15 00:00:00 to 2018-08-18 10:59:59
# Data columns (total 16 columns):
# rougher.input.feed_ag                 13130 non-null float64
# rougher.input.feed_pb                 13130 non-null float64
# rougher.input.feed_rate               13130 non-null float64
# rougher.input.feed_size               13130 non-null float64
# rougher.input.feed_sol                13130 non-null float64
# rougher.input.feed_au                 13130 non-null float64
# rougher.input.floatbank10_sulfate     13130 non-null float64
# rougher.input.floatbank10_xanthate    13130 non-null float64
# rougher.input.floatbank11_sulfate     13130 non-null float64
# rougher.input.floatbank11_xanthate    13130 non-null float64
# rougher.state.floatbank10_a_air       13130 non-null float64
# rougher.state.floatbank10_b_air       13130 non-null float64
# rougher.state.floatbank10_c_air       13130 non-null float64
# rougher.state.floatbank10_d_air       13130 non-null float64
# rougher.state.floatbank10_e_air       13130 non-null float64
# rougher.state.floatbank10_f_air       13130 non-null float64
# dtypes: float64(16)
# memory usage: 1.7 MB

# %% [markdown]
# 2. Уберем признаки уровня жидкости из предобработанного набора признаков для прогнозирования эффективности обогащения финального концентрата:

# %%
X_final_prep_lite = X_final_prep.drop(qdf(X_final_prep, '', '', 'level').columns, axis=1)
X_final_prep_lite.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 13130 entries, 2016-01-15 00:00:00 to 2018-08-18 10:59:59
# Data columns (total 33 columns):
# primary_cleaner.input.sulfate               13130 non-null float64
# primary_cleaner.input.depressant            13130 non-null float64
# primary_cleaner.input.feed_size             13130 non-null float64
# primary_cleaner.input.xanthate              13130 non-null float64
# primary_cleaner.state.floatbank8_a_air      13130 non-null float64
# primary_cleaner.state.floatbank8_b_air      13130 non-null float64
# primary_cleaner.state.floatbank8_c_air      13130 non-null float64
# primary_cleaner.state.floatbank8_d_air      13130 non-null float64
# rougher.input.feed_ag                       13130 non-null float64
# rougher.input.feed_pb                       13130 non-null float64
# rougher.input.feed_rate                     13130 non-null float64
# rougher.input.feed_size                     13130 non-null float64
# rougher.input.feed_sol                      13130 non-null float64
# rougher.input.feed_au                       13130 non-null float64
# rougher.input.floatbank10_sulfate           13130 non-null float64
# rougher.input.floatbank10_xanthate          13130 non-null float64
# rougher.input.floatbank11_sulfate           13130 non-null float64
# rougher.input.floatbank11_xanthate          13130 non-null float64
# rougher.state.floatbank10_a_air             13130 non-null float64
# rougher.state.floatbank10_b_air             13130 non-null float64
# rougher.state.floatbank10_c_air             13130 non-null float64
# rougher.state.floatbank10_d_air             13130 non-null float64
# rougher.state.floatbank10_e_air             13130 non-null float64
# rougher.state.floatbank10_f_air             13130 non-null float64
# secondary_cleaner.state.floatbank2_a_air    13130 non-null float64
# secondary_cleaner.state.floatbank2_b_air    13130 non-null float64
# secondary_cleaner.state.floatbank3_a_air    13130 non-null float64
# secondary_cleaner.state.floatbank3_b_air    13130 non-null float64
# secondary_cleaner.state.floatbank4_a_air    13130 non-null float64
# secondary_cleaner.state.floatbank4_b_air    13130 non-null float64
# secondary_cleaner.state.floatbank5_a_air    13130 non-null float64
# secondary_cleaner.state.floatbank5_b_air    13130 non-null float64
# secondary_cleaner.state.floatbank6_a_air    13130 non-null float64
# dtypes: float64(33)
# memory usage: 3.4 MB

# %% [markdown]
# ### Целевой признак

# %% [markdown]
# Выбирается из оригинального (неизменяемого) набора данных по индексам признаков для соовтетствующей колонки целевого признака

# %%
target_col_1
# Out:
# 'rougher.output.recovery'

# %%
target_col_2
# Out:
# 'final.output.recovery'

# %% [markdown]
# #### Исходный целевой признак

# %%
Y_rougher_origin = df_origin.loc[X_rougher_origin.index, target_col_1]
Y_rougher_origin
# Out:
# date
# 2016-01-15 00:00:00    87.107763
# 2016-01-15 01:00:00    86.843261
# 2016-01-15 02:00:00    86.842308
# 2016-01-15 03:00:00    87.226430
# 2016-01-15 04:00:00    86.688794
#                          ...
# 2018-08-18 06:59:59    89.574376
# 2018-08-18 07:59:59    87.724007
# 2018-08-18 08:59:59    88.890579
# 2018-08-18 09:59:59    89.858126
# 2018-08-18 10:59:59    89.514960
# Name: rougher.output.recovery, Length: 13805, dtype: float64

# %%
Y_final_origin = df_origin.loc[X_final_origin.index, target_col_2]
Y_final_origin
# Out:
# date
# 2016-01-15 00:00:00    70.541216
# 2016-01-15 01:00:00    69.266198
# 2016-01-15 02:00:00    68.116445
# 2016-01-15 03:00:00    68.347543
# 2016-01-15 04:00:00    66.927016
#                          ...
# 2018-08-18 06:59:59    73.755150
# 2018-08-18 07:59:59    69.049291
# 2018-08-18 08:59:59    67.002189
# 2018-08-18 09:59:59    65.523246
# 2018-08-18 10:59:59    70.281454
# Name: final.output.recovery, Length: 13805, dtype: float64

# %% [markdown]
# #### Предобработанный целевой признак

# %%
Y_rougher_prep = df_origin.loc[X_rougher_prep.index, target_col_1]
Y_rougher_prep
# Out:
# date
# 2016-01-15 00:00:00    87.107763
# 2016-01-15 01:00:00    86.843261
# 2016-01-15 02:00:00    86.842308
# 2016-01-15 03:00:00    87.226430
# 2016-01-15 04:00:00    86.688794
#                          ...
# 2018-08-18 06:59:59    89.574376
# 2018-08-18 07:59:59    87.724007
# 2018-08-18 08:59:59    88.890579
# 2018-08-18 09:59:59    89.858126
# 2018-08-18 10:59:59    89.514960
# Name: rougher.output.recovery, Length: 13130, dtype: float64

# %%
Y_final_prep = df_origin.loc[X_final_prep.index, target_col_2]
Y_final_prep
# Out:
# date
# 2016-01-15 00:00:00    70.541216
# 2016-01-15 01:00:00    69.266198
# 2016-01-15 02:00:00    68.116445
# 2016-01-15 03:00:00    68.347543
# 2016-01-15 04:00:00    66.927016
#                          ...
# 2018-08-18 06:59:59    73.755150
# 2018-08-18 07:59:59    69.049291
# 2018-08-18 08:59:59    67.002189
# 2018-08-18 09:59:59    65.523246
# 2018-08-18 10:59:59    70.281454
# Name: final.output.recovery, Length: 13130, dtype: float64

# %% [markdown]
# ## Модель

# %% [markdown]
# ### Функции вычисления метрик

# %%
# метрика sMAPE (англ. Symmetric Mean Absolute Percentage Error, «симметричное среднее абсолютное процентное отклонение»).
# возвращает не процент, а долю от среднего (так удобнее). Абсолютная точность = 0.0
def smape_score(target, predictions):
    if not len(target) == len(predictions):
        print('Длины входных данных не совпадают!')
        return 'error'
    return sum(map(lambda x: 0 if x[0] + x[1] == 0 else abs(x[0]-x[1]) / (abs(x[0]) + abs(x[1])), zip(target, predictions))) / len(target) * 2
    #return sum([abs(t-p) / (abs(t) + abs(p)) for t, p in zip(target, predictions)]) / len(target) * 2

# score will negate the return value of smape_score
# https://scikit-learn.org/stable/modules/model_evaluation.html#scoring
scoring = make_scorer(smape_score, greater_is_better=False)

# %%
# итоговая метрика
def total_smape(rougher_smape, final_smape):
    return 0.25 * rougher_smape + 0.75 * final_smape

# %% [markdown]
# ### Подбор базовой модели

# %% [markdown]
# #### ЛИНЕЙНАЯ РЕГРЕССИЯ

# %% [markdown]
# ##### Оригинальный датасет

# %%
# %%time
model = LinearRegression()
scores_r = cross_val_score(model, X_rougher_origin, Y_rougher_origin, scoring=scoring, cv=10)
scores_f = cross_val_score(model, X_final_origin, Y_final_origin, scoring=scoring, cv=10)
print(f'Среднее значение метрики sMAPE для базовой модели LogisticRegression:\
\nsMAPE(rougher) = {scores_r.mean():.4f}\
\nsMAPE(final) = {scores_f.mean():.4f}\
')
print('_'*TABLE_SIZE)
# Out:
# Среднее значение метрики sMAPE для базовой модели LogisticRegression:
# sMAPE(rougher) = -0.1072
# sMAPE(final) = -0.1097
# ____________________________________________________________________________________________________
# CPU times: user 2.24 s, sys: 1.79 s, total: 4.03 s
# Wall time: 3.98 s

# %% [markdown]
# ##### Предобработанный датасет

# %%
# %%time
model = LinearRegression()
scores_r = cross_val_score(model, X_rougher_prep, Y_rougher_prep, scoring=scoring, cv=10)
scores_f = cross_val_score(model, X_final_prep, Y_final_prep, scoring=scoring, cv=10)
print(f'Среднее значение метрики sMAPE для базовой модели LogisticRegression:\
\nsMAPE(rougher) = {scores_r.mean():.4f}\
\nsMAPE(final) = {scores_f.mean():.4f}\
')
print('_'*TABLE_SIZE)
# Out:
# Среднее значение метрики sMAPE для базовой модели LogisticRegression:
# sMAPE(rougher) = -0.0588
# sMAPE(final) = -0.0987
# ____________________________________________________________________________________________________
# CPU times: user 2.56 s, sys: 2.34 s, total: 4.9 s
# Wall time: 4.9 s

# %% [markdown]
# ##### Предобработанный упрощенный датасет

# %%
# %%time
model = LinearRegression()
scores_r = cross_val_score(model, X_rougher_prep_lite, Y_rougher_prep, scoring=scoring, cv=10)
scores_f = cross_val_score(model, X_final_prep_lite, Y_final_prep, scoring=scoring, cv=10)
print(f'Среднее значение метрики sMAPE для базовой модели LogisticRegression:\
\nsMAPE(rougher) = {scores_r.mean():.4f}\
\nsMAPE(final) = {scores_f.mean():.4f}\
')
print('_'*TABLE_SIZE)
# Out:
# Среднее значение метрики sMAPE для базовой модели LogisticRegression:
# sMAPE(rougher) = -0.0599
# sMAPE(final) = -0.0940
# ____________________________________________________________________________________________________
# CPU times: user 2.01 s, sys: 2.02 s, total: 4.03 s
# Wall time: 4 s

# %% [markdown]
# #### ДЕРЕВО РЕШЕНИЙ

# %% [markdown]
# ##### Оригинальный датасет

# %%
# %%time
model = DecisionTreeRegressor(random_state = 123)
scores_r = cross_val_score(model, X_rougher_origin, Y_rougher_origin, scoring=scoring, cv=10)
scores_f = cross_val_score(model, X_final_origin, Y_final_origin, scoring=scoring, cv=10)
print(f'Среднее значение метрики sMAPE для базовой модели LogisticRegression:\
\nsMAPE(rougher) = {scores_r.mean():.4f}\
\nsMAPE(final) = {scores_f.mean():.4f}\
')
print('_'*TABLE_SIZE)
# Out:
# Среднее значение метрики sMAPE для базовой модели LogisticRegression:
# sMAPE(rougher) = -0.1861
# sMAPE(final) = -0.1603
# ____________________________________________________________________________________________________
# CPU times: user 16.7 s, sys: 74.8 ms, total: 16.8 s
# Wall time: 16.8 s

# %% [markdown]
# ##### Предобработанный датасет

# %%
# %%time
model = DecisionTreeRegressor(random_state = 123)
scores_r = cross_val_score(model, X_rougher_prep, Y_rougher_prep, scoring=scoring, cv=10)
scores_f = cross_val_score(model, X_final_prep, Y_final_prep, scoring=scoring, cv=10)
print(f'Среднее значение метрики sMAPE для базовой модели LogisticRegression:\
\nsMAPE(rougher) = {scores_r.mean():.4f}\
\nsMAPE(final) = {scores_f.mean():.4f}\
')
print('_'*TABLE_SIZE)
# Out:
# Среднее значение метрики sMAPE для базовой модели LogisticRegression:
# sMAPE(rougher) = -0.0814
# sMAPE(final) = -0.1379
# ____________________________________________________________________________________________________
# CPU times: user 14.3 s, sys: 7.28 ms, total: 14.3 s
# Wall time: 14.8 s

# %% [markdown]
# ##### Предобработанный упрощенный датасет

# %%
# %%time
model = DecisionTreeRegressor(random_state = 123)
scores_r = cross_val_score(model, X_rougher_prep_lite, Y_rougher_prep, scoring=scoring, cv=10)
scores_f = cross_val_score(model, X_final_prep_lite, Y_final_prep, scoring=scoring, cv=10)
print(f'Среднее значение метрики sMAPE для базовой модели LogisticRegression:\
\nsMAPE(rougher) = {scores_r.mean():.4f}\
\nsMAPE(final) = {scores_f.mean():.4f}\
')
print('_'*TABLE_SIZE)
# Out:
# Среднее значение метрики sMAPE для базовой модели LogisticRegression:
# sMAPE(rougher) = -0.0832
# sMAPE(final) = -0.1427
# ____________________________________________________________________________________________________
# CPU times: user 9.53 s, sys: 42.5 ms, total: 9.57 s
# Wall time: 9.58 s

# %% [markdown]
# #### СЛУЧАНЫЙ ЛЕС

# %% [markdown]
# ##### Оригинальный датасет

# %%
# %%time
model = RandomForestRegressor(n_estimators=10, random_state=123, n_jobs=-1)
scores_r = cross_val_score(model, X_rougher_origin, Y_rougher_origin, scoring=scoring, cv=10)
scores_f = cross_val_score(model, X_final_origin, Y_final_origin, scoring=scoring, cv=10)
print(f'Среднее значение метрики sMAPE для базовой модели LogisticRegression:\
\nsMAPE(rougher) = {scores_r.mean():.4f}\
\nsMAPE(final) = {scores_f.mean():.4f}\
')
print('_'*TABLE_SIZE)
# Out:
# Среднее значение метрики sMAPE для базовой модели LogisticRegression:
# sMAPE(rougher) = -0.1326
# sMAPE(final) = -0.1124
# ____________________________________________________________________________________________________
# CPU times: user 1min 33s, sys: 177 ms, total: 1min 33s
# Wall time: 1min 33s

# %% [markdown]
# ##### Предобработанный датасет

# %%
# %%time
model = RandomForestRegressor(n_estimators=10, random_state=123, n_jobs=-1)
scores_r = cross_val_score(model, X_rougher_prep, Y_rougher_prep, scoring=scoring, cv=10)
scores_f = cross_val_score(model, X_final_prep, Y_final_prep, scoring=scoring, cv=10)
print(f'Среднее значение метрики sMAPE для базовой модели LogisticRegression:\
\nsMAPE(rougher) = {scores_r.mean():.4f}\
\nsMAPE(final) = {scores_f.mean():.4f}\
')
print('_'*TABLE_SIZE)
# Out:
# Среднее значение метрики sMAPE для базовой модели LogisticRegression:
# sMAPE(rougher) = -0.0638
# sMAPE(final) = -0.0936
# ____________________________________________________________________________________________________
# CPU times: user 1min 19s, sys: 35.2 ms, total: 1min 19s
# Wall time: 1min 20s

# %% [markdown]
# ##### Предобработанный упрощенный датасет

# %%
# %%time
model = RandomForestRegressor(n_estimators=10, random_state=123, n_jobs=-1)
scores_r = cross_val_score(model, X_rougher_prep_lite, Y_rougher_prep, scoring=scoring, cv=10)
scores_f = cross_val_score(model, X_final_prep_lite, Y_final_prep, scoring=scoring, cv=10)
print(f'Среднее значение метрики sMAPE для базовой модели LogisticRegression:\
\nsMAPE(rougher) = {scores_r.mean():.4f}\
\nsMAPE(final) = {scores_f.mean():.4f}\
')
print('_'*TABLE_SIZE)
# Out:
# Среднее значение метрики sMAPE для базовой модели LogisticRegression:
# sMAPE(rougher) = -0.0670
# sMAPE(final) = -0.0930
# ____________________________________________________________________________________________________
# CPU times: user 52 s, sys: 0 ns, total: 52 s
# Wall time: 52.6 s

# %% [markdown]
# #### Вывод:

# %% [markdown]
# 1. Лучшие значения метрики sMAPE для эффективности обогащения **чернового** концентрата показывает базовая модель **Линейной регрессии** на **предобработанном датасете**.
#
# 1. Лучшие значения метрики sMAPE для эффективности обогащения **финального** концентрата показывает базовая модель **Случайного леса** на **предобработанном** и **предобработанном упрощенном** датасете.
#
# 1. Модель Решабщего дерева показывате худшие результаты.
#
# 1. Отброшенные признаки уровня жидкости судя по метрикам дают действительно незначительный вклад в предсказания (*если нужна скорость обработки модели, то можно их убирать*).

# %% [markdown]
# ### Подбор гиперпараметров

# %% [markdown]
# Попробуем подобрать гиперпараметры для модели Случайного леса на предобработанном и предобработанном упрощенном датасетах.

# %% [markdown]
# #### СЛУЧАНЫЙ ЛЕС

# %% [markdown]
# ##### Предобработанный датасет

# %% [markdown]
# Эффективность обогащения **чернового** концентрата:

# %%
# %%time
parameters = {
    'min_samples_split': [2, 1],
    'min_samples_leaf': [1, 1],
    'n_estimators': [5, 5],
    'max_depth': [2, 1],
    }

ascending_grid(X_rougher_prep, Y_rougher_prep, RandomForestRegressor, parameters, scoring=scoring, plot=False, cv=10)
# Out:
# CPU times: user 2min 22s, sys: 149 ms, total: 2min 22s
# Wall time: 2min 23s
# {'iterations': 320,
#  'score': -0.060632999478833646,
#  'parameters': {'max_depth': 4,
#   'n_estimators': 5,
#   'min_samples_leaf': 1,
#   'min_samples_split': 2}}

# %% [markdown]
# Эффективность обогащения **финального** концентрата:

# %%
# %%time
parameters = {
    'min_samples_split': [2, 1],
    'min_samples_leaf': [1, 1],
    'n_estimators': [5, 5],
    'max_depth': [2, 1],
    }

# ascending_grid(X_final_prep, Y_final_prep, RandomForestRegressor, parameters, scoring=scoring, plot=False, cv=10)
# *
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 8.34 µs

# %% [markdown]
# ---
# \* *Функция отрабатывает порядка 40 минут, результат такой:*

# %%
print('''
CPU times: user 38min 30s, sys: 977 ms, total: 38min 31s
Wall time: 38min 43s

{'iterations': 1040,
 'score': -0.0830945138052663,
 'parameters': {'max_depth': 5,
  'n_estimators': 15,
  'min_samples_leaf': 3,
  'min_samples_split': 2}}
''')
# Out:
# CPU times: user 38min 30s, sys: 977 ms, total: 38min 31s
# Wall time: 38min 43s
#
# {'iterations': 1040,
#  'score': -0.0830945138052663,
#  'parameters': {'max_depth': 5,
#   'n_estimators': 15,
#   'min_samples_leaf': 3,
#   'min_samples_split': 2}}

# %% [markdown]
# ##### Предобработанный упрощенный датасет

# %% [markdown]
# Эффективность обогащения **чернового** концентрата:

# %%
# %%time
parameters = {
    'min_samples_split': [2, 1],
    'min_samples_leaf': [1, 1],
    'n_estimators': [5, 5],
    'max_depth': [2, 1],
    }

ascending_grid(X_rougher_prep_lite, Y_rougher_prep, RandomForestRegressor, parameters, scoring=scoring, plot=False, cv=10)
# Out:
# CPU times: user 2min 37s, sys: 148 ms, total: 2min 37s
# Wall time: 2min 38s
# {'iterations': 300,
#  'score': -0.06203181309879509,
#  'parameters': {'max_depth': 6,
#   'n_estimators': 10,
#   'min_samples_leaf': 1,
#   'min_samples_split': 2}}

# %% [markdown]
# Эффективность обогащения **финального** концентрата:

# %%
# %%time
parameters = {
    'min_samples_split': [2, 1],
    'min_samples_leaf': [1, 1],
    'n_estimators': [5, 5],
    'max_depth': [2, 1],
    }

# ascending_grid(X_final_prep_lite, Y_final_prep, RandomForestRegressor, parameters, scoring=scoring, plot=False, cv=10)
# *
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 8.34 µs

# %% [markdown]
# ---
# \* *Функция отрабатывает порядка 10 минут, результат такой:*

# %%
print('''
CPU times: user 10min 11s, sys: 374 ms, total: 10min 11s
Wall time: 10min 14s

{'iterations': 640,
 'score': -0.08340208986646522,
 'parameters': {'max_depth': 4,
  'n_estimators': 15,
  'min_samples_leaf': 1,
  'min_samples_split': 2}}
''')
# Out:
# CPU times: user 10min 11s, sys: 374 ms, total: 10min 11s
# Wall time: 10min 14s
#
# {'iterations': 640,
#  'score': -0.08340208986646522,
#  'parameters': {'max_depth': 4,
#   'n_estimators': 15,
#   'min_samples_leaf': 1,
#   'min_samples_split': 2}}

# %% [markdown]
# #### Вывод:

# %% [markdown]
# 1. Для эффективности обогащения чернового концентрата лучшей остается базовая модель **Линейной регрессии** на **предобработанном датасете** со средним значением метрки **sMAPE(rougher) = 0.0588**
#
# 1. Для эффективности обогащения финального концентрата лучшей определена модель **Случайный лес** на **предобработанном датасете** со средним значением метрки **sMAPE(final) = 0.0831** с гиперпараметрами:
# - `max_depth`: **`5`**,
# - `n_estimators`: **`15`**,
# - `min_samples_leaf`: **`3`**,
# - `min_samples_split`: **`2`**
#
# 1. Потенциальное **итоговое sMAPE** = 0.0588 х 0.25 + 0.0831 х 0.75 = **0.0770**

# %%
# %%time
parameters = {
    'min_samples_split': [2, 1],
    'min_samples_leaf': [1, 1],
    'n_estimators': [5, 5],
    'max_depth': [2, 1],
    }

#best_forest = ascending_grid(X_final_prep, Y_final_prep, RandomForestRegressor, parameters, scoring=scoring, plot=False, cv=10)

best_forest = {'max_depth': 5,
  'n_estimators': 15,
  'min_samples_leaf': 3,
  'min_samples_split': 2}

best_forest
# Out:
# CPU times: user 15 µs, sys: 0 ns, total: 15 µs
# Wall time: 18.4 µs
# {'max_depth': 5,
#  'n_estimators': 15,
#  'min_samples_leaf': 3,
#  'min_samples_split': 2}

# %% [markdown]
# ### Тестирование модели

# %% [markdown]
# Создадим 2 набора тестовых данных:
# - для нахождения эффективности обогащения чернового концентрата
# - для нахождения эффективности обогащения финального концентрата

# %% [markdown]
# Признаки для нахождения эффективности обогащения финального концентрата:

# %%
X_final_test = df['test']
X_final_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5229 entries, 2016-09-01 00:59:59 to 2017-12-31 23:59:59
# Data columns (total 52 columns):
# primary_cleaner.input.sulfate                 5229 non-null float64
# primary_cleaner.input.depressant              5229 non-null float64
# primary_cleaner.input.feed_size               5229 non-null float64
# primary_cleaner.input.xanthate                5229 non-null float64
# primary_cleaner.state.floatbank8_a_air        5229 non-null float64
# primary_cleaner.state.floatbank8_a_level      5229 non-null float64
# primary_cleaner.state.floatbank8_b_air        5229 non-null float64
# primary_cleaner.state.floatbank8_b_level      5229 non-null float64
# primary_cleaner.state.floatbank8_c_air        5229 non-null float64
# primary_cleaner.state.floatbank8_c_level      5229 non-null float64
# primary_cleaner.state.floatbank8_d_air        5229 non-null float64
# primary_cleaner.state.floatbank8_d_level      5229 non-null float64
# rougher.input.feed_ag                         5229 non-null float64
# rougher.input.feed_pb                         5229 non-null float64
# rougher.input.feed_rate                       5229 non-null float64
# rougher.input.feed_size                       5229 non-null float64
# rougher.input.feed_sol                        5229 non-null float64
# rougher.input.feed_au                         5229 non-null float64
# rougher.input.floatbank10_sulfate             5229 non-null float64
# rougher.input.floatbank10_xanthate            5229 non-null float64
# rougher.input.floatbank11_sulfate             5229 non-null float64
# rougher.input.floatbank11_xanthate            5229 non-null float64
# rougher.state.floatbank10_a_air               5229 non-null float64
# rougher.state.floatbank10_a_level             5229 non-null float64
# rougher.state.floatbank10_b_air               5229 non-null float64
# rougher.state.floatbank10_b_level             5229 non-null float64
# rougher.state.floatbank10_c_air               5229 non-null float64
# rougher.state.floatbank10_c_level             5229 non-null float64
# rougher.state.floatbank10_d_air               5229 non-null float64
# rougher.state.floatbank10_d_level             5229 non-null float64
# rougher.state.floatbank10_e_air               5229 non-null float64
# rougher.state.floatbank10_e_level             5229 non-null float64
# rougher.state.floatbank10_f_air               5229 non-null float64
# rougher.state.floatbank10_f_level             5229 non-null float64
# secondary_cleaner.state.floatbank2_a_air      5229 non-null float64
# secondary_cleaner.state.floatbank2_a_level    5229 non-null float64
# secondary_cleaner.state.floatbank2_b_air      5229 non-null float64
# secondary_cleaner.state.floatbank2_b_level    5229 non-null float64
# secondary_cleaner.state.floatbank3_a_air      5229 non-null float64
# secondary_cleaner.state.floatbank3_a_level    5229 non-null float64
# secondary_cleaner.state.floatbank3_b_air      5229 non-null float64
# secondary_cleaner.state.floatbank3_b_level    5229 non-null float64
# secondary_cleaner.state.floatbank4_a_air      5229 non-null float64
# secondary_cleaner.state.floatbank4_a_level    5229 non-null float64
# secondary_cleaner.state.floatbank4_b_air      5229 non-null float64
# secondary_cleaner.state.floatbank4_b_level    5229 non-null float64
# secondary_cleaner.state.floatbank5_a_air      5229 non-null float64
# secondary_cleaner.state.floatbank5_a_level    5229 non-null float64
# secondary_cleaner.state.floatbank5_b_air      5229 non-null float64
# secondary_cleaner.state.floatbank5_b_level    5229 non-null float64
# secondary_cleaner.state.floatbank6_a_air      5229 non-null float64
# secondary_cleaner.state.floatbank6_a_level    5229 non-null float64
# dtypes: float64(52)
# memory usage: 2.1 MB

# %% [markdown]
# Признаки для нахождения эффективности обогащения чернового концентрата:

# %%
X_rougher_test = qdf(X_final_test, 'rougher', '', '')
X_rougher_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5229 entries, 2016-09-01 00:59:59 to 2017-12-31 23:59:59
# Data columns (total 22 columns):
# rougher.input.feed_ag                 5229 non-null float64
# rougher.input.feed_pb                 5229 non-null float64
# rougher.input.feed_rate               5229 non-null float64
# rougher.input.feed_size               5229 non-null float64
# rougher.input.feed_sol                5229 non-null float64
# rougher.input.feed_au                 5229 non-null float64
# rougher.input.floatbank10_sulfate     5229 non-null float64
# rougher.input.floatbank10_xanthate    5229 non-null float64
# rougher.input.floatbank11_sulfate     5229 non-null float64
# rougher.input.floatbank11_xanthate    5229 non-null float64
# rougher.state.floatbank10_a_air       5229 non-null float64
# rougher.state.floatbank10_a_level     5229 non-null float64
# rougher.state.floatbank10_b_air       5229 non-null float64
# rougher.state.floatbank10_b_level     5229 non-null float64
# rougher.state.floatbank10_c_air       5229 non-null float64
# rougher.state.floatbank10_c_level     5229 non-null float64
# rougher.state.floatbank10_d_air       5229 non-null float64
# rougher.state.floatbank10_d_level     5229 non-null float64
# rougher.state.floatbank10_e_air       5229 non-null float64
# rougher.state.floatbank10_e_level     5229 non-null float64
# rougher.state.floatbank10_f_air       5229 non-null float64
# rougher.state.floatbank10_f_level     5229 non-null float64
# dtypes: float64(22)
# memory usage: 939.6 KB

# %% [markdown]
# Целевой признак для нахождения эффективности обогащения чернового концентрата:

# %%
Y_rougher_test = df_origin.loc[X_rougher_test.index, target_col_1]
Y_rougher_test
# Out:
# date
# 2016-09-01 00:59:59    89.993421
# 2016-09-01 01:59:59    88.089657
# 2016-09-01 02:59:59    88.412756
# 2016-09-01 03:59:59    87.360133
# 2016-09-01 04:59:59    83.236367
#                          ...
# 2017-12-31 19:59:59    95.172585
# 2017-12-31 20:59:59    94.575036
# 2017-12-31 21:59:59    93.018138
# 2017-12-31 22:59:59    92.599042
# 2017-12-31 23:59:59    91.177695
# Name: rougher.output.recovery, Length: 5229, dtype: float64

# %% [markdown]
# Целевой признак для нахождения эффективности обогащения финального концентрата:

# %%
Y_final_test = df_origin.loc[X_final_test.index, target_col_2]
Y_final_test
# Out:
# date
# 2016-09-01 00:59:59    70.273583
# 2016-09-01 01:59:59    68.910432
# 2016-09-01 02:59:59    68.143213
# 2016-09-01 03:59:59    67.776393
# 2016-09-01 04:59:59    61.467078
#                          ...
# 2017-12-31 19:59:59    68.919891
# 2017-12-31 20:59:59    68.440582
# 2017-12-31 21:59:59    67.092759
# 2017-12-31 22:59:59    68.061186
# 2017-12-31 23:59:59    71.699976
# Name: final.output.recovery, Length: 5229, dtype: float64

# %% [markdown]
# **Создадим 2 рабочих модели:**

# %% [markdown]
# - Для нахождения эффективности обогащения чернового концентрата:

# %%
model_rougher = LinearRegression()
model_rougher.fit(X_rougher_prep, Y_rougher_prep)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# - Для нахождения эффективности обогащения финального концентрата

# %%
model_final = RandomForestRegressor(**best_forest, random_state=123, n_jobs=-1)
model_final.fit(X_final_prep, Y_final_prep)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=5,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=3, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=15,
#                       n_jobs=None, oob_score=False, random_state=123, verbose=0,
#                       warm_start=False)

# %% [markdown]
# **Получим предсказания**

# %%
predictions_train_rougher = model_rougher.predict(X_rougher_prep)
predictions_train_final = model_final.predict(X_final_prep)

predictions_test_rougher = model_rougher.predict(X_rougher_test)
predictions_test_final = model_final.predict(X_final_test)

# %% [markdown]
# **Протестируем модель:**

# %%
smape_train_rougher = smape_score(Y_rougher_prep, predictions_train_rougher)
smape_train_final = smape_score(Y_final_prep, predictions_train_final)

smape_test_rougher = smape_score(Y_rougher_test, predictions_test_rougher)
smape_test_final = smape_score(Y_final_test, predictions_test_final)

print('-'*TABLE_SIZE)
print()
print(f'Метрика sMAPE на обучающей выборке для эффективности обогащения чернового концентрата : {smape_train_rougher:.4f}')
print()
print(f'Метрика sMAPE на обучающей выборке для эффективности обогащения финального концентрата : {smape_train_final:.4f}')
print()
print(f'Метрика sMAPE на {text.BOLD}тестовой выборке{text.END} для эффективности обогащения чернового концентрата :{text.BG_YELLOW}{text.BOLD} {smape_test_rougher:.4f} {text.END}')
print()
print(f'Метрика sMAPE на {text.BOLD}тестовой выборке{text.END} для эффективности обогащения финального концентрата :{text.BG_YELLOW}{text.BOLD} {smape_test_final:.4f} {text.END}')
print()
print('-'*TABLE_SIZE)
print()
# Out:
# ----------------------------------------------------------------------------------------------------
#
# Метрика sMAPE на обучающей выборке для эффективности обогащения чернового концентрата : 0.0492
#
# Метрика sMAPE на обучающей выборке для эффективности обогащения финального концентрата : 0.0682
#
# Метрика sMAPE на тестовой выборке для эффективности обогащения чернового концентрата : 0.0811
#
# Метрика sMAPE на тестовой выборке для эффективности обогащения финального концентрата : 0.0935
#
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Проверка модели на адекватность

# %% [markdown]
# Воспользуемся классом DummyClassifier для определения значения ключевой метрики модели на констатных средних значениях целевых признаков:

# %%
dummy_clf = DummyRegressor(strategy="mean")
dummy_clf.fit(X_rougher_prep, Y_rougher_prep)
dummy_predictions = dummy_clf.predict(X_rougher_test)
dummy_score_r = smape_score(Y_rougher_test, dummy_predictions)
print(f'Метрика sMAPE для случайной модели: {dummy_score_r:.4f}')
# Out:
# Метрика sMAPE для случайной модели: 0.0888

# %%
dummy_clf = DummyRegressor(strategy="mean")
dummy_clf.fit(X_final_prep, Y_final_prep)
dummy_predictions = dummy_clf.predict(X_final_test)
dummy_score_f = smape_score(Y_final_test, dummy_predictions)
print(f'Метрика sMAPE для случайной модели: {dummy_score_f:.4f}')
# Out:
# Метрика sMAPE для случайной модели: 0.0944

# %%
print(f'Итоговое значение sMAPE:\n\
- для констатной модели среднего {text.BG_SILVER}{text.BOLD} {total_smape(dummy_score_r, dummy_score_f):.4f} {text.END}\n\
')
# Out:
# Итоговое значение sMAPE:
# - для констатной модели среднего  0.0930

# %% [markdown]
# В рабочей модели значения метрик практически такие же как на случайной или константной модели, но все же немного ближе к `0`.
#
# В такоем случае сложно судить о проверке на адекватность, поскольку данныый результат мог получится случайно.
#
# Проверим константную модель на обучающей и валидационной выборках с использованием кросс-валидации:

# %%
# %%time
model = DummyRegressor(strategy="mean")
scores_r = cross_val_score(model, X_rougher_prep, Y_rougher_prep, scoring=scoring, cv=10)
scores_f = cross_val_score(model, X_final_prep, Y_final_prep, scoring=scoring, cv=10)
print(f'Среднее значение метрики sMAPE для базовой модели LogisticRegression:\
\nsMAPE(rougher) = {scores_r.mean():.4f}\
\nsMAPE(final) = {scores_f.mean():.4f}\
')
print('_'*TABLE_SIZE)

print(f'Итоговое значение sMAPE:\n\
- для констатной модели среднего {text.BG_SILVER}{text.BOLD} {total_smape(scores_r.mean(), scores_f.mean()):.4f} {text.END}\n\
')
# Out:
# Среднее значение метрики sMAPE для базовой модели LogisticRegression:
# sMAPE(rougher) = -0.0754
# sMAPE(final) = -0.0990
# ____________________________________________________________________________________________________
# Итоговое значение sMAPE:
# - для констатной модели среднего  -0.0931
#
# CPU times: user 85.1 ms, sys: 17 µs, total: 85.1 ms
# Wall time: 83.5 ms

# %% [markdown]
# В рабочей модели на обучающей/вылидационной выборках с кросс-валидацией значения метрик ближе к `0`, чем на константной модели <br/>(0,0588 против 0,0754 и 0,0831 против 0,0990).
#
# Можно сделать вывод, что на разнообразных данных рабочая модель будет показывать лучшие результаты, чем константная модель, и все-таки рабочая модель проходит проверку на адекватность.

# %% [markdown]
# ### Итоговое sMAPE

# %%
print(f'Итоговое значение sMAPE:\n\
- для обучающей выборки {text.BG_SILVER}{text.BOLD} {total_smape(smape_train_rougher, smape_train_final):.4f} {text.END}\n\
- для тестовой выборки {text.BG_YELLOW}{text.BOLD} {total_smape(smape_test_rougher, smape_test_final):.4f} {text.END}')
# Out:
# Итоговое значение sMAPE:
# - для обучающей выборки  0.0634
# - для тестовой выборки  0.0904

# %% [markdown]
# ## Выводы

# %% [markdown]
# 1. Была проведена работа по разработке прототип модели машинного,<br/> определяющей коэффициент восстановления золота из золотосодержащей руды.
# 1. В исходных данных имеются множественные пропуски значений
#     - Исходные данные (таблица `full`) оставлена без изменений пропусков
#     - В тестовой выборке (таблица `test`) удалены все пропуски
#     - В обучающей выборке (таблица `train`) пропуски с большой долей заменены на медианные значения, а пропуски с малой долей удалены
# 1. Признак `date` приведен к типу даты, все осталные данные - численные с соответствующим типом.
# 1. Исправлены аномальные концентрации по стадиям процесса.
# 1. В данных имеются значительные выбросы по размерам гранул на вход во влотационную установку (оставлены без изменений).
# 1. Распределение размеров гранул сырья на тестовой и обучающей выборках разные,<br/> соовтетсвенно значения получаемых метрик имеют низкую точность.
# 1. Если нужна скорость работы модели, то можно не расссмативать признаки уровня жидкости.<br/> Без данных признаков размер данных значительно меньше, а точность модели практически не страдает.
# 1. Без обработки данных моделирование не имеет смысла, поскольку в таком случае метрики хуже, чем на констатной модели средних величин.
# 1. Подобрана модель с лучшими показателями `sMAPE`, это:
#     - **Линейная регрессия** для для нахождения эффективности обогащения чернового концентрата
#     - **Случайный лес** с гиперпараметрами: `max_depth =`**`5`**, `n_estimators =`**`15`**, `min_samples_leaf =`**`3`**, `min_samples_split =`**`2`**<br/> для нахождения эффективности обогащения финального концентрата.
# 1. По средним величинам эффективности обогащения значение итогового `sMAPE` = **0.0930 (9.30%)**.
# 1. Тест модели показал значение итогового `sMAPE` = **0.0904 (9.04%)**.
# 1. Полученная модель имеет слабую предсказательную силу.
