# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Цель-исследования" data-toc-modified-id="Цель-исследования-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Цель исследования</a></span></li><li><span><a href="#Условия-задачи" data-toc-modified-id="Условия-задачи-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Условия задачи</a></span></li><li><span><a href="#Исходные-данные" data-toc-modified-id="Исходные-данные-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исходные данные</a></span><ul class="toc-item"><li><span><a href="#Подключаемые-модули" data-toc-modified-id="Подключаемые-модули-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Подключаемые модули</a></span></li><li><span><a href="#Общие-параметры" data-toc-modified-id="Общие-параметры-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Общие параметры</a></span></li><li><span><a href="#Общие-функции" data-toc-modified-id="Общие-функции-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Общие функции</a></span></li></ul></li><li><span><a href="#Получение-данных" data-toc-modified-id="Получение-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Получение данных</a></span><ul class="toc-item"><li><span><a href="#Чтение-данных-из-файла" data-toc-modified-id="Чтение-данных-из-файла-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Чтение данных из файла</a></span></li><li><span><a href="#Общая-информацция" data-toc-modified-id="Общая-информацция-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Общая информацция</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Исправление-заголовков" data-toc-modified-id="Исправление-заголовков-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Исправление заголовков</a></span></li><li><span><a href="#Проверка-на-явные-дубликаты" data-toc-modified-id="Проверка-на-явные-дубликаты-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Проверка на явные дубликаты</a></span></li><li><span><a href="#Проверка-пропусков" data-toc-modified-id="Проверка-пропусков-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Проверка пропусков</a></span></li><li><span><a href="#Замена-типов-данных" data-toc-modified-id="Замена-типов-данных-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Замена типов данных</a></span></li><li><span><a href="#Проверка-смысловых-зависимостей" data-toc-modified-id="Проверка-смысловых-зависимостей-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Проверка смысловых зависимостей</a></span></li><li><span><a href="#Проверка-значений:-ошибки,-выбросы,-дубликаты" data-toc-modified-id="Проверка-значений:-ошибки,-выбросы,-дубликаты-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Проверка значений: ошибки, выбросы, дубликаты</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Корреляция" data-toc-modified-id="Корреляция-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Корреляция</a></span></li><li><span><a href="#X,-Y-параметры" data-toc-modified-id="X,-Y-параметры-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>X, Y параметры</a></span></li><li><span><a href="#Набор-данных" data-toc-modified-id="Набор-данных-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Набор данных</a></span></li><li><span><a href="#Разбивка-данных" data-toc-modified-id="Разбивка-данных-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Разбивка данных</a></span></li><li><span><a href="#Масштабирование-данных" data-toc-modified-id="Масштабирование-данных-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Масштабирование данных</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Обучение-и-проверка-модели" data-toc-modified-id="Обучение-и-проверка-модели-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Обучение и проверка модели</a></span><ul class="toc-item"><li><span><a href="#Обучение-модели" data-toc-modified-id="Обучение-модели-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Обучение модели</a></span></li><li><span><a href="#Проверка-модели" data-toc-modified-id="Проверка-модели-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Проверка модели</a></span></li><li><span><a href="#Результаты-обучения" data-toc-modified-id="Результаты-обучения-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Результаты обучения</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Подготовка-к-расчёту-прибыли" data-toc-modified-id="Подготовка-к-расчёту-прибыли-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Подготовка к расчёту прибыли</a></span><ul class="toc-item"><li><span><a href="#Ключевые-параметры-рассчета" data-toc-modified-id="Ключевые-параметры-рассчета-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Ключевые параметры рассчета</a></span></li><li><span><a href="#Достаточный-объем-скважины" data-toc-modified-id="Достаточный-объем-скважины-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Достаточный объем скважины</a></span></li></ul></li><li><span><a href="#Расчёт-прибыли-и-рисков" data-toc-modified-id="Расчёт-прибыли-и-рисков-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Расчёт прибыли и рисков</a></span><ul class="toc-item"><li><span><a href="#Функция-расчета-прибыли" data-toc-modified-id="Функция-расчета-прибыли-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Функция расчета прибыли</a></span></li><li><span><a href="#Расчет-прибыли-по-регионам" data-toc-modified-id="Расчет-прибыли-по-регионам-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Расчет прибыли по регионам</a></span><ul class="toc-item"><li><span><a href="#Регион-1" data-toc-modified-id="Регион-1-9.2.1"><span class="toc-item-num">9.2.1&nbsp;&nbsp;</span>Регион 1</a></span></li><li><span><a href="#Регион-2" data-toc-modified-id="Регион-2-9.2.2"><span class="toc-item-num">9.2.2&nbsp;&nbsp;</span>Регион 2</a></span></li><li><span><a href="#Регион-3" data-toc-modified-id="Регион-3-9.2.3"><span class="toc-item-num">9.2.3&nbsp;&nbsp;</span>Регион 3</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Выбор локации для скважины

# %% [markdown]
# Допустим, вы работаете в добывающей компании «ГлавРосГосНефть». Нужно решить, где бурить новую скважину.
#
# Вам предоставлены пробы нефти в трёх регионах: в каждом 10 000 месторождений, где измерили качество нефти и объём её запасов. Постройте модель машинного обучения, которая поможет определить регион, где добыча принесёт наибольшую прибыль. Проанализируйте возможную прибыль и риски техникой *Bootstrap.*
#
# Шаги для выбора локации:
#
# - В избранном регионе ищут месторождения, для каждого определяют значения признаков;
# - Строят модель и оценивают объём запасов;
# - Выбирают месторождения с самым высокими оценками значений. Количество месторождений зависит от бюджета компании и стоимости разработки одной скважины;
# - Прибыль равна суммарной прибыли отобранных месторождений.

# %% [markdown]
# ## Цель исследования

# %% [markdown]
# Определить наиболее выгодный (прибыльный) регион для разработки скважин.

# %% [markdown]
# <a id='conditions'> </a>

# %% [markdown]
# ## Условия задачи

# %% [markdown]
# - Для обучения модели подходит только **линейная регрессия** (остальные — недостаточно предсказуемые).
#
# - При разведке региона исследуют **500 точек**, из которых с помощью машинного обучения выбирают **200 лучших для разработки**.
#
# - Бюджет на разработку скважин в регионе — **10 млрд рублей**.
#
# - При нынешних ценах один баррель сырья приносит **450 рублей дохода**. Доход с каждой единицы продукта составляет **450 тыс. рублей**, поскольку объём указан в тысячах баррелей.
#
# - После оценки рисков нужно оставить лишь те регионы, в которых **вероятность убытков меньше 2.5%**. Среди них выбирают регион с наибольшей средней прибылью.
#
# - Данные *синтетические*: детали контрактов и характеристики месторождений не разглашаются.

# %% [markdown]
# ## Исходные данные

# %% [markdown]
# ### Подключаемые модули

# %%
# Подключаемые модули:

# Основное
import pandas as pd
import numpy as np
from scipy import stats as st

# Гарфика
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import seaborn as sns

# sklearn
from sklearn.linear_model import LinearRegression

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### Общие параметры

# %%
# ПАРАМЕТРЫ,, общие переменные
yandex_storage = None
table_size = 100
r_state = np.random.RandomState(123)

# %% [markdown]
# ### Общие функции

# %% [markdown]
# Информирование:

# %%
# print("AB\x1b[43mCD\x1b[35mEF\x1b[1mGH\x1b[4mIJ\x1b[7m"
#       "KL\x1b[49mMN\x1b[39mOP\x1b[22mQR\x1b[24mST\x1b[27mUV")

# Вывод информации о всех таблицах:
def display_all(df, names, functions, divider=False):
    size = table_size
    for name in names:
        if divider:
            print('_'*size)
        table_name = ' ТАБЛИЦА ' + name + ' '
        print("\x1b[1m\x1b[47m", table_name + table_name.rjust(size-len(table_name)-2, '='), "\x1b[49m\x1b[22m")
        # 1 -жирность, 41-47 -цвет выделения, 49 -снять выделение, 22- снять жирность
        if type(functions) == str:
            display(eval(f"df['{name}'].{functions}"))
        else:
            for func in functions:
                print("\x1b[1m", end='')
                print('.'*size)
                print(func.rjust(size))
                print("\x1b[22m", end='')
                display(eval(f"df['{name}'].{func}"))
        print()
        
# вывод таблицы описания данных:
def print_description(df):
    len_index = max([len(i) for i in df])
    for index in df:
        end = '' if len(description[index]) < table_size else '...'
        print(f'{index.ljust(len_index)} - {description[index][:table_size]}{end}')

# размер таблиц:
def get_shape(data):
    shape = {}
    for name in data.keys():
        shape[name] = data[name].shape
    shape = pd.DataFrame(shape).T.rename(columns={0:'Число строк', 1:'Число столбцов'})
    return shape

# остаок таблицы:
def show_remain(data):
    display((get_shape(data) / origin_shape).style.format({'Число строк': '{:.1%}', 'Число столбцов': '{:.1%}'}))

# %% [markdown]
# Презентации

# %%
# вывод больших чисел
def big_number(val):
    dec = str(round(val * 100 % 100))
    s = list(str(round(val)).lstrip('-'))
    for i in range(0, len(s)-1, 4):
        s.insert(-i-3, '`')
    return ('','-')[int(val < 0)] + ''.join(s) + '.' + dec

# %%
def hist_box_describe(df, col, subtitle='', xlabel=None, ylabel=None, data=None, bins=None, figsize=(8, 8), **kwargs):
    if type(data) == type(None):
        data = df[col]
    if xlabel == None:
        try:
            xlabel = description[col]
        except:
            pass
    if bins == None:
        bins = data.nunique()
    
    fig = plt.figure()
    
    # Разделение fig на зоны разных размеров:
    gs1 = GridSpec(5, 1, left=0.05, right=0.95, hspace=0.03)
    # (y, x) - размеры сетки (высота, ширина)
    # left - расположние левой границы всей сетки (топа margin)
    # right - расположние правой границы всей сетки (топа margin)
    # wspace, hspace - зазоры между графиками (вертикальный, горизонтальный)
    ax1 = fig.add_subplot(gs1[:1, :]) # (срез по Y, срез по X)
    ax2 = fig.add_subplot(gs1[1:, :])
    
    # Построение графиков:
    data.plot(ax=ax1, kind='box', vert=False, widths=0.6, **kwargs)
    data.plot(ax=ax2, kind='hist', grid=True, bins=bins, **kwargs)
    
    # Различные настройки графиков:
    fig.set_figwidth(figsize[0])
    fig.set_figheight(figsize[1])
    #fig.suptitle(f'Распределение показателя "{xlabel}"', fontsize = 16)
    
    ax1.xaxis.tick_top()
    ax2.minorticks_on()
    ax2.grid(which='major',
            color = 'grey', 
            linewidth = 1.2)
    ax2.grid(which='minor', 
            color = 'grey', 
            linestyle = ':')
    
    ax1.set_yticklabels([''])
    ax2.set_xlabel(xlabel, fontsize = 14)
    ax2.set_ylabel('Количество значений', fontsize = 14)
    ax1.tick_params(labelsize = 12)
    ax2.tick_params(labelsize = 12)
    ax1.set_title(f'Распределение показателя "{xlabel}"{subtitle}', pad=15, fontsize = 16)

    x = ax2.get_xbound()
    y = ax2.get_ybound()
    x_coord = x[0] + (x[1]-x[0])/figsize[0]*figsize[1]*0.03 if data.mean() < data.quantile(0.5) else x[1] - (x[1]-x[0])/figsize[0]*figsize[1]*0.29
    y_coord = y[1] - (y[1]-y[0])*0.35
    ax2.text(x_coord, y_coord, str(data.describe()),
        rotation = 0,
        fontsize = figsize[1]*1.2,
        bbox = {'facecolor':'white', 'boxstyle': 'round', 'pad': 1}
            )

# %%
# Нормальное распределение и вероятность выпадения менее required_score
def gaussian_distribution(data, required_score, figsize=(10, 8)):
    # Нормальное распределение
    min_value = data.min()
    max_value = data.max()
    
    mu = data.mean()
    sigma = np.std(data, ddof=1)

    x = [i/1000 for i in range(int((mu - 4*sigma)*1000), int((mu + 4*sigma)*1000))]
    distr = st.norm(mu, sigma)
    
    # Построение графика
    fig, ax1 = plt.subplots()
    ax2 = ax1.twinx()
    ax1.plot(x, distr.pdf(x), label = 'Нормальное \nраспределние', color='r', linewidth=4)
    ax2.plot(x, distr.cdf(x), label = 'Вероятности', color='b', linestyle='--', linewidth=2)
    ax2.plot([required_score, required_score], [0, 1], label = 'Искомое \nзначение', linestyle=':', color='g', linewidth=4)

    fig.set_figwidth(figsize[0])
    fig.set_figheight(figsize[1])

    #ax1.xaxis.tick_top()
    ax1.minorticks_on()
    ax1.grid(which='major',
            color = 'grey', 
            linewidth = 1.2)
    ax1.grid(which='minor', 
            color = 'grey', 
            linestyle = ':')

    ax1.legend(fontsize = 12, loc = 'center left')
    ax2.legend(fontsize = 12, loc = 'center right')

    ax1.set_xlabel(f'Прибыль (млн. рублей)', fontsize = 14)
    ax1.set_ylabel('Частота для нормального распределения', fontsize = 14)
    ax2.set_ylabel('Вероятность значения больше данного', fontsize = 14)
    ax1.tick_params(labelsize = 12)
    ax2.tick_params(labelsize = 12)
    ax1.set_title(f'Нормальное распределение прибыли\n(набор из {data.shape[0]} значений)', pad=15, fontsize = 16)

    ax2.text(mu - 4*sigma, 0.85, f'Вероятность\nменьше {required_score} (убыток):\n{distr.cdf(required_score):.3%}',
            rotation = 0,
            fontsize = min(figsize)*1.75,
            bbox = {'facecolor':'white', 'pad': min(figsize)}
                )
    ax2.text(mu - 4*sigma, 0.3, f'Среднее = {mu:.4f}\nОтклонение = {sigma:.4f}',
            rotation = 0,
            fontsize = min(figsize)*1.5,
            bbox = {'facecolor':'white', 'pad': min(figsize)}
                )
    plt.show()
    print('-'*table_size)
    print(f'\x1b[1mВероятность получить значение меньше {required_score} = \x1b[43m {distr.cdf(required_score):.3%} \x1b[49m\x1b[22m')
    print('-'*table_size)
    print()

# %% [markdown]
# ## Получение данных

# %% [markdown]
# ### Чтение данных из файла

# %%
df_names = ['region_1', 'region_2', 'region_3']
df = {}
for i in range(3):
    file_name = f'geo_data_{i}' 
    df[df_names[i]] = pd.read_csv(f'{yandex_storage}{file_name}.csv')

# %% [markdown]
# ### Общая информацция

# %%
display_all(df, df_names, ['head()', 'info()', 'nunique()'])
# Out:
#   ТАБЛИЦА region_1 ============================================================== ТАБЛИЦА region_1
# ....................................................................................................
#                                                                                               head()
#       id        f0        f1        f2     product
# 0  txEyH  0.705745 -0.497823  1.221170  105.280062
# 1  2acmU  1.334711 -0.340164  4.365080   73.037750
# 2  409Wp  1.022732  0.151990  1.419926   85.265647
# 3  iJLyR -0.032172  0.139033  2.978566  168.620776
# 4  Xdl7t  1.988431  0.155413  4.751769  154.036647
# ....................................................................................................
#                                                                                               info()
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 5 columns):
# id         100000 non-null object
# ...

# %% [markdown]
# ### Описание данных

# %% [markdown]
# Создадим словарь описания данных на основании предоставленного описания

# %%
# Создадим словарь описания данных
description = {
    'id': 'уникальный идентификатор скважины',
    'f0': 'признак 0',
    'f1': 'признак 1',
    'f2': 'признак 2',
    'product': 'объём запасов в скважине (тыс. баррелей)',
}

# %% [markdown]
# Выведем словарь описания данных (**структура всех таблиц одинаковая, поэтому выведем для одной*)

# %%
print_description(df['region_1'])
# Out:
# id      - уникальный идентификатор скважины
# f0      - признак 0
# f1      - признак 1
# f2      - признак 2
# product - объём запасов в скважине (тыс. баррелей)

# %% [markdown]
# ### Выводы

# %% [markdown]
# Данные представляют собой **3 таблицы по трем регионам** с информацией о геологоразведке:
# - уникальный идентификатор скважины (1)*;
# - характеристика скважины (3):
#     - три скрытых признака характеризующих скважину;
# - **целевой** признак (1):
#     - объём запасов нефти в скважине (тыс. баррелей).
#
# В каждой таблице **`100 000 строк` и `5 колонок`**
#
# СТРУКТУРА ДАННЫХ:
#
# * Названия колонок в таблицах корректны.
# * Проверить данные на явные дубликаты.
# * Пропуски в данных отсутствуют.
#
#
# * Группы данных по типу:
#     - **Текстовые (Наименования):** идентификатор скважины;
#     - **Численные:** признаки скважины, объём запасов.
#
#
# * Типы данных не нуждаются в исправлении.
# * Смыслове (логические) взаимосвязи не выявлены.
#
# **Уникальный идентификатор скважины является только меткой и не является характеристикой, поэтому его следует исключить из параметров при работе с моделью*

# %%
# Исходный размер таблицы:
origin_shape = get_shape(df)
print('Исходный размер таблиц:')
origin_shape
# Out:
# Исходный размер таблиц:
#           Число строк  Число столбцов
# region_1       100000               5
# region_2       100000               5
# region_3       100000               5

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Исправление заголовков

# %%
display_all(df, df_names, 'columns.to_list()')
# Out:
#   ТАБЛИЦА region_1 ============================================================== ТАБЛИЦА region_1
# ['id', 'f0', 'f1', 'f2', 'product']
#   ТАБЛИЦА region_2 ============================================================== ТАБЛИЦА region_2
# ['id', 'f0', 'f1', 'f2', 'product']
#   ТАБЛИЦА region_3 ============================================================== ТАБЛИЦА region_3
# ['id', 'f0', 'f1', 'f2', 'product']

# %% [markdown]
# Заголовки не нуждаются в исправлении

# %% [markdown]
# ### Проверка на явные дубликаты

# %%
display_all(df, df_names, 'duplicated().sum()')
# Out:
#   ТАБЛИЦА region_1 ============================================================== ТАБЛИЦА region_1
# 0
#   ТАБЛИЦА region_2 ============================================================== ТАБЛИЦА region_2
# 0
#   ТАБЛИЦА region_3 ============================================================== ТАБЛИЦА region_3
# 0

# %% [markdown]
# Явных дубликатов нет

# %% [markdown]
# ### Проверка пропусков

# %%
display_all(df, df_names, 'isna().sum()')
# Out:
#   ТАБЛИЦА region_1 ============================================================== ТАБЛИЦА region_1
# id         0
# f0         0
# f1         0
# f2         0
# product    0
# dtype: int64
#   ТАБЛИЦА region_2 ============================================================== ТАБЛИЦА region_2
# id         0
# f0         0
# f1         0
# f2         0
# product    0
# dtype: int64
#   ТАБЛИЦА region_3 ============================================================== ТАБЛИЦА region_3
# id         0
# f0         0
# f1         0
# f2         0
# product    0
# dtype: int64

# %% [markdown]
# Пропуски в данных отсутствуют.

# %% [markdown]
# ### Замена типов данных

# %%
display_all(df, df_names, 'dtypes')
# Out:
#   ТАБЛИЦА region_1 ============================================================== ТАБЛИЦА region_1
# id          object
# f0         float64
# f1         float64
# f2         float64
# product    float64
# dtype: object
#   ТАБЛИЦА region_2 ============================================================== ТАБЛИЦА region_2
# id          object
# f0         float64
# f1         float64
# f2         float64
# product    float64
# dtype: object
#   ТАБЛИЦА region_3 ============================================================== ТАБЛИЦА region_3
# id          object
# f0         float64
# f1         float64
# f2         float64
# product    float64
# dtype: object

# %% [markdown]
# **Вывод:**
#
# 1. Все параметры соответствуют своему типу данных (для каждой таблицы):
# - **1** текстовых (*уникальный идентификатор скважины*) имеют тип **`object`**
# - **4** численных с дробной частью (*признаки скважины, объём запасов нефти в скважине*) имеют тип **`float`**

# %% [markdown]
# ### Проверка смысловых зависимостей

# %% [markdown]
# Противоречий в данных нет.

# %% [markdown]
# ### Проверка значений: ошибки, выбросы, дубликаты

# %% [markdown]
# Проверим распределение значений

# %%
for i in range(3):
    col = f'f{i}'
    for table_name in df_names:
        if not df[table_name][col].dtypes == object:
            hist_box_describe(df[table_name], col, bins=50, subtitle=f' для таблицы {table_name}', figsize=(6,6))

# %% [markdown]
# **Выводы:**
#
# - Диапазон значений приемлимый.
# - Распределения в основноем нормальные (колоколообразные) без скоса.
# - Имеются распределения с несколькими пиками (от 2 до 4), что характерно для выборки, объединяющей результаты нескольких процессов или условий работы. Для дальнейшего анализа таких данных нужно применять стратификации для выделения различных процессов или условий, но поскольку данные синтетические и характеристики месторождейний не разглашаются, то пропустим подобный анализ.
# - Данные по `призанку 2` для таблицы `geo_1` имеют равномерное (плато) распределние.

# %%
col = 'product'
for table_name in df_names:
    if not df[table_name][col].dtypes == object:
        hist_box_describe(df[table_name], col, bins=100, subtitle=f' для таблицы {table_name}', figsize=(6,6))

# %% [markdown]
# **Выводы:**
#
# - Диапазон значений приемлимый.
# - Распределение гребенчатого типа может указывать на ошибки измерений или на систематическую погрешность в способе округления данных. Также вероятна альтернатива того, что это один из вариантов распределения типа плато.

# %% [markdown]
# ### Вывод

# %% [markdown]
# 1. Данные успешно загружены и изучены.
# 1. Произведена первоначальная проверка и предобработка данных.
# 1. В данных не обнаружено дубликатов, пропусков значений, ошибок типов, ошибок значений, ошибок сымсловых зависимостей.

# %% [markdown]
# Размер таблиц после предобработки

# %%
show_remain(df)
# Out:
# <style  type="text/css" >
# </style><table id="T_408856e0_8d57_11ec_bc4e_02420a396a37" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Число строк</th>        <th class="col_heading level0 col1" >Число столбцов</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_408856e0_8d57_11ec_bc4e_02420a396a37level0_row0" class="row_heading level0 row0" >region_1</th>
#                         <td id="T_408856e0_8d57_11ec_bc4e_02420a396a37row0_col0" class="data row0 col0" >100.0%</td>
#                         <td id="T_408856e0_8d57_11ec_bc4e_02420a396a37row0_col1" class="data row0 col1" >100.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_408856e0_8d57_11ec_bc4e_02420a396a37level0_row1" class="row_heading level0 row1" >region_2</th>
#                         <td id="T_408856e0_8d57_11ec_bc4e_02420a396a37row1_col0" class="data row1 col0" >100.0%</td>
# ...

# %% [markdown]
# Удаление данных не производилось, строки сохранены на 100.00%.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Корреляция

# %% [markdown]
# Проверим корреляцию признаков.
#
# Построим график heatmap.

# %%
for name in df_names:
    sns.heatmap(df[name].corr())
    plt.title(f'Корреляция признаков в таблице {name}', pad=15, fontsize= 14)
    plt.show()

# %% [markdown]
# **ВЫВОД:**
#
# Корреляция между признаками слабая, соответственно все признаки включим в обучение модели.
#
# Корреляция целевого признака от f2 высокая (*Качество линейной модели по Региону 2 должно быть высоким*)

# %% [markdown]
# ### X, Y параметры

# %% [markdown]
# Определим рабочие признаки и целевой признак:
# - обучающие признаки: `f0`, `f1`, `f2`;
# - целевой признак: `product`.

# %% [markdown]
# Уникальный идентификатор скважины является только меткой и не является характеристикой, поэтому его следует исключить из параметров при работе с моделью.

# %%
X_cols = ['f0', 'f1', 'f2']
Y_col = 'product'

# %% [markdown]
# ### Набор данных

# %% [markdown]
# Создадим словарь для наборов обучающих и тестовых данных для каждого региона:

# %%
df_ml = {}
for key in df_names:
    df_ml[key] = {} 
df_ml
# Out:
# {'region_1': {}, 'region_2': {}, 'region_3': {}}

# %% [markdown]
# ### Разбивка данных

# %% [markdown]
# Разобъем данные для каждого региона на обучающую и тестовую выборки в соотношении 3:1 (75%:25%)

# %%
for key, tbl in df_ml.items():
    tbl['X_train'], tbl['X_test'], tbl['Y_train'], tbl['Y_test'] = train_test_split(df[key][X_cols],\
                                                        df[key][Y_col], test_size=0.25, random_state=123)

# %% [markdown]
# ### Масштабирование данных

# %% [markdown]
# Поскольку обучение будем производить на линейной модели, то масштабируем признаки.

# %%
for key, tbl in df_ml.items():
    scaler = StandardScaler()
    scaler.fit(tbl['X_train'][X_cols])
    tbl['X_train'][X_cols] = scaler.transform(tbl['X_train'][X_cols])
    tbl['X_test'][X_cols] = scaler.transform(tbl['X_test'][X_cols])

# %% [markdown]
# ### Выводы

# %% [markdown]
# 1. Данные подготовлены к созданию модели.
# 1. Корреляция признаков отсутсвует.
# 1. Наблюдается корреляция признака `f2` и целевого признака (особенно на Регионе 2)
# 1. Удалены явно ненужные признаки.
# 1. Выделена *обучающая* и *тестовая* части из данных в соотношении 3:1 (75% : 25%)
# 1. Применено масштабирование признаков.

# %% [markdown]
# ## Обучение и проверка модели

# %% [markdown]
# ### Обучение модели

# %% [markdown]
# Обучим модели для каждого из регионов и запишем предсказания в словарь:

# %%
for key, tbl in df_ml.items():
    model = LinearRegression().fit(tbl['X_train'], tbl['Y_train'])
    tbl['Y_pred'] = pd.Series(model.predict(tbl['X_test']), index=tbl['X_test'].index)

# %% [markdown]
# ### Проверка модели

# %% [markdown]
# Запишем результаты обучения (метрики) в словарь:

# %%
for key, tbl in df_ml.items():
    tbl['r2'] = r2_score(tbl['Y_test'], tbl['Y_pred'])
    tbl['mse'] = mean_squared_error(tbl['Y_test'], tbl['Y_pred'])
    tbl['rmse'] = tbl['mse'] ** 0.5
    tbl['средний запас предсказанного сырья'] = tbl['Y_pred'].mean()

# %% [markdown]
# ### Результаты обучения

# %% [markdown]
# Выведем основные полученные мертики для каждого региона:

# %%
pd.DataFrame(df_ml).iloc[-4:]
# Out:
#                                     region_1  region_2  region_3
# r2                                  0.281298  0.999618  0.193137
# mse                                  1417.36  0.801766   1610.26
# rmse                                 37.6479  0.895414    40.128
# средний запас предсказанного сырья   92.5494     69.28   95.0986

# %% [markdown]
# ### Выводы

# %% [markdown]
# 1. Судя по метрике `r2` точность модели для Региона 2 очень высокая (практически идеальная).
# 1. Точность модели для Рагиона 1 и Региона 3 ниже (но все же выше среднего).
# 1. Точность модели для Региона 1 выше, чем для Региона 2.
# 1. Средний запас предсказанного сырья по Региону 2 ниже, чем по другим двум на 25%.

# %% [markdown]
# ## Подготовка к расчёту прибыли

# %% [markdown]
# ### Ключевые параметры рассчета

# %% [markdown]
# Сохраним все ключевые значения для расчётов в отдельных переменных (в соответствии с [условиями задачи](#conditions)):

# %% [markdown]
# Число исследуемых точек при разведке региона:

# %%
COUNT_OBJECTS_RESEARCH = 500

# %% [markdown]
# Число отобранных точек с помощью машинного обучения:

# %%
COUNT_OBJECTS_BEST = 200

# %% [markdown]
# Бюджет на разработку скважин в регионе (руб.):

# %%
BUDGET = 10E9

# %% [markdown]
# Цена одной тысячи барреллей нефти (руб.):

# %%
PRICE_1000_BARRELS = 450_000

# %% [markdown]
# ### Достаточный объем скважины

# %% [markdown]
# Рассчитаем достаточный объём сырья для безубыточной разработки новой скважины.

# %%
sufficient_volume = BUDGET / COUNT_OBJECTS_BEST / PRICE_1000_BARRELS
print(f'Достаточный объём сырья для безубыточной разработки новой скважины - {sufficient_volume:.4f} (тыс. баррелей)')
# Out:
# Достаточный объём сырья для безубыточной разработки новой скважины - 111.1111 (тыс. баррелей)

# %% [markdown]
# Рассмотрим возможные фактические средние запасы объемов нефти в исследуемых скважинах:

# %%
results = {}
for region in df_names:
    results[region] = {}
    values = []
    for _ in range(500):
        values.append(df[region]['product'].sample(COUNT_OBJECTS_RESEARCH, random_state=r_state).mean())
    values = pd.Series(values)

    results[region]['Средний объем запасов (тыс. баррелей):'] = values.mean()
    results[region]['99% доверительный интервал для среднего:'] = f'{values.quantile(0.005):.2f} - {values.quantile(0.995):.2f}'

pd.DataFrame(results)
# Out:
#                                                region_1       region_2  \
# Средний объем запасов (тыс. баррелей):          92.5167        68.9642
# 99% доверительный интервал для среднего:  87.34 - 97.15  63.98 - 73.64
#
#                                                 region_3
# Средний объем запасов (тыс. баррелей):           95.0626
# 99% доверительный интервал для среднего:  90.46 - 100.14

# %% [markdown]
# **ВЫВОДЫ:**
#
# 1. Средние значения для всех регионов в наборе исследумеых скважин меньше безубыточного объема.
# 1. Верхняя граница 99%-доверительного интервала для всех регионов ниже безубыточного объема.
# 1. **Без прогнозиреумой модели не обойтись**.

# %% [markdown]
# ## Расчёт прибыли и рисков

# %% [markdown]
# ### Функция расчета прибыли

# %% [markdown]
# Функция для расчёта прибыли по выбранным скважинам и предсказаниям модели:

# %%
def revenue(target, probabilities, count):
    probs_sorted = probabilities.sort_values(ascending=False)
    selected = target[probs_sorted.index][:count]
    return PRICE_1000_BARRELS * selected.sum() - BUDGET

# %% [markdown]
# ### Расчет прибыли по регионам

# %%
def bootstrap_region(df_ml, region, bootstrap_count=100, interval=95):
    values = []
    for _ in range(bootstrap_count):
        target_subsample = df_ml[region]['Y_test'].sample(COUNT_OBJECTS_RESEARCH, replace=True, random_state=r_state)
        probs_subsample = df_ml[region]['Y_pred'][target_subsample.index]
        values.append(revenue(target_subsample, probs_subsample, COUNT_OBJECTS_BEST))
    values = pd.Series(values)
    
    hist_box_describe(values, 'ss', xlabel='Выручка', data=values, bins=100)
    
    gaussian_distribution(values/1E6, 0, figsize=(8, 7))
    
    print(f'Средняя выручка: {big_number(values.mean())} руб.')
    print()
    print(f'\x1b[1mВероятность убытков (упрощенный рассчет): \x1b[47m {(values < 0).sum() / bootstrap_count:.2%} \x1b[49m\x1b[22m')
    print()
    alpha = 1-interval/100
    lower = values.quantile(alpha/2)
    upper = values.quantile(1 - alpha/2)
    print(f'\x1b[1m{interval}%-й доверительный интервал: от \x1b[46m {big_number(lower)} \x1b[49m руб. до \x1b[46m {big_number(upper)} \x1b[49m руб.\x1b[22m')
    print('-'*table_size)
    print()
    print()

# %% [markdown]
# #### Регион 1

# %%
# %%time
bootstrap_region(df_ml, 'region_1', bootstrap_count=1000)
# Out:
# ----------------------------------------------------------------------------------------------------
# Вероятность получить значение меньше 0 =  2.673%
# ----------------------------------------------------------------------------------------------------
#
# Средняя выручка: 501`868`655.98 руб.
#
# Вероятность убытков (упрощенный рассчет):  2.60%
#
# 95%-й доверительный интервал: от  -1`072`941.65  руб. до  1`000`118`445.53  руб.
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Регион 2

# %%
# %%time
bootstrap_region(df_ml, 'region_2', bootstrap_count=1000)
# Out:
# ----------------------------------------------------------------------------------------------------
# Вероятность получить значение меньше 0 =  0.652%
# ----------------------------------------------------------------------------------------------------
#
# Средняя выручка: 522`992`590.0 руб.
#
# Вероятность убытков (упрощенный рассчет):  0.40%
#
# 95%-й доверительный интервал: от  111`666`711.58  руб. до  930`689`234.56  руб.
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Регион 3

# %%
# %%time
bootstrap_region(df_ml, 'region_3', bootstrap_count=1000)
# Out:
# ----------------------------------------------------------------------------------------------------
# Вероятность получить значение меньше 0 =  9.468%
# ----------------------------------------------------------------------------------------------------
#
# Средняя выручка: 360`034`983.60 руб.
#
# Вероятность убытков (упрощенный рассчет):  10.30%
#
# 95%-й доверительный интервал: от  -208`986`509.67  руб. до  878`314`729.98  руб.
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Выводы

# %% [markdown]
# 1. Для разработки скважин с веротностью убытков менее 2.5% подходит только **Регион 2** (`geo_data_1.csv`).
# 1. Средняя выручка по Региону 2 составит **523 млн.руб.**.
# 1. С вероятностью 95% выручка по региону 2 будет от 111.7 млн.руб до 930.7 млн.руб.
#
# Обоснования выбора региона 2:
# - Веростность убытоков по Району 1 составляет 2.7%
# - Веростность убытоков по Району 2 составляет 0,7%
# - Веростность убытоков по Району 3 составляет 9,5%
# - Поскольку нужно отобрать районы с вероятностью убытков меньше 2.5%, то выбираем Район 2 (`geo_data_1.csv`).
