# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Цель-исследования" data-toc-modified-id="Цель-исследования-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Цель исследования</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Исходные-данные" data-toc-modified-id="Исходные-данные-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Исходные данные</a></span><ul class="toc-item"><li><span><a href="#Путь-к-базе-данных" data-toc-modified-id="Путь-к-базе-данных-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Путь к базе данных</a></span></li><li><span><a href="#Подключаемые-модули" data-toc-modified-id="Подключаемые-модули-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Подключаемые модули</a></span></li><li><span><a href="#Общие-параметры" data-toc-modified-id="Общие-параметры-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Общие параметры</a></span></li><li><span><a href="#Функции" data-toc-modified-id="Функции-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>Функции</a></span></li></ul></li><li><span><a href="#Получение-данных" data-toc-modified-id="Получение-данных-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Получение данных</a></span><ul class="toc-item"><li><span><a href="#Чтение-данных-из-файла" data-toc-modified-id="Чтение-данных-из-файла-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Чтение данных из файла</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Общая-информация" data-toc-modified-id="Общая-информация-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Общая информация</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-2.2.4"><span class="toc-item-num">2.2.4&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Признаки-изображений" data-toc-modified-id="Признаки-изображений-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Признаки изображений</a></span></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Проверка-значений:-ошибки,-выбросы,-дубликаты" data-toc-modified-id="Проверка-значений:-ошибки,-выбросы,-дубликаты-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Проверка значений: ошибки, выбросы, дубликаты</a></span><ul class="toc-item"><li><span><a href="#Числовые" data-toc-modified-id="Числовые-2.4.1.1"><span class="toc-item-num">2.4.1.1&nbsp;&nbsp;</span>Числовые</a></span></li><li><span><a href="#Изображения" data-toc-modified-id="Изображения-2.4.1.2"><span class="toc-item-num">2.4.1.2&nbsp;&nbsp;</span>Изображения</a></span></li></ul></li><li><span><a href="#Выводы-по-результатам-исследования" data-toc-modified-id="Выводы-по-результатам-исследования-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Выводы по результатам исследования</a></span></li></ul></li><li><span><a href="#Подбор-моделей" data-toc-modified-id="Подбор-моделей-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Подбор моделей</a></span><ul class="toc-item"><li><span><a href="#Базовые-изменения-модели" data-toc-modified-id="Базовые-изменения-модели-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>Базовые изменения модели</a></span><ul class="toc-item"><li><span><a href="#Результаты-пробных-обучений" data-toc-modified-id="Результаты-пробных-обучений-2.5.1.1"><span class="toc-item-num">2.5.1.1&nbsp;&nbsp;</span>Результаты пробных обучений</a></span></li><li><span><a href="#Подбор-характеристик-моделирования" data-toc-modified-id="Подбор-характеристик-моделирования-2.5.1.2"><span class="toc-item-num">2.5.1.2&nbsp;&nbsp;</span>Подбор характеристик моделирования</a></span></li></ul></li><li><span><a href="#Комбинированные-изменения-модели" data-toc-modified-id="Комбинированные-изменения-модели-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span>Комбинированные изменения модели</a></span><ul class="toc-item"><li><span><a href="#Результаты-пробных-обучений" data-toc-modified-id="Результаты-пробных-обучений-2.5.2.1"><span class="toc-item-num">2.5.2.1&nbsp;&nbsp;</span>Результаты пробных обучений</a></span></li><li><span><a href="#Подбор-характеристик-моделирования" data-toc-modified-id="Подбор-характеристик-моделирования-2.5.2.2"><span class="toc-item-num">2.5.2.2&nbsp;&nbsp;</span>Подбор характеристик моделирования</a></span></li></ul></li><li><span><a href="#Лучшие-комбинированные-изменения-модели" data-toc-modified-id="Лучшие-комбинированные-изменения-модели-2.5.3"><span class="toc-item-num">2.5.3&nbsp;&nbsp;</span>Лучшие комбинированные изменения модели</a></span><ul class="toc-item"><li><span><a href="#Результаты-пробных-обучений" data-toc-modified-id="Результаты-пробных-обучений-2.5.3.1"><span class="toc-item-num">2.5.3.1&nbsp;&nbsp;</span>Результаты пробных обучений</a></span></li><li><span><a href="#Подбор-характеристик-моделирования" data-toc-modified-id="Подбор-характеристик-моделирования-2.5.3.2"><span class="toc-item-num">2.5.3.2&nbsp;&nbsp;</span>Подбор характеристик моделирования</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Обучение-модели" data-toc-modified-id="Обучение-модели-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Обучение модели</a></span></li><li><span><a href="#Проверка-модели-на-адекватность" data-toc-modified-id="Проверка-модели-на-адекватность-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Проверка модели на адекватность</a></span></li><li><span><a href="#Анализ-обученной-модели" data-toc-modified-id="Анализ-обученной-модели-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Анализ обученной модели</a></span></li></ul></div>

# %%
import time
START_PROJECT = time.time()

# %% [markdown]
# # Определение возраста покупателей

# %% [markdown]
# ## Цель исследования

# %% [markdown]
# 1. Создать модель для определения возраста клиента по фотографии
# 1. Добиться показателей метрики модели MAE менее 7 на тестовой выборке

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Исходные данные

# %% [markdown]
# #### Путь к базе данных

# %%
path = '/datasets/faces/'

# %% [markdown]
# #### Подключаемые модули

# %%
# Main
# ---------------------------------------------------------------------
import numpy as np
import pandas as pd

# %%
# Plotting
# ---------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.gridspec import GridSpec
from PIL import Image

# %%
# computer vision
# ---------------------------------------------------------------------
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# sklearn
# ---------------------------------------------------------------------
from sklearn.dummy import DummyRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# #### Общие параметры

# %%
TABLE_SIZE = 100
TARGET_COL = 'real_age'

# %% [markdown]
# #### Функции

# %% [markdown]
# Инструменты

# %%
# формат текста для output
class text:
    END = '\x1b[0m'
    BOLD = '\x1b[1m'
    
    UNDERLINE = '\x1b[4m'
    
    NEGATIVE = '\x1b[7m'

    GREY = '\x1b[30m'
    RED = '\x1b[31m'
    GREEN = '\x1b[32m'
    YELLOW = '\x1b[33m'
    BLUE = '\x1b[34m'
    PURPLE = '\x1b[35m'
    CYAN = '\x1b[36m'
    SILVER = '\x1b[37m'
    BLACK = '\x1b[39m'
    
    BG_GREY = '\x1b[40m'
    BG_RED = '\x1b[41m'
    BG_GREEN = '\x1b[42m'
    BG_YELLOW = '\x1b[43m'
    BG_BLUE = '\x1b[44m'
    BG_PURPLE = '\x1b[45m'
    BG_CYAN = '\x1b[46m'
    BG_SILVER = '\x1b[47m'
    
    DARKGREY = '\x1b[90m'
    DARKRED = '\x1b[91m'
    DARKGREEN = '\x1b[92m'
    DARKYELLOW = '\x1b[93m'
    DARKBLUE = '\x1b[94m'
    DARKPURPLE = '\x1b[95m'
    DARKCYAN = '\x1b[96m'
    DARKSILVER = '\x1b[97m'
    
    BG_DARKGREY = '\x1b[100m'
    BG_DARKRED = '\x1b[101m'
    BG_DARKGREEN = '\x1b[102m'
    BG_DARKYELLOW = '\x1b[103m'
    BG_DARKBLUE = '\x1b[104m'
    BG_DARKPURPLE = '\x1b[105m'
    BG_DARKCYAN = '\x1b[106m'
    BG_DARKSILVER = '\x1b[107m'
    
    END_B = '\x1b[21m'
    END_U = '\x1b[24m'
    END_NEGATIVE = '\x1b[27m'
    END_C = '\x1b[39m'
    END_BG = '\x1b[49m'

# %% [markdown]
# Информирование

# %%
# вывод таблицы описания данных
def print_description(df):
    len_index = max([len(i) for i in df])
    for ind, name in enumerate(df):
        end = '' if len(description[name]) < TABLE_SIZE else '...'
        print(f'{str(ind).ljust(3)} {name.ljust(len_index)} - {description[name][:TABLE_SIZE]}{end}')

# %%
# общая информация об исходной таблице
def start_information(df):
    result = []
    for col in df:
        result.append([
            col, df[col].count(), df[col].isna().sum(),
            df[col].dtype, df[col].nunique(), df[col].sample(10).values,
        ])
        if str(df[col].dtype)[:3] in ('intflo'):
            result[-1].extend([df[col].min(), df[col].max()])
        else:
            result[-1].extend(['-', '-'])
        result[-1].append(description[col])
    
    res = pd.DataFrame(result, columns=['Name', 'Count', 'NA', 'Type', 'Unique', 'Sample', 'min', 'max', 'description'])
    res.index = res['Name']
    res = res.drop('Name', axis=1)
    display(res)
    print(f'Размер таблицы: {text.BOLD} {df.shape} {text.END}')
    print(f'Целевой признак: {text.BOLD} {TARGET_COL} {text.END}')

# %% [markdown]
# Презентации

# %%
def hist_box_describe(df, col, subtitle='', xlabel=None, ylabel=None, data=None, bins=None, figsize=(8, 8), **kwargs):
    if type(data) == type(None):
        data = df[col]
    if xlabel == None:
        try:
            xlabel = description[col]
        except:
            pass
    if bins == None:
        bins = data.nunique()
    
    fig = plt.figure()
    
    # Разделение fig на зоны разных размеров:
    gs1 = GridSpec(5, 1, left=0.05, right=0.95, hspace=0.03)
    # (y, x) - размеры сетки (высота, ширина)
    # left - расположние левой границы всей сетки (топа margin)
    # right - расположние правой границы всей сетки (топа margin)
    # wspace, hspace - зазоры между графиками (вертикальный, горизонтальный)
    ax1 = fig.add_subplot(gs1[:1, :]) # (срез по Y, срез по X)
    ax2 = fig.add_subplot(gs1[1:, :])
    
    # Построение графиков:
    data.plot(ax=ax1, kind='box', vert=False, widths=0.6, **kwargs)
    data.plot(ax=ax2, kind='hist', grid=True, bins=bins, **kwargs)
    
    # Различные настройки графиков:
    fig.set_figwidth(figsize[0])
    fig.set_figheight(figsize[1])
    #fig.suptitle(f'Распределение показателя "{xlabel}"', fontsize = 16)
    
    ax1.xaxis.tick_top()
    ax2.minorticks_on()
    ax2.grid(which='major',
            color = 'grey', 
            linewidth = 1.2)
    ax2.grid(which='minor', 
            color = 'grey', 
            linestyle = ':')
    
    ax1.set_yticklabels([''])
    ax2.set_xlabel(xlabel, fontsize = 14)
    ax2.set_ylabel('Количество значений', fontsize = 14)
    ax1.tick_params(labelsize = 12)
    ax2.tick_params(labelsize = 12)
    ax1.set_title(f'Распределение показателя "{xlabel}"{subtitle}', pad=15, fontsize = 16)

    x = ax2.get_xbound()
    y = ax2.get_ybound()
    x_coord = x[0] + (x[1]-x[0])/figsize[0]*figsize[1]*0.03 if data.mean() < data.quantile(0.5) else x[1] - (x[1]-x[0])/figsize[0]*figsize[1]*0.36
    y_coord = y[1] - (y[1]-y[0])*0.35
    ax2.text(x_coord, y_coord, str(data.describe()),
        rotation = 0,
        fontsize = figsize[1]*1.2,
        bbox = {'facecolor':'white', 'boxstyle': 'round', 'pad': 1}
            )

# %% [markdown]
# ### Получение данных

# %% [markdown]
# #### Чтение данных из файла

# %%
file_labels = 'labels.csv'

# %%
df = pd.read_csv(f'{path}{file_labels}')

# %% [markdown]
# #### Описание данных

# %% [markdown]
# Создадим словарь описания данных на основании предоставленного описания

# %%
# Создадим словарь описания данных
description = {
    'file_name' : 'название файла',
    'real_age' : 'реальный возраст человека',
}

# %% [markdown]
# Выведем словарь описания данных

# %%
print_description(df)
# Out:
# 0   file_name - название файла
# 1   real_age  - реальный возраст человека

# %% [markdown]
# #### Общая информация

# %%
start_information(df)
# Out:
#            Count  NA    Type  Unique  \
# Name
# file_name   7591   0  object    7591
# real_age    7591   0   int64      97
#
#                                                       Sample min  max  \
# Name
# file_name  [000890.jpg, 003631.jpg, 000190.jpg, 006585.jp...   -    -
# real_age            [27, 34, 42, 29, 51, 56, 16, 34, 25, 31]   1  100
#
#                          description
# Name
# file_name             название файла
# real_age   реальный возраст человека
# Размер таблицы:  (7591, 2)
# Целевой признак:  real_age

# %%
# Исходный размер таблицы:
original_shape = df.shape

# %% [markdown]
# #### Выводы

# %% [markdown]
# В таблице данных
# **`7591` объектов и `2` признака**
#
# В данных содержатся имена фалов и целевые признаки реального возраста чееловека на соответствующем файле изображения.
#
# ---
# ---
#
# **СТРУКТУРА ДАННЫХ:**
#
# 1. Названия колонок в змеином регистре (в правке не нуждаются)
# 1. Явных дубликатов нет, поскольку кол-во уникальных значений названий файлов равно количеству объектов
# 1. Пропуски в данных отсутствуют
#
#
# 4. **`Типы данных`** соответствуют содержимому:
#     - **Наименования (текстовые):**
#         - название файла [file_name]
#     - **Численные:**
#         - реальный возраст человека [real_age]
#
#
# 5. Смыслове (логические) взаимосвязи отсутствуют.
#
# **Итого: Данные не нуждаются в преобработке**

# %% [markdown]
# ### Признаки изображений

# %% [markdown]
# Добавим признаки размеров изображений (высота, ширина и глубина канала) для анализа набора данных

# %% [markdown]
# Создадим новый датафрейм, чтобы оставить исходный без изменений

# %%
df_new = df.copy()

# %% [markdown]
# Функция для добавления размерности:

# %%
def get_image_size(file_name, n):
    image = Image.open(f'{path}final_files/{file_name}')
    array = np.array(image)
    return array.shape[n]

# %% [markdown]
# Добавление высоты изображения:

# %%
# %%time
df_new['height'] = df_new['file_name'].apply(lambda x: get_image_size(x, 0))
# Out:
# CPU times: user 48.2 s, sys: 3.55 s, total: 51.8 s
# Wall time: 8min 8s

# %%
description['height'] = 'высота изображения'

# %% [markdown]
# Добавление ширины изображения:

# %%
# %%time
df_new['width'] = df_new['file_name'].apply(lambda x: get_image_size(x, 1))

# %%
description['width'] = 'ширина изображения'

# %% [markdown]
# Добавление глубины изображения:

# %%
# %%time
df_new['depth'] = df_new['file_name'].apply(lambda x: get_image_size(x, 2))
# Out:
# CPU times: user 44.6 s, sys: 2.93 s, total: 47.5 s
# Wall time: 3min 43s

# %%
description['depth'] = 'глубина изображения'

# %% [markdown]
# Добавление соотношения сторон изображения:

# %%
df_new['aspect_ratio'] = round(df_new['width'] / df_new['height'], 2)

# %%
description['aspect_ratio'] = 'соотношение сторон изображения'

# %% [markdown]
# Проверим:

# %%
df_new.head()
# Out:
#     file_name  real_age  height  width  depth  aspect_ratio
# 0  000000.jpg         4     114    114      3           1.0
# 1  000001.jpg        18     784    784      3           1.0
# 2  000002.jpg        80     133    133      3           1.0
# 3  000003.jpg        50     370    370      3           1.0
# 4  000004.jpg        17     212    212      3           1.0

# %% [markdown]
# ### Анализ данных

# %% [markdown]
# #### Проверка значений: ошибки, выбросы, дубликаты

# %% [markdown]
# ##### Числовые

# %% [markdown]
# ###### Реальный возраст человека

# %% [markdown]
# Рассмотрим распределение значений возраста

# %%
hist_box_describe(df, 'real_age')

# %% [markdown]
# **Вывод:**
#
# - Диапазон значений приемлимый.
# - Большое количество значений **1**, видимо ввиду присвоения 1 года всем от 0 до 1 года.
# - Средний возраст (медиана) составляет **29** лет.
# - Распределение нормальное со смещением вправо.

# %% [markdown]
# ###### Соотношение сторон изображения

# %%
hist_box_describe(df_new, 'aspect_ratio')

# %%
df_new['aspect_ratio'].value_counts(normalize=True)
# Out:
# 1.00    0.916875
# 0.99    0.027928
# 1.01    0.024239
# 0.75    0.004347
# 1.33    0.003952
#           ...
# 1.23    0.000132
# 0.91    0.000132
# 1.20    0.000132
# 1.30    0.000132
# 1.11    0.000132
# Name: aspect_ratio, Length: 66, dtype: float64

# %% [markdown]
# **Вывод:**
#
# - Диапазон значений приемлимый
# - Более 90% изображений - квадратные, но есть и изображения прямоугольной формы.
# - Минимальное соотношение сторон = **0.5**, максимальное = **3**.

# %% [markdown]
# ###### Высота изображения

# %%
hist_box_describe(df_new, 'height', bins=200)

# %% [markdown]
# **Вывод:**
#
# - Диапазон значений приемлимый.
# - Средняя высота (медиана) составляет **331** пикселей.
# - Распределение нормальное со смщением вправо.

# %% [markdown]
# ###### Ширина изображения

# %%
hist_box_describe(df_new, 'width', bins=200)

# %% [markdown]
# **Вывод:**
#
# - Диапазон значений приемлимый.
# - Средняя ширина (медиана) составляет **331** пикселей.
# - Распределение нормальное со смщением вправо.

# %% [markdown]
# ###### Глубина изображения

# %%
df_new['depth'].value_counts()
# Out:
# 3    7591
# Name: depth, dtype: int64

# %% [markdown]
# **Вывод:**
#
# - Все картинки цветные с 3-мя каналами цвета.

# %% [markdown]
# ##### Изображения

# %% [markdown]
# Выведем несколько случайных изображений

# %%
fig = plt.figure(figsize=(12,14))
fig.suptitle(f'Набор случайных изображений из базы данных \n', fontsize = 16)

for i, ind in enumerate(df_new.sample(16).index):
    fig.add_subplot(4, 4, i+1)
    file_name = df_new.loc[ind, 'file_name']
    real_age = df_new.loc[ind, 'real_age']
    img_height = df_new.loc[ind, 'height']
    img_width = df_new.loc[ind, 'width']
    
    image = Image.open(f'{path}final_files/{file_name}')
    plt.imshow(image)

    plt.title(f'Возраст: {real_age}', pad=0, fontsize = 16)
    plt.xlabel(f'Размер: {img_height}х{img_width}', fontsize = 12)
    plt.margins(0, 100)
    plt.xticks([])
    plt.yticks([])
    plt.tight_layout()

# %% [markdown]
# **Вывод:**
#
# - Набор данных отредактирован:
#     - к некоторым изображениям примен поворот
#     - к некоторым изображениям применено масштабирвоание
#     - к некоторым изображениям применено смещение
#     - к некоторым изображениям примена обрезка
# - Вероятно целью обработки изображений было сориентировать лица вертикально и отцентрировать:
#     - в основном это удалось, но есть неудачные преобразования (*где лицо сильно смещено или вовсе ушло из кадра*)

# %% [markdown]
# При обучении модели также можно будет применить подобные трансформации.

# %% [markdown]
# #### Выводы по результатам исследования

# %% [markdown]
# 1. Определение возраста - задача регрессии, соответсвенно на выходе сети нужно оставить 1 нейрон с линейной активацией.
# 1. Для обучения модули будем использовать функцию потерь MSE (*для более быстрого обучения*), для валидации - MAE.
# 1. Более 95% изображений - квадратные, значит примем для загрузчика данных квадратную форму
#     - примем стандартный размер изображений из арихитектуры ResNet50 - 224х224 (октоло четверти изображений имеют меньшее разрешение)
# 1. Возможные аугментации:
#     - горизонтальное отражение
#     - повороты
#     - смещения (рогизонтальные и вертикальные)
#     - изменение яркости
#     - масштабирование
# 1. В наборе данных только цветные изображения, поэтому будем работать с глубиной = 3.

# %% [markdown]
# ### Подбор моделей

# %% [markdown]
# #### Базовые изменения модели

# %% [markdown]
# Примем базовую модель со следующими основными характеристиками:
# - ResNet50 с верхушкой:
#     - GlobalAveragePooling2D()
#     - Dense(1, activation='relu')
# - optimizer = Adam(learning_rate=**0.001**)
# - loss='mean_squared_error'
# - metrics=['mae']
# - BATCH_SIZE = **32**
# - validation_split=0.25
# - без аугментаций
# - epochs=**10**

# %% [markdown]
# Проведем обучение с последовательными изменением одного из параметров:
# 1. Измениение learning_rate:
#     - 0.0005
#     - 0.0002
#     - 0.0001
# 1. Изменение batch_size:
#     - 8
#     - 16
#     - 32
#     - 64
#     - 128
#     - 256
# 1. Добавление аугментаций:
#     - horizontal_flip=True
#     - rotation_range=15
#     - rotation_range=30
#     - width_shift_range=0.1
#     - width_shift_range=0.2
#     - height_shift_range=0.1
#     - height_shift_range=0.2
#     - brightness_range=(0.9, 1.1)
#     - zoom_range=(0.8, 0.8)
#     - zoom_range=(0.6, 0.6)
#     - width_shift_range=0.1 & height_shift_range=0.1
#     - width_shift_range=0.2 & height_shift_range=0.2

# %% [markdown]
# ##### Результаты пробных обучений

# %% [markdown]
# Результаты обучений:

# %%
res_dict_base = {
 0: {'name': 'base', 'epoch': 1, 'loss': 249.6271, 'val_loss': 298.5576},
 1: {'name': 'base', 'epoch': 2, 'loss': 160.7603, 'val_loss': 293.5807},
 2: {'name': 'base', 'epoch': 3, 'loss': 126.6581, 'val_loss': 341.3035},
 3: {'name': 'base', 'epoch': 4, 'loss': 105.41, 'val_loss': 290.2146},
 4: {'name': 'base', 'epoch': 5, 'loss': 80.139, 'val_loss': 291.3425},
 5: {'name': 'base', 'epoch': 6, 'loss': 56.9429, 'val_loss': 130.55},
 6: {'name': 'base', 'epoch': 7, 'loss': 45.7083, 'val_loss': 148.8701},
 7: {'name': 'base', 'epoch': 8, 'loss': 34.3391, 'val_loss': 103.0357},
 8: {'name': 'base', 'epoch': 9, 'loss': 27.0102, 'val_loss': 102.7554},
 9: {'name': 'base', 'epoch': 10, 'loss': 22.309, 'val_loss': 116.5199},
 10: {'name': 'learning_rate=0.0005', 'epoch': 1, 'loss': 192.9855, 'val_loss': 570.7288},
 11: {'name': 'learning_rate=0.0005', 'epoch': 2, 'loss': 103.6676, 'val_loss': 315.8996},
 12: {'name': 'learning_rate=0.0005', 'epoch': 3, 'loss': 66.8897, 'val_loss': 353.8465},
 13: {'name': 'learning_rate=0.0005', 'epoch': 4, 'loss': 44.2734, 'val_loss': 191.9956},
 14: {'name': 'learning_rate=0.0005', 'epoch': 5, 'loss': 33.2844, 'val_loss': 121.0501},
 15: {'name': 'learning_rate=0.0005', 'epoch': 6, 'loss': 25.8633, 'val_loss': 85.3259},
 16: {'name': 'learning_rate=0.0005', 'epoch': 7, 'loss': 22.228, 'val_loss': 106.4066},
 17: {'name': 'learning_rate=0.0005', 'epoch': 8, 'loss': 18.8656, 'val_loss': 81.3198},
 18: {'name': 'learning_rate=0.0005', 'epoch': 9, 'loss': 17.8619, 'val_loss': 85.8327},
 19: {'name': 'learning_rate=0.0005', 'epoch': 10, 'loss': 14.2535, 'val_loss': 80.0937},
 20: {'name': 'learning_rate=0.0002', 'epoch': 1, 'loss': 205.3961, 'val_loss': 573.1819},
 21: {'name': 'learning_rate=0.0002', 'epoch': 2, 'loss': 74.966, 'val_loss': 545.7758},
 22: {'name': 'learning_rate=0.0002', 'epoch': 3, 'loss': 42.2394, 'val_loss': 230.3484},
 23: {'name': 'learning_rate=0.0002', 'epoch': 4, 'loss': 25.9975, 'val_loss': 117.3886},
 24: {'name': 'learning_rate=0.0002', 'epoch': 5, 'loss': 20.228, 'val_loss': 103.0208},
 25: {'name': 'learning_rate=0.0002', 'epoch': 6, 'loss': 15.8177, 'val_loss': 69.5477},
 26: {'name': 'learning_rate=0.0002', 'epoch': 7, 'loss': 16.5841, 'val_loss': 73.7688},
 27: {'name': 'learning_rate=0.0002', 'epoch': 8, 'loss': 14.7868, 'val_loss': 66.9713},
 28: {'name': 'learning_rate=0.0002', 'epoch': 9, 'loss': 12.3619, 'val_loss': 84.1668},
 29: {'name': 'learning_rate=0.0002', 'epoch': 10, 'loss': 13.4265, 'val_loss': 103.6037},
 30: {'name': 'learning_rate=0.0001', 'epoch': 1, 'loss': 239.0793, 'val_loss': 442.526},
 31: {'name': 'learning_rate=0.0001', 'epoch': 2, 'loss': 68.7726, 'val_loss': 495.1131},
 32: {'name': 'learning_rate=0.0001', 'epoch': 3, 'loss': 36.1231, 'val_loss': 580.2292},
 33: {'name': 'learning_rate=0.0001', 'epoch': 4, 'loss': 24.2855, 'val_loss': 151.7658},
 34: {'name': 'learning_rate=0.0001', 'epoch': 5, 'loss': 18.7764, 'val_loss': 76.4898},
 35: {'name': 'learning_rate=0.0001', 'epoch': 6, 'loss': 16.3153, 'val_loss': 74.5303},
 36: {'name': 'learning_rate=0.0001', 'epoch': 7, 'loss': 15.616, 'val_loss': 75.6037},
 37: {'name': 'learning_rate=0.0001', 'epoch': 8, 'loss': 13.7244, 'val_loss': 68.1135},
 38: {'name': 'learning_rate=0.0001', 'epoch': 9, 'loss': 14.6005, 'val_loss': 114.6678},
 39: {'name': 'learning_rate=0.0001', 'epoch': 10, 'loss': 15.3215, 'val_loss': 73.7458},
 40: {'name': 'batch_size=8', 'epoch': 1, 'loss': 304.0397, 'val_loss': 328.2476},
 41: {'name': 'batch_size=8', 'epoch': 2, 'loss': 261.7705, 'val_loss': 261.3304},
 42: {'name': 'batch_size=8', 'epoch': 3, 'loss': 233.2381, 'val_loss': 264.5231},
 43: {'name': 'batch_size=8', 'epoch': 4, 'loss': 210.3397, 'val_loss': 211.5155},
 44: {'name': 'batch_size=8', 'epoch': 5, 'loss': 194.4573, 'val_loss': 265.0979},
 45: {'name': 'batch_size=8', 'epoch': 6, 'loss': 175.5277, 'val_loss': 251.1522},
 46: {'name': 'batch_size=8', 'epoch': 7, 'loss': 161.0784, 'val_loss': 158.9062},
 47: {'name': 'batch_size=8', 'epoch': 8, 'loss': 147.9419, 'val_loss': 191.6781},
 48: {'name': 'batch_size=8', 'epoch': 9, 'loss': 133.5244, 'val_loss': 293.3513},
 49: {'name': 'batch_size=8', 'epoch': 10, 'loss': 115.2648, 'val_loss': 214.6636},
 50: {'name': 'batch_size=16', 'epoch': 1, 'loss': 251.7705, 'val_loss': 1158.0159},
 51: {'name': 'batch_size=16', 'epoch': 2, 'loss': 184.474, 'val_loss': 287.4091},
 52: {'name': 'batch_size=16', 'epoch': 3, 'loss': 157.8738, 'val_loss': 267.3164},
 53: {'name': 'batch_size=16', 'epoch': 4, 'loss': 131.628, 'val_loss': 126.6345},
 54: {'name': 'batch_size=16', 'epoch': 5, 'loss': 110.2401, 'val_loss': 188.8369},
 55: {'name': 'batch_size=16', 'epoch': 6, 'loss': 88.3366, 'val_loss': 139.0189},
 56: {'name': 'batch_size=16', 'epoch': 7, 'loss': 70.1997, 'val_loss': 154.2914},
 57: {'name': 'batch_size=16', 'epoch': 8, 'loss': 55.0485, 'val_loss': 201.1318},
 58: {'name': 'batch_size=16', 'epoch': 9, 'loss': 42.4652, 'val_loss': 136.6211},
 59: {'name': 'batch_size=16', 'epoch': 10, 'loss': 33.871, 'val_loss': 116.6584},
 60: {'name': 'batch_size=32 (base)', 'epoch': 1, 'loss': 240.3076, 'val_loss': 420.7121},
 61: {'name': 'batch_size=32 (base)', 'epoch': 2, 'loss': 155.5953, 'val_loss': 282.8297},
 62: {'name': 'batch_size=32 (base)', 'epoch': 3, 'loss': 122.9863, 'val_loss': 283.616},
 63: {'name': 'batch_size=32 (base)', 'epoch': 4, 'loss': 95.5943, 'val_loss': 293.0568},
 64: {'name': 'batch_size=32 (base)', 'epoch': 5, 'loss': 71.4544, 'val_loss': 292.4042},
 65: {'name': 'batch_size=32 (base)', 'epoch': 6, 'loss': 55.2838, 'val_loss': 133.0721},
 66: {'name': 'batch_size=32 (base)', 'epoch': 7, 'loss': 46.0576, 'val_loss': 106.0481},
 67: {'name': 'batch_size=32 (base)', 'epoch': 8, 'loss': 33.8585, 'val_loss': 181.327},
 68: {'name': 'batch_size=32 (base)', 'epoch': 9, 'loss': 25.341, 'val_loss': 128.9385},
 69: {'name': 'batch_size=32 (base)', 'epoch': 10, 'loss': 20.3742, 'val_loss': 106.3262},
 70: {'name': 'batch_size=64', 'epoch': 1, 'loss': 242.7118, 'val_loss': 841.464},
 71: {'name': 'batch_size=64', 'epoch': 2, 'loss': 133.8661, 'val_loss': 468.2376},
 72: {'name': 'batch_size=64', 'epoch': 3, 'loss': 96.553, 'val_loss': 293.6481},
 73: {'name': 'batch_size=64', 'epoch': 4, 'loss': 68.328, 'val_loss': 289.6978},
 74: {'name': 'batch_size=64', 'epoch': 5, 'loss': 46.7119, 'val_loss': 416.5961},
 75: {'name': 'batch_size=64', 'epoch': 6, 'loss': 33.5517, 'val_loss': 420.7569},
 76: {'name': 'batch_size=64', 'epoch': 7, 'loss': 23.209, 'val_loss': 433.1053},
 77: {'name': 'batch_size=64', 'epoch': 8, 'loss': 17.8168, 'val_loss': 240.3762},
 78: {'name': 'batch_size=64', 'epoch': 9, 'loss': 13.0008, 'val_loss': 167.7897},
 79: {'name': 'batch_size=64', 'epoch': 10, 'loss': 10.4087, 'val_loss': 107.1143},
 80: {'name': 'batch_size=128', 'epoch': 1, 'loss': 251.0462, 'val_loss': 1709.7703},
 81: {'name': 'batch_size=128', 'epoch': 2, 'loss': 105.7152, 'val_loss': 341.5446},
 82: {'name': 'batch_size=128', 'epoch': 3, 'loss': 71.6239, 'val_loss': 431.9932},
 83: {'name': 'batch_size=128', 'epoch': 4, 'loss': 45.7735, 'val_loss': 441.1516},
 84: {'name': 'batch_size=128', 'epoch': 5, 'loss': 36.3027, 'val_loss': 422.9865},
 85: {'name': 'batch_size=128', 'epoch': 6, 'loss': 23.1903, 'val_loss': 440.6092},
 86: {'name': 'batch_size=128', 'epoch': 7, 'loss': 15.577, 'val_loss': 475.4223},
 87: {'name': 'batch_size=128', 'epoch': 8, 'loss': 12.5705, 'val_loss': 508.6954},
 88: {'name': 'batch_size=128', 'epoch': 9, 'loss': 10.0144, 'val_loss': 410.7631},
 89: {'name': 'batch_size=128', 'epoch': 10, 'loss': 8.0897, 'val_loss': 478.629},
 90: {'name': 'batch_size=256', 'epoch': 1, 'loss': 343.8817, 'val_loss': 388.2564},
 91: {'name': 'batch_size=256', 'epoch': 2, 'loss': 118.059, 'val_loss': 574.9022},
 92: {'name': 'batch_size=256', 'epoch': 3, 'loss': 72.5043, 'val_loss': 676.6321},
 93: {'name': 'batch_size=256', 'epoch': 4, 'loss': 46.0447, 'val_loss': 748.8424},
 94: {'name': 'batch_size=256', 'epoch': 5, 'loss': 32.1298, 'val_loss': 608.1349},
 95: {'name': 'batch_size=256', 'epoch': 6, 'loss': 25.1994, 'val_loss': 742.0905},
 96: {'name': 'batch_size=256', 'epoch': 7, 'loss': 21.3737, 'val_loss': 749.8247},
 97: {'name': 'batch_size=256', 'epoch': 8, 'loss': 15.1143, 'val_loss': 871.2739},
 98: {'name': 'batch_size=256', 'epoch': 9, 'loss': 9.4313, 'val_loss': 783.6093},
 99: {'name': 'batch_size=256', 'epoch': 10, 'loss': 8.6688, 'val_loss': 518.3968},
 100: {'name': 'horizontal_flip', 'epoch': 1, 'loss': 235.0603, 'val_loss': 327.63},
 101: {'name': 'horizontal_flip', 'epoch': 2, 'loss': 155.6444, 'val_loss': 1158.1847},
 102: {'name': 'horizontal_flip', 'epoch': 3, 'loss': 132.4264, 'val_loss': 329.6758},
 103: {'name': 'horizontal_flip', 'epoch': 4, 'loss': 112.7715, 'val_loss': 312.1767},
 104: {'name': 'horizontal_flip', 'epoch': 5, 'loss': 97.9035, 'val_loss': 195.9722},
 105: {'name': 'horizontal_flip', 'epoch': 6, 'loss': 84.2045, 'val_loss': 110.1463},
 106: {'name': 'horizontal_flip', 'epoch': 7, 'loss': 75.9213, 'val_loss': 211.0855},
 107: {'name': 'horizontal_flip', 'epoch': 8, 'loss': 71.1278, 'val_loss': 96.8379},
 108: {'name': 'horizontal_flip', 'epoch': 9, 'loss': 57.4892, 'val_loss': 151.607},
 109: {'name': 'horizontal_flip', 'epoch': 10, 'loss': 54.6323, 'val_loss': 95.3011},
 110: {'name': 'rotation_range=15', 'epoch': 1, 'loss': 234.8956, 'val_loss': 515.7093},
 111: {'name': 'rotation_range=15', 'epoch': 2, 'loss': 163.9776, 'val_loss': 294.6054},
 112: {'name': 'rotation_range=15', 'epoch': 3, 'loss': 137.054, 'val_loss': 402.5381},
 113: {'name': 'rotation_range=15', 'epoch': 4, 'loss': 117.8797, 'val_loss': 628.1215},
 114: {'name': 'rotation_range=15', 'epoch': 5, 'loss': 107.7519, 'val_loss': 217.2617},
 115: {'name': 'rotation_range=15', 'epoch': 6, 'loss': 93.1139, 'val_loss': 147.076},
 116: {'name': 'rotation_range=15', 'epoch': 7, 'loss': 90.3969, 'val_loss': 276.545},
 117: {'name': 'rotation_range=15', 'epoch': 8, 'loss': 81.6548, 'val_loss': 135.0024},
 118: {'name': 'rotation_range=15', 'epoch': 9, 'loss': 69.2198, 'val_loss': 175.0596},
 119: {'name': 'rotation_range=15', 'epoch': 10, 'loss': 65.3639, 'val_loss': 96.79},
 120: {'name': 'rotation_range=30', 'epoch': 1, 'loss': 289.6757, 'val_loss': 327.7808},
 121: {'name': 'rotation_range=30', 'epoch': 2, 'loss': 197.1004, 'val_loss': 308.9717},
 122: {'name': 'rotation_range=30', 'epoch': 3, 'loss': 181.4726, 'val_loss': 289.7922},
 123: {'name': 'rotation_range=30', 'epoch': 4, 'loss': 162.1621, 'val_loss': 272.9675},
 124: {'name': 'rotation_range=30', 'epoch': 5, 'loss': 155.4866, 'val_loss': 278.8462},
 125: {'name': 'rotation_range=30', 'epoch': 6, 'loss': 145.5887, 'val_loss': 140.4188},
 126: {'name': 'rotation_range=30', 'epoch': 7, 'loss': 138.5096, 'val_loss': 220.1993},
 127: {'name': 'rotation_range=30', 'epoch': 8, 'loss': 130.1198, 'val_loss': 166.7075},
 128: {'name': 'rotation_range=30', 'epoch': 9, 'loss': 119.6469, 'val_loss': 171.234},
 129: {'name': 'rotation_range=30', 'epoch': 10, 'loss': 116.6714, 'val_loss': 150.4151},
 130: {'name': 'width_shift_range=0.1', 'epoch': 1, 'loss': 226.9273, 'val_loss': 343.0928},
 131: {'name': 'width_shift_range=0.1', 'epoch': 2, 'loss': 148.3155, 'val_loss': 328.1271},
 132: {'name': 'width_shift_range=0.1', 'epoch': 3, 'loss': 128.2899, 'val_loss': 346.9905},
 133: {'name': 'width_shift_range=0.1', 'epoch': 4, 'loss': 111.3481, 'val_loss': 352.7148},
 134: {'name': 'width_shift_range=0.1', 'epoch': 5, 'loss': 96.5441, 'val_loss': 119.9808},
 135: {'name': 'width_shift_range=0.1', 'epoch': 6, 'loss': 80.8399, 'val_loss': 140.7885},
 136: {'name': 'width_shift_range=0.1', 'epoch': 7, 'loss': 70.4758, 'val_loss': 229.5988},
 137: {'name': 'width_shift_range=0.1', 'epoch': 8, 'loss': 65.3283, 'val_loss': 132.5938},
 138: {'name': 'width_shift_range=0.1', 'epoch': 9, 'loss': 53.0038, 'val_loss': 131.4246},
 139: {'name': 'width_shift_range=0.1', 'epoch': 10, 'loss': 46.4231, 'val_loss': 115.2136},
 140: {'name': 'width_shift_range=0.2', 'epoch': 1, 'loss': 229.2208, 'val_loss': 283.4445},
 141: {'name': 'width_shift_range=0.2', 'epoch': 2, 'loss': 156.8574, 'val_loss': 339.3477},
 142: {'name': 'width_shift_range=0.2', 'epoch': 3, 'loss': 131.3793, 'val_loss': 285.0114},
 143: {'name': 'width_shift_range=0.2', 'epoch': 4, 'loss': 113.6998, 'val_loss': 234.9573},
 144: {'name': 'width_shift_range=0.2', 'epoch': 5, 'loss': 98.7543, 'val_loss': 402.4125},
 145: {'name': 'width_shift_range=0.2', 'epoch': 6, 'loss': 88.6337, 'val_loss': 121.9788},
 146: {'name': 'width_shift_range=0.2', 'epoch': 7, 'loss': 76.9127, 'val_loss': 228.9536},
 147: {'name': 'width_shift_range=0.2', 'epoch': 8, 'loss': 68.7623, 'val_loss': 186.4148},
 148: {'name': 'width_shift_range=0.2', 'epoch': 9, 'loss': 59.7644, 'val_loss': 231.1881},
 149: {'name': 'width_shift_range=0.2', 'epoch': 10, 'loss': 53.7481, 'val_loss': 127.0142},
 150: {'name': 'height_shift_range=0.1', 'epoch': 1, 'loss': 249.4681, 'val_loss': 286.2359},
 151: {'name': 'height_shift_range=0.1', 'epoch': 2, 'loss': 167.3507, 'val_loss': 338.8916},
 152: {'name': 'height_shift_range=0.1', 'epoch': 3, 'loss': 141.3533, 'val_loss': 373.0732},
 153: {'name': 'height_shift_range=0.1', 'epoch': 4, 'loss': 120.0132, 'val_loss': 517.2373},
 154: {'name': 'height_shift_range=0.1', 'epoch': 5, 'loss': 105.3807, 'val_loss': 246.5221},
 155: {'name': 'height_shift_range=0.1', 'epoch': 6, 'loss': 91.2184, 'val_loss': 250.8577},
 156: {'name': 'height_shift_range=0.1', 'epoch': 7, 'loss': 84.3414, 'val_loss': 125.3136},
 157: {'name': 'height_shift_range=0.1', 'epoch': 8, 'loss': 69.8104, 'val_loss': 160.5624},
 158: {'name': 'height_shift_range=0.1', 'epoch': 9, 'loss': 59.5057, 'val_loss': 111.7521},
 159: {'name': 'height_shift_range=0.1', 'epoch': 10, 'loss': 52.9725, 'val_loss': 169.656},
 160: {'name': 'height_shift_range=0.2', 'epoch': 1, 'loss': 247.0943, 'val_loss': 588.7793},
 161: {'name': 'height_shift_range=0.2', 'epoch': 2, 'loss': 164.5848, 'val_loss': 375.151},
 162: {'name': 'height_shift_range=0.2', 'epoch': 3, 'loss': 132.008, 'val_loss': 281.8838},
 163: {'name': 'height_shift_range=0.2', 'epoch': 4, 'loss': 118.4908, 'val_loss': 299.5063},
 164: {'name': 'height_shift_range=0.2', 'epoch': 5, 'loss': 104.0327, 'val_loss': 145.1258},
 165: {'name': 'height_shift_range=0.2', 'epoch': 6, 'loss': 88.2325, 'val_loss': 121.2072},
 166: {'name': 'height_shift_range=0.2', 'epoch': 7, 'loss': 81.6255, 'val_loss': 158.864},
 167: {'name': 'height_shift_range=0.2', 'epoch': 8, 'loss': 72.1112, 'val_loss': 271.929},
 168: {'name': 'height_shift_range=0.2', 'epoch': 9, 'loss': 67.0772, 'val_loss': 144.775},
 169: {'name': 'height_shift_range=0.2', 'epoch': 10, 'loss': 52.461, 'val_loss': 107.1487},
 170: {'name': 'brightness_range=(0.9, 1.1)', 'epoch': 1, 'loss': 227.6156, 'val_loss': 401.0022},
 171: {'name': 'brightness_range=(0.9, 1.1)', 'epoch': 2, 'loss': 153.9983, 'val_loss': 346.652},
 172: {'name': 'brightness_range=(0.9, 1.1)', 'epoch': 3, 'loss': 117.8255, 'val_loss': 383.5469},
 173: {'name': 'brightness_range=(0.9, 1.1)', 'epoch': 4, 'loss': 93.8942, 'val_loss': 328.4104},
 174: {'name': 'brightness_range=(0.9, 1.1)', 'epoch': 5, 'loss': 70.8692, 'val_loss': 248.8275},
 175: {'name': 'brightness_range=(0.9, 1.1)', 'epoch': 6, 'loss': 51.9277, 'val_loss': 126.5477},
 176: {'name': 'brightness_range=(0.9, 1.1)', 'epoch': 7, 'loss': 38.7658, 'val_loss': 102.4199},
 177: {'name': 'brightness_range=(0.9, 1.1)', 'epoch': 8, 'loss': 29.5428, 'val_loss': 111.5733},
 178: {'name': 'brightness_range=(0.9, 1.1)', 'epoch': 9, 'loss': 27.397, 'val_loss': 127.4309},
 179: {'name': 'brightness_range=(0.9, 1.1)', 'epoch': 10, 'loss': 20.7961, 'val_loss': 106.0626},
 180: {'name': 'zoom_range=(0.8, 0.8)', 'epoch': 1, 'loss': 234.5854, 'val_loss': 468.1606},
 181: {'name': 'zoom_range=(0.8, 0.8)', 'epoch': 2, 'loss': 158.9613, 'val_loss': 303.9539},
 182: {'name': 'zoom_range=(0.8, 0.8)', 'epoch': 3, 'loss': 131.3159, 'val_loss': 349.0398},
 183: {'name': 'zoom_range=(0.8, 0.8)', 'epoch': 4, 'loss': 105.7653, 'val_loss': 284.0369},
 184: {'name': 'zoom_range=(0.8, 0.8)', 'epoch': 5, 'loss': 83.913, 'val_loss': 160.5024},
 185: {'name': 'zoom_range=(0.8, 0.8)', 'epoch': 6, 'loss': 62.9893, 'val_loss': 155.9018},
 186: {'name': 'zoom_range=(0.8, 0.8)', 'epoch': 7, 'loss': 47.4915, 'val_loss': 192.6939},
 187: {'name': 'zoom_range=(0.8, 0.8)', 'epoch': 8, 'loss': 34.0281, 'val_loss': 130.1918},
 188: {'name': 'zoom_range=(0.8, 0.8)', 'epoch': 9, 'loss': 25.7112, 'val_loss': 178.7774},
 189: {'name': 'zoom_range=(0.8, 0.8)', 'epoch': 10, 'loss': 20.4598, 'val_loss': 155.6832},
 190: {'name': 'zoom_range=(0.6, 0.6)', 'epoch': 1, 'loss': 224.6796, 'val_loss': 1158.0159},
 191: {'name': 'zoom_range=(0.6, 0.6)', 'epoch': 2, 'loss': 156.294, 'val_loss': 406.6914},
 192: {'name': 'zoom_range=(0.6, 0.6)', 'epoch': 3, 'loss': 121.6212, 'val_loss': 429.8206},
 193: {'name': 'zoom_range=(0.6, 0.6)', 'epoch': 4, 'loss': 97.6916, 'val_loss': 350.1265},
 194: {'name': 'zoom_range=(0.6, 0.6)', 'epoch': 5, 'loss': 79.8456, 'val_loss': 232.7651},
 195: {'name': 'zoom_range=(0.6, 0.6)', 'epoch': 6, 'loss': 56.3285, 'val_loss': 257.2368},
 196: {'name': 'zoom_range=(0.6, 0.6)', 'epoch': 7, 'loss': 42.4288, 'val_loss': 358.2532},
 197: {'name': 'zoom_range=(0.6, 0.6)', 'epoch': 8, 'loss': 33.3982, 'val_loss': 254.6345},
 198: {'name': 'zoom_range=(0.6, 0.6)', 'epoch': 9, 'loss': 28.1866, 'val_loss': 183.2533},
 199: {'name': 'zoom_range=(0.6, 0.6)', 'epoch': 10, 'loss': 23.9766, 'val_loss': 241.3974},
 200: {'name': 'width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 1, 'loss': 224.8313, 'val_loss': 405.5373},
 201: {'name': 'width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 2, 'loss': 172.7096, 'val_loss': 371.6781},
 202: {'name': 'width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 3, 'loss': 138.8515, 'val_loss': 372.2154},
 203: {'name': 'width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 4, 'loss': 130.0446, 'val_loss': 326.0196},
 204: {'name': 'width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 5, 'loss': 116.639, 'val_loss': 295.256},
 205: {'name': 'width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 6, 'loss': 106.2395, 'val_loss': 140.1356},
 206: {'name': 'width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 7, 'loss': 102.8499, 'val_loss': 106.4579},
 207: {'name': 'width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 8, 'loss': 96.4828, 'val_loss': 156.8585},
 208: {'name': 'width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 9, 'loss': 85.707, 'val_loss': 124.0083},
 209: {'name': 'width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 10, 'loss': 83.7066, 'val_loss': 109.3291},
 210: {'name': 'width_shift_range=0.2 & height_shift_range=0.2', 'epoch': 1, 'loss': 286.8656, 'val_loss': 314.5526},
 211: {'name': 'width_shift_range=0.2 & height_shift_range=0.2', 'epoch': 2, 'loss': 181.9126, 'val_loss': 1158.0159},
 212: {'name': 'width_shift_range=0.2 & height_shift_range=0.2', 'epoch': 3, 'loss': 151.2304, 'val_loss': 291.3698},
 213: {'name': 'width_shift_range=0.2 & height_shift_range=0.2', 'epoch': 4, 'loss': 133.4177, 'val_loss': 536.4338},
 214: {'name': 'width_shift_range=0.2 & height_shift_range=0.2', 'epoch': 5, 'loss': 124.3885, 'val_loss': 224.2228},
 215: {'name': 'width_shift_range=0.2 & height_shift_range=0.2', 'epoch': 6, 'loss': 117.7839, 'val_loss': 235.0399},
 216: {'name': 'width_shift_range=0.2 & height_shift_range=0.2', 'epoch': 7, 'loss': 110.9162, 'val_loss': 224.042},
 217: {'name': 'width_shift_range=0.2 & height_shift_range=0.2', 'epoch': 8, 'loss': 98.8839, 'val_loss': 228.166},
 218: {'name': 'width_shift_range=0.2 & height_shift_range=0.2', 'epoch': 9, 'loss': 93.6128, 'val_loss': 229.8622},
 219: {'name': 'width_shift_range=0.2 & height_shift_range=0.2', 'epoch': 10, 'loss': 89.985, 'val_loss': 232.1081}}

# %%
res = pd.DataFrame(res_dict_base).T
res['epoch'] = res['epoch'].astype('int')
res['loss'] = res['loss'].astype('float')
res['val_loss'] = res['val_loss'].astype('float')
res
# Out:
#                                                name  epoch      loss  val_loss
# 0                                              base      1  249.6271  298.5576
# 1                                              base      2  160.7603  293.5807
# 2                                              base      3  126.6581  341.3035
# 3                                              base      4  105.4100  290.2146
# 4                                              base      5   80.1390  291.3425
# ..                                              ...    ...       ...       ...
# 215  width_shift_range=0.2 & height_shift_range=0.2      6  117.7839  235.0399
# 216  width_shift_range=0.2 & height_shift_range=0.2      7  110.9162  224.0420
# 217  width_shift_range=0.2 & height_shift_range=0.2      8   98.8839  228.1660
# 218  width_shift_range=0.2 & height_shift_range=0.2      9   93.6128  229.8622
# 219  width_shift_range=0.2 & height_shift_range=0.2     10   89.9850  232.1081
#
# [220 rows x 4 columns]

# %% [markdown]
# Возьмем для анализа средние значения потерь по последним 5-ти эпохам:

# %%
mean_last_5 = res.query('epoch > 5').groupby('name').mean()

# %% [markdown]
# Добавим сумму и разность потерь обучения и валидации:

# %%
mean_last_5['sum_loss'] = mean_last_5['loss'] + mean_last_5['val_loss']
mean_last_5['diff_loss'] = abs(mean_last_5['val_loss'] - mean_last_5['loss'])

# %% [markdown]
# ##### Подбор характеристик моделирования

# %% [markdown]
# ###### batch_size

# %% [markdown]
# Для определения подходящих значений `batch_size` отсортируем результаты по средним значениями `loss`:

# %%
mean_last_5.sort_values('loss').head(15)
# Out:
#                              epoch      loss   val_loss   sum_loss  diff_loss
# name
# batch_size=128                   8  13.88838  462.82380  476.71218  448.93542
# learning_rate=0.0002             8  14.59540   79.61166   94.20706   65.01626
# learning_rate=0.0001             8  15.11554   81.33222   96.44776   66.21668
# batch_size=256                   8  15.95750  733.03904  748.99654  717.08154
# batch_size=64                    8  19.59740  273.82848  293.42588  254.23108
# learning_rate=0.0005             8  19.81446   87.79574  107.61020   67.98128
# brightness_range=(0.9, 1.1)      8  33.68588  114.80688  148.49276   81.12100
# batch_size=32 (base)             8  36.18302  131.14238  167.32540   94.95936
# zoom_range=(0.6, 0.6)            8  36.86374  258.95504  295.81878  222.09130
# base                             8  37.26190  120.34622  157.60812   83.08432
# zoom_range=(0.8, 0.8)            8  38.13598  162.64962  200.78560  124.51364
# ...

# %% [markdown]
# Лучшая метрика обучения `batch_size`=128, но при этом `val_loss` очень высокое, т.е. происходит сильное переобучение (показатель `diff_loss`).
#
# Из тех значениий `batch_size`, у которых показатели `loss` лучше базовой модели, выберем для дальнейшей работы **batch_size=64** с меньшим переобучением (`diff_loss`).

# %% [markdown]
# ###### learning_rate и аугментации

# %% [markdown]
# Для определения подходящих значений `learning_rate` и аугментаций отсортируем результаты по средним значениями `val_loss`:

# %%
mean_last_5.sort_values('val_loss').head(15)
# Out:
#                                                 epoch       loss   val_loss  \
# name
# learning_rate=0.0002                                8   14.59540   79.61166
# learning_rate=0.0001                                8   15.11554   81.33222
# learning_rate=0.0005                                8   19.81446   87.79574
# brightness_range=(0.9, 1.1)                         8   33.68588  114.80688
# base                                                8   37.26190  120.34622
# width_shift_range=0.1 & height_shift_range=0.1      8   94.99716  127.35788
# batch_size=32 (base)                                8   36.18302  131.14238
# horizontal_flip                                     8   68.67502  132.99556
# batch_size=16                                       8   57.98420  149.54432
# width_shift_range=0.1                               8   63.21418  149.92386
# height_shift_range=0.2                              8   72.30148  160.78478
# ...

# %% [markdown]
# Лучшее значение `learning_rate`=**0.0002**

# %% [markdown]
# Из обучений с аугментациями лучше базовой только **brightness_range=(0.9, 1.1)**

# %% [markdown]
# Для дальнейшей работы возьмем следующие аугментации (в силу возможных отклонений на одноразовом обучении):
# - brightness_range=(0.9, 1.1)
# - width_shift_range=0.1 & height_shift_range=0.1
# - horizontal_flip
# - zoom_range=(0.8, 0.8)

# %% [markdown]
# Рассмотрим какие аугментации приводят к наименьшему переобучению (`diff_loss`):

# %%
mean_last_5.sort_values('diff_loss').head(15)
# Out:
#                                                 epoch       loss   val_loss  \
# name
# width_shift_range=0.1 & height_shift_range=0.1      8   94.99716  127.35788
# rotation_range=30                                   8  130.10728  169.79494
# horizontal_flip                                     8   68.67502  132.99556
# learning_rate=0.0002                                8   14.59540   79.61166
# learning_rate=0.0001                                8   15.11554   81.33222
# learning_rate=0.0005                                8   19.81446   87.79574
# batch_size=8                                        8  146.66744  221.95028
# brightness_range=(0.9, 1.1)                         8   33.68588  114.80688
# base                                                8   37.26190  120.34622
# rotation_range=15                                   8   79.94986  166.09460
# width_shift_range=0.1                               8   63.21418  149.92386
# ...

# %% [markdown]
# Для дальнейшей работы возьмем следующие аугментации:
# - width_shift_range=0.1 & height_shift_range=0.1
# - rotation_range=30
# - horizontal_flip
# - brightness_range=(0.9, 1.1)
# - rotation_range=30

# %% [markdown]
# #### Комбинированные изменения модели

# %% [markdown]
# Проведем обучения модели с настройками learning_rate=0.0002, batch_size=64 и отобранными аугментациями на 10-ти эпохах

# %% [markdown]
# ##### Результаты пробных обучений

# %%
res_dict_comb = {
 0: {'name': 'learning_rate=0.0002 & batch_size=128', 'epoch': 1, 'loss': 335.4911, 'val_loss': 866.4419},
 1: {'name': 'learning_rate=0.0002 & batch_size=128', 'epoch': 2, 'loss': 68.3172, 'val_loss': 869.2356},
 2: {'name': 'learning_rate=0.0002 & batch_size=128', 'epoch': 3, 'loss': 31.2648, 'val_loss': 901.8944},
 3: {'name': 'learning_rate=0.0002 & batch_size=128', 'epoch': 4, 'loss': 17.2251, 'val_loss': 931.7336},
 4: {'name': 'learning_rate=0.0002 & batch_size=128', 'epoch': 5, 'loss': 13.5534, 'val_loss': 950.2889},
 5: {'name': 'learning_rate=0.0002 & batch_size=128', 'epoch': 6, 'loss': 9.5095, 'val_loss': 943.4403},
 6: {'name': 'learning_rate=0.0002 & batch_size=128', 'epoch': 7, 'loss': 7.9895, 'val_loss': 820.7442},
 7: {'name': 'learning_rate=0.0002 & batch_size=128', 'epoch': 8, 'loss': 7.0138, 'val_loss': 602.6887},
 8: {'name': 'learning_rate=0.0002 & batch_size=128', 'epoch': 9, 'loss': 7.4183, 'val_loss': 664.3484},
 9: {'name': 'learning_rate=0.0002 & batch_size=128', 'epoch': 10, 'loss': 6.0389, 'val_loss': 412.2839},
 10: {'name': 'learning_rate=0.0002 & batch_size=64', 'epoch': 1, 'loss': 265.3913, 'val_loss': 1158.0159},
 11: {'name': 'learning_rate=0.0002 & batch_size=64', 'epoch': 2, 'loss': 67.7456, 'val_loss': 1157.9952},
 12: {'name': 'learning_rate=0.0002 & batch_size=64', 'epoch': 3, 'loss': 34.1948, 'val_loss': 970.5068},
 13: {'name': 'learning_rate=0.0002 & batch_size=64', 'epoch': 4, 'loss': 21.8345, 'val_loss': 894.938},
 14: {'name': 'learning_rate=0.0002 & batch_size=64', 'epoch': 5, 'loss': 14.9921, 'val_loss': 740.7316},
 15: {'name': 'learning_rate=0.0002 & batch_size=64', 'epoch': 6, 'loss': 13.4058, 'val_loss': 331.1054},
 16: {'name': 'learning_rate=0.0002 & batch_size=64', 'epoch': 7, 'loss': 11.699, 'val_loss': 163.5145},
 17: {'name': 'learning_rate=0.0002 & batch_size=64', 'epoch': 8, 'loss': 9.8579, 'val_loss': 111.4439},
 18: {'name': 'learning_rate=0.0002 & batch_size=64', 'epoch': 9, 'loss': 8.5086, 'val_loss': 95.0818},
 19: {'name': 'learning_rate=0.0002 & batch_size=64', 'epoch': 10, 'loss': 9.7281, 'val_loss': 77.4159},
 20: {'name': 'learning_rate=0.0002 & batch_size=64 & brightness_range=(0.9, 1.1)', 'epoch': 1, 'loss': 235.8415, 'val_loss': 498.4384},
 21: {'name': 'learning_rate=0.0002 & batch_size=64 & brightness_range=(0.9, 1.1)', 'epoch': 2, 'loss': 66.3482, 'val_loss': 726.0442},
 22: {'name': 'learning_rate=0.0002 & batch_size=64 & brightness_range=(0.9, 1.1)', 'epoch': 3, 'loss': 33.8852, 'val_loss': 593.0587},
 23: {'name': 'learning_rate=0.0002 & batch_size=64 & brightness_range=(0.9, 1.1)', 'epoch': 4, 'loss': 23.0331, 'val_loss': 721.8921},
 24: {'name': 'learning_rate=0.0002 & batch_size=64 & brightness_range=(0.9, 1.1)', 'epoch': 5, 'loss': 15.9373, 'val_loss': 624.8735},
 25: {'name': 'learning_rate=0.0002 & batch_size=64 & brightness_range=(0.9, 1.1)', 'epoch': 6, 'loss': 14.9448, 'val_loss': 292.4987},
 26: {'name': 'learning_rate=0.0002 & batch_size=64 & brightness_range=(0.9, 1.1)', 'epoch': 7, 'loss': 12.8576, 'val_loss': 186.7588},
 27: {'name': 'learning_rate=0.0002 & batch_size=64 & brightness_range=(0.9, 1.1)', 'epoch': 8, 'loss': 11.4224, 'val_loss': 111.9457},
 28: {'name': 'learning_rate=0.0002 & batch_size=64 & brightness_range=(0.9, 1.1)', 'epoch': 9, 'loss': 9.9851, 'val_loss': 91.281},
 29: {'name': 'learning_rate=0.0002 & batch_size=64 & brightness_range=(0.9, 1.1)', 'epoch': 10, 'loss': 10.8758, 'val_loss': 102.6959},
 30: {'name': 'learning_rate=0.0002 & batch_size=64 & width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 1, 'loss': 222.1285, 'val_loss': 845.6136},
 31: {'name': 'learning_rate=0.0002 & batch_size=64 & width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 2, 'loss': 80.238, 'val_loss': 785.09},
 32: {'name': 'learning_rate=0.0002 & batch_size=64 & width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 3, 'loss': 61.074, 'val_loss': 711.833},
 33: {'name': 'learning_rate=0.0002 & batch_size=64 & width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 4, 'loss': 43.395, 'val_loss': 623.168},
 34: {'name': 'learning_rate=0.0002 & batch_size=64 & width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 5, 'loss': 32.4461, 'val_loss': 472.5165},
 35: {'name': 'learning_rate=0.0002 & batch_size=64 & width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 6, 'loss': 28.3656, 'val_loss': 432.7376},
 36: {'name': 'learning_rate=0.0002 & batch_size=64 & width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 7, 'loss': 24.7252, 'val_loss': 184.4528},
 37: {'name': 'learning_rate=0.0002 & batch_size=64 & width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 8, 'loss': 19.6234, 'val_loss': 111.1846},
 38: {'name': 'learning_rate=0.0002 & batch_size=64 & width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 9, 'loss': 15.9155, 'val_loss': 96.9027},
 39: {'name': 'learning_rate=0.0002 & batch_size=64 & width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 10, 'loss': 17.625, 'val_loss': 75.1959},
 40: {'name': 'learning_rate=0.0002 & batch_size=64 & horizontal_flip', 'epoch': 1, 'loss': 248.3456, 'val_loss': 890.9014},
 41: {'name': 'learning_rate=0.0002 & batch_size=64 & horizontal_flip', 'epoch': 2, 'loss': 76.6125, 'val_loss': 958.7913},
 42: {'name': 'learning_rate=0.0002 & batch_size=64 & horizontal_flip', 'epoch': 3, 'loss': 50.001, 'val_loss': 824.286},
 43: {'name': 'learning_rate=0.0002 & batch_size=64 & horizontal_flip', 'epoch': 4, 'loss': 35.6995, 'val_loss': 435.2758},
 44: {'name': 'learning_rate=0.0002 & batch_size=64 & horizontal_flip', 'epoch': 5, 'loss': 27.3451, 'val_loss': 370.7824},
 45: {'name': 'learning_rate=0.0002 & batch_size=64 & horizontal_flip', 'epoch': 6, 'loss': 22.1827, 'val_loss': 238.8802},
 46: {'name': 'learning_rate=0.0002 & batch_size=64 & horizontal_flip', 'epoch': 7, 'loss': 16.4803, 'val_loss': 158.5936},
 47: {'name': 'learning_rate=0.0002 & batch_size=64 & horizontal_flip', 'epoch': 8, 'loss': 13.6695, 'val_loss': 107.4133},
 48: {'name': 'learning_rate=0.0002 & batch_size=64 & horizontal_flip', 'epoch': 9, 'loss': 12.0021, 'val_loss': 83.6249},
 49: {'name': 'learning_rate=0.0002 & batch_size=64 & horizontal_flip', 'epoch': 10, 'loss': 10.3514, 'val_loss': 77.7827},
 50: {'name': 'learning_rate=0.0002 & batch_size=64 & zoom_range=(0.8, 0.8)', 'epoch': 1, 'loss': 250.8118, 'val_loss': 817.8012},
 51: {'name': 'learning_rate=0.0002 & batch_size=64 & zoom_range=(0.8, 0.8)', 'epoch': 2, 'loss': 68.2627, 'val_loss': 501.3509},
 52: {'name': 'learning_rate=0.0002 & batch_size=64 & zoom_range=(0.8, 0.8)', 'epoch': 3, 'loss': 30.771, 'val_loss': 468.145},
 53: {'name': 'learning_rate=0.0002 & batch_size=64 & zoom_range=(0.8, 0.8)', 'epoch': 4, 'loss': 19.2787, 'val_loss': 501.4028},
 54: {'name': 'learning_rate=0.0002 & batch_size=64 & zoom_range=(0.8, 0.8)', 'epoch': 5, 'loss': 14.4572, 'val_loss': 318.1695},
 55: {'name': 'learning_rate=0.0002 & batch_size=64 & zoom_range=(0.8, 0.8)', 'epoch': 6, 'loss': 12.1, 'val_loss': 255.9207},
 56: {'name': 'learning_rate=0.0002 & batch_size=64 & zoom_range=(0.8, 0.8)', 'epoch': 7, 'loss': 10.795, 'val_loss': 204.5765},
 57: {'name': 'learning_rate=0.0002 & batch_size=64 & zoom_range=(0.8, 0.8)', 'epoch': 8, 'loss': 8.4064, 'val_loss': 138.9606},
 58: {'name': 'learning_rate=0.0002 & batch_size=64 & zoom_range=(0.8, 0.8)', 'epoch': 9, 'loss': 7.2886, 'val_loss': 114.9249},
 59: {'name': 'learning_rate=0.0002 & batch_size=64 & zoom_range=(0.8, 0.8)', 'epoch': 10, 'loss': 6.346, 'val_loss': 97.1426},
 60: {'name': 'base', 'epoch': 1, 'loss': 249.6271, 'val_loss': 298.5576},
 61: {'name': 'base', 'epoch': 2, 'loss': 160.7603, 'val_loss': 293.5807},
 62: {'name': 'base', 'epoch': 3, 'loss': 126.6581, 'val_loss': 341.3035},
 63: {'name': 'base', 'epoch': 4, 'loss': 105.41, 'val_loss': 290.2146},
 64: {'name': 'base', 'epoch': 5, 'loss': 80.139, 'val_loss': 291.3425},
 65: {'name': 'base', 'epoch': 6, 'loss': 56.9429, 'val_loss': 130.55},
 66: {'name': 'base', 'epoch': 7, 'loss': 45.7083, 'val_loss': 148.8701},
 67: {'name': 'base', 'epoch': 8, 'loss': 34.3391, 'val_loss': 103.0357},
 68: {'name': 'base', 'epoch': 9, 'loss': 27.0102, 'val_loss': 102.7554},
 69: {'name': 'base', 'epoch': 10, 'loss': 22.309, 'val_loss': 116.5199},
 70: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=30', 'epoch': 1, 'loss': 263.31, 'val_loss': 621.7222},
 71: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=30', 'epoch': 2, 'loss': 96.3487, 'val_loss': 653.5545},
 72: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=30', 'epoch': 3, 'loss': 72.3928, 'val_loss': 636.4168},
 73: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=30', 'epoch': 4, 'loss': 59.5569, 'val_loss': 598.3022},
 74: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=30', 'epoch': 5, 'loss': 45.2179, 'val_loss': 674.7928},
 75: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=30', 'epoch': 6, 'loss': 36.2554, 'val_loss': 484.5652},
 76: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=30', 'epoch': 7, 'loss': 29.1958, 'val_loss': 223.4526},
 77: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=30', 'epoch': 8, 'loss': 25.7687, 'val_loss': 188.4219},
 78: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=30', 'epoch': 9, 'loss': 23.4622, 'val_loss': 113.544},
 79: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=30', 'epoch': 10, 'loss': 22.031, 'val_loss': 87.8469},
 80: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=15', 'epoch': 1, 'loss': 217.276, 'val_loss': 984.5266},
 81: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=15', 'epoch': 2, 'loss': 81.6456, 'val_loss': 917.6649},
 82: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=15', 'epoch': 3, 'loss': 55.4064, 'val_loss': 900.8612},
 83: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=15', 'epoch': 4, 'loss': 36.5817, 'val_loss': 812.6822},
 84: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=15', 'epoch': 5, 'loss': 29.3376, 'val_loss': 793.9027},
 85: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=15', 'epoch': 6, 'loss': 23.2268, 'val_loss': 357.8889},
 86: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=15', 'epoch': 7, 'loss': 20.9225, 'val_loss': 179.0283},
 87: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=15', 'epoch': 8, 'loss': 17.1137, 'val_loss': 125.6189},
 88: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=15', 'epoch': 9, 'loss': 15.4772, 'val_loss': 89.6985},
 89: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=15', 'epoch': 10, 'loss': 13.0858, 'val_loss': 91.5172}}

# %%
res_comb = pd.DataFrame(res_dict_comb).T
res_comb['epoch'] = res_comb['epoch'].astype('int')
res_comb['loss'] = res_comb['loss'].astype('float')
res_comb['val_loss'] = res_comb['val_loss'].astype('float')
res_comb
# Out:
#                                                  name  epoch      loss  \
# 0               learning_rate=0.0002 & batch_size=128      1  335.4911
# 1               learning_rate=0.0002 & batch_size=128      2   68.3172
# 2               learning_rate=0.0002 & batch_size=128      3   31.2648
# 3               learning_rate=0.0002 & batch_size=128      4   17.2251
# 4               learning_rate=0.0002 & batch_size=128      5   13.5534
# ..                                                ...    ...       ...
# 85  learning_rate=0.0002 & batch_size=64 & rotatio...      6   23.2268
# 86  learning_rate=0.0002 & batch_size=64 & rotatio...      7   20.9225
# 87  learning_rate=0.0002 & batch_size=64 & rotatio...      8   17.1137
# 88  learning_rate=0.0002 & batch_size=64 & rotatio...      9   15.4772
# 89  learning_rate=0.0002 & batch_size=64 & rotatio...     10   13.0858
#
#     val_loss
# 0   866.4419
# 1   869.2356
# 2   901.8944
# 3   931.7336
# 4   950.2889
# ..       ...
# ...

# %% [markdown]
# Возьмем для анализа средние значения потерь по последним 3-м эпохам:

# %%
mean_last_3_comb = res_comb.query('epoch > 7').groupby('name').mean()

# %% [markdown]
# Добавим сумму и разность потерь обучения и валидации:

# %%
mean_last_3_comb['sum_loss'] = mean_last_3_comb['loss'] + mean_last_3_comb['val_loss']
mean_last_3_comb['diff_loss'] = abs(mean_last_3_comb['val_loss'] - mean_last_3_comb['loss'])

# %% [markdown]
# Выведем результаты средних значений на экран:

# %%
mean_last_3_comb.sort_values('sum_loss')

# %% [markdown]
# ##### Подбор характеристик моделирования

# %% [markdown]
# Для определения наиболее подходящих комбинаций характеристик моделирования отберем половину с минимальным переобучением (т.е. `diff_loss`) и отсортируем по `val_loss`:

# %%
mean_last_3_comb.query('diff_loss <= diff_loss.median()').sort_values('val_loss')

# %% [markdown]
# Для дальнейшего анализа возьмем следующие характеристики моделирования:
# - learning_rate=0.0002 & batch_size=64
# - learning_rate=0.0002 & batch_size=64 & horizontal_flip
# - learning_rate=0.0002 & batch_size=64 & rotation_range=15
# - learning_rate=0.0002 & batch_size=64 & width_shift_range=0.1 & height_shift_range=0.1

# %% [markdown]
# Проверим также полную комбинацию лучших характеристик:
# - learning_rate=0.0002 & batch_size=64 & horizontal_flip & rotation_range=15 & width_shift_range=0.1 & height_shift_range=0.1

# %% [markdown]
# #### Лучшие комбинированные изменения модели

# %% [markdown]
# Проведем обучения модели на отобранных настройках на 20-ти эпохах

# %% [markdown]
# ##### Результаты пробных обучений

# %%
res_dict_best = {
 0: {'name': 'learning_rate=0.0002 & batch_size=64', 'epoch': 1, 'loss': 219.7398, 'val_loss': 502.0246},
 1: {'name': 'learning_rate=0.0002 & batch_size=64', 'epoch': 2, 'loss': 64.9282, 'val_loss': 782.093},
 2: {'name': 'learning_rate=0.0002 & batch_size=64', 'epoch': 3, 'loss': 31.7746, 'val_loss': 841.7279},
 3: {'name': 'learning_rate=0.0002 & batch_size=64', 'epoch': 4, 'loss': 18.627, 'val_loss': 601.9359},
 4: {'name': 'learning_rate=0.0002 & batch_size=64', 'epoch': 5, 'loss': 13.6447, 'val_loss': 453.3884},
 5: {'name': 'learning_rate=0.0002 & batch_size=64', 'epoch': 6, 'loss': 10.9195, 'val_loss': 281.5749},
 6: {'name': 'learning_rate=0.0002 & batch_size=64', 'epoch': 7, 'loss': 10.2035, 'val_loss': 170.8218},
 7: {'name': 'learning_rate=0.0002 & batch_size=64', 'epoch': 8, 'loss': 10.0795, 'val_loss': 124.298},
 8: {'name': 'learning_rate=0.0002 & batch_size=64', 'epoch': 9, 'loss': 8.4241, 'val_loss': 93.2285},
 9: {'name': 'learning_rate=0.0002 & batch_size=64', 'epoch': 10, 'loss': 8.7879, 'val_loss': 80.7493},
 10: {'name': 'learning_rate=0.0002 & batch_size=64', 'epoch': 11, 'loss': 6.6616, 'val_loss': 68.0083},
 11: {'name': 'learning_rate=0.0002 & batch_size=64', 'epoch': 12, 'loss': 5.3028, 'val_loss': 64.6708},
 12: {'name': 'learning_rate=0.0002 & batch_size=64', 'epoch': 13, 'loss': 5.5572, 'val_loss': 63.8128},
 13: {'name': 'learning_rate=0.0002 & batch_size=64', 'epoch': 14, 'loss': 5.1818, 'val_loss': 63.3869},
 14: {'name': 'learning_rate=0.0002 & batch_size=64', 'epoch': 15, 'loss': 5.2602, 'val_loss': 61.9724},
 15: {'name': 'learning_rate=0.0002 & batch_size=64', 'epoch': 16, 'loss': 4.7859, 'val_loss': 63.129},
 16: {'name': 'learning_rate=0.0002 & batch_size=64', 'epoch': 17, 'loss': 4.1315, 'val_loss': 65.5092},
 17: {'name': 'learning_rate=0.0002 & batch_size=64', 'epoch': 18, 'loss': 3.4796, 'val_loss': 61.8734},
 18: {'name': 'learning_rate=0.0002 & batch_size=64', 'epoch': 19, 'loss': 2.9672, 'val_loss': 60.0749},
 19: {'name': 'learning_rate=0.0002 & batch_size=64', 'epoch': 20, 'loss': 2.85, 'val_loss': 60.9438},
 20: {'name': 'learning_rate=0.0002 & batch_size=64 & horizontal_flip', 'epoch': 1, 'loss': 208.8555, 'val_loss': 668.67},
 21: {'name': 'learning_rate=0.0002 & batch_size=64 & horizontal_flip', 'epoch': 2, 'loss': 75.265, 'val_loss': 646.822},
 22: {'name': 'learning_rate=0.0002 & batch_size=64 & horizontal_flip', 'epoch': 3, 'loss': 54.9332, 'val_loss': 391.6002},
 23: {'name': 'learning_rate=0.0002 & batch_size=64 & horizontal_flip', 'epoch': 4, 'loss': 38.7233, 'val_loss': 520.5431},
 24: {'name': 'learning_rate=0.0002 & batch_size=64 & horizontal_flip', 'epoch': 5, 'loss': 26.0949, 'val_loss': 284.019},
 25: {'name': 'learning_rate=0.0002 & batch_size=64 & horizontal_flip', 'epoch': 6, 'loss': 20.0524, 'val_loss': 195.1184},
 26: {'name': 'learning_rate=0.0002 & batch_size=64 & horizontal_flip', 'epoch': 7, 'loss': 17.2771, 'val_loss': 150.3456},
 27: {'name': 'learning_rate=0.0002 & batch_size=64 & horizontal_flip', 'epoch': 8, 'loss': 15.4954, 'val_loss': 98.2105},
 28: {'name': 'learning_rate=0.0002 & batch_size=64 & horizontal_flip', 'epoch': 9, 'loss': 12.6643, 'val_loss': 91.5678},
 29: {'name': 'learning_rate=0.0002 & batch_size=64 & horizontal_flip', 'epoch': 10, 'loss': 10.485, 'val_loss': 83.0868},
 30: {'name': 'learning_rate=0.0002 & batch_size=64 & horizontal_flip', 'epoch': 11, 'loss': 9.9185, 'val_loss': 68.8225},
 31: {'name': 'learning_rate=0.0002 & batch_size=64 & horizontal_flip', 'epoch': 12, 'loss': 8.3105, 'val_loss': 64.9277},
 32: {'name': 'learning_rate=0.0002 & batch_size=64 & horizontal_flip', 'epoch': 13, 'loss': 7.379, 'val_loss': 76.2481},
 33: {'name': 'learning_rate=0.0002 & batch_size=64 & horizontal_flip', 'epoch': 14, 'loss': 7.2853, 'val_loss': 62.768},
 34: {'name': 'learning_rate=0.0002 & batch_size=64 & horizontal_flip', 'epoch': 15, 'loss': 6.9313, 'val_loss': 66.2114},
 35: {'name': 'learning_rate=0.0002 & batch_size=64 & horizontal_flip', 'epoch': 16, 'loss': 6.2431, 'val_loss': 59.5055},
 36: {'name': 'learning_rate=0.0002 & batch_size=64 & horizontal_flip', 'epoch': 17, 'loss': 6.2874, 'val_loss': 64.6439},
 37: {'name': 'learning_rate=0.0002 & batch_size=64 & horizontal_flip', 'epoch': 18, 'loss': 6.1583, 'val_loss': 64.9295},
 38: {'name': 'learning_rate=0.0002 & batch_size=64 & horizontal_flip', 'epoch': 19, 'loss': 5.6188, 'val_loss': 61.4443},
 39: {'name': 'learning_rate=0.0002 & batch_size=64 & horizontal_flip', 'epoch': 20, 'loss': 5.0274, 'val_loss': 62.7007},
 40: {'name': 'learning_rate=0.0002 & batch_size=64 & width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 1, 'loss': 271.3921, 'val_loss': 525.9499},
 41: {'name': 'learning_rate=0.0002 & batch_size=64 & width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 2, 'loss': 89.4171, 'val_loss': 476.9758},
 42: {'name': 'learning_rate=0.0002 & batch_size=64 & width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 3, 'loss': 59.4912, 'val_loss': 653.4998},
 43: {'name': 'learning_rate=0.0002 & batch_size=64 & width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 4, 'loss': 41.2919, 'val_loss': 476.7709},
 44: {'name': 'learning_rate=0.0002 & batch_size=64 & width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 5, 'loss': 32.0344, 'val_loss': 439.5104},
 45: {'name': 'learning_rate=0.0002 & batch_size=64 & width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 6, 'loss': 27.3568, 'val_loss': 272.5929},
 46: {'name': 'learning_rate=0.0002 & batch_size=64 & width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 7, 'loss': 21.3035, 'val_loss': 154.8193},
 47: {'name': 'learning_rate=0.0002 & batch_size=64 & width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 8, 'loss': 18.967, 'val_loss': 123.3352},
 48: {'name': 'learning_rate=0.0002 & batch_size=64 & width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 9, 'loss': 16.751, 'val_loss': 142.8341},
 49: {'name': 'learning_rate=0.0002 & batch_size=64 & width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 10, 'loss': 15.499, 'val_loss': 79.5952},
 50: {'name': 'learning_rate=0.0002 & batch_size=64 & width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 11, 'loss': 12.1825, 'val_loss': 72.798},
 51: {'name': 'learning_rate=0.0002 & batch_size=64 & width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 12, 'loss': 10.8909, 'val_loss': 75.4455},
 52: {'name': 'learning_rate=0.0002 & batch_size=64 & width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 13, 'loss': 12.0197, 'val_loss': 66.8197},
 53: {'name': 'learning_rate=0.0002 & batch_size=64 & width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 14, 'loss': 9.9242, 'val_loss': 61.8292},
 54: {'name': 'learning_rate=0.0002 & batch_size=64 & width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 15, 'loss': 9.882, 'val_loss': 81.1646},
 55: {'name': 'learning_rate=0.0002 & batch_size=64 & width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 16, 'loss': 8.4689, 'val_loss': 65.0835},
 56: {'name': 'learning_rate=0.0002 & batch_size=64 & width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 17, 'loss': 7.4863, 'val_loss': 67.6999},
 57: {'name': 'learning_rate=0.0002 & batch_size=64 & width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 18, 'loss': 7.6624, 'val_loss': 67.8027},
 58: {'name': 'learning_rate=0.0002 & batch_size=64 & width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 19, 'loss': 6.4405, 'val_loss': 63.9088},
 59: {'name': 'learning_rate=0.0002 & batch_size=64 & width_shift_range=0.1 & height_shift_range=0.1', 'epoch': 20, 'loss': 6.1714, 'val_loss': 61.9211},
 60: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=15', 'epoch': 1, 'loss': 292.3507, 'val_loss': 319.7459},
 61: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=15', 'epoch': 2, 'loss': 84.5059, 'val_loss': 477.4339},
 62: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=15', 'epoch': 3, 'loss': 58.0644, 'val_loss': 751.8489},
 63: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=15', 'epoch': 4, 'loss': 40.0645, 'val_loss': 754.6682},
 64: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=15', 'epoch': 5, 'loss': 31.1313, 'val_loss': 357.8606},
 65: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=15', 'epoch': 6, 'loss': 25.8926, 'val_loss': 208.1748},
 66: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=15', 'epoch': 7, 'loss': 23.1858, 'val_loss': 217.866},
 67: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=15', 'epoch': 8, 'loss': 18.3867, 'val_loss': 120.2676},
 68: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=15', 'epoch': 9, 'loss': 15.9588, 'val_loss': 104.2885},
 69: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=15', 'epoch': 10, 'loss': 13.5146, 'val_loss': 76.7183},
 70: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=15', 'epoch': 11, 'loss': 12.1936, 'val_loss': 78.5437},
 71: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=15', 'epoch': 12, 'loss': 11.7502, 'val_loss': 71.7484},
 72: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=15', 'epoch': 13, 'loss': 10.5336, 'val_loss': 67.0439},
 73: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=15', 'epoch': 14, 'loss': 9.3319, 'val_loss': 63.4166},
 74: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=15', 'epoch': 15, 'loss': 8.2531, 'val_loss': 66.3735},
 75: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=15', 'epoch': 16, 'loss': 7.0218, 'val_loss': 63.5038},
 76: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=15', 'epoch': 17, 'loss': 6.6462, 'val_loss': 71.7627},
 77: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=15', 'epoch': 18, 'loss': 6.0374, 'val_loss': 64.0581},
 78: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=15', 'epoch': 19, 'loss': 6.1115, 'val_loss': 61.2721},
 79: {'name': 'learning_rate=0.0002 & batch_size=64 & rotation_range=15', 'epoch': 20, 'loss': 6.4532, 'val_loss': 93.8672},
 80: {'name': 'super_complex', 'epoch': 1, 'loss': 228.3446, 'val_loss': 438.6943},
 81: {'name': 'super_complex', 'epoch': 2, 'loss': 92.4536, 'val_loss': 489.0936},
 82: {'name': 'super_complex', 'epoch': 3, 'loss': 71.8465, 'val_loss': 492.4736},
 83: {'name': 'super_complex', 'epoch': 4, 'loss': 64.1213, 'val_loss': 474.4172},
 84: {'name': 'super_complex', 'epoch': 5, 'loss': 51.4377, 'val_loss': 482.4991},
 85: {'name': 'super_complex', 'epoch': 6, 'loss': 43.6279, 'val_loss': 364.2697},
 86: {'name': 'super_complex', 'epoch': 7, 'loss': 41.0328, 'val_loss': 237.1243},
 87: {'name': 'super_complex', 'epoch': 8, 'loss': 39.2636, 'val_loss': 116.233},
 88: {'name': 'super_complex', 'epoch': 9, 'loss': 34.4812, 'val_loss': 88.35},
 89: {'name': 'super_complex', 'epoch': 10, 'loss': 28.3294, 'val_loss': 74.2345},
 90: {'name': 'super_complex', 'epoch': 11, 'loss': 23.6006, 'val_loss': 75.6148},
 91: {'name': 'super_complex', 'epoch': 12, 'loss': 22.0088, 'val_loss': 76.9088},
 92: {'name': 'super_complex', 'epoch': 13, 'loss': 20.7463, 'val_loss': 77.9785},
 93: {'name': 'super_complex', 'epoch': 14, 'loss': 18.0044, 'val_loss': 62.5881},
 94: {'name': 'super_complex', 'epoch': 15, 'loss': 16.5716, 'val_loss': 70.5292},
 95: {'name': 'super_complex', 'epoch': 16, 'loss': 15.1135, 'val_loss': 82.029},
 96: {'name': 'super_complex', 'epoch': 17, 'loss': 15.5196, 'val_loss': 84.8208},
 97: {'name': 'super_complex', 'epoch': 18, 'loss': 15.5411, 'val_loss': 65.9412},
 98: {'name': 'super_complex', 'epoch': 19, 'loss': 13.6064, 'val_loss': 65.5876},
 99: {'name': 'super_complex', 'epoch': 20, 'loss': 13.1575, 'val_loss': 96.7731}}

# %%
res_best = pd.DataFrame(res_dict_best).T
res_best['epoch'] = res_best['epoch'].astype('int')
res_best['loss'] = res_best['loss'].astype('float')
res_best['val_loss'] = res_best['val_loss'].astype('float')
res_best

# %% [markdown]
# Добавим сумму и разность потерь обучения и валидации:

# %%
res_best['sum_loss'] = res_best['loss'] + res_best['val_loss']
res_best['diff_loss'] = abs(res_best['val_loss'] - res_best['loss'])

# %% [markdown]
# Добавим значение изменения `val_loss` от эпохи к эпохе:

# %%
res_best['val_loss_change'] = res_best['val_loss'] - res_best['val_loss'].shift(1)

# %% [markdown]
# Выведем результаты на экран:

# %%
res_best

# %% [markdown]
# ##### Подбор характеристик моделирования

# %% [markdown]
# Построим график изменения значений функции потерь на валидации:

# %%
plt.figure(figsize=(12, 10))
plt.grid(visible=True, axis='both')
sns.lineplot(data = res_best.query('epoch > 8'), x='epoch', y='val_loss', hue='name', linewidth=2.5)
plt.title('График изменения функции потерь валидации по эпохам обучения', pad=15, fontsize = 16)
plt.xlabel('Эпоха обучения', fontsize = 14)
plt.ylabel('MSE валидации', fontsize = 14)
plt.tick_params(labelsize = 12)

# %% [markdown]
# Как видно из графика после 13-14 эпохи не происходит улучшения модели и значения функции потерь валидации колеблятся далее около одних и тех же значений.
#
# Для набора параметров без аугментаций колебания минимальные и наблюдается продолжение снижения метрики.

# %% [markdown]
# Возьмем для анализа средние значения по последним 10-ти эпохам:

# %%
mean_last_10_best = res_best.query('epoch > 10').groupby('name').mean()

# %%
mean_last_10_best.sort_values('val_loss')

# %% [markdown]
# Примем для создания финальной модели **`learning_rate`=0.0002** & **`batch_size`=64** без применения аугментаций.
#
# Поскольку:
# - для этого набора характеристик наименьшее `lav_loss`
# - сохраняется нисходящий тренд (т.е. отрицательное `val_loss_change`)
# - оценка переобучения модели (т.е. `diff_loss`) для всех вариантов различается незначительно.

# %% [markdown]
# ## Обучение модели

# %% [markdown]
# Приведем код обучения модели и её результат вывода на экран.
#
#
# (Код в этом разделе запускается в отдельном GPU-тренажёре, поэтому оформлен не как ячейка с кодом, а как код в текстовой ячейке)

# %% [markdown]
# ```python
#
# import pandas as pd
#
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
# from tensorflow.keras.applications.resnet import ResNet50
# from tensorflow.keras.optimizers import Adam
#
# BATCH_SIZE = 64
#
# def load_train(path):
#     train_datagen = ImageDataGenerator(
#         validation_split=0.25,
#         rescale=1./255,
#         # vertical_flip=True,
#         # horizontal_flip=True,
#         # rotation_range=15, # повороты в обе стороны на случайный угол до 90 град
#         # width_shift_range=0.1, # сдвиги изоражения случайно в обе стороны
#         # height_shift_range=0.1,
#         # brightness_range=(0.9, 1.1) # меньше 1 – светлее, больше 1 – темнее
#         # zoom_range=(0.8, 0.8) # <1 увеличение, >1 уменьшение, случайно в обе стороны
#     )
#
#     labels = pd.read_csv(f'{path}labels.csv')
#
#     train_datagen_flow = train_datagen.flow_from_dataframe(
#         dataframe = labels,
#         directory=f'{path}final_files/',
#         x_col='file_name',
#         y_col='real_age',
#         target_size=(224, 224),
#         batch_size=BATCH_SIZE,
#         class_mode='raw',
#         subset='training',
#         seed=12345
#     )
#
#     return train_datagen_flow
#
#
# def load_test(path):
#     validation_datagen = ImageDataGenerator(
#         validation_split=0.25,
#         rescale=1./255
#     )
#
#     labels = pd.read_csv(f'{path}labels.csv')
#
#     val_datagen_flow = validation_datagen.flow_from_dataframe(
#         dataframe = labels,
#         directory=f'{path}final_files/',
#         x_col='file_name',
#         y_col='real_age',
#         target_size=(224, 224),
#         batch_size=BATCH_SIZE,
#         class_mode='raw',
#         subset='validation',
#         seed=12345
#     )
#
#     return val_datagen_flow
#
#
# def create_model(input_shape):
#     backbone = ResNet50(input_shape=input_shape,
#                         weights='/datasets/keras_models/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5',
#                         # weights='imagenet',
#                         include_top=False)
#
#     model = Sequential()
#     model.add(backbone)
#     model.add(GlobalAveragePooling2D())
#     model.add(Dense(1, activation='relu'))
#
#     optimizer = Adam(learning_rate=0.0002)
#     model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae'])
#
#     print(model.summary())
#
#     return model
#
#
# def train_model(model, train_datagen_flow, val_datagen_flow,
#                 batch_size=None,
#                 epochs=20,
#                 steps_per_epoch=None,
#                 validation_steps=None
#                 ):
#     if steps_per_epoch is None:
#         steps_per_epoch = len(train_datagen_flow)
#     if validation_steps is None:
#         validation_steps = len(val_datagen_flow)
#
#     model.fit(train_datagen_flow,
#               validation_data=val_datagen_flow,
#               batch_size=batch_size,
#               epochs=epochs,
#               steps_per_epoch=steps_per_epoch,
#               validation_steps=validation_steps,
#               verbose=2)
#
#     return model
#
# ```

# %% [markdown]
# ```
# Found 5694 validated image filenames.
# Found 1897 validated image filenames.
#
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Model)             (None, 7, 7, 2048)        23587712
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 2049
# =================================================================
# Total params: 23,589,761
# Trainable params: 23,536,641
# Non-trainable params: 53,120
# _________________________________________________________________
# None
# <class 'tensorflow.python.keras.engine.sequential.Sequential'>
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 89 steps, validate for 30 steps
# Epoch 1/20
# 89/89 - 119s - loss: 245.4340 - mae: 11.1039 - val_loss: 986.3302 - val_mae: 26.7039
# Epoch 2/20
# 89/89 - 39s - loss: 64.7861 - mae: 6.0732 - val_loss: 780.8376 - val_mae: 23.0438
# Epoch 3/20
# 89/89 - 38s - loss: 30.5146 - mae: 4.1877 - val_loss: 790.9935 - val_mae: 23.2051
# Epoch 4/20
# 89/89 - 39s - loss: 18.0348 - mae: 3.2693 - val_loss: 684.5950 - val_mae: 20.9554
# Epoch 5/20
# 89/89 - 38s - loss: 13.8104 - mae: 2.8515 - val_loss: 355.3978 - val_mae: 13.8941
# Epoch 6/20
# 89/89 - 39s - loss: 11.8187 - mae: 2.6124 - val_loss: 198.5823 - val_mae: 10.6316
# Epoch 7/20
# 89/89 - 38s - loss: 10.8603 - mae: 2.5359 - val_loss: 147.0673 - val_mae: 9.1788
# Epoch 8/20
# 89/89 - 38s - loss: 8.4152 - mae: 2.2336 - val_loss: 111.4998 - val_mae: 8.1259
# Epoch 9/20
# 89/89 - 38s - loss: 8.1953 - mae: 2.1859 - val_loss: 84.1040 - val_mae: 6.9458
# Epoch 10/20
# 89/89 - 39s - loss: 7.4915 - mae: 2.1187 - val_loss: 79.1673 - val_mae: 6.7940
# Epoch 11/20
# 89/89 - 39s - loss: 6.7967 - mae: 1.9733 - val_loss: 91.1599 - val_mae: 7.2503
# Epoch 12/20
# 89/89 - 39s - loss: 6.4743 - mae: 1.9376 - val_loss: 65.7280 - val_mae: 6.0620
# Epoch 13/20
# 89/89 - 38s - loss: 5.9078 - mae: 1.8164 - val_loss: 76.7976 - val_mae: 6.8108
# Epoch 14/20
# 89/89 - 39s - loss: 5.7550 - mae: 1.7853 - val_loss: 65.1153 - val_mae: 6.1299
# Epoch 15/20
# 89/89 - 39s - loss: 5.3033 - mae: 1.7180 - val_loss: 70.9849 - val_mae: 6.2710
# Epoch 16/20
# 89/89 - 39s - loss: 4.8194 - mae: 1.6104 - val_loss: 69.7708 - val_mae: 6.1711
# Epoch 17/20
# 89/89 - 39s - loss: 3.9567 - mae: 1.5029 - val_loss: 66.6356 - val_mae: 6.2406
# Epoch 18/20
# 89/89 - 39s - loss: 3.5190 - mae: 1.4022 - val_loss: 65.1155 - val_mae: 6.0776
# Epoch 19/20
# 89/89 - 40s - loss: 3.6310 - mae: 1.4370 - val_loss: 66.1222 - val_mae: 6.0925
# Epoch 20/20
# 89/89 - 39s - loss: 3.4046 - mae: 1.3925 - val_loss: 62.8760 - val_mae: 5.9175
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 30/30 - 10s - loss: 62.8760 - mae: 5.9175
# Test MAE: 5.9175
#
# ```

# %% [markdown]
# ## Проверка модели на адекватность

# %% [markdown]
# Воспользуемся классом DummyRegressor для определения значения метрики MAE константной модели (при медианных значениях целевых признаков):

# %%
X = df['file_name']
y = df[TARGET_COL]

# %%
dummy_clf = DummyRegressor(strategy="median")
dummy_clf.fit(X, y)
dummy_predictions = dummy_clf.predict(X)
dummy_score_a = mean_absolute_error(y, dummy_predictions)
print(f'Метрика MAE для случайной модели: {dummy_score_a:.1f}')

# %% [markdown]
# Метрика MAE на константной модели хуже, чем в модели, значит модель проходит проверку на адекватность.

# %% [markdown]
# ## Анализ обученной модели

# %% [markdown]
# **Выводы:**
# 1. Получена модель предсказания реального возраста человека по изображению
# 1. Метрика **MSE = 5.9** (лучше константной модели)
# 1. Для построения модели были получены уже обработанные данные (лица сориентированы на изображениях одинаковым образом)
# 1. Для обучения принята архитектура сверточных сетей `ResNet50`
# 1. Лучшие значения предсказаний дает предобученная модель **ResNet('imagenet')** с оптимизатором **Adam(learning_rate=0.0002)** и загрузчиком данных батчами по **64**, **без агументаций**.
# 1. Получанная модель может быть использована для анализа покупок и предложения товаров, которые могут заинтересовать покупателей определенной возрастной группы
# 1. Для контроля добросовестности кассиров при продаже алкоголя точность данной модели не подойдет и применяться не может.

# %%
END_PROJECT = time.time()

# %%
full_time = END_PROJECT - START_PROJECT
hour = int(full_time / 3600)
print(f'Время вычисления проекта:\n{text.BOLD}{text.BG_CYAN} {hour} ч {time.localtime(full_time)[4]} мин {time.localtime(full_time)[5]} сек {text.END}')
